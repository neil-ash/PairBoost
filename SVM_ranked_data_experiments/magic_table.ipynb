# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import sys; sys.path.insert(0,'..')
from main import *

# %%
data = pd.read_csv('../data/magic/magic04.data')
X = data.iloc[:, :-1].values
y  = data.iloc[:, -1].values

# %%
# Convert labels to -1, 1 and scale features
y = np.array([-1.0 if yi == 'g' else 1.0 for yi in y])

scaler = MinMaxScaler(feature_range=(0, 1))

for i in range(X.shape[1]):
    X[:, i] = scaler.fit_transform(X[:, i].reshape(-1, 1)).ravel()
    
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.5, stratify=y, 
                                                    shuffle=True, random_state=1)

# %%
svm_arr, tree_arr = data_size_experiment(X_train, y_train, X_test, y_test,
                                         experiment_type='table', kernel='linear',
                                         random_state=1, verbose=True)
# Out:
# Progress:
# Training accuracy of rank SVM: 0.86
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# /Users/Ashtekar15/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# t	Train		Test
# 1	0.77		0.80
# 2	0.76		0.79
# 3	0.77		0.79
# 4	0.70		0.75
# 5	0.62		0.64
# 6	0.60		0.60
# 7	0.74		0.78
# 8	0.64		0.66
# 9	0.71		0.71
# 10	0.56		0.54
# 11	0.72		0.73
# 12	0.60		0.58
# 13	0.71		0.72
# 14	0.59		0.56
# 15	0.74		0.75
# 16	0.59		0.55
# 17	0.71		0.72
# 18	0.58		0.56
# 19	0.73		0.73
# 20	0.57		0.55
# t = 3 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 1 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.80
# 2	0.76		0.80
# 3	0.77		0.79
# 4	0.74		0.76
# 5	0.68		0.71
# 6	0.46		0.46
# 7	0.72		0.76
# 8	0.73		0.75
# 9	0.73		0.74
# 10	0.60		0.62
# 11	0.67		0.69
# 12	0.71		0.73
# 13	0.74		0.74
# 14	0.68		0.70
# 15	0.68		0.69
# 16	0.67		0.68
# 17	0.73		0.73
# 18	0.63		0.67
# 19	0.70		0.73
# 20	0.61		0.63
# t = 3 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 2 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.80
# 2	0.77		0.80
# 3	0.77		0.79
# 4	0.75		0.78
# 5	0.69		0.68
# 6	0.63		0.67
# 7	0.73		0.74
# 8	0.72		0.76
# 9	0.77		0.78
# 10	0.66		0.70
# 11	0.67		0.70
# 12	0.65		0.67
# 13	0.73		0.78
# 14	0.57		0.55
# 15	0.66		0.69
# 16	0.69		0.73
# 17	0.74		0.77
# 18	0.65		0.68
# 19	0.69		0.71
# 20	0.62		0.63
# t = 1 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 3 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.76		0.79
# 2	0.73		0.77
# 3	0.75		0.80
# 4	0.56		0.53
# 5	0.64		0.65
# 6	0.65		0.64
# 7	0.75		0.77
# 8	0.61		0.60
# 9	0.65		0.68
# 10	0.60		0.59
# 11	0.74		0.78
# 12	0.63		0.65
# 13	0.70		0.71
# 14	0.55		0.52
# 15	0.73		0.74
# 16	0.58		0.56
# 17	0.72		0.73
# 18	0.54		0.52
# 19	0.69		0.70
# 20	0.62		0.60
# t = 1 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 4 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.80
# 2	0.76		0.79
# 3	0.77		0.79
# 4	0.64		0.68
# 5	0.58		0.58
# 6	0.60		0.60
# 7	0.74		0.79
# 8	0.74		0.76
# 9	0.74		0.78
# 10	0.55		0.52
# 11	0.65		0.68
# 12	0.77		0.79
# 13	0.77		0.77
# 14	0.75		0.76
# 15	0.67		0.69
# 16	0.57		0.54
# 17	0.72		0.74
# 18	0.65		0.68
# 19	0.71		0.73
# 20	0.61		0.61
# t = 12 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 5 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.79
# 2	0.75		0.78
# 3	0.76		0.79
# 4	0.70		0.71
# 5	0.67		0.66
# 6	0.53		0.48
# 7	0.71		0.76
# 8	0.66		0.68
# 9	0.74		0.78
# 10	0.60		0.59
# 11	0.67		0.68
# 12	0.68		0.71
# 13	0.76		0.79
# 14	0.65		0.67
# 15	0.67		0.67
# 16	0.60		0.58
# 17	0.74		0.79
# 18	0.64		0.65
# 19	0.71		0.72
# 20	0.57		0.54
# t = 1 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 6 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.80
# 2	0.76		0.79
# 3	0.76		0.79
# 4	0.69		0.72
# 5	0.65		0.66
# 6	0.57		0.57
# 7	0.71		0.76
# 8	0.67		0.69
# 9	0.74		0.77
# 10	0.55		0.50
# 11	0.65		0.67
# 12	0.79		0.78
# 13	0.77		0.78
# 14	0.78		0.78
# 15	0.75		0.75
# 16	0.66		0.68
# 17	0.64		0.67
# 18	0.75		0.78
# 19	0.76		0.76
# 20	0.75		0.76
# t = 12 was best iteration with accuracy 0.78
#
# -----------------------------------------------
# 7 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.76		0.79
# 2	0.74		0.78
# 3	0.75		0.78
# 4	0.65		0.67
# 5	0.54		0.53
# 6	0.60		0.61
# 7	0.76		0.79
# 8	0.68		0.69
# 9	0.73		0.75
# 10	0.46		0.44
# 11	0.70		0.71
# 12	0.69		0.70
# 13	0.77		0.79
# 14	0.71		0.72
# 15	0.69		0.71
# 16	0.54		0.51
# 17	0.72		0.74
# 18	0.68		0.70
# 19	0.76		0.79
# 20	0.71		0.72
# t = 13 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 8 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.79
# 2	0.76		0.79
# 3	0.77		0.80
# 4	0.73		0.74
# 5	0.64		0.64
# 6	0.54		0.52
# 7	0.73		0.77
# 8	0.66		0.69
# 9	0.73		0.77
# 10	0.54		0.51
# 11	0.67		0.69
# 12	0.64		0.66
# 13	0.75		0.78
# 14	0.64		0.63
# 15	0.69		0.70
# 16	0.51		0.49
# 17	0.71		0.73
# 18	0.60		0.59
# 19	0.72		0.73
# 20	0.58		0.55
# t = 3 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 9 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.80
# 2	0.76		0.80
# 3	0.77		0.79
# 4	0.74		0.76
# 5	0.65		0.66
# 6	0.56		0.52
# 7	0.75		0.80
# 8	0.74		0.77
# 9	0.77		0.79
# 10	0.72		0.73
# 11	0.73		0.76
# 12	0.45		0.43
# 13	0.71		0.72
# 14	0.65		0.68
# 15	0.76		0.79
# 16	0.73		0.74
# 17	0.73		0.76
# 18	0.45		0.43
# 19	0.71		0.72
# 20	0.70		0.70
# t = 3 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 10 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.76		0.80
# 2	0.76		0.79
# 3	0.77		0.80
# 4	0.75		0.77
# 5	0.72		0.75
# 6	0.47		0.48
# 7	0.70		0.74
# 8	0.78		0.79
# 9	0.78		0.78
# 10	0.79		0.78
# 11	0.76		0.75
# 12	0.66		0.68
# 13	0.65		0.68
# 14	0.67		0.69
# 15	0.73		0.74
# 16	0.71		0.73
# 17	0.69		0.71
# 18	0.61		0.62
# 19	0.71		0.72
# 20	0.68		0.71
# t = 10 was best iteration with accuracy 0.78
#
# -----------------------------------------------
# 11 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.80
# 2	0.75		0.79
# 3	0.77		0.79
# 4	0.63		0.63
# 5	0.57		0.57
# 6	0.63		0.64
# 7	0.73		0.77
# 8	0.59		0.58
# 9	0.70		0.71
# 10	0.58		0.56
# 11	0.73		0.74
# 12	0.63		0.64
# 13	0.72		0.74
# 14	0.59		0.56
# 15	0.70		0.72
# 16	0.61		0.61
# 17	0.73		0.76
# 18	0.62		0.63
# 19	0.69		0.71
# 20	0.60		0.59
# t = 3 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 12 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.79
# 2	0.73		0.77
# 3	0.76		0.79
# 4	0.56		0.57
# 5	0.65		0.68
# 6	0.79		0.79
# 7	0.78		0.77
# 8	0.76		0.79
# 9	0.67		0.69
# 10	0.50		0.48
# 11	0.72		0.76
# 12	0.73		0.75
# 13	0.74		0.75
# 14	0.71		0.73
# 15	0.69		0.70
# 16	0.60		0.61
# 17	0.71		0.74
# 18	0.69		0.72
# 19	0.73		0.73
# 20	0.65		0.67
# t = 6 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 13 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.80
# 2	0.76		0.80
# 3	0.77		0.80
# 4	0.76		0.78
# 5	0.76		0.76
# 6	0.61		0.67
# 7	0.67		0.64
# 8	0.76		0.79
# 9	0.75		0.78
# 10	0.77		0.79
# 11	0.67		0.72
# 12	0.67		0.67
# 13	0.73		0.77
# 14	0.77		0.79
# 15	0.76		0.77
# 16	0.74		0.74
# 17	0.70		0.74
# 18	0.73		0.74
# 19	0.77		0.78
# 20	0.77		0.77
# t = 14 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 14 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.80
# 2	0.76		0.80
# 3	0.78		0.79
# 4	0.77		0.77
# 5	0.56		0.55
# 6	0.70		0.74
# 7	0.76		0.77
# 8	0.76		0.76
# 9	0.66		0.69
# 10	0.69		0.70
# 11	0.63		0.61
# 12	0.73		0.77
# 13	0.62		0.63
# 14	0.70		0.71
# 15	0.63		0.63
# 16	0.73		0.76
# 17	0.63		0.65
# 18	0.68		0.70
# 19	0.64		0.66
# 20	0.73		0.76
# t = 3 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 15 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.79
# 2	0.76		0.79
# 3	0.77		0.78
# 4	0.66		0.70
# 5	0.60		0.61
# 6	0.63		0.64
# 7	0.74		0.77
# 8	0.69		0.71
# 9	0.71		0.74
# 10	0.56		0.53
# 11	0.72		0.76
# 12	0.66		0.68
# 13	0.74		0.77
# 14	0.61		0.61
# 15	0.69		0.71
# 16	0.62		0.62
# 17	0.74		0.77
# 18	0.65		0.68
# 19	0.71		0.73
# 20	0.58		0.55
# t = 1 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 16 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.80
# 2	0.77		0.79
# 3	0.78		0.79
# 4	0.75		0.77
# 5	0.72		0.75
# 6	0.49		0.48
# 7	0.70		0.74
# 8	0.72		0.76
# 9	0.76		0.78
# 10	0.73		0.78
# 11	0.73		0.72
# 12	0.54		0.50
# 13	0.72		0.72
# 14	0.65		0.65
# 15	0.74		0.78
# 16	0.63		0.61
# 17	0.70		0.70
# 18	0.55		0.51
# 19	0.72		0.73
# 20	0.57		0.55
# t = 3 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 17 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.79
# 2	0.73		0.76
# 3	0.75		0.80
# 4	0.53		0.51
# 5	0.66		0.68
# 6	0.72		0.73
# 7	0.77		0.80
# 8	0.73		0.78
# 9	0.75		0.79
# 10	0.50		0.48
# 11	0.66		0.67
# 12	0.73		0.76
# 13	0.73		0.78
# 14	0.70		0.75
# 15	0.71		0.76
# 16	0.58		0.62
# 17	0.62		0.64
# 18	0.51		0.49
# 19	0.72		0.73
# 20	0.63		0.61
# t = 1 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 18 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.80
# 2	0.77		0.80
# 3	0.77		0.80
# 4	0.77		0.78
# 5	0.73		0.75
# 6	0.43		0.42
# 7	0.72		0.74
# 8	0.71		0.74
# 9	0.76		0.77
# 10	0.73		0.77
# 11	0.72		0.74
# 12	0.55		0.51
# 13	0.72		0.73
# 14	0.64		0.65
# 15	0.73		0.76
# 16	0.63		0.63
# 17	0.69		0.69
# 18	0.63		0.63
# 19	0.73		0.77
# 20	0.66		0.68
# t = 1 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 19 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.80
# 2	0.78		0.79
# 3	0.78		0.79
# 4	0.78		0.77
# 5	0.70		0.71
# 6	0.63		0.70
# 7	0.74		0.77
# 8	0.74		0.78
# 9	0.77		0.79
# 10	0.71		0.75
# 11	0.69		0.72
# 12	0.57		0.57
# 13	0.70		0.74
# 14	0.71		0.72
# 15	0.75		0.79
# 16	0.67		0.68
# 17	0.70		0.72
# 18	0.54		0.50
# 19	0.72		0.75
# 20	0.65		0.67
# t = 4 was best iteration with accuracy 0.77
#
# -----------------------------------------------
# 20 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.80
# 2	0.76		0.79
# 3	0.77		0.79
# 4	0.78		0.78
# 5	0.68		0.65
# 6	0.65		0.67
# 7	0.64		0.63
# 8	0.77		0.80
# 9	0.74		0.77
# 10	0.76		0.79
# 11	0.56		0.53
# 12	0.63		0.65
# 13	0.79		0.79
# 14	0.78		0.79
# 15	0.77		0.77
# 16	0.74		0.75
# 17	0.71		0.70
# 18	0.71		0.72
# 19	0.75		0.75
# 20	0.77		0.76
# t = 13 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 21 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.80
# 2	0.76		0.79
# 3	0.77		0.79
# 4	0.74		0.77
# 5	0.56		0.58
# 6	0.57		0.55
# 7	0.76		0.78
# 8	0.77		0.80
# 9	0.76		0.80
# 10	0.77		0.79
# 11	0.71		0.75
# 12	0.59		0.61
# 13	0.59		0.56
# 14	0.76		0.79
# 15	0.73		0.76
# 16	0.76		0.79
# 17	0.54		0.51
# 18	0.66		0.68
# 19	0.75		0.77
# 20	0.77		0.80
# t = 10 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 22 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.79
# 2	0.73		0.78
# 3	0.77		0.79
# 4	0.64		0.67
# 5	0.60		0.59
# 6	0.61		0.62
# 7	0.75		0.79
# 8	0.75		0.77
# 9	0.75		0.78
# 10	0.61		0.61
# 11	0.64		0.67
# 12	0.69		0.71
# 13	0.75		0.77
# 14	0.70		0.73
# 15	0.68		0.70
# 16	0.59		0.56
# 17	0.73		0.77
# 18	0.69		0.72
# 19	0.71		0.74
# 20	0.57		0.56
# t = 1 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 23 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.80
# 2	0.76		0.80
# 3	0.77		0.80
# 4	0.75		0.77
# 5	0.61		0.63
# 6	0.61		0.61
# 7	0.75		0.79
# 8	0.70		0.73
# 9	0.69		0.72
# 10	0.51		0.50
# 11	0.71		0.72
# 12	0.66		0.68
# 13	0.75		0.79
# 14	0.67		0.69
# 15	0.74		0.75
# 16	0.46		0.45
# 17	0.69		0.70
# 18	0.73		0.74
# 19	0.76		0.79
# 20	0.74		0.76
# t = 3 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 24 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.80
# 2	0.77		0.79
# 3	0.76		0.79
# 4	0.76		0.77
# 5	0.57		0.55
# 6	0.64		0.66
# 7	0.77		0.80
# 8	0.78		0.80
# 9	0.78		0.78
# 10	0.77		0.78
# 11	0.78		0.77
# 12	0.76		0.76
# 13	0.65		0.65
# 14	0.67		0.71
# 15	0.78		0.79
# 16	0.78		0.78
# 17	0.76		0.78
# 18	0.69		0.70
# 19	0.66		0.67
# 20	0.62		0.66
# t = 11 was best iteration with accuracy 0.77
#
# -----------------------------------------------
# 25 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.80
# 2	0.75		0.78
# 3	0.76		0.79
# 4	0.66		0.68
# 5	0.57		0.57
# 6	0.59		0.59
# 7	0.75		0.77
# 8	0.76		0.79
# 9	0.76		0.77
# 10	0.66		0.68
# 11	0.64		0.67
# 12	0.65		0.66
# 13	0.75		0.76
# 14	0.72		0.74
# 15	0.71		0.75
# 16	0.56		0.52
# 17	0.72		0.72
# 18	0.68		0.69
# 19	0.74		0.76
# 20	0.66		0.68
# t = 1 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 26 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.76		0.80
# 2	0.75		0.79
# 3	0.77		0.80
# 4	0.73		0.73
# 5	0.63		0.64
# 6	0.56		0.54
# 7	0.75		0.78
# 8	0.74		0.77
# 9	0.76		0.78
# 10	0.64		0.66
# 11	0.66		0.70
# 12	0.61		0.61
# 13	0.73		0.78
# 14	0.63		0.65
# 15	0.69		0.70
# 16	0.63		0.64
# 17	0.73		0.77
# 18	0.62		0.62
# 19	0.69		0.70
# 20	0.63		0.64
# t = 3 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 27 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.80
# 2	0.74		0.78
# 3	0.77		0.79
# 4	0.50		0.48
# 5	0.67		0.70
# 6	0.77		0.78
# 7	0.79		0.79
# 8	0.78		0.77
# 9	0.75		0.78
# 10	0.66		0.66
# 11	0.53		0.50
# 12	0.74		0.76
# 13	0.69		0.71
# 14	0.73		0.76
# 15	0.60		0.60
# 16	0.71		0.72
# 17	0.66		0.66
# 18	0.73		0.75
# 19	0.63		0.64
# 20	0.66		0.70
# t = 7 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 28 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.79
# 2	0.77		0.80
# 3	0.77		0.79
# 4	0.77		0.79
# 5	0.53		0.49
# 6	0.67		0.71
# 7	0.77		0.78
# 8	0.77		0.79
# 9	0.78		0.78
# 10	0.77		0.77
# 11	0.76		0.78
# 12	0.64		0.67
# 13	0.58		0.56
# 14	0.74		0.78
# 15	0.67		0.71
# 16	0.70		0.74
# 17	0.58		0.56
# 18	0.69		0.70
# 19	0.69		0.72
# 20	0.76		0.77
# t = 9 was best iteration with accuracy 0.78
#
# -----------------------------------------------
# 29 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.80
# 2	0.76		0.78
# 3	0.77		0.79
# 4	0.72		0.75
# 5	0.62		0.61
# 6	0.62		0.66
# 7	0.73		0.77
# 8	0.71		0.74
# 9	0.74		0.78
# 10	0.44		0.44
# 11	0.70		0.71
# 12	0.74		0.78
# 13	0.77		0.80
# 14	0.76		0.80
# 15	0.76		0.79
# 16	0.75		0.78
# 17	0.75		0.76
# 18	0.59		0.63
# 19	0.62		0.59
# 20	0.75		0.76
# t = 3 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 30 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.81
# 2	0.76		0.79
# 3	0.77		0.79
# 4	0.59		0.61
# 5	0.58		0.59
# 6	0.74		0.75
# 7	0.77		0.80
# 8	0.76		0.79
# 9	0.77		0.79
# 10	0.68		0.70
# 11	0.59		0.59
# 12	0.56		0.57
# 13	0.75		0.78
# 14	0.73		0.76
# 15	0.74		0.77
# 16	0.53		0.49
# 17	0.66		0.69
# 18	0.76		0.78
# 19	0.77		0.80
# 20	0.78		0.78
# t = 20 was best iteration with accuracy 0.78
#
# -----------------------------------------------
# 31 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.81
# 2	0.75		0.79
# 3	0.77		0.79
# 4	0.63		0.66
# 5	0.56		0.58
# 6	0.66		0.68
# 7	0.76		0.78
# 8	0.74		0.79
# 9	0.74		0.76
# 10	0.55		0.54
# 11	0.68		0.68
# 12	0.75		0.78
# 13	0.77		0.79
# 14	0.78		0.79
# 15	0.76		0.76
# 16	0.54		0.54
# 17	0.66		0.68
# 18	0.78		0.80
# 19	0.78		0.79
# 20	0.77		0.79
# t = 18 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 32 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.80
# 2	0.75		0.79
# 3	0.77		0.79
# 4	0.69		0.71
# 5	0.65		0.66
# 6	0.54		0.53
# 7	0.72		0.75
# 8	0.65		0.68
# 9	0.74		0.78
# 10	0.64		0.65
# 11	0.70		0.71
# 12	0.62		0.61
# 13	0.73		0.77
# 14	0.65		0.65
# 15	0.72		0.74
# 16	0.61		0.62
# 17	0.73		0.77
# 18	0.62		0.63
# 19	0.69		0.70
# 20	0.64		0.65
# t = 3 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 33 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.79
# 2	0.76		0.79
# 3	0.77		0.79
# 4	0.73		0.74
# 5	0.65		0.66
# 6	0.55		0.51
# 7	0.75		0.79
# 8	0.73		0.75
# 9	0.73		0.77
# 10	0.48		0.46
# 11	0.70		0.71
# 12	0.68		0.70
# 13	0.77		0.79
# 14	0.73		0.73
# 15	0.73		0.75
# 16	0.46		0.44
# 17	0.70		0.71
# 18	0.74		0.75
# 19	0.77		0.79
# 20	0.75		0.77
# t = 3 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 34 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.80
# 2	0.77		0.80
# 3	0.77		0.80
# 4	0.74		0.77
# 5	0.73		0.74
# 6	0.52		0.54
# 7	0.70		0.74
# 8	0.73		0.74
# 9	0.75		0.78
# 10	0.61		0.60
# 11	0.65		0.66
# 12	0.69		0.71
# 13	0.74		0.78
# 14	0.63		0.66
# 15	0.65		0.68
# 16	0.63		0.65
# 17	0.73		0.76
# 18	0.63		0.64
# 19	0.67		0.69
# 20	0.65		0.66
# t = 1 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 35 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.80
# 2	0.76		0.80
# 3	0.78		0.79
# 4	0.56		0.60
# 5	0.65		0.67
# 6	0.75		0.78
# 7	0.77		0.77
# 8	0.76		0.79
# 9	0.75		0.75
# 10	0.67		0.68
# 11	0.64		0.67
# 12	0.67		0.68
# 13	0.75		0.76
# 14	0.76		0.77
# 15	0.70		0.72
# 16	0.54		0.53
# 17	0.73		0.75
# 18	0.73		0.74
# 19	0.76		0.76
# 20	0.77		0.79
# t = 3 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 36 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.80
# 2	0.77		0.78
# 3	0.77		0.77
# 4	0.66		0.69
# 5	0.60		0.62
# 6	0.66		0.67
# 7	0.77		0.80
# 8	0.70		0.72
# 9	0.70		0.71
# 10	0.52		0.47
# 11	0.72		0.75
# 12	0.63		0.63
# 13	0.73		0.75
# 14	0.61		0.59
# 15	0.71		0.71
# 16	0.68		0.70
# 17	0.74		0.76
# 18	0.66		0.69
# 19	0.71		0.71
# 20	0.61		0.59
# t = 3 was best iteration with accuracy 0.77
#
# -----------------------------------------------
# 37 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.80
# 2	0.75		0.79
# 3	0.77		0.79
# 4	0.60		0.63
# 5	0.66		0.68
# 6	0.66		0.69
# 7	0.74		0.78
# 8	0.62		0.62
# 9	0.68		0.70
# 10	0.63		0.61
# 11	0.73		0.76
# 12	0.61		0.61
# 13	0.71		0.72
# 14	0.61		0.61
# 15	0.71		0.75
# 16	0.62		0.63
# 17	0.73		0.76
# 18	0.62		0.62
# 19	0.71		0.75
# 20	0.61		0.62
# t = 3 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 38 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.80
# 2	0.74		0.77
# 3	0.77		0.78
# 4	0.59		0.61
# 5	0.66		0.69
# 6	0.75		0.77
# 7	0.77		0.78
# 8	0.65		0.66
# 9	0.64		0.67
# 10	0.63		0.62
# 11	0.73		0.77
# 12	0.62		0.64
# 13	0.68		0.71
# 14	0.65		0.66
# 15	0.76		0.76
# 16	0.70		0.73
# 17	0.71		0.74
# 18	0.58		0.57
# 19	0.72		0.75
# 20	0.69		0.70
# t = 1 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 39 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.79
# 2	0.76		0.79
# 3	0.78		0.79
# 4	0.76		0.77
# 5	0.64		0.62
# 6	0.69		0.72
# 7	0.77		0.79
# 8	0.73		0.76
# 9	0.74		0.78
# 10	0.39		0.39
# 11	0.71		0.75
# 12	0.77		0.79
# 13	0.77		0.80
# 14	0.77		0.79
# 15	0.77		0.76
# 16	0.51		0.52
# 17	0.68		0.74
# 18	0.77		0.78
# 19	0.79		0.78
# 20	0.78		0.77
# t = 19 was best iteration with accuracy 0.78
#
# -----------------------------------------------
# 40 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.80
# 2	0.75		0.78
# 3	0.77		0.80
# 4	0.65		0.69
# 5	0.63		0.63
# 6	0.63		0.64
# 7	0.74		0.78
# 8	0.71		0.75
# 9	0.71		0.74
# 10	0.52		0.49
# 11	0.72		0.75
# 12	0.69		0.70
# 13	0.73		0.78
# 14	0.64		0.65
# 15	0.69		0.70
# 16	0.62		0.63
# 17	0.74		0.77
# 18	0.68		0.71
# 19	0.71		0.73
# 20	0.59		0.59
# t = 3 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 41 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.81
# 2	0.75		0.78
# 3	0.77		0.78
# 4	0.60		0.63
# 5	0.67		0.70
# 6	0.75		0.77
# 7	0.75		0.77
# 8	0.65		0.68
# 9	0.65		0.68
# 10	0.66		0.66
# 11	0.74		0.76
# 12	0.68		0.69
# 13	0.71		0.70
# 14	0.62		0.62
# 15	0.74		0.75
# 16	0.66		0.69
# 17	0.71		0.75
# 18	0.65		0.66
# 19	0.72		0.74
# 20	0.63		0.64
# t = 1 was best iteration with accuracy 0.81
#
# -----------------------------------------------
# 42 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.80
# 2	0.77		0.79
# 3	0.77		0.78
# 4	0.59		0.60
# 5	0.63		0.66
# 6	0.69		0.72
# 7	0.76		0.78
# 8	0.74		0.79
# 9	0.73		0.76
# 10	0.48		0.47
# 11	0.71		0.74
# 12	0.73		0.77
# 13	0.77		0.78
# 14	0.76		0.79
# 15	0.74		0.75
# 16	0.61		0.62
# 17	0.64		0.67
# 18	0.74		0.77
# 19	0.76		0.76
# 20	0.77		0.78
# t = 3 was best iteration with accuracy 0.78
#
# -----------------------------------------------
# 43 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.79
# 2	0.77		0.79
# 3	0.77		0.80
# 4	0.63		0.66
# 5	0.61		0.64
# 6	0.66		0.67
# 7	0.74		0.77
# 8	0.68		0.70
# 9	0.73		0.75
# 10	0.59		0.56
# 11	0.71		0.76
# 12	0.58		0.56
# 13	0.68		0.70
# 14	0.66		0.67
# 15	0.74		0.77
# 16	0.64		0.65
# 17	0.65		0.68
# 18	0.64		0.66
# 19	0.74		0.77
# 20	0.62		0.63
# t = 1 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 44 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.79
# 2	0.75		0.78
# 3	0.75		0.78
# 4	0.70		0.74
# 5	0.70		0.69
# 6	0.58		0.56
# 7	0.70		0.72
# 8	0.64		0.65
# 9	0.74		0.79
# 10	0.73		0.77
# 11	0.73		0.76
# 12	0.55		0.52
# 13	0.69		0.72
# 14	0.68		0.71
# 15	0.75		0.78
# 16	0.75		0.78
# 17	0.74		0.77
# 18	0.59		0.58
# 19	0.65		0.68
# 20	0.69		0.72
# t = 1 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 45 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.79
# 2	0.75		0.79
# 3	0.77		0.79
# 4	0.61		0.64
# 5	0.64		0.67
# 6	0.72		0.75
# 7	0.74		0.76
# 8	0.71		0.75
# 9	0.69		0.71
# 10	0.59		0.58
# 11	0.72		0.75
# 12	0.64		0.67
# 13	0.69		0.73
# 14	0.62		0.63
# 15	0.71		0.74
# 16	0.63		0.65
# 17	0.72		0.74
# 18	0.65		0.68
# 19	0.70		0.72
# 20	0.66		0.68
# t = 1 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 46 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.80
# 2	0.75		0.79
# 3	0.77		0.79
# 4	0.64		0.67
# 5	0.63		0.65
# 6	0.64		0.69
# 7	0.74		0.78
# 8	0.62		0.63
# 9	0.70		0.72
# 10	0.60		0.58
# 11	0.72		0.76
# 12	0.60		0.57
# 13	0.71		0.73
# 14	0.59		0.57
# 15	0.72		0.75
# 16	0.63		0.64
# 17	0.73		0.75
# 18	0.56		0.54
# 19	0.69		0.71
# 20	0.65		0.66
# t = 3 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 47 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.80
# 2	0.77		0.79
# 3	0.77		0.80
# 4	0.70		0.73
# 5	0.67		0.69
# 6	0.60		0.62
# 7	0.70		0.74
# 8	0.64		0.66
# 9	0.73		0.77
# 10	0.62		0.63
# 11	0.70		0.74
# 12	0.61		0.60
# 13	0.72		0.76
# 14	0.61		0.61
# 15	0.71		0.74
# 16	0.64		0.66
# 17	0.73		0.76
# 18	0.63		0.64
# 19	0.71		0.71
# 20	0.61		0.62
# t = 1 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 48 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.80
# 2	0.76		0.79
# 3	0.77		0.80
# 4	0.74		0.77
# 5	0.76		0.78
# 6	0.53		0.56
# 7	0.68		0.71
# 8	0.76		0.78
# 9	0.75		0.79
# 10	0.77		0.79
# 11	0.73		0.76
# 12	0.73		0.75
# 13	0.42		0.42
# 14	0.71		0.74
# 15	0.69		0.73
# 16	0.74		0.78
# 17	0.62		0.63
# 18	0.69		0.71
# 19	0.60		0.60
# 20	0.72		0.74
# t = 1 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 49 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.77		0.80
# 2	0.75		0.78
# 3	0.77		0.80
# 4	0.66		0.70
# 5	0.64		0.64
# 6	0.59		0.59
# 7	0.73		0.76
# 8	0.67		0.70
# 9	0.71		0.73
# 10	0.56		0.54
# 11	0.72		0.74
# 12	0.61		0.63
# 13	0.72		0.74
# 14	0.59		0.57
# 15	0.71		0.72
# 16	0.63		0.64
# 17	0.73		0.77
# 18	0.66		0.70
# 19	0.71		0.70
# 20	0.61		0.62
# t = 1 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 50 / 100 complete
# -----------------------------------------------
#
# Training accuracy of rank SVM: 0.82
# /Users/Ashtekar15/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.80
# 2	0.75		0.79
# 3	0.75		0.79
# 4	0.75		0.79
# 5	0.75		0.79
# 6	0.75		0.80
# 7	0.76		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.76		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 7 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 51 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.80
# 2	0.75		0.80
# 3	0.75		0.79
# 4	0.76		0.80
# 5	0.75		0.80
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 4 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 52 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.76		0.80
# 2	0.75		0.80
# 3	0.75		0.80
# 4	0.75		0.80
# 5	0.75		0.80
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 1 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 53 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.80
# 2	0.75		0.80
# 3	0.76		0.80
# 4	0.76		0.80
# 5	0.75		0.80
# 6	0.76		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 3 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 54 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.80
# 2	0.75		0.80
# 3	0.76		0.79
# 4	0.75		0.79
# 5	0.75		0.79
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 3 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 55 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.80
# 2	0.75		0.80
# 3	0.75		0.79
# 4	0.75		0.80
# 5	0.75		0.80
# 6	0.76		0.80
# 7	0.76		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.76		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 6 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 56 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.80
# 2	0.75		0.80
# 3	0.75		0.80
# 4	0.75		0.80
# 5	0.75		0.80
# 6	0.75		0.79
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 6 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 57 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.76		0.80
# 2	0.75		0.80
# 3	0.75		0.80
# 4	0.75		0.80
# 5	0.75		0.80
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 1 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 58 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.80
# 2	0.75		0.80
# 3	0.75		0.80
# 4	0.75		0.80
# 5	0.75		0.80
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 1 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 59 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.80
# 2	0.75		0.80
# 3	0.76		0.80
# 4	0.76		0.80
# 5	0.75		0.80
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.76		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 3 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 60 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.80
# 2	0.76		0.80
# 3	0.76		0.80
# 4	0.75		0.80
# 5	0.76		0.80
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 2 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 61 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.76		0.80
# 2	0.75		0.80
# 3	0.75		0.80
# 4	0.75		0.80
# 5	0.75		0.80
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 1 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 62 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.80
# 2	0.75		0.80
# 3	0.76		0.79
# 4	0.75		0.80
# 5	0.75		0.80
# 6	0.75		0.80
# 7	0.76		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 3 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 63 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.81
# 2	0.76		0.80
# 3	0.75		0.80
# 4	0.75		0.80
# 5	0.75		0.80
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 2 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 64 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.80
# 2	0.76		0.80
# 3	0.75		0.80
# 4	0.75		0.80
# 5	0.76		0.80
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.76		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 2 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 65 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.76		0.80
# 2	0.76		0.80
# 3	0.76		0.80
# 4	0.76		0.80
# 5	0.75		0.80
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 1 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 66 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.80
# 2	0.75		0.80
# 3	0.76		0.80
# 4	0.75		0.80
# 5	0.75		0.80
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 3 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 67 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.79
# 2	0.75		0.80
# 3	0.76		0.79
# 4	0.76		0.79
# 5	0.76		0.79
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.76		0.80
# 10	0.76		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 3 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 68 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.80
# 2	0.75		0.80
# 3	0.75		0.80
# 4	0.75		0.80
# 5	0.75		0.80
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 2 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 69 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.76		0.80
# 2	0.75		0.80
# 3	0.76		0.79
# 4	0.75		0.80
# 5	0.75		0.80
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 1 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 70 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.80
# 2	0.75		0.79
# 3	0.76		0.80
# 4	0.75		0.80
# 5	0.76		0.80
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 3 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 71 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.80
# 2	0.75		0.80
# 3	0.75		0.80
# 4	0.75		0.80
# 5	0.75		0.80
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 3 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 72 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.76		0.79
# 2	0.75		0.80
# 3	0.75		0.80
# 4	0.75		0.80
# 5	0.75		0.80
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 1 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 73 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.76		0.80
# 2	0.75		0.80
# 3	0.75		0.80
# 4	0.75		0.80
# 5	0.75		0.80
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 1 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 74 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.80
# 2	0.75		0.80
# 3	0.75		0.80
# 4	0.75		0.80
# 5	0.76		0.80
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 5 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 75 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.76		0.80
# 2	0.75		0.80
# 3	0.75		0.80
# 4	0.75		0.80
# 5	0.75		0.80
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 1 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 76 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.76		0.80
# 2	0.75		0.80
# 3	0.75		0.80
# 4	0.75		0.80
# 5	0.75		0.80
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 1 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 77 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.80
# 2	0.76		0.80
# 3	0.75		0.80
# 4	0.76		0.80
# 5	0.76		0.80
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 2 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 78 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.80
# 2	0.75		0.80
# 3	0.75		0.80
# 4	0.76		0.80
# 5	0.75		0.80
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 4 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 79 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.80
# 2	0.75		0.80
# 3	0.75		0.80
# 4	0.75		0.80
# 5	0.75		0.80
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.76		0.80
# 9	0.75		0.80
# 10	0.76		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 8 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 80 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.80
# 2	0.75		0.80
# 3	0.75		0.80
# 4	0.75		0.80
# 5	0.75		0.80
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 1 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 81 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.76		0.80
# 2	0.76		0.80
# 3	0.75		0.80
# 4	0.75		0.80
# 5	0.75		0.80
# 6	0.76		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 1 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 82 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.76		0.80
# 2	0.75		0.80
# 3	0.76		0.80
# 4	0.75		0.80
# 5	0.75		0.80
# 6	0.75		0.80
# 7	0.76		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 1 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 83 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.80
# 2	0.76		0.80
# 3	0.75		0.80
# 4	0.75		0.80
# 5	0.75		0.80
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 2 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 84 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.79
# 2	0.75		0.80
# 3	0.75		0.80
# 4	0.75		0.80
# 5	0.75		0.80
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 1 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 85 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.76		0.80
# 2	0.75		0.80
# 3	0.75		0.80
# 4	0.76		0.80
# 5	0.75		0.80
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 4 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 86 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.76		0.80
# 2	0.76		0.80
# 3	0.76		0.80
# 4	0.76		0.80
# 5	0.76		0.80
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.76		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 2 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 87 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.76		0.80
# 2	0.76		0.80
# 3	0.75		0.80
# 4	0.75		0.80
# 5	0.75		0.80
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 1 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 88 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.76		0.80
# 2	0.75		0.80
# 3	0.75		0.80
# 4	0.75		0.80
# 5	0.75		0.80
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 1 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 89 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.79
# 2	0.75		0.80
# 3	0.75		0.80
# 4	0.75		0.80
# 5	0.76		0.80
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.76		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.79
# 19	0.75		0.80
# 20	0.75		0.80
# t = 5 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 90 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.80
# 2	0.76		0.80
# 3	0.75		0.80
# 4	0.75		0.80
# 5	0.75		0.80
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 2 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 91 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.80
# 2	0.75		0.80
# 3	0.76		0.80
# 4	0.76		0.80
# 5	0.75		0.80
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 3 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 92 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.80
# 2	0.76		0.80
# 3	0.75		0.80
# 4	0.75		0.80
# 5	0.75		0.79
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.79
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 2 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 93 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.80
# 2	0.75		0.80
# 3	0.75		0.80
# 4	0.75		0.80
# 5	0.75		0.80
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 2 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 94 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.76		0.80
# 2	0.75		0.80
# 3	0.76		0.80
# 4	0.75		0.80
# 5	0.76		0.80
# 6	0.76		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.79
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 1 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 95 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.76		0.80
# 2	0.76		0.80
# 3	0.75		0.80
# 4	0.76		0.80
# 5	0.75		0.80
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 2 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 96 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.80
# 2	0.76		0.80
# 3	0.75		0.80
# 4	0.75		0.80
# 5	0.75		0.80
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 2 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 97 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.76		0.80
# 2	0.76		0.80
# 3	0.75		0.80
# 4	0.75		0.80
# 5	0.75		0.79
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 1 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 98 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.80
# 2	0.75		0.80
# 3	0.76		0.80
# 4	0.75		0.80
# 5	0.75		0.80
# 6	0.75		0.80
# 7	0.75		0.80
# 8	0.75		0.80
# 9	0.75		0.80
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 3 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 99 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.80
# 2	0.75		0.80
# 3	0.75		0.80
# 4	0.75		0.80
# 5	0.75		0.80
# 6	0.75		0.80
# 7	0.75		0.81
# 8	0.75		0.81
# 9	0.75		0.81
# 10	0.75		0.80
# 11	0.75		0.80
# 12	0.75		0.80
# 13	0.75		0.80
# 14	0.75		0.80
# 15	0.75		0.80
# 16	0.75		0.80
# 17	0.75		0.80
# 18	0.75		0.80
# 19	0.75		0.80
# 20	0.75		0.80
# t = 1 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 100 / 100 complete
# -----------------------------------------------

# %%
table_results(svm_arr, tree_arr)
# Out:
# (Performance on test set)
#
# 50 comparisons
# 	acc	sderr
# SVM: 	79.1	0.2
# Tree: 	nan	nan
#
# 200 comparisons
# 	acc	sderr
# SVM: 	79.8	0.1
# Tree: 	nan	nan
