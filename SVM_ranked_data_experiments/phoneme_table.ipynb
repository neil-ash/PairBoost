# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import sys; sys.path.insert(0,'..')
from main import *

# %%
data = pd.read_csv('../data/phoneme/phoneme.csv')
X = data.iloc[:, :-1].values
y  = data.iloc[:, -1].values

# Convert labels to -1, 1 and scale features
y = np.array([1.0 if yi == 2 else -1.0 for yi in y])

scaler = MinMaxScaler(feature_range=(0, 1))

for i in range(X.shape[1]):
    X[:, i] = scaler.fit_transform(X[:, i].reshape(-1, 1)).ravel()
    
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.5, stratify=y, 
                                                    shuffle=True, random_state=1)

# %%
svm_arr, tree_arr = data_size_experiment(X_train, y_train, X_test, y_test,
                                         experiment_type='table', kernel='linear',
                                         random_state=1, verbose=True)
# Out:
# Progress:
# Training accuracy of rank SVM: 0.86
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# /Users/Ashtekar15/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# t	Train		Test
# 1	0.71		0.70
# 2	0.73		0.77
# 3	0.68		0.70
# 4	0.69		0.70
# 5	0.70		0.70
# 6	0.72		0.73
# 7	0.30		0.30
# 8	0.75		0.77
# 9	0.75		0.77
# 10	0.73		0.74
# 11	0.68		0.67
# 12	0.69		0.66
# 13	0.68		0.68
# 14	0.70		0.70
# 15	0.57		0.57
# 16	0.63		0.60
# 17	0.68		0.67
# 18	0.76		0.76
# 19	0.44		0.42
# 20	0.67		0.69
# t = 18 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 1 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.69
# 2	0.68		0.67
# 3	0.29		0.29
# 4	0.71		0.73
# 5	0.74		0.77
# 6	0.71		0.73
# 7	0.75		0.73
# 8	0.64		0.62
# 9	0.76		0.77
# 10	0.77		0.73
# 11	0.71		0.70
# 12	0.71		0.67
# 13	0.72		0.73
# 14	0.76		0.73
# 15	0.45		0.44
# 16	0.72		0.69
# 17	0.73		0.71
# 18	0.72		0.73
# 19	0.74		0.70
# 20	0.37		0.39
# t = 10 was best iteration with accuracy 0.73
#
# -----------------------------------------------
# 2 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.68
# 2	0.68		0.68
# 3	0.25		0.26
# 4	0.73		0.75
# 5	0.74		0.77
# 6	0.70		0.69
# 7	0.36		0.36
# 8	0.68		0.66
# 9	0.68		0.66
# 10	0.66		0.65
# 11	0.48		0.46
# 12	0.58		0.62
# 13	0.64		0.64
# 14	0.50		0.53
# 15	0.46		0.45
# 16	0.54		0.60
# 17	0.54		0.51
# 18	0.48		0.48
# 19	0.49		0.46
# 20	0.55		0.56
# t = 3 was best iteration with accuracy 0.74
#
# -----------------------------------------------
# 3 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.68
# 2	0.69		0.69
# 3	0.24		0.25
# 4	0.75		0.77
# 5	0.75		0.77
# 6	0.75		0.73
# 7	0.74		0.71
# 8	0.55		0.53
# 9	0.74		0.78
# 10	0.75		0.78
# 11	0.74		0.72
# 12	0.65		0.65
# 13	0.69		0.65
# 14	0.70		0.69
# 15	0.76		0.77
# 16	0.46		0.44
# 17	0.64		0.67
# 18	0.72		0.74
# 19	0.72		0.72
# 20	0.71		0.68
# t = 3 was best iteration with accuracy 0.75
#
# -----------------------------------------------
# 4 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.70
# 2	0.75		0.78
# 3	0.28		0.25
# 4	0.75		0.77
# 5	0.75		0.77
# 6	0.73		0.75
# 7	0.76		0.72
# 8	0.41		0.39
# 9	0.68		0.68
# 10	0.69		0.68
# 11	0.71		0.70
# 12	0.27		0.32
# 13	0.71		0.68
# 14	0.71		0.69
# 15	0.68		0.68
# 16	0.65		0.63
# 17	0.26		0.31
# 18	0.71		0.69
# 19	0.72		0.69
# 20	0.68		0.68
# t = 7 was best iteration with accuracy 0.72
#
# -----------------------------------------------
# 5 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.69
# 2	0.72		0.75
# 3	0.42		0.42
# 4	0.71		0.73
# 5	0.73		0.76
# 6	0.71		0.70
# 7	0.55		0.57
# 8	0.66		0.64
# 9	0.68		0.66
# 10	0.67		0.65
# 11	0.27		0.29
# 12	0.72		0.74
# 13	0.73		0.75
# 14	0.69		0.67
# 15	0.41		0.41
# 16	0.70		0.65
# 17	0.69		0.70
# 18	0.69		0.68
# 19	0.35		0.37
# 20	0.66		0.65
# t = 11 was best iteration with accuracy 0.71
#
# -----------------------------------------------
# 6 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.69
# 2	0.73		0.77
# 3	0.29		0.28
# 4	0.75		0.77
# 5	0.75		0.77
# 6	0.75		0.74
# 7	0.71		0.71
# 8	0.59		0.59
# 9	0.74		0.74
# 10	0.75		0.71
# 11	0.71		0.69
# 12	0.67		0.69
# 13	0.76		0.76
# 14	0.73		0.70
# 15	0.71		0.69
# 16	0.65		0.62
# 17	0.76		0.76
# 18	0.73		0.70
# 19	0.72		0.70
# 20	0.65		0.64
# t = 13 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 7 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.69
# 2	0.73		0.74
# 3	0.55		0.56
# 4	0.71		0.74
# 5	0.73		0.76
# 6	0.71		0.72
# 7	0.71		0.72
# 8	0.67		0.63
# 9	0.74		0.75
# 10	0.61		0.60
# 11	0.57		0.61
# 12	0.67		0.66
# 13	0.60		0.63
# 14	0.60		0.59
# 15	0.62		0.65
# 16	0.65		0.64
# 17	0.62		0.66
# 18	0.58		0.56
# 19	0.63		0.65
# 20	0.66		0.65
# t = 9 was best iteration with accuracy 0.75
#
# -----------------------------------------------
# 8 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.69
# 2	0.75		0.77
# 3	0.25		0.25
# 4	0.75		0.76
# 5	0.75		0.77
# 6	0.74		0.74
# 7	0.71		0.71
# 8	0.71		0.67
# 9	0.77		0.74
# 10	0.73		0.71
# 11	0.70		0.71
# 12	0.72		0.70
# 13	0.75		0.71
# 14	0.75		0.72
# 15	0.71		0.68
# 16	0.73		0.68
# 17	0.71		0.70
# 18	0.76		0.75
# 19	0.70		0.69
# 20	0.73		0.71
# t = 9 was best iteration with accuracy 0.74
#
# -----------------------------------------------
# 9 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.70
# 2	0.71		0.72
# 3	0.30		0.29
# 4	0.75		0.77
# 5	0.76		0.77
# 6	0.75		0.73
# 7	0.71		0.71
# 8	0.73		0.69
# 9	0.73		0.70
# 10	0.76		0.75
# 11	0.71		0.70
# 12	0.56		0.54
# 13	0.73		0.71
# 14	0.75		0.74
# 15	0.72		0.70
# 16	0.66		0.63
# 17	0.75		0.70
# 18	0.75		0.74
# 19	0.71		0.68
# 20	0.73		0.75
# t = 5 was best iteration with accuracy 0.77
#
# -----------------------------------------------
# 10 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.68
# 2	0.69		0.68
# 3	0.23		0.24
# 4	0.75		0.76
# 5	0.75		0.77
# 6	0.71		0.72
# 7	0.71		0.69
# 8	0.38		0.38
# 9	0.69		0.67
# 10	0.73		0.74
# 11	0.35		0.40
# 12	0.65		0.65
# 13	0.69		0.68
# 14	0.74		0.75
# 15	0.59		0.61
# 16	0.67		0.69
# 17	0.68		0.68
# 18	0.73		0.72
# 19	0.67		0.66
# 20	0.76		0.77
# t = 3 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 11 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.68
# 2	0.72		0.72
# 3	0.24		0.23
# 4	0.75		0.76
# 5	0.74		0.76
# 6	0.70		0.71
# 7	0.67		0.66
# 8	0.37		0.38
# 9	0.66		0.65
# 10	0.69		0.67
# 11	0.28		0.27
# 12	0.76		0.75
# 13	0.74		0.74
# 14	0.67		0.67
# 15	0.59		0.62
# 16	0.67		0.61
# 17	0.75		0.76
# 18	0.56		0.55
# 19	0.61		0.64
# 20	0.67		0.67
# t = 3 was best iteration with accuracy 0.77
#
# -----------------------------------------------
# 12 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.69
# 2	0.72		0.72
# 3	0.29		0.28
# 4	0.74		0.76
# 5	0.75		0.77
# 6	0.72		0.73
# 7	0.74		0.71
# 8	0.39		0.40
# 9	0.69		0.66
# 10	0.72		0.74
# 11	0.53		0.51
# 12	0.70		0.70
# 13	0.71		0.70
# 14	0.64		0.66
# 15	0.55		0.54
# 16	0.67		0.68
# 17	0.71		0.69
# 18	0.56		0.56
# 19	0.58		0.59
# 20	0.66		0.66
# t = 5 was best iteration with accuracy 0.77
#
# -----------------------------------------------
# 13 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.68
# 2	0.73		0.73
# 3	0.36		0.32
# 4	0.69		0.71
# 5	0.74		0.77
# 6	0.70		0.70
# 7	0.38		0.39
# 8	0.68		0.67
# 9	0.68		0.67
# 10	0.70		0.68
# 11	0.67		0.67
# 12	0.32		0.33
# 13	0.68		0.66
# 14	0.67		0.66
# 15	0.68		0.66
# 16	0.50		0.53
# 17	0.27		0.32
# 18	0.67		0.65
# 19	0.67		0.66
# 20	0.64		0.64
# t = 5 was best iteration with accuracy 0.77
#
# -----------------------------------------------
# 14 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.69
# 2	0.72		0.71
# 3	0.24		0.24
# 4	0.75		0.77
# 5	0.75		0.78
# 6	0.72		0.74
# 7	0.71		0.69
# 8	0.67		0.67
# 9	0.72		0.73
# 10	0.68		0.67
# 11	0.57		0.59
# 12	0.62		0.61
# 13	0.69		0.67
# 14	0.69		0.67
# 15	0.24		0.24
# 16	0.75		0.76
# 17	0.75		0.77
# 18	0.73		0.74
# 19	0.74		0.73
# 20	0.36		0.37
# t = 3 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 15 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.69
# 2	0.73		0.75
# 3	0.26		0.26
# 4	0.75		0.77
# 5	0.75		0.78
# 6	0.74		0.74
# 7	0.71		0.71
# 8	0.71		0.68
# 9	0.71		0.71
# 10	0.76		0.77
# 11	0.58		0.56
# 12	0.75		0.76
# 13	0.75		0.78
# 14	0.75		0.73
# 15	0.71		0.72
# 16	0.53		0.51
# 17	0.71		0.74
# 18	0.74		0.73
# 19	0.73		0.72
# 20	0.58		0.57
# t = 10 was best iteration with accuracy 0.77
#
# -----------------------------------------------
# 16 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.67
# 2	0.72		0.71
# 3	0.23		0.24
# 4	0.75		0.76
# 5	0.75		0.77
# 6	0.71		0.72
# 7	0.72		0.71
# 8	0.32		0.35
# 9	0.70		0.69
# 10	0.70		0.70
# 11	0.74		0.78
# 12	0.43		0.43
# 13	0.75		0.77
# 14	0.76		0.77
# 15	0.76		0.74
# 16	0.71		0.71
# 17	0.71		0.69
# 18	0.72		0.70
# 19	0.75		0.76
# 20	0.73		0.71
# t = 3 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 17 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.70
# 2	0.72		0.75
# 3	0.60		0.59
# 4	0.67		0.67
# 5	0.70		0.71
# 6	0.73		0.76
# 7	0.29		0.30
# 8	0.74		0.76
# 9	0.75		0.78
# 10	0.74		0.73
# 11	0.71		0.71
# 12	0.71		0.64
# 13	0.72		0.69
# 14	0.75		0.78
# 15	0.69		0.66
# 16	0.63		0.64
# 17	0.72		0.71
# 18	0.73		0.74
# 19	0.59		0.62
# 20	0.64		0.64
# t = 9 was best iteration with accuracy 0.78
#
# -----------------------------------------------
# 18 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.69
# 2	0.73		0.74
# 3	0.32		0.30
# 4	0.75		0.77
# 5	0.75		0.77
# 6	0.74		0.74
# 7	0.75		0.71
# 8	0.46		0.41
# 9	0.71		0.73
# 10	0.75		0.77
# 11	0.74		0.71
# 12	0.57		0.59
# 13	0.70		0.66
# 14	0.70		0.70
# 15	0.76		0.77
# 16	0.35		0.32
# 17	0.76		0.76
# 18	0.76		0.77
# 19	0.75		0.77
# 20	0.74		0.70
# t = 15 was best iteration with accuracy 0.77
#
# -----------------------------------------------
# 19 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.70
# 2	0.69		0.69
# 3	0.42		0.40
# 4	0.71		0.73
# 5	0.73		0.76
# 6	0.70		0.72
# 7	0.76		0.74
# 8	0.54		0.56
# 9	0.72		0.74
# 10	0.73		0.73
# 11	0.72		0.71
# 12	0.68		0.66
# 13	0.72		0.70
# 14	0.75		0.76
# 15	0.51		0.53
# 16	0.71		0.74
# 17	0.73		0.77
# 18	0.71		0.72
# 19	0.70		0.71
# 20	0.68		0.62
# t = 7 was best iteration with accuracy 0.74
#
# -----------------------------------------------
# 20 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.68
# 2	0.73		0.75
# 3	0.63		0.63
# 4	0.71		0.72
# 5	0.73		0.75
# 6	0.70		0.69
# 7	0.37		0.37
# 8	0.67		0.64
# 9	0.69		0.67
# 10	0.68		0.67
# 11	0.24		0.24
# 12	0.75		0.76
# 13	0.73		0.76
# 14	0.69		0.69
# 15	0.57		0.57
# 16	0.36		0.37
# 17	0.66		0.65
# 18	0.67		0.64
# 19	0.29		0.28
# 20	0.77		0.75
# t = 20 was best iteration with accuracy 0.75
#
# -----------------------------------------------
# 21 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.69
# 2	0.72		0.73
# 3	0.27		0.28
# 4	0.74		0.75
# 5	0.74		0.76
# 6	0.71		0.72
# 7	0.73		0.73
# 8	0.35		0.37
# 9	0.69		0.69
# 10	0.71		0.71
# 11	0.72		0.73
# 12	0.71		0.70
# 13	0.72		0.74
# 14	0.74		0.78
# 15	0.74		0.76
# 16	0.77		0.72
# 17	0.70		0.70
# 18	0.70		0.68
# 19	0.70		0.71
# 20	0.75		0.77
# t = 16 was best iteration with accuracy 0.72
#
# -----------------------------------------------
# 22 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.69
# 2	0.74		0.78
# 3	0.27		0.25
# 4	0.75		0.76
# 5	0.75		0.77
# 6	0.73		0.74
# 7	0.76		0.71
# 8	0.67		0.68
# 9	0.71		0.72
# 10	0.71		0.70
# 11	0.74		0.72
# 12	0.55		0.54
# 13	0.67		0.69
# 14	0.69		0.69
# 15	0.68		0.67
# 16	0.67		0.65
# 17	0.74		0.76
# 18	0.68		0.67
# 19	0.65		0.68
# 20	0.69		0.66
# t = 7 was best iteration with accuracy 0.71
#
# -----------------------------------------------
# 23 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.68
# 2	0.71		0.71
# 3	0.23		0.24
# 4	0.74		0.76
# 5	0.74		0.77
# 6	0.71		0.72
# 7	0.75		0.74
# 8	0.26		0.26
# 9	0.74		0.77
# 10	0.74		0.75
# 11	0.71		0.70
# 12	0.57		0.58
# 13	0.69		0.66
# 14	0.70		0.70
# 15	0.55		0.55
# 16	0.53		0.55
# 17	0.68		0.67
# 18	0.74		0.74
# 19	0.51		0.50
# 20	0.72		0.72
# t = 3 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 24 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.68
# 2	0.73		0.73
# 3	0.25		0.24
# 4	0.76		0.76
# 5	0.75		0.77
# 6	0.74		0.74
# 7	0.75		0.72
# 8	0.45		0.42
# 9	0.74		0.76
# 10	0.75		0.78
# 11	0.77		0.73
# 12	0.71		0.71
# 13	0.68		0.66
# 14	0.72		0.72
# 15	0.77		0.76
# 16	0.35		0.35
# 17	0.76		0.76
# 18	0.76		0.76
# 19	0.76		0.77
# 20	0.71		0.71
# t = 15 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 25 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.69
# 2	0.72		0.73
# 3	0.24		0.24
# 4	0.75		0.76
# 5	0.75		0.77
# 6	0.73		0.74
# 7	0.71		0.68
# 8	0.36		0.39
# 9	0.67		0.66
# 10	0.68		0.65
# 11	0.26		0.26
# 12	0.75		0.76
# 13	0.73		0.75
# 14	0.71		0.70
# 15	0.59		0.59
# 16	0.70		0.65
# 17	0.70		0.68
# 18	0.73		0.77
# 19	0.45		0.44
# 20	0.63		0.67
# t = 3 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 26 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.68
# 2	0.75		0.77
# 3	0.41		0.37
# 4	0.71		0.73
# 5	0.74		0.77
# 6	0.72		0.71
# 7	0.37		0.37
# 8	0.67		0.65
# 9	0.69		0.67
# 10	0.68		0.66
# 11	0.62		0.61
# 12	0.31		0.32
# 13	0.70		0.68
# 14	0.68		0.67
# 15	0.65		0.66
# 16	0.35		0.39
# 17	0.69		0.71
# 18	0.70		0.70
# 19	0.67		0.66
# 20	0.35		0.38
# t = 2 was best iteration with accuracy 0.77
#
# -----------------------------------------------
# 27 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.70
# 2	0.71		0.73
# 3	0.51		0.54
# 4	0.68		0.70
# 5	0.72		0.72
# 6	0.70		0.70
# 7	0.69		0.69
# 8	0.67		0.61
# 9	0.72		0.73
# 10	0.60		0.61
# 11	0.55		0.58
# 12	0.66		0.66
# 13	0.63		0.65
# 14	0.46		0.44
# 15	0.59		0.62
# 16	0.66		0.65
# 17	0.37		0.37
# 18	0.24		0.24
# 19	0.75		0.76
# 20	0.72		0.74
# t = 18 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 28 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.68
# 2	0.74		0.77
# 3	0.25		0.25
# 4	0.75		0.77
# 5	0.75		0.78
# 6	0.71		0.74
# 7	0.77		0.72
# 8	0.38		0.40
# 9	0.71		0.69
# 10	0.71		0.71
# 11	0.74		0.76
# 12	0.58		0.57
# 13	0.76		0.76
# 14	0.75		0.78
# 15	0.75		0.73
# 16	0.71		0.68
# 17	0.68		0.66
# 18	0.69		0.67
# 19	0.70		0.69
# 20	0.70		0.69
# t = 7 was best iteration with accuracy 0.72
#
# -----------------------------------------------
# 29 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.70
# 2	0.73		0.76
# 3	0.49		0.46
# 4	0.73		0.76
# 5	0.73		0.76
# 6	0.72		0.72
# 7	0.38		0.39
# 8	0.67		0.66
# 9	0.69		0.67
# 10	0.68		0.68
# 11	0.24		0.26
# 12	0.73		0.75
# 13	0.73		0.76
# 14	0.69		0.68
# 15	0.59		0.59
# 16	0.40		0.42
# 17	0.67		0.66
# 18	0.56		0.62
# 19	0.45		0.41
# 20	0.61		0.65
# t = 11 was best iteration with accuracy 0.74
#
# -----------------------------------------------
# 30 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.69
# 2	0.73		0.75
# 3	0.53		0.53
# 4	0.71		0.74
# 5	0.72		0.74
# 6	0.70		0.69
# 7	0.74		0.76
# 8	0.39		0.38
# 9	0.74		0.76
# 10	0.73		0.73
# 11	0.71		0.71
# 12	0.61		0.60
# 13	0.66		0.62
# 14	0.71		0.67
# 15	0.65		0.67
# 16	0.61		0.57
# 17	0.62		0.64
# 18	0.65		0.61
# 19	0.67		0.63
# 20	0.63		0.61
# t = 9 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 31 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.68
# 2	0.71		0.72
# 3	0.23		0.23
# 4	0.75		0.76
# 5	0.75		0.77
# 6	0.73		0.74
# 7	0.71		0.69
# 8	0.41		0.42
# 9	0.68		0.65
# 10	0.71		0.71
# 11	0.44		0.43
# 12	0.59		0.62
# 13	0.67		0.67
# 14	0.61		0.65
# 15	0.62		0.61
# 16	0.72		0.72
# 17	0.69		0.67
# 18	0.68		0.70
# 19	0.58		0.59
# 20	0.66		0.68
# t = 3 was best iteration with accuracy 0.77
#
# -----------------------------------------------
# 32 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.69
# 2	0.69		0.69
# 3	0.27		0.26
# 4	0.75		0.76
# 5	0.75		0.76
# 6	0.74		0.74
# 7	0.71		0.71
# 8	0.69		0.62
# 9	0.75		0.77
# 10	0.75		0.73
# 11	0.56		0.56
# 12	0.68		0.63
# 13	0.72		0.73
# 14	0.76		0.77
# 15	0.63		0.60
# 16	0.72		0.74
# 17	0.74		0.77
# 18	0.71		0.71
# 19	0.62		0.62
# 20	0.65		0.63
# t = 14 was best iteration with accuracy 0.77
#
# -----------------------------------------------
# 33 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.68
# 2	0.74		0.77
# 3	0.40		0.36
# 4	0.67		0.69
# 5	0.73		0.74
# 6	0.71		0.69
# 7	0.66		0.65
# 8	0.67		0.64
# 9	0.73		0.73
# 10	0.76		0.75
# 11	0.69		0.65
# 12	0.73		0.77
# 13	0.76		0.77
# 14	0.77		0.76
# 15	0.74		0.70
# 16	0.71		0.71
# 17	0.75		0.77
# 18	0.76		0.76
# 19	0.77		0.76
# 20	0.72		0.70
# t = 14 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 34 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.69
# 2	0.74		0.76
# 3	0.45		0.42
# 4	0.63		0.66
# 5	0.71		0.72
# 6	0.69		0.68
# 7	0.64		0.67
# 8	0.65		0.64
# 9	0.74		0.73
# 10	0.75		0.76
# 11	0.68		0.63
# 12	0.61		0.59
# 13	0.73		0.70
# 14	0.71		0.71
# 15	0.73		0.68
# 16	0.63		0.61
# 17	0.68		0.66
# 18	0.70		0.70
# 19	0.75		0.71
# 20	0.64		0.64
# t = 10 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 35 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.68
# 2	0.74		0.77
# 3	0.26		0.25
# 4	0.76		0.76
# 5	0.76		0.77
# 6	0.74		0.76
# 7	0.77		0.72
# 8	0.50		0.48
# 9	0.73		0.68
# 10	0.73		0.71
# 11	0.75		0.74
# 12	0.77		0.76
# 13	0.52		0.52
# 14	0.77		0.78
# 15	0.74		0.74
# 16	0.77		0.76
# 17	0.55		0.53
# 18	0.73		0.70
# 19	0.72		0.71
# 20	0.74		0.74
# t = 14 was best iteration with accuracy 0.78
#
# -----------------------------------------------
# 36 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.68
# 2	0.69		0.70
# 3	0.24		0.24
# 4	0.75		0.76
# 5	0.75		0.77
# 6	0.74		0.75
# 7	0.72		0.68
# 8	0.61		0.65
# 9	0.68		0.64
# 10	0.73		0.75
# 11	0.62		0.62
# 12	0.75		0.74
# 13	0.70		0.69
# 14	0.77		0.77
# 15	0.49		0.49
# 16	0.70		0.72
# 17	0.76		0.77
# 18	0.75		0.72
# 19	0.68		0.66
# 20	0.70		0.65
# t = 14 was best iteration with accuracy 0.77
#
# -----------------------------------------------
# 37 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.68
# 2	0.72		0.72
# 3	0.22		0.22
# 4	0.75		0.76
# 5	0.73		0.76
# 6	0.69		0.68
# 7	0.67		0.67
# 8	0.42		0.40
# 9	0.63		0.66
# 10	0.70		0.69
# 11	0.67		0.66
# 12	0.60		0.63
# 13	0.56		0.55
# 14	0.67		0.65
# 15	0.54		0.56
# 16	0.29		0.33
# 17	0.67		0.66
# 18	0.65		0.63
# 19	0.29		0.29
# 20	0.28		0.30
# t = 3 was best iteration with accuracy 0.78
#
# -----------------------------------------------
# 38 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.68
# 2	0.72		0.74
# 3	0.27		0.26
# 4	0.74		0.76
# 5	0.75		0.77
# 6	0.73		0.74
# 7	0.75		0.72
# 8	0.36		0.40
# 9	0.69		0.66
# 10	0.68		0.67
# 11	0.59		0.59
# 12	0.29		0.32
# 13	0.71		0.68
# 14	0.69		0.67
# 15	0.66		0.65
# 16	0.38		0.40
# 17	0.48		0.50
# 18	0.69		0.66
# 19	0.59		0.58
# 20	0.26		0.29
# t = 7 was best iteration with accuracy 0.72
#
# -----------------------------------------------
# 39 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.69
# 2	0.72		0.74
# 3	0.40		0.40
# 4	0.73		0.75
# 5	0.75		0.77
# 6	0.72		0.72
# 7	0.49		0.48
# 8	0.67		0.66
# 9	0.68		0.67
# 10	0.69		0.66
# 11	0.49		0.51
# 12	0.24		0.26
# 13	0.75		0.76
# 14	0.72		0.71
# 15	0.68		0.65
# 16	0.35		0.36
# 17	0.66		0.66
# 18	0.67		0.65
# 19	0.56		0.58
# 20	0.30		0.33
# t = 12 was best iteration with accuracy 0.74
#
# -----------------------------------------------
# 40 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.70
# 2	0.73		0.74
# 3	0.63		0.62
# 4	0.68		0.69
# 5	0.73		0.74
# 6	0.69		0.67
# 7	0.39		0.40
# 8	0.69		0.67
# 9	0.72		0.72
# 10	0.29		0.30
# 11	0.73		0.75
# 12	0.69		0.68
# 13	0.29		0.30
# 14	0.66		0.63
# 15	0.71		0.68
# 16	0.67		0.69
# 17	0.68		0.66
# 18	0.63		0.63
# 19	0.71		0.68
# 20	0.66		0.65
# t = 2 was best iteration with accuracy 0.74
#
# -----------------------------------------------
# 41 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.68
# 2	0.73		0.77
# 3	0.53		0.53
# 4	0.71		0.75
# 5	0.71		0.72
# 6	0.71		0.69
# 7	0.36		0.36
# 8	0.70		0.68
# 9	0.70		0.68
# 10	0.67		0.66
# 11	0.43		0.49
# 12	0.59		0.59
# 13	0.71		0.69
# 14	0.60		0.60
# 15	0.59		0.59
# 16	0.58		0.59
# 17	0.70		0.66
# 18	0.61		0.63
# 19	0.65		0.62
# 20	0.60		0.61
# t = 2 was best iteration with accuracy 0.77
#
# -----------------------------------------------
# 42 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.69
# 2	0.72		0.74
# 3	0.31		0.30
# 4	0.74		0.76
# 5	0.75		0.78
# 6	0.72		0.73
# 7	0.57		0.60
# 8	0.68		0.66
# 9	0.67		0.67
# 10	0.69		0.68
# 11	0.55		0.56
# 12	0.29		0.35
# 13	0.69		0.67
# 14	0.68		0.67
# 15	0.67		0.65
# 16	0.29		0.29
# 17	0.30		0.27
# 18	0.66		0.65
# 19	0.67		0.65
# 20	0.42		0.46
# t = 5 was best iteration with accuracy 0.78
#
# -----------------------------------------------
# 43 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.68
# 2	0.73		0.73
# 3	0.24		0.23
# 4	0.76		0.76
# 5	0.75		0.77
# 6	0.73		0.75
# 7	0.73		0.71
# 8	0.42		0.45
# 9	0.69		0.66
# 10	0.73		0.75
# 11	0.37		0.34
# 12	0.74		0.74
# 13	0.68		0.67
# 14	0.76		0.76
# 15	0.45		0.43
# 16	0.68		0.70
# 17	0.70		0.71
# 18	0.75		0.74
# 19	0.34		0.35
# 20	0.72		0.68
# t = 3 was best iteration with accuracy 0.77
#
# -----------------------------------------------
# 44 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.70
# 2	0.73		0.75
# 3	0.50		0.53
# 4	0.71		0.73
# 5	0.72		0.73
# 6	0.71		0.70
# 7	0.66		0.66
# 8	0.70		0.66
# 9	0.75		0.76
# 10	0.50		0.49
# 11	0.63		0.67
# 12	0.68		0.67
# 13	0.69		0.70
# 14	0.45		0.42
# 15	0.65		0.66
# 16	0.70		0.69
# 17	0.66		0.69
# 18	0.63		0.66
# 19	0.70		0.71
# 20	0.68		0.67
# t = 9 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 45 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.69
# 2	0.73		0.76
# 3	0.24		0.24
# 4	0.75		0.76
# 5	0.75		0.77
# 6	0.73		0.74
# 7	0.76		0.72
# 8	0.39		0.41
# 9	0.68		0.67
# 10	0.67		0.68
# 11	0.71		0.71
# 12	0.31		0.33
# 13	0.76		0.76
# 14	0.72		0.72
# 15	0.67		0.64
# 16	0.38		0.38
# 17	0.67		0.65
# 18	0.68		0.66
# 19	0.26		0.25
# 20	0.70		0.68
# t = 3 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 46 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.70
# 2	0.70		0.71
# 3	0.26		0.25
# 4	0.73		0.76
# 5	0.75		0.77
# 6	0.72		0.73
# 7	0.76		0.72
# 8	0.67		0.65
# 9	0.71		0.72
# 10	0.67		0.67
# 11	0.70		0.69
# 12	0.61		0.64
# 13	0.72		0.73
# 14	0.69		0.69
# 15	0.72		0.74
# 16	0.62		0.60
# 17	0.71		0.73
# 18	0.70		0.68
# 19	0.66		0.70
# 20	0.64		0.62
# t = 7 was best iteration with accuracy 0.72
#
# -----------------------------------------------
# 47 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.70
# 2	0.73		0.76
# 3	0.25		0.24
# 4	0.75		0.76
# 5	0.75		0.76
# 6	0.72		0.73
# 7	0.75		0.74
# 8	0.39		0.40
# 9	0.68		0.70
# 10	0.70		0.72
# 11	0.74		0.75
# 12	0.53		0.50
# 13	0.62		0.67
# 14	0.73		0.75
# 15	0.69		0.68
# 16	0.76		0.77
# 17	0.43		0.40
# 18	0.67		0.69
# 19	0.71		0.73
# 20	0.77		0.76
# t = 20 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 48 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.69
# 2	0.70		0.71
# 3	0.29		0.28
# 4	0.75		0.76
# 5	0.75		0.78
# 6	0.75		0.76
# 7	0.75		0.69
# 8	0.42		0.45
# 9	0.69		0.66
# 10	0.72		0.74
# 11	0.67		0.64
# 12	0.37		0.38
# 13	0.65		0.66
# 14	0.66		0.66
# 15	0.28		0.27
# 16	0.75		0.74
# 17	0.71		0.70
# 18	0.68		0.68
# 19	0.32		0.36
# 20	0.68		0.67
# t = 16 was best iteration with accuracy 0.74
#
# -----------------------------------------------
# 49 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.69
# 2	0.73		0.76
# 3	0.46		0.45
# 4	0.72		0.75
# 5	0.75		0.78
# 6	0.74		0.72
# 7	0.66		0.65
# 8	0.69		0.66
# 9	0.70		0.69
# 10	0.73		0.76
# 11	0.74		0.68
# 12	0.37		0.39
# 13	0.67		0.66
# 14	0.69		0.67
# 15	0.29		0.29
# 16	0.74		0.75
# 17	0.70		0.70
# 18	0.62		0.61
# 19	0.37		0.38
# 20	0.65		0.64
# t = 5 was best iteration with accuracy 0.78
#
# -----------------------------------------------
# 50 / 100 complete
# -----------------------------------------------
#
# Training accuracy of rank SVM: 0.80
# /Users/Ashtekar15/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.68
# 2	0.71		0.68
# 3	0.71		0.68
# 4	0.69		0.67
# 5	0.55		0.54
# 6	0.66		0.65
# 7	0.71		0.68
# 8	0.71		0.67
# 9	0.70		0.67
# 10	0.67		0.65
# 11	0.59		0.61
# 12	0.66		0.66
# 13	0.72		0.69
# 14	0.73		0.70
# 15	0.74		0.71
# 16	0.74		0.70
# 17	0.73		0.69
# 18	0.64		0.65
# 19	0.72		0.70
# 20	0.73		0.70
# t = 15 was best iteration with accuracy 0.71
#
# -----------------------------------------------
# 51 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.68
# 2	0.71		0.68
# 3	0.71		0.67
# 4	0.71		0.67
# 5	0.30		0.29
# 6	0.66		0.66
# 7	0.71		0.68
# 8	0.72		0.68
# 9	0.71		0.68
# 10	0.71		0.67
# 11	0.67		0.67
# 12	0.39		0.42
# 13	0.75		0.75
# 14	0.74		0.69
# 15	0.72		0.69
# 16	0.72		0.69
# 17	0.73		0.70
# 18	0.73		0.70
# 19	0.75		0.76
# 20	0.63		0.62
# t = 13 was best iteration with accuracy 0.75
#
# -----------------------------------------------
# 52 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.68
# 2	0.71		0.68
# 3	0.71		0.68
# 4	0.71		0.67
# 5	0.55		0.55
# 6	0.66		0.67
# 7	0.72		0.69
# 8	0.72		0.70
# 9	0.73		0.70
# 10	0.75		0.71
# 11	0.71		0.66
# 12	0.75		0.74
# 13	0.67		0.64
# 14	0.75		0.71
# 15	0.73		0.71
# 16	0.75		0.72
# 17	0.69		0.68
# 18	0.75		0.76
# 19	0.70		0.70
# 20	0.75		0.72
# t = 12 was best iteration with accuracy 0.74
#
# -----------------------------------------------
# 53 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.67
# 2	0.70		0.67
# 3	0.70		0.67
# 4	0.68		0.66
# 5	0.44		0.44
# 6	0.66		0.65
# 7	0.68		0.68
# 8	0.71		0.67
# 9	0.70		0.66
# 10	0.68		0.66
# 11	0.60		0.60
# 12	0.28		0.30
# 13	0.73		0.74
# 14	0.72		0.70
# 15	0.72		0.69
# 16	0.72		0.69
# 17	0.73		0.69
# 18	0.74		0.71
# 19	0.73		0.68
# 20	0.60		0.66
# t = 18 was best iteration with accuracy 0.71
#
# -----------------------------------------------
# 54 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.68
# 2	0.72		0.68
# 3	0.72		0.69
# 4	0.72		0.68
# 5	0.77		0.76
# 6	0.47		0.49
# 7	0.76		0.77
# 8	0.75		0.71
# 9	0.76		0.73
# 10	0.75		0.73
# 11	0.71		0.70
# 12	0.68		0.67
# 13	0.73		0.69
# 14	0.73		0.70
# 15	0.74		0.71
# 16	0.74		0.70
# 17	0.75		0.72
# 18	0.76		0.73
# 19	0.73		0.73
# 20	0.71		0.71
# t = 5 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 55 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.68
# 2	0.72		0.68
# 3	0.72		0.69
# 4	0.73		0.70
# 5	0.65		0.65
# 6	0.73		0.72
# 7	0.73		0.70
# 8	0.74		0.71
# 9	0.73		0.72
# 10	0.76		0.73
# 11	0.62		0.63
# 12	0.74		0.71
# 13	0.71		0.70
# 14	0.75		0.72
# 15	0.68		0.66
# 16	0.75		0.76
# 17	0.72		0.69
# 18	0.74		0.71
# 19	0.69		0.70
# 20	0.74		0.74
# t = 10 was best iteration with accuracy 0.73
#
# -----------------------------------------------
# 56 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.68
# 2	0.72		0.68
# 3	0.72		0.69
# 4	0.72		0.68
# 5	0.76		0.75
# 6	0.51		0.53
# 7	0.75		0.74
# 8	0.73		0.70
# 9	0.74		0.70
# 10	0.74		0.71
# 11	0.75		0.74
# 12	0.56		0.58
# 13	0.69		0.67
# 14	0.72		0.69
# 15	0.73		0.69
# 16	0.73		0.70
# 17	0.74		0.70
# 18	0.74		0.73
# 19	0.49		0.46
# 20	0.69		0.67
# t = 5 was best iteration with accuracy 0.75
#
# -----------------------------------------------
# 57 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.68
# 2	0.72		0.68
# 3	0.72		0.68
# 4	0.71		0.68
# 5	0.67		0.69
# 6	0.55		0.54
# 7	0.71		0.68
# 8	0.70		0.67
# 9	0.73		0.69
# 10	0.66		0.67
# 11	0.58		0.60
# 12	0.65		0.66
# 13	0.71		0.67
# 14	0.70		0.67
# 15	0.72		0.68
# 16	0.69		0.68
# 17	0.54		0.59
# 18	0.68		0.66
# 19	0.69		0.68
# 20	0.70		0.67
# t = 9 was best iteration with accuracy 0.69
#
# -----------------------------------------------
# 58 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.68
# 2	0.72		0.68
# 3	0.72		0.69
# 4	0.72		0.70
# 5	0.65		0.63
# 6	0.76		0.74
# 7	0.72		0.69
# 8	0.75		0.71
# 9	0.74		0.71
# 10	0.74		0.72
# 11	0.63		0.64
# 12	0.75		0.76
# 13	0.73		0.70
# 14	0.75		0.74
# 15	0.73		0.70
# 16	0.71		0.72
# 17	0.66		0.66
# 18	0.76		0.76
# 19	0.75		0.71
# 20	0.73		0.74
# t = 6 was best iteration with accuracy 0.74
#
# -----------------------------------------------
# 59 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.68
# 2	0.72		0.69
# 3	0.72		0.69
# 4	0.72		0.69
# 5	0.75		0.71
# 6	0.45		0.44
# 7	0.76		0.75
# 8	0.73		0.70
# 9	0.73		0.69
# 10	0.74		0.71
# 11	0.74		0.72
# 12	0.74		0.74
# 13	0.63		0.62
# 14	0.77		0.76
# 15	0.76		0.72
# 16	0.73		0.71
# 17	0.78		0.77
# 18	0.70		0.68
# 19	0.77		0.77
# 20	0.69		0.67
# t = 17 was best iteration with accuracy 0.77
#
# -----------------------------------------------
# 60 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.68
# 2	0.72		0.68
# 3	0.72		0.68
# 4	0.72		0.68
# 5	0.71		0.71
# 6	0.53		0.55
# 7	0.74		0.76
# 8	0.74		0.71
# 9	0.75		0.71
# 10	0.72		0.72
# 11	0.71		0.71
# 12	0.59		0.62
# 13	0.75		0.72
# 14	0.73		0.71
# 15	0.74		0.71
# 16	0.74		0.71
# 17	0.74		0.73
# 18	0.59		0.63
# 19	0.73		0.70
# 20	0.74		0.70
# t = 13 was best iteration with accuracy 0.72
#
# -----------------------------------------------
# 61 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.68
# 2	0.72		0.68
# 3	0.71		0.68
# 4	0.72		0.69
# 5	0.66		0.65
# 6	0.52		0.53
# 7	0.68		0.67
# 8	0.71		0.67
# 9	0.68		0.67
# 10	0.68		0.66
# 11	0.62		0.64
# 12	0.66		0.69
# 13	0.68		0.67
# 14	0.70		0.67
# 15	0.66		0.65
# 16	0.60		0.64
# 17	0.66		0.67
# 18	0.70		0.67
# 19	0.67		0.66
# 20	0.65		0.68
# t = 4 was best iteration with accuracy 0.69
#
# -----------------------------------------------
# 62 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.68
# 2	0.72		0.67
# 3	0.72		0.68
# 4	0.71		0.68
# 5	0.73		0.69
# 6	0.65		0.68
# 7	0.58		0.60
# 8	0.71		0.69
# 9	0.72		0.67
# 10	0.71		0.68
# 11	0.58		0.61
# 12	0.73		0.74
# 13	0.72		0.67
# 14	0.71		0.68
# 15	0.70		0.68
# 16	0.72		0.72
# 17	0.61		0.62
# 18	0.73		0.71
# 19	0.73		0.69
# 20	0.72		0.70
# t = 12 was best iteration with accuracy 0.74
#
# -----------------------------------------------
# 63 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.67
# 2	0.71		0.67
# 3	0.71		0.67
# 4	0.70		0.67
# 5	0.60		0.58
# 6	0.61		0.60
# 7	0.65		0.61
# 8	0.70		0.67
# 9	0.71		0.67
# 10	0.70		0.67
# 11	0.66		0.65
# 12	0.43		0.44
# 13	0.64		0.67
# 14	0.72		0.67
# 15	0.71		0.67
# 16	0.71		0.67
# 17	0.70		0.67
# 18	0.67		0.64
# 19	0.26		0.26
# 20	0.78		0.77
# t = 20 was best iteration with accuracy 0.77
#
# -----------------------------------------------
# 64 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.68
# 2	0.72		0.69
# 3	0.72		0.69
# 4	0.73		0.70
# 5	0.49		0.49
# 6	0.72		0.68
# 7	0.72		0.68
# 8	0.72		0.68
# 9	0.72		0.68
# 10	0.72		0.69
# 11	0.72		0.69
# 12	0.73		0.70
# 13	0.74		0.76
# 14	0.62		0.62
# 15	0.71		0.68
# 16	0.74		0.70
# 17	0.70		0.69
# 18	0.69		0.70
# 19	0.66		0.65
# 20	0.73		0.70
# t = 13 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 65 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.68
# 2	0.70		0.67
# 3	0.70		0.67
# 4	0.70		0.67
# 5	0.47		0.49
# 6	0.53		0.54
# 7	0.67		0.67
# 8	0.69		0.66
# 9	0.66		0.65
# 10	0.58		0.57
# 11	0.45		0.44
# 12	0.62		0.64
# 13	0.68		0.67
# 14	0.68		0.65
# 15	0.63		0.63
# 16	0.50		0.48
# 17	0.65		0.66
# 18	0.70		0.67
# 19	0.69		0.68
# 20	0.70		0.66
# t = 1 was best iteration with accuracy 0.68
#
# -----------------------------------------------
# 66 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.68
# 2	0.72		0.68
# 3	0.72		0.68
# 4	0.72		0.69
# 5	0.73		0.69
# 6	0.70		0.70
# 7	0.71		0.68
# 8	0.72		0.70
# 9	0.73		0.70
# 10	0.74		0.71
# 11	0.55		0.56
# 12	0.76		0.77
# 13	0.76		0.72
# 14	0.74		0.71
# 15	0.76		0.74
# 16	0.71		0.70
# 17	0.71		0.71
# 18	0.66		0.64
# 19	0.75		0.71
# 20	0.75		0.74
# t = 13 was best iteration with accuracy 0.72
#
# -----------------------------------------------
# 67 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.68
# 2	0.70		0.67
# 3	0.70		0.67
# 4	0.70		0.67
# 5	0.61		0.59
# 6	0.37		0.37
# 7	0.67		0.66
# 8	0.69		0.65
# 9	0.66		0.65
# 10	0.59		0.59
# 11	0.62		0.62
# 12	0.61		0.65
# 13	0.66		0.65
# 14	0.64		0.62
# 15	0.65		0.65
# 16	0.60		0.61
# 17	0.64		0.65
# 18	0.62		0.62
# 19	0.66		0.65
# 20	0.64		0.63
# t = 1 was best iteration with accuracy 0.68
#
# -----------------------------------------------
# 68 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.68
# 2	0.71		0.67
# 3	0.72		0.68
# 4	0.71		0.68
# 5	0.51		0.49
# 6	0.66		0.65
# 7	0.71		0.68
# 8	0.71		0.68
# 9	0.70		0.67
# 10	0.70		0.66
# 11	0.68		0.66
# 12	0.55		0.55
# 13	0.71		0.71
# 14	0.72		0.68
# 15	0.70		0.67
# 16	0.72		0.68
# 17	0.72		0.70
# 18	0.55		0.59
# 19	0.73		0.74
# 20	0.73		0.69
# t = 19 was best iteration with accuracy 0.74
#
# -----------------------------------------------
# 69 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.68
# 2	0.71		0.67
# 3	0.71		0.67
# 4	0.71		0.67
# 5	0.33		0.35
# 6	0.69		0.65
# 7	0.72		0.68
# 8	0.72		0.70
# 9	0.73		0.69
# 10	0.77		0.78
# 11	0.58		0.60
# 12	0.78		0.76
# 13	0.74		0.71
# 14	0.76		0.73
# 15	0.73		0.73
# 16	0.71		0.71
# 17	0.70		0.73
# 18	0.75		0.73
# 19	0.74		0.70
# 20	0.76		0.75
# t = 12 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 70 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.68
# 2	0.72		0.69
# 3	0.72		0.69
# 4	0.73		0.70
# 5	0.69		0.65
# 6	0.61		0.63
# 7	0.66		0.67
# 8	0.73		0.69
# 9	0.71		0.68
# 10	0.75		0.71
# 11	0.68		0.69
# 12	0.66		0.68
# 13	0.67		0.67
# 14	0.75		0.73
# 15	0.71		0.68
# 16	0.78		0.78
# 17	0.68		0.67
# 18	0.73		0.72
# 19	0.71		0.70
# 20	0.79		0.78
# t = 20 was best iteration with accuracy 0.78
#
# -----------------------------------------------
# 71 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.68
# 2	0.70		0.67
# 3	0.71		0.67
# 4	0.70		0.67
# 5	0.65		0.62
# 6	0.49		0.48
# 7	0.66		0.68
# 8	0.69		0.67
# 9	0.70		0.66
# 10	0.67		0.65
# 11	0.48		0.52
# 12	0.39		0.39
# 13	0.63		0.66
# 14	0.70		0.67
# 15	0.70		0.66
# 16	0.69		0.66
# 17	0.68		0.65
# 18	0.59		0.59
# 19	0.32		0.33
# 20	0.62		0.60
# t = 1 was best iteration with accuracy 0.68
#
# -----------------------------------------------
# 72 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.68
# 2	0.72		0.68
# 3	0.71		0.68
# 4	0.72		0.68
# 5	0.66		0.65
# 6	0.52		0.54
# 7	0.68		0.66
# 8	0.72		0.68
# 9	0.70		0.67
# 10	0.71		0.67
# 11	0.71		0.69
# 12	0.59		0.62
# 13	0.71		0.69
# 14	0.71		0.68
# 15	0.71		0.68
# 16	0.58		0.60
# 17	0.74		0.74
# 18	0.72		0.67
# 19	0.70		0.67
# 20	0.70		0.66
# t = 17 was best iteration with accuracy 0.74
#
# -----------------------------------------------
# 73 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.68
# 2	0.72		0.69
# 3	0.72		0.69
# 4	0.73		0.70
# 5	0.72		0.69
# 6	0.62		0.59
# 7	0.67		0.66
# 8	0.72		0.69
# 9	0.73		0.70
# 10	0.74		0.70
# 11	0.74		0.71
# 12	0.76		0.72
# 13	0.71		0.71
# 14	0.63		0.63
# 15	0.78		0.78
# 16	0.75		0.70
# 17	0.72		0.74
# 18	0.70		0.67
# 19	0.70		0.70
# 20	0.69		0.69
# t = 15 was best iteration with accuracy 0.78
#
# -----------------------------------------------
# 74 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.68
# 2	0.72		0.68
# 3	0.72		0.68
# 4	0.70		0.68
# 5	0.48		0.47
# 6	0.67		0.67
# 7	0.71		0.69
# 8	0.70		0.67
# 9	0.71		0.67
# 10	0.69		0.67
# 11	0.60		0.59
# 12	0.68		0.68
# 13	0.62		0.61
# 14	0.70		0.67
# 15	0.70		0.67
# 16	0.69		0.67
# 17	0.54		0.57
# 18	0.71		0.72
# 19	0.71		0.67
# 20	0.70		0.67
# t = 3 was best iteration with accuracy 0.68
#
# -----------------------------------------------
# 75 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.68
# 2	0.72		0.68
# 3	0.71		0.68
# 4	0.72		0.68
# 5	0.69		0.68
# 6	0.50		0.52
# 7	0.70		0.68
# 8	0.72		0.68
# 9	0.71		0.69
# 10	0.71		0.70
# 11	0.72		0.73
# 12	0.60		0.61
# 13	0.71		0.69
# 14	0.73		0.68
# 15	0.70		0.68
# 16	0.65		0.65
# 17	0.69		0.67
# 18	0.70		0.65
# 19	0.69		0.67
# 20	0.70		0.66
# t = 14 was best iteration with accuracy 0.68
#
# -----------------------------------------------
# 76 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.68
# 2	0.72		0.68
# 3	0.71		0.67
# 4	0.71		0.67
# 5	0.69		0.67
# 6	0.37		0.38
# 7	0.76		0.77
# 8	0.76		0.73
# 9	0.74		0.71
# 10	0.76		0.73
# 11	0.75		0.73
# 12	0.73		0.74
# 13	0.69		0.67
# 14	0.70		0.70
# 15	0.71		0.69
# 16	0.78		0.79
# 17	0.71		0.67
# 18	0.74		0.73
# 19	0.67		0.67
# 20	0.76		0.74
# t = 16 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 77 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.68
# 2	0.71		0.68
# 3	0.72		0.69
# 4	0.71		0.68
# 5	0.36		0.36
# 6	0.71		0.68
# 7	0.71		0.67
# 8	0.71		0.68
# 9	0.71		0.67
# 10	0.70		0.67
# 11	0.70		0.67
# 12	0.68		0.66
# 13	0.41		0.43
# 14	0.61		0.60
# 15	0.72		0.68
# 16	0.71		0.68
# 17	0.72		0.67
# 18	0.71		0.68
# 19	0.68		0.65
# 20	0.74		0.75
# t = 20 was best iteration with accuracy 0.75
#
# -----------------------------------------------
# 78 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.68
# 2	0.72		0.68
# 3	0.72		0.69
# 4	0.71		0.68
# 5	0.58		0.57
# 6	0.65		0.64
# 7	0.71		0.68
# 8	0.70		0.67
# 9	0.70		0.67
# 10	0.67		0.65
# 11	0.40		0.42
# 12	0.66		0.67
# 13	0.71		0.67
# 14	0.70		0.67
# 15	0.70		0.67
# 16	0.68		0.66
# 17	0.29		0.30
# 18	0.69		0.67
# 19	0.71		0.67
# 20	0.71		0.67
# t = 2 was best iteration with accuracy 0.68
#
# -----------------------------------------------
# 79 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.68
# 2	0.72		0.68
# 3	0.72		0.69
# 4	0.72		0.68
# 5	0.76		0.75
# 6	0.45		0.45
# 7	0.76		0.77
# 8	0.75		0.71
# 9	0.75		0.73
# 10	0.76		0.73
# 11	0.71		0.70
# 12	0.75		0.73
# 13	0.67		0.65
# 14	0.75		0.72
# 15	0.72		0.71
# 16	0.76		0.74
# 17	0.68		0.67
# 18	0.76		0.77
# 19	0.74		0.71
# 20	0.75		0.71
# t = 5 was best iteration with accuracy 0.75
#
# -----------------------------------------------
# 80 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.68
# 2	0.72		0.68
# 3	0.71		0.68
# 4	0.73		0.70
# 5	0.65		0.64
# 6	0.62		0.66
# 7	0.70		0.69
# 8	0.72		0.69
# 9	0.69		0.68
# 10	0.71		0.70
# 11	0.65		0.63
# 12	0.65		0.66
# 13	0.68		0.68
# 14	0.72		0.68
# 15	0.68		0.67
# 16	0.60		0.62
# 17	0.67		0.67
# 18	0.69		0.66
# 19	0.69		0.68
# 20	0.70		0.66
# t = 4 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 81 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.68
# 2	0.71		0.68
# 3	0.71		0.68
# 4	0.71		0.67
# 5	0.53		0.54
# 6	0.66		0.65
# 7	0.69		0.67
# 8	0.69		0.66
# 9	0.68		0.66
# 10	0.65		0.64
# 11	0.57		0.57
# 12	0.30		0.30
# 13	0.39		0.41
# 14	0.68		0.65
# 15	0.70		0.67
# 16	0.70		0.66
# 17	0.69		0.66
# 18	0.53		0.55
# 19	0.36		0.34
# 20	0.66		0.66
# t = 2 was best iteration with accuracy 0.68
#
# -----------------------------------------------
# 82 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.68
# 2	0.71		0.68
# 3	0.72		0.68
# 4	0.72		0.69
# 5	0.53		0.54
# 6	0.73		0.74
# 7	0.75		0.71
# 8	0.73		0.69
# 9	0.74		0.71
# 10	0.75		0.71
# 11	0.73		0.70
# 12	0.71		0.70
# 13	0.60		0.60
# 14	0.70		0.68
# 15	0.72		0.68
# 16	0.70		0.68
# 17	0.67		0.67
# 18	0.68		0.65
# 19	0.72		0.69
# 20	0.71		0.69
# t = 7 was best iteration with accuracy 0.71
#
# -----------------------------------------------
# 83 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.68
# 2	0.72		0.68
# 3	0.71		0.68
# 4	0.72		0.68
# 5	0.72		0.70
# 6	0.50		0.53
# 7	0.73		0.74
# 8	0.72		0.69
# 9	0.72		0.69
# 10	0.76		0.72
# 11	0.70		0.66
# 12	0.64		0.67
# 13	0.66		0.64
# 14	0.74		0.70
# 15	0.71		0.68
# 16	0.75		0.72
# 17	0.71		0.69
# 18	0.65		0.69
# 19	0.65		0.65
# 20	0.74		0.70
# t = 10 was best iteration with accuracy 0.72
#
# -----------------------------------------------
# 84 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.68
# 2	0.71		0.67
# 3	0.71		0.68
# 4	0.71		0.68
# 5	0.64		0.62
# 6	0.52		0.51
# 7	0.70		0.68
# 8	0.72		0.68
# 9	0.70		0.68
# 10	0.69		0.67
# 11	0.68		0.66
# 12	0.62		0.62
# 13	0.71		0.69
# 14	0.70		0.68
# 15	0.70		0.68
# 16	0.52		0.57
# 17	0.74		0.75
# 18	0.73		0.70
# 19	0.72		0.69
# 20	0.74		0.71
# t = 20 was best iteration with accuracy 0.71
#
# -----------------------------------------------
# 85 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.67
# 2	0.71		0.67
# 3	0.71		0.68
# 4	0.72		0.68
# 5	0.69		0.68
# 6	0.46		0.50
# 7	0.72		0.73
# 8	0.72		0.68
# 9	0.71		0.68
# 10	0.68		0.65
# 11	0.73		0.73
# 12	0.63		0.62
# 13	0.71		0.69
# 14	0.71		0.66
# 15	0.70		0.68
# 16	0.68		0.65
# 17	0.70		0.67
# 18	0.68		0.63
# 19	0.70		0.68
# 20	0.71		0.67
# t = 11 was best iteration with accuracy 0.73
#
# -----------------------------------------------
# 86 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.68
# 2	0.72		0.69
# 3	0.72		0.68
# 4	0.72		0.69
# 5	0.64		0.64
# 6	0.72		0.74
# 7	0.72		0.69
# 8	0.72		0.70
# 9	0.72		0.68
# 10	0.75		0.74
# 11	0.66		0.66
# 12	0.75		0.73
# 13	0.73		0.71
# 14	0.76		0.72
# 15	0.69		0.68
# 16	0.76		0.77
# 17	0.69		0.70
# 18	0.75		0.72
# 19	0.70		0.69
# 20	0.75		0.75
# t = 14 was best iteration with accuracy 0.72
#
# -----------------------------------------------
# 87 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.68
# 2	0.72		0.68
# 3	0.71		0.68
# 4	0.72		0.68
# 5	0.68		0.66
# 6	0.48		0.50
# 7	0.71		0.71
# 8	0.72		0.69
# 9	0.71		0.68
# 10	0.73		0.70
# 11	0.71		0.69
# 12	0.54		0.54
# 13	0.66		0.66
# 14	0.73		0.69
# 15	0.71		0.67
# 16	0.73		0.69
# 17	0.70		0.69
# 18	0.64		0.66
# 19	0.65		0.65
# 20	0.73		0.69
# t = 10 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 88 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.68
# 2	0.72		0.68
# 3	0.72		0.69
# 4	0.72		0.68
# 5	0.67		0.67
# 6	0.70		0.66
# 7	0.72		0.68
# 8	0.73		0.69
# 9	0.72		0.70
# 10	0.73		0.70
# 11	0.77		0.75
# 12	0.63		0.64
# 13	0.75		0.73
# 14	0.73		0.70
# 15	0.78		0.75
# 16	0.69		0.68
# 17	0.76		0.76
# 18	0.71		0.70
# 19	0.77		0.74
# 20	0.70		0.69
# t = 15 was best iteration with accuracy 0.75
#
# -----------------------------------------------
# 89 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.68
# 2	0.71		0.67
# 3	0.71		0.67
# 4	0.71		0.68
# 5	0.67		0.68
# 6	0.53		0.55
# 7	0.75		0.77
# 8	0.73		0.71
# 9	0.73		0.71
# 10	0.71		0.71
# 11	0.75		0.76
# 12	0.67		0.67
# 13	0.75		0.71
# 14	0.71		0.71
# 15	0.77		0.75
# 16	0.69		0.69
# 17	0.76		0.77
# 18	0.71		0.70
# 19	0.75		0.72
# 20	0.71		0.70
# t = 15 was best iteration with accuracy 0.75
#
# -----------------------------------------------
# 90 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.67
# 2	0.71		0.68
# 3	0.71		0.67
# 4	0.71		0.68
# 5	0.58		0.56
# 6	0.73		0.70
# 7	0.73		0.70
# 8	0.75		0.72
# 9	0.75		0.71
# 10	0.73		0.73
# 11	0.66		0.64
# 12	0.68		0.70
# 13	0.74		0.71
# 14	0.76		0.76
# 15	0.74		0.70
# 16	0.71		0.72
# 17	0.65		0.64
# 18	0.75		0.74
# 19	0.74		0.70
# 20	0.74		0.75
# t = 14 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 91 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.68
# 2	0.72		0.69
# 3	0.72		0.69
# 4	0.72		0.68
# 5	0.77		0.76
# 6	0.63		0.62
# 7	0.74		0.71
# 8	0.72		0.70
# 9	0.76		0.74
# 10	0.74		0.69
# 11	0.70		0.72
# 12	0.66		0.64
# 13	0.73		0.71
# 14	0.74		0.70
# 15	0.75		0.72
# 16	0.75		0.74
# 17	0.68		0.64
# 18	0.76		0.77
# 19	0.74		0.71
# 20	0.77		0.75
# t = 5 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 92 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.68
# 2	0.71		0.67
# 3	0.71		0.68
# 4	0.71		0.67
# 5	0.32		0.33
# 6	0.70		0.68
# 7	0.71		0.68
# 8	0.71		0.67
# 9	0.71		0.67
# 10	0.71		0.67
# 11	0.70		0.66
# 12	0.69		0.67
# 13	0.63		0.62
# 14	0.29		0.29
# 15	0.58		0.58
# 16	0.67		0.65
# 17	0.64		0.62
# 18	0.60		0.60
# 19	0.35		0.34
# 20	0.66		0.64
# t = 1 was best iteration with accuracy 0.68
#
# -----------------------------------------------
# 93 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.68
# 2	0.72		0.68
# 3	0.72		0.69
# 4	0.72		0.68
# 5	0.75		0.71
# 6	0.56		0.57
# 7	0.76		0.76
# 8	0.75		0.71
# 9	0.75		0.74
# 10	0.75		0.72
# 11	0.68		0.68
# 12	0.68		0.67
# 13	0.76		0.72
# 14	0.73		0.71
# 15	0.76		0.72
# 16	0.76		0.73
# 17	0.71		0.71
# 18	0.75		0.74
# 19	0.70		0.67
# 20	0.75		0.72
# t = 7 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 94 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.68
# 2	0.72		0.68
# 3	0.71		0.67
# 4	0.71		0.67
# 5	0.68		0.66
# 6	0.38		0.39
# 7	0.74		0.75
# 8	0.74		0.70
# 9	0.72		0.70
# 10	0.76		0.76
# 11	0.73		0.69
# 12	0.64		0.67
# 13	0.68		0.67
# 14	0.75		0.73
# 15	0.74		0.71
# 16	0.76		0.74
# 17	0.71		0.67
# 18	0.68		0.69
# 19	0.68		0.67
# 20	0.75		0.74
# t = 10 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 95 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.68
# 2	0.72		0.68
# 3	0.72		0.69
# 4	0.72		0.69
# 5	0.71		0.68
# 6	0.59		0.63
# 7	0.69		0.66
# 8	0.71		0.67
# 9	0.70		0.66
# 10	0.68		0.66
# 11	0.53		0.53
# 12	0.51		0.49
# 13	0.68		0.65
# 14	0.70		0.67
# 15	0.69		0.66
# 16	0.66		0.65
# 17	0.36		0.35
# 18	0.44		0.43
# 19	0.76		0.76
# 20	0.72		0.70
# t = 19 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 96 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.68
# 2	0.72		0.69
# 3	0.72		0.69
# 4	0.72		0.69
# 5	0.78		0.76
# 6	0.48		0.47
# 7	0.76		0.77
# 8	0.75		0.71
# 9	0.74		0.71
# 10	0.76		0.73
# 11	0.73		0.70
# 12	0.76		0.73
# 13	0.65		0.65
# 14	0.75		0.71
# 15	0.76		0.73
# 16	0.76		0.74
# 17	0.73		0.71
# 18	0.71		0.71
# 19	0.70		0.68
# 20	0.73		0.73
# t = 5 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 97 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.68
# 2	0.71		0.68
# 3	0.72		0.68
# 4	0.71		0.68
# 5	0.70		0.67
# 6	0.65		0.64
# 7	0.68		0.65
# 8	0.70		0.68
# 9	0.72		0.67
# 10	0.70		0.68
# 11	0.52		0.58
# 12	0.73		0.74
# 13	0.72		0.69
# 14	0.72		0.69
# 15	0.72		0.69
# 16	0.73		0.69
# 17	0.39		0.39
# 18	0.70		0.67
# 19	0.71		0.67
# 20	0.71		0.68
# t = 12 was best iteration with accuracy 0.74
#
# -----------------------------------------------
# 98 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.68
# 2	0.71		0.68
# 3	0.70		0.67
# 4	0.71		0.67
# 5	0.59		0.59
# 6	0.60		0.62
# 7	0.65		0.65
# 8	0.67		0.64
# 9	0.66		0.65
# 10	0.53		0.53
# 11	0.65		0.64
# 12	0.59		0.59
# 13	0.66		0.65
# 14	0.62		0.61
# 15	0.65		0.65
# 16	0.55		0.56
# 17	0.64		0.65
# 18	0.59		0.59
# 19	0.66		0.65
# 20	0.58		0.57
# t = 1 was best iteration with accuracy 0.68
#
# -----------------------------------------------
# 99 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.68
# 2	0.72		0.69
# 3	0.72		0.69
# 4	0.72		0.68
# 5	0.79		0.78
# 6	0.63		0.63
# 7	0.73		0.70
# 8	0.75		0.73
# 9	0.75		0.72
# 10	0.75		0.73
# 11	0.70		0.67
# 12	0.66		0.65
# 13	0.70		0.69
# 14	0.78		0.77
# 15	0.73		0.69
# 16	0.72		0.71
# 17	0.69		0.67
# 18	0.72		0.72
# 19	0.73		0.69
# 20	0.77		0.77
# t = 5 was best iteration with accuracy 0.78
#
# -----------------------------------------------
# 100 / 100 complete
# -----------------------------------------------

# %%
table_results(svm_arr, tree_arr)
# Out:
# (Performance on test set)
#
# 50 comparisons
# 	acc	sderr
# SVM: 	75.4	0.4
# Tree: 	nan	nan
#
# 200 comparisons
# 	acc	sderr
# SVM: 	72.9	0.7
# Tree: 	nan	nan
