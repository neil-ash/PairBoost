# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_svmlight_file
from sklearn.model_selection import train_test_split
import sys; sys.path.insert(0,'..')
from main import *

# %%
X, y = load_svmlight_file('../data/phishing/phishing.txt')
X = X.toarray()

# Convert labels from {0, 1} to {-1, 1}
y = y * 2 - 1

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.5, stratify=y, 
                                                    shuffle=True, random_state=1)

# %%
svm_arr, tree_arr = data_size_experiment(X_train, y_train, X_test, y_test,
                                         experiment_type='table', kernel='linear',
                                         random_state=1, verbose=True)
# Out:
# Progress:
# Training accuracy of rank SVM: 1.00
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# /Users/Ashtekar15/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# t	Train		Test
# 1	0.93		0.91
# 2	0.88		0.83
# 3	0.89		0.88
# 4	0.47		0.45
# 5	0.87		0.89
# 6	0.85		0.81
# 7	0.92		0.91
# 8	0.52		0.48
# 9	0.86		0.86
# 10	0.78		0.76
# 11	0.91		0.91
# 12	0.59		0.59
# 13	0.89		0.88
# 14	0.69		0.66
# 15	0.91		0.90
# 16	0.67		0.63
# 17	0.85		0.85
# 18	0.67		0.64
# 19	0.87		0.88
# 20	0.65		0.61
# t = 1 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 1 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.91
# 2	0.88		0.83
# 3	0.92		0.92
# 4	0.46		0.41
# 5	0.91		0.91
# 6	0.73		0.68
# 7	0.89		0.90
# 8	0.57		0.57
# 9	0.89		0.90
# 10	0.73		0.71
# 11	0.91		0.92
# 12	0.65		0.59
# 13	0.86		0.86
# 14	0.70		0.66
# 15	0.90		0.90
# 16	0.67		0.61
# 17	0.87		0.87
# 18	0.71		0.65
# 19	0.90		0.89
# 20	0.65		0.61
# t = 1 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 2 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.92		0.89
# 2	0.91		0.88
# 3	0.92		0.90
# 4	0.48		0.49
# 5	0.82		0.83
# 6	0.91		0.88
# 7	0.93		0.90
# 8	0.74		0.73
# 9	0.76		0.78
# 10	0.80		0.79
# 11	0.93		0.92
# 12	0.67		0.63
# 13	0.84		0.85
# 14	0.73		0.67
# 15	0.91		0.92
# 16	0.65		0.61
# 17	0.85		0.85
# 18	0.72		0.67
# 19	0.91		0.93
# 20	0.61		0.56
# t = 11 was best iteration with accuracy 0.92
#
# -----------------------------------------------
# 3 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.91
# 2	0.89		0.87
# 3	0.85		0.88
# 4	0.57		0.51
# 5	0.88		0.89
# 6	0.91		0.88
# 7	0.92		0.91
# 8	0.71		0.68
# 9	0.80		0.85
# 10	0.82		0.80
# 11	0.89		0.87
# 12	0.78		0.74
# 13	0.82		0.83
# 14	0.85		0.82
# 15	0.86		0.86
# 16	0.79		0.74
# 17	0.82		0.81
# 18	0.82		0.79
# 19	0.83		0.80
# 20	0.81		0.78
# t = 1 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 4 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.91
# 2	0.88		0.85
# 3	0.92		0.91
# 4	0.27		0.26
# 5	0.91		0.91
# 6	0.89		0.85
# 7	0.89		0.87
# 8	0.81		0.75
# 9	0.79		0.77
# 10	0.89		0.87
# 11	0.92		0.88
# 12	0.87		0.84
# 13	0.82		0.81
# 14	0.80		0.77
# 15	0.90		0.88
# 16	0.88		0.84
# 17	0.88		0.88
# 18	0.73		0.73
# 19	0.83		0.83
# 20	0.87		0.83
# t = 1 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 5 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.92		0.91
# 2	0.89		0.85
# 3	0.91		0.90
# 4	0.48		0.43
# 5	0.93		0.92
# 6	0.87		0.81
# 7	0.90		0.88
# 8	0.48		0.48
# 9	0.90		0.88
# 10	0.83		0.80
# 11	0.90		0.88
# 12	0.64		0.63
# 13	0.87		0.88
# 14	0.76		0.72
# 15	0.90		0.90
# 16	0.66		0.62
# 17	0.87		0.87
# 18	0.77		0.74
# 19	0.91		0.90
# 20	0.74		0.70
# t = 5 was best iteration with accuracy 0.92
#
# -----------------------------------------------
# 6 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.91
# 2	0.89		0.84
# 3	0.91		0.91
# 4	0.46		0.44
# 5	0.91		0.91
# 6	0.83		0.81
# 7	0.90		0.90
# 8	0.63		0.62
# 9	0.85		0.87
# 10	0.79		0.76
# 11	0.87		0.86
# 12	0.75		0.72
# 13	0.86		0.86
# 14	0.69		0.64
# 15	0.90		0.89
# 16	0.71		0.71
# 17	0.91		0.90
# 18	0.75		0.73
# 19	0.88		0.88
# 20	0.70		0.67
# t = 1 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 7 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.91
# 2	0.88		0.86
# 3	0.91		0.91
# 4	0.30		0.27
# 5	0.90		0.91
# 6	0.85		0.80
# 7	0.88		0.88
# 8	0.63		0.61
# 9	0.91		0.90
# 10	0.79		0.78
# 11	0.88		0.88
# 12	0.66		0.67
# 13	0.89		0.88
# 14	0.74		0.72
# 15	0.90		0.88
# 16	0.74		0.71
# 17	0.87		0.86
# 18	0.78		0.77
# 19	0.84		0.83
# 20	0.74		0.74
# t = 1 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 8 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.90
# 2	0.90		0.86
# 3	0.93		0.92
# 4	0.33		0.33
# 5	0.91		0.92
# 6	0.89		0.84
# 7	0.92		0.90
# 8	0.54		0.53
# 9	0.84		0.86
# 10	0.86		0.85
# 11	0.93		0.90
# 12	0.77		0.75
# 13	0.77		0.77
# 14	0.75		0.75
# 15	0.86		0.88
# 16	0.75		0.75
# 17	0.87		0.87
# 18	0.76		0.75
# 19	0.89		0.89
# 20	0.77		0.77
# t = 1 was best iteration with accuracy 0.90
#
# -----------------------------------------------
# 9 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.94		0.91
# 2	0.88		0.85
# 3	0.93		0.91
# 4	0.35		0.36
# 5	0.89		0.90
# 6	0.91		0.87
# 7	0.91		0.90
# 8	0.60		0.56
# 9	0.82		0.81
# 10	0.92		0.88
# 11	0.93		0.89
# 12	0.89		0.85
# 13	0.59		0.58
# 14	0.73		0.73
# 15	0.92		0.87
# 16	0.92		0.89
# 17	0.87		0.83
# 18	0.57		0.58
# 19	0.81		0.79
# 20	0.89		0.85
# t = 1 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 10 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.90
# 2	0.88		0.85
# 3	0.91		0.91
# 4	0.31		0.26
# 5	0.86		0.89
# 6	0.92		0.89
# 7	0.93		0.88
# 8	0.91		0.88
# 9	0.70		0.68
# 10	0.75		0.73
# 11	0.92		0.89
# 12	0.91		0.88
# 13	0.81		0.80
# 14	0.57		0.59
# 15	0.88		0.87
# 16	0.81		0.80
# 17	0.88		0.86
# 18	0.67		0.69
# 19	0.83		0.84
# 20	0.72		0.72
# t = 1 was best iteration with accuracy 0.90
#
# -----------------------------------------------
# 11 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.91
# 2	0.89		0.85
# 3	0.91		0.91
# 4	0.41		0.37
# 5	0.88		0.89
# 6	0.89		0.88
# 7	0.86		0.87
# 8	0.70		0.70
# 9	0.86		0.85
# 10	0.80		0.81
# 11	0.86		0.86
# 12	0.78		0.77
# 13	0.90		0.89
# 14	0.82		0.80
# 15	0.85		0.84
# 16	0.74		0.73
# 17	0.88		0.88
# 18	0.78		0.77
# 19	0.78		0.79
# 20	0.73		0.71
# t = 1 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 12 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.89
# 2	0.90		0.87
# 3	0.92		0.90
# 4	0.27		0.25
# 5	0.89		0.90
# 6	0.88		0.85
# 7	0.91		0.89
# 8	0.57		0.60
# 9	0.86		0.87
# 10	0.92		0.89
# 11	0.89		0.87
# 12	0.72		0.73
# 13	0.69		0.69
# 14	0.87		0.86
# 15	0.93		0.90
# 16	0.79		0.80
# 17	0.71		0.70
# 18	0.73		0.75
# 19	0.93		0.91
# 20	0.75		0.72
# t = 19 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 13 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.89
# 2	0.88		0.85
# 3	0.92		0.92
# 4	0.22		0.21
# 5	0.89		0.90
# 6	0.92		0.87
# 7	0.86		0.83
# 8	0.74		0.72
# 9	0.67		0.68
# 10	0.90		0.86
# 11	0.86		0.83
# 12	0.85		0.87
# 13	0.52		0.53
# 14	0.80		0.83
# 15	0.83		0.83
# 16	0.89		0.88
# 17	0.61		0.60
# 18	0.84		0.83
# 19	0.80		0.77
# 20	0.89		0.85
# t = 1 was best iteration with accuracy 0.89
#
# -----------------------------------------------
# 14 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.91
# 2	0.89		0.85
# 3	0.87		0.88
# 4	0.45		0.41
# 5	0.91		0.91
# 6	0.87		0.85
# 7	0.89		0.89
# 8	0.32		0.32
# 9	0.88		0.90
# 10	0.83		0.81
# 11	0.85		0.84
# 12	0.75		0.72
# 13	0.83		0.84
# 14	0.83		0.81
# 15	0.89		0.89
# 16	0.67		0.66
# 17	0.81		0.81
# 18	0.82		0.80
# 19	0.92		0.90
# 20	0.75		0.75
# t = 1 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 15 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.90
# 2	0.87		0.82
# 3	0.89		0.90
# 4	0.54		0.52
# 5	0.88		0.88
# 6	0.85		0.79
# 7	0.90		0.91
# 8	0.59		0.57
# 9	0.78		0.80
# 10	0.84		0.80
# 11	0.91		0.90
# 12	0.61		0.61
# 13	0.78		0.77
# 14	0.85		0.82
# 15	0.89		0.88
# 16	0.58		0.57
# 17	0.81		0.81
# 18	0.82		0.77
# 19	0.93		0.91
# 20	0.64		0.62
# t = 19 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 16 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.94		0.91
# 2	0.86		0.80
# 3	0.88		0.91
# 4	0.50		0.42
# 5	0.88		0.89
# 6	0.77		0.73
# 7	0.83		0.85
# 8	0.58		0.56
# 9	0.92		0.92
# 10	0.57		0.53
# 11	0.85		0.87
# 12	0.79		0.74
# 13	0.93		0.91
# 14	0.50		0.49
# 15	0.84		0.86
# 16	0.83		0.77
# 17	0.85		0.83
# 18	0.62		0.57
# 19	0.72		0.73
# 20	0.62		0.55
# t = 1 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 17 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.91
# 2	0.90		0.86
# 3	0.88		0.90
# 4	0.39		0.36
# 5	0.92		0.91
# 6	0.85		0.80
# 7	0.84		0.85
# 8	0.68		0.65
# 9	0.91		0.90
# 10	0.73		0.71
# 11	0.83		0.83
# 12	0.73		0.73
# 13	0.90		0.91
# 14	0.66		0.63
# 15	0.87		0.87
# 16	0.72		0.67
# 17	0.88		0.87
# 18	0.70		0.66
# 19	0.90		0.89
# 20	0.70		0.66
# t = 1 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 18 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.90
# 2	0.89		0.87
# 3	0.92		0.91
# 4	0.39		0.38
# 5	0.87		0.90
# 6	0.90		0.86
# 7	0.92		0.88
# 8	0.90		0.89
# 9	0.49		0.47
# 10	0.84		0.82
# 11	0.93		0.89
# 12	0.91		0.88
# 13	0.92		0.91
# 14	0.56		0.53
# 15	0.85		0.87
# 16	0.92		0.90
# 17	0.92		0.88
# 18	0.90		0.87
# 19	0.66		0.64
# 20	0.84		0.82
# t = 11 was best iteration with accuracy 0.89
#
# -----------------------------------------------
# 19 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.91
# 2	0.90		0.87
# 3	0.91		0.90
# 4	0.38		0.33
# 5	0.89		0.90
# 6	0.91		0.89
# 7	0.91		0.88
# 8	0.90		0.88
# 9	0.52		0.50
# 10	0.88		0.90
# 11	0.86		0.83
# 12	0.82		0.79
# 13	0.71		0.73
# 14	0.78		0.76
# 15	0.86		0.83
# 16	0.88		0.88
# 17	0.73		0.75
# 18	0.80		0.80
# 19	0.85		0.81
# 20	0.91		0.92
# t = 1 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 20 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.91
# 2	0.89		0.85
# 3	0.89		0.89
# 4	0.48		0.44
# 5	0.91		0.92
# 6	0.85		0.77
# 7	0.89		0.90
# 8	0.59		0.56
# 9	0.92		0.91
# 10	0.84		0.81
# 11	0.91		0.90
# 12	0.42		0.44
# 13	0.88		0.87
# 14	0.86		0.84
# 15	0.92		0.89
# 16	0.62		0.58
# 17	0.87		0.87
# 18	0.70		0.66
# 19	0.88		0.86
# 20	0.63		0.60
# t = 1 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 21 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.91
# 2	0.88		0.85
# 3	0.92		0.92
# 4	0.43		0.40
# 5	0.85		0.87
# 6	0.88		0.86
# 7	0.91		0.89
# 8	0.41		0.38
# 9	0.85		0.88
# 10	0.83		0.79
# 11	0.86		0.84
# 12	0.61		0.58
# 13	0.68		0.70
# 14	0.64		0.59
# 15	0.86		0.83
# 16	0.65		0.61
# 17	0.71		0.70
# 18	0.54		0.52
# 19	0.85		0.86
# 20	0.59		0.55
# t = 1 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 22 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.89
# 2	0.91		0.88
# 3	0.86		0.82
# 4	0.67		0.63
# 5	0.79		0.79
# 6	0.89		0.85
# 7	0.89		0.85
# 8	0.80		0.79
# 9	0.78		0.79
# 10	0.79		0.76
# 11	0.82		0.83
# 12	0.82		0.80
# 13	0.87		0.88
# 14	0.84		0.78
# 15	0.81		0.81
# 16	0.78		0.75
# 17	0.85		0.84
# 18	0.84		0.78
# 19	0.88		0.88
# 20	0.81		0.77
# t = 1 was best iteration with accuracy 0.89
#
# -----------------------------------------------
# 23 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.90
# 2	0.91		0.88
# 3	0.93		0.89
# 4	0.23		0.21
# 5	0.90		0.91
# 6	0.92		0.90
# 7	0.90		0.86
# 8	0.81		0.85
# 9	0.70		0.65
# 10	0.90		0.90
# 11	0.83		0.78
# 12	0.85		0.86
# 13	0.56		0.51
# 14	0.67		0.72
# 15	0.51		0.48
# 16	0.71		0.78
# 17	0.56		0.51
# 18	0.71		0.78
# 19	0.56		0.52
# 20	0.77		0.81
# t = 1 was best iteration with accuracy 0.90
#
# -----------------------------------------------
# 24 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.94		0.91
# 2	0.89		0.85
# 3	0.93		0.91
# 4	0.22		0.18
# 5	0.91		0.92
# 6	0.91		0.90
# 7	0.92		0.89
# 8	0.91		0.90
# 9	0.49		0.46
# 10	0.81		0.84
# 11	0.93		0.89
# 12	0.92		0.89
# 13	0.88		0.85
# 14	0.68		0.65
# 15	0.71		0.70
# 16	0.92		0.87
# 17	0.88		0.86
# 18	0.83		0.78
# 19	0.70		0.70
# 20	0.90		0.89
# t = 1 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 25 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.92		0.90
# 2	0.90		0.86
# 3	0.92		0.90
# 4	0.38		0.36
# 5	0.88		0.90
# 6	0.92		0.89
# 7	0.85		0.79
# 8	0.91		0.90
# 9	0.36		0.35
# 10	0.90		0.90
# 11	0.87		0.81
# 12	0.92		0.91
# 13	0.42		0.42
# 14	0.88		0.89
# 15	0.89		0.85
# 16	0.91		0.90
# 17	0.47		0.47
# 18	0.83		0.85
# 19	0.87		0.85
# 20	0.93		0.89
# t = 20 was best iteration with accuracy 0.89
#
# -----------------------------------------------
# 26 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.90
# 2	0.88		0.86
# 3	0.91		0.91
# 4	0.31		0.34
# 5	0.89		0.90
# 6	0.87		0.83
# 7	0.91		0.90
# 8	0.72		0.69
# 9	0.84		0.86
# 10	0.78		0.73
# 11	0.93		0.90
# 12	0.83		0.78
# 13	0.81		0.82
# 14	0.74		0.71
# 15	0.88		0.89
# 16	0.81		0.75
# 17	0.87		0.89
# 18	0.78		0.72
# 19	0.86		0.88
# 20	0.79		0.75
# t = 1 was best iteration with accuracy 0.90
#
# -----------------------------------------------
# 27 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.94		0.91
# 2	0.88		0.84
# 3	0.89		0.90
# 4	0.45		0.40
# 5	0.88		0.89
# 6	0.90		0.85
# 7	0.92		0.89
# 8	0.43		0.42
# 9	0.86		0.87
# 10	0.91		0.89
# 11	0.93		0.89
# 12	0.54		0.49
# 13	0.86		0.87
# 14	0.88		0.84
# 15	0.94		0.91
# 16	0.68		0.63
# 17	0.82		0.83
# 18	0.74		0.70
# 19	0.91		0.91
# 20	0.56		0.53
# t = 1 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 28 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.89
# 2	0.89		0.85
# 3	0.90		0.90
# 4	0.36		0.30
# 5	0.93		0.92
# 6	0.88		0.84
# 7	0.92		0.91
# 8	0.51		0.51
# 9	0.83		0.85
# 10	0.84		0.81
# 11	0.84		0.81
# 12	0.52		0.49
# 13	0.80		0.79
# 14	0.59		0.56
# 15	0.78		0.77
# 16	0.55		0.53
# 17	0.78		0.77
# 18	0.61		0.56
# 19	0.76		0.75
# 20	0.61		0.57
# t = 1 was best iteration with accuracy 0.89
#
# -----------------------------------------------
# 29 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.92		0.89
# 2	0.90		0.86
# 3	0.93		0.91
# 4	0.26		0.25
# 5	0.89		0.91
# 6	0.93		0.91
# 7	0.91		0.86
# 8	0.92		0.91
# 9	0.28		0.24
# 10	0.91		0.92
# 11	0.91		0.89
# 12	0.93		0.91
# 13	0.45		0.43
# 14	0.85		0.85
# 15	0.93		0.90
# 16	0.93		0.90
# 17	0.91		0.89
# 18	0.38		0.38
# 19	0.89		0.86
# 20	0.92		0.91
# t = 12 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 30 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.92
# 2	0.85		0.79
# 3	0.89		0.89
# 4	0.44		0.43
# 5	0.90		0.91
# 6	0.90		0.87
# 7	0.93		0.92
# 8	0.44		0.41
# 9	0.86		0.88
# 10	0.89		0.88
# 11	0.90		0.88
# 12	0.50		0.51
# 13	0.85		0.86
# 14	0.91		0.89
# 15	0.91		0.87
# 16	0.74		0.72
# 17	0.69		0.67
# 18	0.73		0.72
# 19	0.88		0.87
# 20	0.89		0.86
# t = 1 was best iteration with accuracy 0.92
#
# -----------------------------------------------
# 31 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.94		0.91
# 2	0.91		0.87
# 3	0.92		0.91
# 4	0.31		0.29
# 5	0.87		0.89
# 6	0.91		0.91
# 7	0.91		0.89
# 8	0.83		0.80
# 9	0.61		0.62
# 10	0.75		0.75
# 11	0.91		0.88
# 12	0.93		0.90
# 13	0.51		0.50
# 14	0.80		0.80
# 15	0.91		0.90
# 16	0.90		0.89
# 17	0.82		0.81
# 18	0.66		0.67
# 19	0.58		0.56
# 20	0.75		0.73
# t = 1 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 32 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.90
# 2	0.88		0.84
# 3	0.91		0.91
# 4	0.35		0.34
# 5	0.91		0.91
# 6	0.88		0.83
# 7	0.91		0.91
# 8	0.43		0.43
# 9	0.91		0.91
# 10	0.67		0.63
# 11	0.90		0.91
# 12	0.48		0.48
# 13	0.88		0.90
# 14	0.68		0.64
# 15	0.88		0.89
# 16	0.62		0.57
# 17	0.92		0.92
# 18	0.65		0.60
# 19	0.88		0.88
# 20	0.74		0.67
# t = 1 was best iteration with accuracy 0.90
#
# -----------------------------------------------
# 33 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.94		0.91
# 2	0.88		0.85
# 3	0.93		0.91
# 4	0.34		0.35
# 5	0.90		0.91
# 6	0.87		0.82
# 7	0.92		0.92
# 8	0.52		0.49
# 9	0.88		0.89
# 10	0.86		0.81
# 11	0.92		0.91
# 12	0.50		0.46
# 13	0.85		0.87
# 14	0.89		0.86
# 15	0.93		0.91
# 16	0.65		0.63
# 17	0.75		0.76
# 18	0.83		0.78
# 19	0.91		0.90
# 20	0.65		0.62
# t = 1 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 34 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.90
# 2	0.91		0.87
# 3	0.92		0.91
# 4	0.45		0.47
# 5	0.84		0.88
# 6	0.89		0.87
# 7	0.93		0.90
# 8	0.61		0.56
# 9	0.81		0.79
# 10	0.76		0.69
# 11	0.91		0.89
# 12	0.58		0.53
# 13	0.83		0.86
# 14	0.67		0.61
# 15	0.86		0.86
# 16	0.55		0.53
# 17	0.83		0.83
# 18	0.65		0.60
# 19	0.86		0.86
# 20	0.55		0.52
# t = 7 was best iteration with accuracy 0.90
#
# -----------------------------------------------
# 35 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.90
# 2	0.89		0.86
# 3	0.89		0.91
# 4	0.35		0.33
# 5	0.92		0.90
# 6	0.87		0.83
# 7	0.93		0.91
# 8	0.43		0.39
# 9	0.86		0.85
# 10	0.88		0.85
# 11	0.93		0.91
# 12	0.63		0.61
# 13	0.89		0.90
# 14	0.58		0.56
# 15	0.89		0.91
# 16	0.82		0.81
# 17	0.86		0.87
# 18	0.77		0.72
# 19	0.87		0.88
# 20	0.80		0.77
# t = 1 was best iteration with accuracy 0.90
#
# -----------------------------------------------
# 36 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.89
# 2	0.92		0.88
# 3	0.92		0.92
# 4	0.35		0.34
# 5	0.88		0.90
# 6	0.88		0.85
# 7	0.92		0.89
# 8	0.48		0.44
# 9	0.84		0.85
# 10	0.80		0.75
# 11	0.91		0.90
# 12	0.58		0.56
# 13	0.85		0.88
# 14	0.57		0.53
# 15	0.89		0.90
# 16	0.67		0.64
# 17	0.87		0.87
# 18	0.54		0.52
# 19	0.85		0.87
# 20	0.72		0.67
# t = 1 was best iteration with accuracy 0.89
#
# -----------------------------------------------
# 37 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.90
# 2	0.88		0.85
# 3	0.88		0.88
# 4	0.46		0.42
# 5	0.90		0.91
# 6	0.86		0.80
# 7	0.86		0.87
# 8	0.61		0.61
# 9	0.89		0.88
# 10	0.77		0.72
# 11	0.92		0.92
# 12	0.71		0.66
# 13	0.84		0.86
# 14	0.69		0.67
# 15	0.91		0.91
# 16	0.66		0.64
# 17	0.89		0.89
# 18	0.72		0.70
# 19	0.91		0.89
# 20	0.70		0.68
# t = 1 was best iteration with accuracy 0.90
#
# -----------------------------------------------
# 38 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.91
# 2	0.89		0.86
# 3	0.93		0.92
# 4	0.29		0.27
# 5	0.86		0.87
# 6	0.92		0.90
# 7	0.93		0.89
# 8	0.84		0.79
# 9	0.68		0.71
# 10	0.79		0.78
# 11	0.90		0.88
# 12	0.90		0.86
# 13	0.84		0.78
# 14	0.63		0.64
# 15	0.78		0.75
# 16	0.90		0.88
# 17	0.91		0.89
# 18	0.56		0.53
# 19	0.78		0.77
# 20	0.83		0.80
# t = 1 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 39 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.89
# 2	0.90		0.85
# 3	0.93		0.92
# 4	0.31		0.27
# 5	0.89		0.89
# 6	0.93		0.91
# 7	0.89		0.87
# 8	0.90		0.89
# 9	0.44		0.41
# 10	0.87		0.88
# 11	0.89		0.87
# 12	0.92		0.89
# 13	0.54		0.53
# 14	0.81		0.82
# 15	0.89		0.87
# 16	0.92		0.89
# 17	0.82		0.80
# 18	0.76		0.76
# 19	0.62		0.61
# 20	0.91		0.90
# t = 3 was best iteration with accuracy 0.92
#
# -----------------------------------------------
# 40 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.90
# 2	0.88		0.85
# 3	0.92		0.92
# 4	0.41		0.37
# 5	0.84		0.86
# 6	0.87		0.82
# 7	0.91		0.89
# 8	0.56		0.55
# 9	0.77		0.75
# 10	0.74		0.71
# 11	0.85		0.83
# 12	0.63		0.57
# 13	0.76		0.75
# 14	0.62		0.62
# 15	0.82		0.81
# 16	0.65		0.63
# 17	0.82		0.80
# 18	0.63		0.61
# 19	0.81		0.79
# 20	0.61		0.61
# t = 1 was best iteration with accuracy 0.90
#
# -----------------------------------------------
# 41 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.90
# 2	0.89		0.86
# 3	0.91		0.91
# 4	0.25		0.25
# 5	0.89		0.90
# 6	0.90		0.86
# 7	0.90		0.87
# 8	0.56		0.56
# 9	0.78		0.78
# 10	0.92		0.89
# 11	0.91		0.87
# 12	0.87		0.84
# 13	0.50		0.51
# 14	0.73		0.72
# 15	0.91		0.88
# 16	0.88		0.83
# 17	0.86		0.84
# 18	0.41		0.39
# 19	0.86		0.88
# 20	0.92		0.89
# t = 1 was best iteration with accuracy 0.90
#
# -----------------------------------------------
# 42 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.90
# 2	0.89		0.86
# 3	0.91		0.92
# 4	0.41		0.39
# 5	0.85		0.88
# 6	0.92		0.89
# 7	0.89		0.86
# 8	0.92		0.89
# 9	0.45		0.44
# 10	0.83		0.87
# 11	0.92		0.90
# 12	0.88		0.86
# 13	0.89		0.89
# 14	0.41		0.42
# 15	0.91		0.92
# 16	0.91		0.86
# 17	0.93		0.93
# 18	0.50		0.50
# 19	0.87		0.89
# 20	0.88		0.86
# t = 1 was best iteration with accuracy 0.90
#
# -----------------------------------------------
# 43 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.90
# 2	0.88		0.85
# 3	0.91		0.92
# 4	0.51		0.48
# 5	0.87		0.89
# 6	0.89		0.86
# 7	0.93		0.93
# 8	0.39		0.40
# 9	0.89		0.90
# 10	0.90		0.86
# 11	0.93		0.92
# 12	0.46		0.45
# 13	0.83		0.84
# 14	0.91		0.88
# 15	0.90		0.89
# 16	0.72		0.67
# 17	0.74		0.75
# 18	0.68		0.64
# 19	0.91		0.90
# 20	0.79		0.74
# t = 7 was best iteration with accuracy 0.93
#
# -----------------------------------------------
# 44 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.89
# 2	0.92		0.88
# 3	0.91		0.91
# 4	0.58		0.55
# 5	0.81		0.82
# 6	0.92		0.89
# 7	0.93		0.89
# 8	0.86		0.86
# 9	0.80		0.78
# 10	0.69		0.67
# 11	0.93		0.90
# 12	0.88		0.86
# 13	0.76		0.72
# 14	0.58		0.58
# 15	0.93		0.90
# 16	0.88		0.88
# 17	0.91		0.90
# 18	0.55		0.56
# 19	0.79		0.80
# 20	0.89		0.86
# t = 11 was best iteration with accuracy 0.90
#
# -----------------------------------------------
# 45 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.94		0.91
# 2	0.89		0.86
# 3	0.90		0.91
# 4	0.47		0.40
# 5	0.90		0.90
# 6	0.87		0.84
# 7	0.90		0.91
# 8	0.50		0.47
# 9	0.90		0.90
# 10	0.90		0.86
# 11	0.93		0.90
# 12	0.40		0.39
# 13	0.89		0.90
# 14	0.91		0.90
# 15	0.91		0.90
# 16	0.70		0.71
# 17	0.76		0.76
# 18	0.75		0.76
# 19	0.92		0.88
# 20	0.82		0.80
# t = 1 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 46 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.90
# 2	0.87		0.85
# 3	0.91		0.92
# 4	0.27		0.29
# 5	0.91		0.92
# 6	0.88		0.86
# 7	0.91		0.91
# 8	0.36		0.38
# 9	0.87		0.88
# 10	0.91		0.88
# 11	0.86		0.81
# 12	0.77		0.72
# 13	0.40		0.40
# 14	0.89		0.90
# 15	0.88		0.85
# 16	0.88		0.88
# 17	0.54		0.51
# 18	0.82		0.86
# 19	0.85		0.80
# 20	0.92		0.89
# t = 1 was best iteration with accuracy 0.90
#
# -----------------------------------------------
# 47 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.90
# 2	0.88		0.84
# 3	0.92		0.90
# 4	0.37		0.35
# 5	0.88		0.90
# 6	0.91		0.88
# 7	0.93		0.90
# 8	0.41		0.40
# 9	0.86		0.86
# 10	0.90		0.86
# 11	0.93		0.89
# 12	0.75		0.72
# 13	0.70		0.71
# 14	0.73		0.69
# 15	0.92		0.90
# 16	0.76		0.68
# 17	0.82		0.83
# 18	0.56		0.52
# 19	0.88		0.86
# 20	0.64		0.60
# t = 7 was best iteration with accuracy 0.90
#
# -----------------------------------------------
# 48 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.90
# 2	0.90		0.87
# 3	0.89		0.90
# 4	0.35		0.34
# 5	0.89		0.91
# 6	0.86		0.85
# 7	0.88		0.87
# 8	0.60		0.58
# 9	0.87		0.87
# 10	0.84		0.82
# 11	0.92		0.90
# 12	0.57		0.57
# 13	0.81		0.81
# 14	0.85		0.81
# 15	0.89		0.87
# 16	0.57		0.54
# 17	0.79		0.80
# 18	0.64		0.65
# 19	0.86		0.84
# 20	0.60		0.59
# t = 1 was best iteration with accuracy 0.90
#
# -----------------------------------------------
# 49 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.91
# 2	0.89		0.87
# 3	0.91		0.90
# 4	0.35		0.36
# 5	0.92		0.92
# 6	0.89		0.87
# 7	0.88		0.88
# 8	0.66		0.63
# 9	0.85		0.87
# 10	0.80		0.77
# 11	0.89		0.89
# 12	0.64		0.62
# 13	0.87		0.87
# 14	0.85		0.82
# 15	0.92		0.91
# 16	0.63		0.61
# 17	0.78		0.80
# 18	0.84		0.79
# 19	0.90		0.90
# 20	0.62		0.57
# t = 1 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 50 / 100 complete
# -----------------------------------------------
#
# Training accuracy of rank SVM: 1.00
# /Users/Ashtekar15/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.93
# 2	0.94		0.92
# 3	0.94		0.93
# 4	0.92		0.92
# 5	0.92		0.91
# 6	0.72		0.75
# 7	0.85		0.85
# 8	0.90		0.91
# 9	0.93		0.92
# 10	0.92		0.92
# 11	0.92		0.89
# 12	0.73		0.77
# 13	0.86		0.85
# 14	0.91		0.91
# 15	0.93		0.91
# 16	0.93		0.92
# 17	0.92		0.91
# 18	0.81		0.83
# 19	0.84		0.80
# 20	0.89		0.89
# t = 2 was best iteration with accuracy 0.92
#
# -----------------------------------------------
# 51 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.92
# 2	0.94		0.93
# 3	0.94		0.92
# 4	0.93		0.92
# 5	0.93		0.93
# 6	0.77		0.74
# 7	0.87		0.90
# 8	0.86		0.83
# 9	0.90		0.92
# 10	0.87		0.84
# 11	0.90		0.91
# 12	0.86		0.84
# 13	0.91		0.92
# 14	0.87		0.84
# 15	0.92		0.91
# 16	0.88		0.84
# 17	0.90		0.90
# 18	0.87		0.84
# 19	0.91		0.89
# 20	0.86		0.82
# t = 2 was best iteration with accuracy 0.93
#
# -----------------------------------------------
# 52 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.94		0.93
# 2	0.94		0.93
# 3	0.94		0.93
# 4	0.93		0.92
# 5	0.93		0.92
# 6	0.84		0.81
# 7	0.78		0.80
# 8	0.91		0.89
# 9	0.93		0.92
# 10	0.93		0.92
# 11	0.93		0.91
# 12	0.92		0.93
# 13	0.81		0.78
# 14	0.84		0.86
# 15	0.92		0.90
# 16	0.94		0.93
# 17	0.94		0.92
# 18	0.93		0.93
# 19	0.85		0.83
# 20	0.84		0.85
# t = 2 was best iteration with accuracy 0.93
#
# -----------------------------------------------
# 53 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.92
# 2	0.93		0.93
# 3	0.94		0.93
# 4	0.94		0.92
# 5	0.94		0.92
# 6	0.92		0.92
# 7	0.64		0.62
# 8	0.86		0.88
# 9	0.93		0.92
# 10	0.94		0.92
# 11	0.93		0.92
# 12	0.94		0.93
# 13	0.86		0.82
# 14	0.77		0.77
# 15	0.81		0.81
# 16	0.92		0.91
# 17	0.91		0.87
# 18	0.93		0.92
# 19	0.87		0.85
# 20	0.85		0.87
# t = 3 was best iteration with accuracy 0.93
#
# -----------------------------------------------
# 54 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.92
# 2	0.94		0.92
# 3	0.94		0.93
# 4	0.93		0.93
# 5	0.93		0.94
# 6	0.66		0.63
# 7	0.81		0.84
# 8	0.93		0.92
# 9	0.94		0.92
# 10	0.92		0.91
# 11	0.92		0.91
# 12	0.88		0.87
# 13	0.85		0.86
# 14	0.85		0.83
# 15	0.93		0.92
# 16	0.93		0.91
# 17	0.93		0.92
# 18	0.89		0.87
# 19	0.82		0.83
# 20	0.79		0.76
# t = 3 was best iteration with accuracy 0.93
#
# -----------------------------------------------
# 55 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.92
# 2	0.93		0.92
# 3	0.93		0.92
# 4	0.93		0.92
# 5	0.93		0.91
# 6	0.88		0.88
# 7	0.75		0.74
# 8	0.78		0.79
# 9	0.92		0.90
# 10	0.92		0.91
# 11	0.91		0.88
# 12	0.90		0.88
# 13	0.82		0.80
# 14	0.77		0.78
# 15	0.83		0.82
# 16	0.90		0.89
# 17	0.91		0.88
# 18	0.91		0.89
# 19	0.86		0.83
# 20	0.80		0.80
# t = 2 was best iteration with accuracy 0.92
#
# -----------------------------------------------
# 56 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.92
# 2	0.94		0.93
# 3	0.94		0.92
# 4	0.94		0.93
# 5	0.94		0.92
# 6	0.85		0.81
# 7	0.81		0.82
# 8	0.87		0.85
# 9	0.94		0.93
# 10	0.94		0.91
# 11	0.94		0.93
# 12	0.91		0.90
# 13	0.88		0.87
# 14	0.80		0.81
# 15	0.89		0.88
# 16	0.89		0.85
# 17	0.94		0.93
# 18	0.91		0.88
# 19	0.92		0.91
# 20	0.88		0.85
# t = 2 was best iteration with accuracy 0.93
#
# -----------------------------------------------
# 57 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.92
# 2	0.94		0.93
# 3	0.95		0.92
# 4	0.94		0.92
# 5	0.94		0.94
# 6	0.75		0.74
# 7	0.84		0.85
# 8	0.89		0.86
# 9	0.94		0.92
# 10	0.91		0.89
# 11	0.93		0.93
# 12	0.77		0.73
# 13	0.86		0.89
# 14	0.88		0.85
# 15	0.93		0.92
# 16	0.91		0.89
# 17	0.93		0.92
# 18	0.89		0.87
# 19	0.90		0.91
# 20	0.85		0.83
# t = 3 was best iteration with accuracy 0.92
#
# -----------------------------------------------
# 58 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.93
# 2	0.94		0.93
# 3	0.95		0.93
# 4	0.93		0.93
# 5	0.92		0.91
# 6	0.71		0.70
# 7	0.85		0.86
# 8	0.92		0.89
# 9	0.95		0.93
# 10	0.93		0.92
# 11	0.93		0.93
# 12	0.83		0.82
# 13	0.76		0.77
# 14	0.91		0.87
# 15	0.94		0.93
# 16	0.91		0.89
# 17	0.92		0.90
# 18	0.85		0.82
# 19	0.78		0.80
# 20	0.87		0.86
# t = 3 was best iteration with accuracy 0.93
#
# -----------------------------------------------
# 59 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.93
# 2	0.94		0.93
# 3	0.93		0.92
# 4	0.94		0.93
# 5	0.93		0.93
# 6	0.73		0.69
# 7	0.82		0.80
# 8	0.93		0.93
# 9	0.94		0.93
# 10	0.95		0.93
# 11	0.92		0.92
# 12	0.92		0.92
# 13	0.76		0.73
# 14	0.79		0.81
# 15	0.91		0.88
# 16	0.94		0.92
# 17	0.92		0.90
# 18	0.93		0.91
# 19	0.86		0.84
# 20	0.77		0.79
# t = 10 was best iteration with accuracy 0.93
#
# -----------------------------------------------
# 60 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.94		0.92
# 2	0.94		0.93
# 3	0.94		0.93
# 4	0.93		0.92
# 5	0.93		0.92
# 6	0.78		0.74
# 7	0.78		0.84
# 8	0.93		0.89
# 9	0.94		0.93
# 10	0.93		0.92
# 11	0.94		0.93
# 12	0.92		0.89
# 13	0.84		0.84
# 14	0.70		0.67
# 15	0.91		0.92
# 16	0.92		0.89
# 17	0.94		0.93
# 18	0.91		0.86
# 19	0.87		0.89
# 20	0.83		0.79
# t = 3 was best iteration with accuracy 0.93
#
# -----------------------------------------------
# 61 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.92
# 2	0.95		0.93
# 3	0.94		0.93
# 4	0.94		0.92
# 5	0.93		0.91
# 6	0.74		0.70
# 7	0.86		0.89
# 8	0.91		0.88
# 9	0.94		0.93
# 10	0.86		0.84
# 11	0.87		0.90
# 12	0.87		0.85
# 13	0.93		0.92
# 14	0.88		0.85
# 15	0.91		0.92
# 16	0.86		0.84
# 17	0.91		0.91
# 18	0.88		0.85
# 19	0.93		0.93
# 20	0.89		0.87
# t = 2 was best iteration with accuracy 0.93
#
# -----------------------------------------------
# 62 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.92
# 2	0.94		0.93
# 3	0.94		0.93
# 4	0.94		0.94
# 5	0.93		0.92
# 6	0.87		0.87
# 7	0.76		0.68
# 8	0.89		0.88
# 9	0.92		0.91
# 10	0.94		0.93
# 11	0.94		0.90
# 12	0.91		0.91
# 13	0.76		0.75
# 14	0.73		0.74
# 15	0.92		0.89
# 16	0.93		0.92
# 17	0.93		0.92
# 18	0.92		0.90
# 19	0.90		0.91
# 20	0.67		0.65
# t = 3 was best iteration with accuracy 0.93
#
# -----------------------------------------------
# 63 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.94		0.94
# 2	0.94		0.93
# 3	0.95		0.94
# 4	0.93		0.92
# 5	0.94		0.93
# 6	0.71		0.66
# 7	0.87		0.90
# 8	0.69		0.66
# 9	0.88		0.90
# 10	0.89		0.86
# 11	0.91		0.92
# 12	0.80		0.79
# 13	0.91		0.91
# 14	0.91		0.89
# 15	0.93		0.94
# 16	0.92		0.90
# 17	0.92		0.93
# 18	0.87		0.86
# 19	0.92		0.91
# 20	0.89		0.89
# t = 3 was best iteration with accuracy 0.94
#
# -----------------------------------------------
# 64 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.94		0.93
# 2	0.94		0.93
# 3	0.95		0.93
# 4	0.93		0.93
# 5	0.92		0.92
# 6	0.72		0.72
# 7	0.83		0.88
# 8	0.91		0.89
# 9	0.95		0.93
# 10	0.93		0.92
# 11	0.94		0.93
# 12	0.88		0.86
# 13	0.84		0.87
# 14	0.74		0.72
# 15	0.92		0.91
# 16	0.91		0.89
# 17	0.93		0.92
# 18	0.91		0.87
# 19	0.86		0.88
# 20	0.82		0.79
# t = 3 was best iteration with accuracy 0.93
#
# -----------------------------------------------
# 65 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.93
# 2	0.94		0.93
# 3	0.94		0.93
# 4	0.94		0.93
# 5	0.93		0.92
# 6	0.82		0.82
# 7	0.75		0.75
# 8	0.92		0.90
# 9	0.94		0.92
# 10	0.94		0.93
# 11	0.91		0.91
# 12	0.91		0.92
# 13	0.73		0.74
# 14	0.88		0.88
# 15	0.90		0.87
# 16	0.93		0.92
# 17	0.92		0.89
# 18	0.93		0.92
# 19	0.89		0.86
# 20	0.90		0.90
# t = 3 was best iteration with accuracy 0.93
#
# -----------------------------------------------
# 66 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.94		0.93
# 2	0.94		0.92
# 3	0.94		0.93
# 4	0.93		0.91
# 5	0.93		0.93
# 6	0.72		0.70
# 7	0.85		0.89
# 8	0.91		0.89
# 9	0.94		0.94
# 10	0.92		0.90
# 11	0.93		0.93
# 12	0.68		0.65
# 13	0.87		0.90
# 14	0.46		0.41
# 15	0.87		0.90
# 16	0.91		0.87
# 17	0.85		0.90
# 18	0.57		0.53
# 19	0.91		0.92
# 20	0.93		0.91
# t = 2 was best iteration with accuracy 0.92
#
# -----------------------------------------------
# 67 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.93
# 2	0.94		0.93
# 3	0.95		0.93
# 4	0.94		0.93
# 5	0.93		0.94
# 6	0.81		0.79
# 7	0.86		0.89
# 8	0.80		0.75
# 9	0.91		0.92
# 10	0.92		0.90
# 11	0.93		0.93
# 12	0.87		0.85
# 13	0.86		0.89
# 14	0.72		0.72
# 15	0.89		0.91
# 16	0.90		0.87
# 17	0.93		0.93
# 18	0.92		0.89
# 19	0.91		0.93
# 20	0.78		0.75
# t = 3 was best iteration with accuracy 0.93
#
# -----------------------------------------------
# 68 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.94		0.93
# 2	0.95		0.93
# 3	0.94		0.93
# 4	0.94		0.93
# 5	0.92		0.93
# 6	0.74		0.74
# 7	0.82		0.84
# 8	0.94		0.93
# 9	0.95		0.94
# 10	0.93		0.92
# 11	0.93		0.94
# 12	0.87		0.86
# 13	0.89		0.90
# 14	0.74		0.74
# 15	0.92		0.93
# 16	0.90		0.88
# 17	0.94		0.93
# 18	0.89		0.88
# 19	0.93		0.93
# 20	0.74		0.74
# t = 2 was best iteration with accuracy 0.93
#
# -----------------------------------------------
# 69 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.94
# 2	0.94		0.93
# 3	0.94		0.93
# 4	0.93		0.92
# 5	0.93		0.93
# 6	0.81		0.79
# 7	0.85		0.89
# 8	0.81		0.81
# 9	0.93		0.92
# 10	0.91		0.88
# 11	0.92		0.92
# 12	0.75		0.72
# 13	0.86		0.89
# 14	0.92		0.88
# 15	0.94		0.94
# 16	0.92		0.90
# 17	0.94		0.94
# 18	0.67		0.65
# 19	0.85		0.89
# 20	0.94		0.92
# t = 15 was best iteration with accuracy 0.94
#
# -----------------------------------------------
# 70 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.93
# 2	0.94		0.93
# 3	0.94		0.93
# 4	0.94		0.93
# 5	0.93		0.93
# 6	0.84		0.89
# 7	0.84		0.81
# 8	0.87		0.89
# 9	0.93		0.90
# 10	0.92		0.93
# 11	0.93		0.91
# 12	0.90		0.93
# 13	0.87		0.84
# 14	0.87		0.89
# 15	0.88		0.83
# 16	0.93		0.93
# 17	0.92		0.91
# 18	0.91		0.92
# 19	0.88		0.85
# 20	0.86		0.88
# t = 3 was best iteration with accuracy 0.93
#
# -----------------------------------------------
# 71 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.94		0.93
# 2	0.95		0.93
# 3	0.94		0.93
# 4	0.94		0.93
# 5	0.92		0.91
# 6	0.80		0.82
# 7	0.71		0.72
# 8	0.90		0.90
# 9	0.92		0.90
# 10	0.92		0.93
# 11	0.91		0.90
# 12	0.85		0.87
# 13	0.77		0.77
# 14	0.87		0.89
# 15	0.92		0.90
# 16	0.92		0.93
# 17	0.92		0.91
# 18	0.91		0.92
# 19	0.86		0.86
# 20	0.85		0.88
# t = 2 was best iteration with accuracy 0.93
#
# -----------------------------------------------
# 72 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.93
# 2	0.94		0.93
# 3	0.94		0.93
# 4	0.93		0.92
# 5	0.93		0.92
# 6	0.74		0.72
# 7	0.80		0.81
# 8	0.93		0.91
# 9	0.94		0.94
# 10	0.93		0.91
# 11	0.93		0.92
# 12	0.83		0.82
# 13	0.80		0.80
# 14	0.88		0.88
# 15	0.92		0.92
# 16	0.93		0.90
# 17	0.92		0.93
# 18	0.86		0.83
# 19	0.86		0.86
# 20	0.86		0.84
# t = 2 was best iteration with accuracy 0.93
#
# -----------------------------------------------
# 73 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.92
# 2	0.94		0.93
# 3	0.94		0.93
# 4	0.94		0.93
# 5	0.94		0.93
# 6	0.91		0.90
# 7	0.84		0.85
# 8	0.84		0.83
# 9	0.93		0.91
# 10	0.92		0.92
# 11	0.94		0.91
# 12	0.94		0.93
# 13	0.92		0.91
# 14	0.83		0.85
# 15	0.84		0.85
# 16	0.88		0.88
# 17	0.92		0.92
# 18	0.92		0.91
# 19	0.93		0.92
# 20	0.86		0.86
# t = 2 was best iteration with accuracy 0.93
#
# -----------------------------------------------
# 74 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.93
# 2	0.94		0.94
# 3	0.93		0.93
# 4	0.94		0.94
# 5	0.92		0.90
# 6	0.91		0.92
# 7	0.38		0.34
# 8	0.87		0.90
# 9	0.92		0.94
# 10	0.92		0.90
# 11	0.88		0.91
# 12	0.79		0.78
# 13	0.89		0.90
# 14	0.91		0.91
# 15	0.93		0.94
# 16	0.91		0.90
# 17	0.91		0.91
# 18	0.85		0.84
# 19	0.87		0.89
# 20	0.89		0.86
# t = 2 was best iteration with accuracy 0.94
#
# -----------------------------------------------
# 75 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.94		0.92
# 2	0.94		0.93
# 3	0.94		0.92
# 4	0.93		0.92
# 5	0.94		0.94
# 6	0.74		0.67
# 7	0.76		0.81
# 8	0.88		0.85
# 9	0.93		0.91
# 10	0.92		0.89
# 11	0.91		0.90
# 12	0.75		0.71
# 13	0.79		0.81
# 14	0.73		0.68
# 15	0.89		0.89
# 16	0.85		0.81
# 17	0.89		0.88
# 18	0.76		0.73
# 19	0.84		0.84
# 20	0.76		0.72
# t = 3 was best iteration with accuracy 0.92
#
# -----------------------------------------------
# 76 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.94		0.92
# 2	0.94		0.93
# 3	0.94		0.92
# 4	0.94		0.93
# 5	0.93		0.91
# 6	0.89		0.91
# 7	0.75		0.72
# 8	0.87		0.88
# 9	0.92		0.91
# 10	0.94		0.93
# 11	0.93		0.92
# 12	0.94		0.93
# 13	0.85		0.83
# 14	0.83		0.83
# 15	0.86		0.84
# 16	0.93		0.93
# 17	0.92		0.91
# 18	0.94		0.93
# 19	0.89		0.87
# 20	0.81		0.85
# t = 2 was best iteration with accuracy 0.93
#
# -----------------------------------------------
# 77 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.94		0.93
# 2	0.94		0.93
# 3	0.94		0.92
# 4	0.92		0.92
# 5	0.92		0.93
# 6	0.47		0.45
# 7	0.84		0.87
# 8	0.92		0.92
# 9	0.93		0.90
# 10	0.93		0.91
# 11	0.91		0.88
# 12	0.81		0.80
# 13	0.75		0.74
# 14	0.90		0.89
# 15	0.93		0.91
# 16	0.92		0.90
# 17	0.92		0.89
# 18	0.89		0.89
# 19	0.75		0.70
# 20	0.83		0.85
# t = 2 was best iteration with accuracy 0.93
#
# -----------------------------------------------
# 78 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.94		0.93
# 2	0.94		0.93
# 3	0.94		0.94
# 4	0.94		0.92
# 5	0.94		0.94
# 6	0.77		0.78
# 7	0.81		0.84
# 8	0.91		0.90
# 9	0.94		0.92
# 10	0.93		0.92
# 11	0.94		0.93
# 12	0.83		0.82
# 13	0.85		0.86
# 14	0.81		0.79
# 15	0.92		0.92
# 16	0.91		0.91
# 17	0.94		0.92
# 18	0.91		0.89
# 19	0.89		0.88
# 20	0.82		0.82
# t = 2 was best iteration with accuracy 0.93
#
# -----------------------------------------------
# 79 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.94		0.93
# 2	0.94		0.93
# 3	0.94		0.92
# 4	0.94		0.93
# 5	0.92		0.92
# 6	0.81		0.79
# 7	0.80		0.81
# 8	0.92		0.90
# 9	0.94		0.93
# 10	0.93		0.92
# 11	0.94		0.93
# 12	0.88		0.86
# 13	0.78		0.81
# 14	0.80		0.79
# 15	0.93		0.92
# 16	0.93		0.92
# 17	0.94		0.93
# 18	0.93		0.90
# 19	0.89		0.90
# 20	0.72		0.72
# t = 2 was best iteration with accuracy 0.93
#
# -----------------------------------------------
# 80 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.94		0.93
# 2	0.94		0.93
# 3	0.94		0.93
# 4	0.94		0.92
# 5	0.94		0.93
# 6	0.74		0.73
# 7	0.83		0.87
# 8	0.89		0.85
# 9	0.94		0.94
# 10	0.92		0.89
# 11	0.93		0.93
# 12	0.80		0.78
# 13	0.88		0.90
# 14	0.85		0.84
# 15	0.93		0.93
# 16	0.91		0.90
# 17	0.93		0.93
# 18	0.91		0.89
# 19	0.92		0.93
# 20	0.88		0.88
# t = 5 was best iteration with accuracy 0.93
#
# -----------------------------------------------
# 81 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.92
# 2	0.94		0.93
# 3	0.94		0.93
# 4	0.94		0.93
# 5	0.93		0.94
# 6	0.83		0.81
# 7	0.79		0.82
# 8	0.91		0.89
# 9	0.94		0.93
# 10	0.93		0.90
# 11	0.94		0.93
# 12	0.85		0.81
# 13	0.75		0.76
# 14	0.89		0.85
# 15	0.91		0.91
# 16	0.89		0.86
# 17	0.87		0.88
# 18	0.74		0.71
# 19	0.80		0.81
# 20	0.88		0.85
# t = 3 was best iteration with accuracy 0.93
#
# -----------------------------------------------
# 82 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.94		0.93
# 2	0.94		0.93
# 3	0.94		0.93
# 4	0.93		0.92
# 5	0.92		0.92
# 6	0.68		0.66
# 7	0.82		0.83
# 8	0.92		0.91
# 9	0.93		0.93
# 10	0.92		0.91
# 11	0.92		0.89
# 12	0.84		0.82
# 13	0.75		0.77
# 14	0.73		0.74
# 15	0.91		0.93
# 16	0.91		0.90
# 17	0.92		0.91
# 18	0.91		0.90
# 19	0.89		0.88
# 20	0.79		0.77
# t = 3 was best iteration with accuracy 0.93
#
# -----------------------------------------------
# 83 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.94		0.93
# 2	0.94		0.93
# 3	0.95		0.93
# 4	0.95		0.93
# 5	0.94		0.92
# 6	0.85		0.86
# 7	0.77		0.76
# 8	0.91		0.92
# 9	0.93		0.93
# 10	0.94		0.94
# 11	0.93		0.93
# 12	0.92		0.92
# 13	0.88		0.86
# 14	0.89		0.89
# 15	0.91		0.89
# 16	0.92		0.92
# 17	0.93		0.91
# 18	0.92		0.92
# 19	0.92		0.89
# 20	0.90		0.91
# t = 3 was best iteration with accuracy 0.93
#
# -----------------------------------------------
# 84 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.92
# 2	0.93		0.93
# 3	0.94		0.93
# 4	0.93		0.91
# 5	0.91		0.92
# 6	0.52		0.50
# 7	0.86		0.88
# 8	0.89		0.86
# 9	0.90		0.89
# 10	0.87		0.85
# 11	0.89		0.87
# 12	0.56		0.53
# 13	0.82		0.84
# 14	0.78		0.76
# 15	0.86		0.84
# 16	0.74		0.70
# 17	0.80		0.79
# 18	0.55		0.50
# 19	0.83		0.85
# 20	0.71		0.67
# t = 3 was best iteration with accuracy 0.93
#
# -----------------------------------------------
# 85 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.94		0.93
# 2	0.93		0.92
# 3	0.94		0.93
# 4	0.93		0.91
# 5	0.92		0.92
# 6	0.77		0.77
# 7	0.83		0.84
# 8	0.90		0.85
# 9	0.93		0.92
# 10	0.91		0.87
# 11	0.90		0.90
# 12	0.78		0.74
# 13	0.83		0.85
# 14	0.83		0.79
# 15	0.92		0.91
# 16	0.89		0.84
# 17	0.91		0.91
# 18	0.86		0.81
# 19	0.85		0.87
# 20	0.82		0.79
# t = 3 was best iteration with accuracy 0.93
#
# -----------------------------------------------
# 86 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.94		0.93
# 2	0.94		0.93
# 3	0.94		0.92
# 4	0.94		0.92
# 5	0.94		0.93
# 6	0.88		0.89
# 7	0.72		0.72
# 8	0.85		0.86
# 9	0.93		0.91
# 10	0.93		0.93
# 11	0.94		0.91
# 12	0.91		0.92
# 13	0.89		0.87
# 14	0.85		0.85
# 15	0.77		0.78
# 16	0.92		0.92
# 17	0.93		0.92
# 18	0.93		0.94
# 19	0.93		0.91
# 20	0.90		0.92
# t = 2 was best iteration with accuracy 0.93
#
# -----------------------------------------------
# 87 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.94		0.93
# 2	0.94		0.93
# 3	0.94		0.93
# 4	0.93		0.92
# 5	0.93		0.93
# 6	0.79		0.76
# 7	0.85		0.86
# 8	0.79		0.78
# 9	0.93		0.94
# 10	0.91		0.88
# 11	0.93		0.94
# 12	0.87		0.84
# 13	0.91		0.91
# 14	0.77		0.74
# 15	0.90		0.91
# 16	0.88		0.85
# 17	0.93		0.93
# 18	0.88		0.86
# 19	0.93		0.93
# 20	0.87		0.85
# t = 3 was best iteration with accuracy 0.93
#
# -----------------------------------------------
# 88 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.92		0.92
# 2	0.94		0.93
# 3	0.94		0.93
# 4	0.94		0.93
# 5	0.94		0.93
# 6	0.84		0.83
# 7	0.77		0.76
# 8	0.88		0.87
# 9	0.94		0.92
# 10	0.93		0.91
# 11	0.94		0.92
# 12	0.89		0.88
# 13	0.82		0.83
# 14	0.72		0.70
# 15	0.91		0.91
# 16	0.92		0.88
# 17	0.92		0.92
# 18	0.89		0.85
# 19	0.85		0.88
# 20	0.86		0.82
# t = 3 was best iteration with accuracy 0.93
#
# -----------------------------------------------
# 89 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.93
# 2	0.95		0.93
# 3	0.94		0.93
# 4	0.94		0.93
# 5	0.93		0.92
# 6	0.92		0.93
# 7	0.61		0.59
# 8	0.87		0.89
# 9	0.93		0.92
# 10	0.94		0.92
# 11	0.93		0.93
# 12	0.94		0.94
# 13	0.84		0.83
# 14	0.85		0.84
# 15	0.84		0.82
# 16	0.93		0.94
# 17	0.92		0.90
# 18	0.92		0.93
# 19	0.85		0.85
# 20	0.87		0.88
# t = 2 was best iteration with accuracy 0.93
#
# -----------------------------------------------
# 90 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.92
# 2	0.94		0.92
# 3	0.94		0.93
# 4	0.94		0.93
# 5	0.93		0.93
# 6	0.89		0.88
# 7	0.80		0.80
# 8	0.84		0.83
# 9	0.94		0.92
# 10	0.94		0.92
# 11	0.94		0.93
# 12	0.91		0.90
# 13	0.90		0.91
# 14	0.73		0.71
# 15	0.87		0.88
# 16	0.91		0.92
# 17	0.94		0.94
# 18	0.92		0.91
# 19	0.92		0.93
# 20	0.73		0.72
# t = 2 was best iteration with accuracy 0.92
#
# -----------------------------------------------
# 91 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.93
# 2	0.94		0.92
# 3	0.95		0.94
# 4	0.93		0.92
# 5	0.93		0.93
# 6	0.67		0.64
# 7	0.84		0.86
# 8	0.93		0.92
# 9	0.93		0.92
# 10	0.93		0.91
# 11	0.93		0.92
# 12	0.87		0.84
# 13	0.85		0.85
# 14	0.66		0.66
# 15	0.91		0.92
# 16	0.90		0.88
# 17	0.93		0.92
# 18	0.90		0.88
# 19	0.91		0.91
# 20	0.59		0.55
# t = 3 was best iteration with accuracy 0.94
#
# -----------------------------------------------
# 92 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.93
# 2	0.94		0.93
# 3	0.95		0.93
# 4	0.93		0.91
# 5	0.93		0.93
# 6	0.62		0.61
# 7	0.86		0.87
# 8	0.94		0.93
# 9	0.93		0.92
# 10	0.93		0.93
# 11	0.94		0.91
# 12	0.90		0.91
# 13	0.75		0.70
# 14	0.77		0.79
# 15	0.92		0.88
# 16	0.93		0.93
# 17	0.94		0.91
# 18	0.88		0.88
# 19	0.85		0.83
# 20	0.69		0.71
# t = 3 was best iteration with accuracy 0.93
#
# -----------------------------------------------
# 93 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.93
# 2	0.93		0.92
# 3	0.94		0.93
# 4	0.93		0.91
# 5	0.93		0.93
# 6	0.81		0.77
# 7	0.80		0.84
# 8	0.83		0.81
# 9	0.91		0.91
# 10	0.92		0.89
# 11	0.91		0.91
# 12	0.87		0.83
# 13	0.85		0.88
# 14	0.82		0.81
# 15	0.89		0.90
# 16	0.92		0.90
# 17	0.92		0.91
# 18	0.89		0.88
# 19	0.88		0.90
# 20	0.85		0.84
# t = 3 was best iteration with accuracy 0.93
#
# -----------------------------------------------
# 94 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.92
# 2	0.93		0.93
# 3	0.95		0.93
# 4	0.93		0.93
# 5	0.93		0.90
# 6	0.87		0.90
# 7	0.80		0.76
# 8	0.76		0.72
# 9	0.90		0.86
# 10	0.91		0.93
# 11	0.93		0.92
# 12	0.85		0.83
# 13	0.86		0.83
# 14	0.70		0.73
# 15	0.78		0.74
# 16	0.87		0.87
# 17	0.84		0.81
# 18	0.88		0.88
# 19	0.85		0.82
# 20	0.88		0.88
# t = 3 was best iteration with accuracy 0.93
#
# -----------------------------------------------
# 95 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.92		0.93
# 2	0.94		0.92
# 3	0.94		0.93
# 4	0.92		0.91
# 5	0.91		0.90
# 6	0.78		0.78
# 7	0.84		0.85
# 8	0.91		0.89
# 9	0.93		0.92
# 10	0.92		0.91
# 11	0.93		0.90
# 12	0.85		0.83
# 13	0.82		0.86
# 14	0.76		0.74
# 15	0.93		0.92
# 16	0.92		0.89
# 17	0.93		0.93
# 18	0.90		0.87
# 19	0.88		0.88
# 20	0.73		0.71
# t = 2 was best iteration with accuracy 0.92
#
# -----------------------------------------------
# 96 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.94		0.92
# 2	0.94		0.93
# 3	0.94		0.93
# 4	0.93		0.92
# 5	0.93		0.93
# 6	0.71		0.66
# 7	0.82		0.87
# 8	0.92		0.89
# 9	0.94		0.94
# 10	0.93		0.92
# 11	0.92		0.92
# 12	0.88		0.86
# 13	0.82		0.83
# 14	0.84		0.82
# 15	0.92		0.93
# 16	0.92		0.90
# 17	0.92		0.92
# 18	0.90		0.88
# 19	0.86		0.86
# 20	0.86		0.84
# t = 2 was best iteration with accuracy 0.93
#
# -----------------------------------------------
# 97 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.92		0.92
# 2	0.94		0.92
# 3	0.94		0.94
# 4	0.93		0.92
# 5	0.89		0.91
# 6	0.73		0.70
# 7	0.81		0.85
# 8	0.88		0.83
# 9	0.92		0.93
# 10	0.91		0.88
# 11	0.92		0.93
# 12	0.87		0.84
# 13	0.86		0.86
# 14	0.84		0.81
# 15	0.93		0.93
# 16	0.92		0.91
# 17	0.93		0.93
# 18	0.91		0.88
# 19	0.86		0.86
# 20	0.85		0.81
# t = 3 was best iteration with accuracy 0.94
#
# -----------------------------------------------
# 98 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.92
# 2	0.94		0.92
# 3	0.95		0.93
# 4	0.94		0.93
# 5	0.93		0.92
# 6	0.84		0.82
# 7	0.78		0.80
# 8	0.86		0.82
# 9	0.93		0.93
# 10	0.92		0.89
# 11	0.94		0.93
# 12	0.91		0.87
# 13	0.89		0.89
# 14	0.77		0.74
# 15	0.82		0.84
# 16	0.77		0.74
# 17	0.85		0.86
# 18	0.80		0.79
# 19	0.86		0.88
# 20	0.84		0.81
# t = 3 was best iteration with accuracy 0.93
#
# -----------------------------------------------
# 99 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.94		0.93
# 2	0.94		0.94
# 3	0.94		0.93
# 4	0.94		0.92
# 5	0.94		0.93
# 6	0.81		0.76
# 7	0.79		0.84
# 8	0.88		0.87
# 9	0.94		0.93
# 10	0.93		0.92
# 11	0.94		0.93
# 12	0.85		0.83
# 13	0.85		0.87
# 14	0.77		0.77
# 15	0.93		0.93
# 16	0.90		0.88
# 17	0.94		0.93
# 18	0.90		0.86
# 19	0.92		0.92
# 20	0.85		0.80
# t = 2 was best iteration with accuracy 0.94
#
# -----------------------------------------------
# 100 / 100 complete
# -----------------------------------------------

# %%
table_results(svm_arr, tree_arr)
# Out:
# (Performance on test set)
#
# 50 comparisons
# 	acc	sderr
# SVM: 	90.6	0.2
# Tree: 	nan	nan
#
# 200 comparisons
# 	acc	sderr
# SVM: 	92.9	0.1
# Tree: 	nan	nan
