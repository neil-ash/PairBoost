# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import sys; sys.path.insert(0,'..')
from main import *

# %%
data = pd.read_csv('../data/spambase/spambase.data')
X = data.iloc[:, :-1].values
y  = data.iloc[:, -1].values

# {0, 1} -> {-1, 1}
y = y * 2 - 1

scaler = MinMaxScaler(feature_range=(0, 1))

for i in range(X.shape[1]):
    X[:, i] = scaler.fit_transform(X[:, i].reshape(-1, 1)).ravel()
    
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.5, stratify=y, 
                                                    shuffle=True, random_state=1)

# %% [markdown]
# ## SD

# %%
svm_arr, tree_arr = data_size_experiment(X_train, y_train, X_test, y_test, 
                                         experiment_type='SD', kernel='linear', 
                                         random_state=1, verbose=True)
# Out:
# Progress:
# Training accuracy of rank SVM: 0.92
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.83		0.83
# 2	0.83		0.86
# 3	0.84		0.86
# 4	0.84		0.87
# 5	0.84		0.88
# 6	0.83		0.86
# 7	0.83		0.83
# 8	0.78		0.82
# 9	0.77		0.78
# 10	0.78		0.81
# 11	0.85		0.84
# 12	0.81		0.82
# 13	0.85		0.85
# 14	0.80		0.82
# 15	0.83		0.83
# 16	0.79		0.80
# 17	0.83		0.85
# 18	0.81		0.83
# 19	0.83		0.85
# 20	0.77		0.79
# t = 13 was best iteration
#
# -----------------------------------------------
# 1 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.82		0.82
# 2	0.83		0.84
# 3	0.84		0.85
# 4	0.84		0.85
# 5	0.83		0.86
# 6	0.83		0.86
# 7	0.80		0.81
# 8	0.78		0.80
# 9	0.65		0.59
# 10	0.74		0.80
# 11	0.82		0.86
# 12	0.83		0.85
# 13	0.83		0.86
# 14	0.78		0.83
# 15	0.40		0.35
# 16	0.73		0.78
# 17	0.81		0.83
# 18	0.84		0.86
# 19	0.83		0.87
# ...

# %%
np.save('temp_arrays/SD/spambase_svm', svm_arr)
plot_err(svm_arr, 'Spambase', 'SVM', experiment_type='SD', scale=1, save=True)

# %% [markdown]
# ## U

# %%
svm_arr, tree_arr = data_size_experiment(X_train, y_train, X_test, y_test, 
                                         experiment_type='U', kernel='linear', 
                                         random_state=1, verbose=True)
# Out:
# Progress:
# Training accuracy of rank SVM: 0.92
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.83		0.82
# 2	0.85		0.84
# 3	0.87		0.86
# 4	0.88		0.86
# 5	0.87		0.85
# 6	0.27		0.28
# 7	0.83		0.80
# 8	0.83		0.81
# 9	0.84		0.82
# 10	0.86		0.85
# 11	0.87		0.86
# 12	0.87		0.86
# 13	0.85		0.85
# 14	0.89		0.86
# 15	0.60		0.64
# 16	0.65		0.57
# 17	0.87		0.82
# 18	0.87		0.84
# 19	0.88		0.85
# 20	0.90		0.86
# t = 20 was best iteration
#
# -----------------------------------------------
# 1 / 60 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.82		0.82
# 2	0.84		0.83
# 3	0.86		0.85
# 4	0.86		0.85
# 5	0.86		0.85
# 6	0.85		0.82
# 7	0.75		0.75
# 8	0.61		0.66
# 9	0.56		0.51
# 10	0.82		0.82
# 11	0.85		0.84
# 12	0.87		0.84
# 13	0.81		0.80
# 14	0.60		0.61
# 15	0.43		0.39
# 16	0.77		0.81
# 17	0.72		0.67
# 18	0.83		0.84
# 19	0.83		0.83
# ...

# %%
np.save('temp_arrays/U/spambase_svm', svm_arr)
plot_err(svm_arr, 'Spambase', 'SVM', experiment_type='U', scale=1, save=True)

# %% [markdown]
# ## m

# %%
svm_arr, tree_arr, ls_base = data_size_experiment(X_train, y_train, X_test, y_test, 
                                         experiment_type='m', kernel='linear', 
                                         random_state=1, verbose=True)
# Out:
# Progress:
# Training accuracy of rank SVM: 0.94
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.81		0.83
# 2	0.81		0.83
# 3	0.81		0.83
# 4	0.81		0.83
# 5	0.81		0.83
# 6	0.82		0.83
# 7	0.82		0.83
# 8	0.82		0.83
# 9	0.82		0.83
# 10	0.81		0.83
# 11	0.82		0.83
# 12	0.82		0.83
# 13	0.81		0.83
# 14	0.81		0.83
# 15	0.81		0.83
# 16	0.81		0.83
# 17	0.82		0.83
# 18	0.82		0.83
# 19	0.81		0.83
# 20	0.82		0.84
# t = 7 was best iteration
#
# -----------------------------------------------
# 1 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.80		0.82
# 2	0.81		0.83
# 3	0.81		0.83
# 4	0.81		0.83
# 5	0.81		0.83
# 6	0.81		0.83
# 7	0.81		0.83
# 8	0.81		0.83
# 9	0.81		0.83
# 10	0.81		0.83
# 11	0.81		0.83
# 12	0.81		0.83
# 13	0.81		0.83
# 14	0.81		0.83
# 15	0.81		0.83
# 16	0.81		0.83
# 17	0.81		0.83
# 18	0.81		0.83
# 19	0.81		0.83
# ...

# %%
np.save('temp_arrays/m/spambase_svm', svm_arr)
plot_err(svm_arr, 'Spambase', 'SVM', experiment_type='m', ls_base=ls_base, scale=1, save=True)

# %% [markdown]
# ## n

# %%
svm_arr, tree_arr, ls_base = data_size_experiment(X_train, y_train, X_test, y_test, 
                                         experiment_type='n', kernel='linear', 
                                         random_state=1, verbose=True)
# Out:
# Progress:
# Cut at 41 rather than expected 50
# Training accuracy of rank SVM: 0.93
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.84		0.81
# 2	0.85		0.83
# 3	0.85		0.84
# 4	0.88		0.84
# 5	0.90		0.85
# 6	0.89		0.85
# 7	0.89		0.86
# 8	0.66		0.65
# 9	0.77		0.76
# 10	0.75		0.70
# 11	0.86		0.83
# 12	0.86		0.84
# 13	0.88		0.84
# 14	0.85		0.82
# 15	0.74		0.72
# 16	0.80		0.76
# 17	0.51		0.41
# 18	0.76		0.77
# 19	0.77		0.75
# 20	0.72		0.67
# t = 5 was best iteration
#
# -----------------------------------------------
# 1 / 60 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.86		0.83
# 2	0.89		0.84
# 3	0.88		0.84
# 4	0.89		0.84
# 5	0.89		0.85
# 6	0.83		0.80
# 7	0.57		0.62
# 8	0.68		0.72
# 9	0.85		0.83
# 10	0.83		0.81
# 11	0.79		0.76
# 12	0.82		0.78
# 13	0.61		0.62
# 14	0.70		0.71
# 15	0.87		0.83
# 16	0.88		0.85
# 17	0.88		0.85
# ...

# %%
np.save('temp_arrays/n/spambase_svm', svm_arr)
plot_err(svm_arr, 'Spambase', 'SVM', experiment_type='n', ls_base=ls_base, scale=1, save=True)
