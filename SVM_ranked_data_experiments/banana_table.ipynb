# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import sys; sys.path.insert(0,'..')
from main import *

# %%
data = pd.read_csv('../data/banana/banana.csv')
X = data[['V1', 'V2']].values
y = data['Class'].values

# Since classes are 1, 2
y = (y - 1) * 2 - 1

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.5, stratify=y, 
                                                    shuffle=True, random_state=1)

# %%
svm_arr, tree_arr = data_size_experiment(X_train, y_train, X_test, y_test,
                                         experiment_type='table', kernel='linear',
                                         random_state=157, verbose=True)
# Out:
# Progress:
# Training accuracy of rank SVM: 0.64
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.61		0.58
# 2	0.64		0.61
# 3	0.47		0.47
# /Users/Ashtekar15/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 4	0.63		0.59
# 5	0.62		0.57
# 6	0.60		0.53
# 7	0.49		0.52
# 8	0.59		0.55
# 9	0.61		0.56
# 10	0.63		0.58
# 11	0.57		0.50
# 12	0.47		0.50
# 13	0.59		0.54
# 14	0.62		0.56
# 15	0.63		0.58
# 16	0.46		0.45
# 17	0.52		0.47
# 18	0.57		0.52
# 19	0.62		0.57
# 20	0.63		0.59
# t = 2 was best iteration with accuracy 0.61
#
# -----------------------------------------------
# 1 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.61		0.56
# 2	0.61		0.57
# 3	0.40		0.42
# 4	0.62		0.58
# 5	0.61		0.58
# 6	0.61		0.57
# 7	0.43		0.47
# 8	0.59		0.55
# 9	0.62		0.57
# 10	0.63		0.58
# 11	0.46		0.45
# 12	0.45		0.50
# 13	0.64		0.60
# 14	0.62		0.54
# 15	0.42		0.50
# 16	0.51		0.45
# 17	0.63		0.58
# 18	0.45		0.42
# 19	0.51		0.53
# 20	0.63		0.59
# t = 13 was best iteration with accuracy 0.60
#
# -----------------------------------------------
# 2 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.61		0.58
# 2	0.59		0.56
# 3	0.46		0.51
# 4	0.60		0.55
# 5	0.61		0.58
# 6	0.62		0.57
# 7	0.43		0.44
# 8	0.60		0.56
# 9	0.60		0.58
# 10	0.61		0.58
# 11	0.62		0.58
# 12	0.45		0.46
# 13	0.62		0.58
# 14	0.61		0.58
# 15	0.61		0.56
# 16	0.56		0.52
# 17	0.46		0.52
# 18	0.59		0.53
# 19	0.60		0.58
# 20	0.61		0.58
# t = 11 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 3 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.61		0.58
# 2	0.62		0.58
# 3	0.39		0.43
# 4	0.61		0.58
# 5	0.61		0.58
# 6	0.61		0.59
# 7	0.63		0.58
# 8	0.51		0.53
# 9	0.61		0.57
# 10	0.60		0.56
# 11	0.58		0.56
# 12	0.58		0.55
# 13	0.45		0.49
# 14	0.50		0.45
# 15	0.61		0.58
# 16	0.58		0.54
# 17	0.45		0.48
# 18	0.60		0.57
# 19	0.50		0.45
# 20	0.44		0.49
# t = 7 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 4 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.61		0.56
# 2	0.60		0.56
# 3	0.42		0.48
# 4	0.59		0.53
# 5	0.61		0.57
# 6	0.62		0.58
# 7	0.62		0.54
# 8	0.47		0.55
# 9	0.55		0.49
# 10	0.61		0.56
# 11	0.64		0.59
# 12	0.51		0.50
# 13	0.61		0.58
# 14	0.63		0.59
# 15	0.62		0.57
# 16	0.46		0.45
# 17	0.55		0.55
# 18	0.60		0.58
# 19	0.63		0.59
# 20	0.63		0.56
# t = 11 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 5 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.60		0.56
# 2	0.51		0.47
# 3	0.49		0.54
# 4	0.51		0.47
# 5	0.59		0.55
# 6	0.61		0.58
# 7	0.46		0.46
# 8	0.60		0.58
# 9	0.62		0.57
# 10	0.59		0.56
# 11	0.49		0.54
# 12	0.51		0.47
# 13	0.60		0.55
# 14	0.63		0.59
# 15	0.53		0.48
# 16	0.46		0.48
# 17	0.63		0.59
# 18	0.59		0.54
# 19	0.47		0.55
# 20	0.53		0.47
# t = 17 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 6 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.61		0.56
# 2	0.57		0.56
# 3	0.44		0.44
# 4	0.60		0.59
# 5	0.61		0.56
# 6	0.61		0.56
# 7	0.38		0.42
# 8	0.61		0.57
# 9	0.61		0.57
# 10	0.60		0.56
# 11	0.40		0.45
# 12	0.58		0.54
# 13	0.59		0.55
# 14	0.60		0.56
# 15	0.57		0.53
# 16	0.37		0.44
# 17	0.59		0.54
# 18	0.58		0.54
# 19	0.56		0.53
# 20	0.54		0.56
# t = 16 was best iteration with accuracy 0.56
#
# -----------------------------------------------
# 7 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.61		0.58
# 2	0.60		0.56
# 3	0.50		0.56
# 4	0.56		0.50
# 5	0.60		0.56
# 6	0.63		0.58
# 7	0.43		0.40
# 8	0.46		0.51
# 9	0.54		0.49
# 10	0.64		0.60
# 11	0.48		0.43
# 12	0.41		0.47
# 13	0.51		0.46
# 14	0.64		0.59
# 15	0.51		0.51
# 16	0.52		0.52
# 17	0.64		0.60
# 18	0.57		0.52
# 19	0.39		0.45
# 20	0.52		0.45
# t = 10 was best iteration with accuracy 0.60
#
# -----------------------------------------------
# 8 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.61		0.56
# 2	0.51		0.47
# 3	0.36		0.40
# 4	0.63		0.58
# 5	0.62		0.58
# 6	0.61		0.57
# 7	0.49		0.49
# 8	0.56		0.49
# 9	0.58		0.52
# 10	0.61		0.59
# 11	0.58		0.55
# 12	0.52		0.52
# 13	0.60		0.57
# 14	0.63		0.60
# 15	0.47		0.46
# 16	0.63		0.59
# 17	0.59		0.55
# 18	0.52		0.53
# 19	0.55		0.52
# 20	0.59		0.58
# t = 3 was best iteration with accuracy 0.60
#
# -----------------------------------------------
# 9 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.61		0.58
# 2	0.63		0.58
# 3	0.41		0.43
# 4	0.62		0.57
# 5	0.61		0.58
# 6	0.60		0.57
# 7	0.45		0.51
# 8	0.58		0.51
# 9	0.60		0.56
# 10	0.61		0.58
# 11	0.63		0.58
# 12	0.42		0.44
# 13	0.61		0.57
# 14	0.61		0.56
# 15	0.60		0.56
# 16	0.41		0.46
# 17	0.59		0.54
# 18	0.60		0.57
# 19	0.61		0.58
# 20	0.61		0.58
# t = 2 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 10 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.61		0.58
# 2	0.61		0.56
# 3	0.40		0.43
# 4	0.61		0.57
# 5	0.60		0.56
# 6	0.60		0.57
# 7	0.37		0.41
# 8	0.61		0.58
# 9	0.60		0.57
# 10	0.59		0.56
# 11	0.53		0.50
# 12	0.37		0.42
# 13	0.61		0.56
# 14	0.60		0.56
# 15	0.59		0.56
# 16	0.38		0.44
# 17	0.59		0.54
# 18	0.60		0.56
# 19	0.61		0.56
# 20	0.58		0.54
# t = 7 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 11 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.61		0.57
# 2	0.60		0.56
# 3	0.37		0.42
# 4	0.61		0.58
# 5	0.61		0.58
# 6	0.62		0.58
# 7	0.44		0.42
# 8	0.46		0.49
# 9	0.63		0.59
# 10	0.59		0.53
# 11	0.43		0.47
# 12	0.51		0.44
# 13	0.60		0.55
# 14	0.64		0.60
# 15	0.53		0.52
# 16	0.58		0.57
# 17	0.63		0.59
# 18	0.59		0.56
# 19	0.49		0.56
# 20	0.54		0.49
# t = 14 was best iteration with accuracy 0.60
#
# -----------------------------------------------
# 12 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.61		0.57
# 2	0.61		0.57
# 3	0.41		0.46
# 4	0.60		0.56
# 5	0.61		0.57
# 6	0.61		0.56
# 7	0.61		0.57
# 8	0.39		0.42
# 9	0.61		0.57
# 10	0.61		0.57
# 11	0.61		0.58
# 12	0.45		0.46
# 13	0.61		0.59
# 14	0.59		0.56
# 15	0.58		0.56
# 16	0.51		0.50
# 17	0.59		0.58
# 18	0.62		0.58
# 19	0.62		0.57
# 20	0.41		0.45
# t = 19 was best iteration with accuracy 0.57
#
# -----------------------------------------------
# 13 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.61		0.58
# 2	0.64		0.59
# 3	0.42		0.44
# 4	0.61		0.59
# 5	0.61		0.58
# 6	0.60		0.57
# 7	0.44		0.50
# 8	0.59		0.54
# 9	0.60		0.57
# 10	0.61		0.57
# 11	0.63		0.58
# 12	0.42		0.44
# 13	0.62		0.58
# 14	0.61		0.58
# 15	0.61		0.58
# 16	0.41		0.44
# 17	0.60		0.56
# 18	0.61		0.58
# 19	0.61		0.58
# 20	0.48		0.51
# t = 2 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 14 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.61		0.58
# 2	0.62		0.58
# 3	0.38		0.42
# 4	0.62		0.58
# 5	0.60		0.56
# 6	0.61		0.57
# 7	0.40		0.41
# 8	0.62		0.59
# 9	0.63		0.58
# 10	0.61		0.58
# 11	0.62		0.58
# 12	0.44		0.46
# 13	0.64		0.59
# 14	0.63		0.57
# 15	0.63		0.56
# 16	0.51		0.54
# 17	0.64		0.60
# 18	0.65		0.59
# 19	0.63		0.58
# 20	0.46		0.45
# t = 18 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 15 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.61		0.57
# 2	0.64		0.60
# 3	0.43		0.44
# 4	0.62		0.60
# 5	0.61		0.58
# 6	0.61		0.58
# 7	0.36		0.40
# 8	0.62		0.57
# 9	0.61		0.59
# 10	0.61		0.58
# 11	0.60		0.55
# 12	0.43		0.44
# 13	0.61		0.58
# 14	0.61		0.57
# 15	0.53		0.51
# 16	0.47		0.55
# 17	0.51		0.45
# 18	0.59		0.54
# 19	0.61		0.57
# 20	0.45		0.45
# t = 2 was best iteration with accuracy 0.60
#
# -----------------------------------------------
# 16 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.61		0.58
# 2	0.61		0.58
# 3	0.40		0.44
# 4	0.60		0.57
# 5	0.61		0.57
# 6	0.60		0.56
# 7	0.57		0.54
# 8	0.37		0.42
# 9	0.60		0.57
# 10	0.60		0.56
# 11	0.60		0.56
# 12	0.41		0.43
# 13	0.61		0.58
# 14	0.60		0.57
# 15	0.59		0.55
# 16	0.48		0.47
# 17	0.36		0.40
# 18	0.60		0.58
# 19	0.60		0.56
# 20	0.60		0.56
# t = 17 was best iteration with accuracy 0.60
#
# -----------------------------------------------
# 17 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.61		0.58
# 2	0.60		0.57
# 3	0.39		0.42
# 4	0.62		0.57
# 5	0.61		0.58
# 6	0.61		0.58
# 7	0.58		0.57
# 8	0.58		0.53
# 9	0.58		0.56
# 10	0.53		0.50
# 11	0.46		0.45
# 12	0.58		0.53
# 13	0.51		0.51
# 14	0.50		0.47
# 15	0.46		0.46
# 16	0.55		0.50
# 17	0.58		0.57
# 18	0.59		0.52
# 19	0.44		0.44
# 20	0.52		0.49
# t = 4 was best iteration with accuracy 0.57
#
# -----------------------------------------------
# 18 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.60		0.56
# 2	0.56		0.53
# 3	0.36		0.41
# 4	0.61		0.57
# 5	0.61		0.57
# 6	0.60		0.56
# 7	0.43		0.51
# 8	0.59		0.53
# 9	0.61		0.57
# 10	0.61		0.58
# 11	0.60		0.57
# 12	0.45		0.51
# 13	0.58		0.52
# 14	0.60		0.56
# 15	0.60		0.56
# 16	0.52		0.47
# 17	0.49		0.54
# 18	0.55		0.49
# 19	0.61		0.57
# 20	0.61		0.58
# t = 3 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 19 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.61		0.59
# 2	0.62		0.57
# 3	0.41		0.45
# 4	0.60		0.57
# 5	0.62		0.58
# 6	0.64		0.58
# 7	0.42		0.45
# 8	0.61		0.58
# 9	0.62		0.58
# 10	0.63		0.59
# 11	0.47		0.48
# 12	0.63		0.59
# 13	0.63		0.59
# 14	0.63		0.58
# 15	0.62		0.54
# 16	0.50		0.52
# 17	0.57		0.52
# 18	0.61		0.57
# 19	0.64		0.58
# 20	0.45		0.44
# t = 6 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 20 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.60		0.56
# 2	0.56		0.52
# 3	0.43		0.48
# 4	0.58		0.52
# 5	0.60		0.57
# 6	0.61		0.57
# 7	0.53		0.47
# 8	0.44		0.51
# 9	0.52		0.46
# 10	0.60		0.57
# 11	0.51		0.48
# 12	0.48		0.52
# 13	0.53		0.47
# 14	0.60		0.56
# 15	0.59		0.56
# 16	0.61		0.56
# 17	0.41		0.45
# 18	0.50		0.44
# 19	0.60		0.57
# 20	0.61		0.55
# t = 16 was best iteration with accuracy 0.56
#
# -----------------------------------------------
# 21 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.61		0.56
# 2	0.61		0.58
# 3	0.41		0.46
# 4	0.59		0.55
# 5	0.61		0.59
# 6	0.62		0.58
# 7	0.45		0.44
# 8	0.51		0.51
# 9	0.63		0.59
# 10	0.58		0.52
# 11	0.44		0.48
# 12	0.53		0.47
# 13	0.58		0.53
# 14	0.60		0.57
# 15	0.51		0.49
# 16	0.57		0.56
# 17	0.61		0.58
# 18	0.59		0.55
# 19	0.48		0.54
# 20	0.55		0.49
# t = 9 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 22 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.61		0.57
# 2	0.58		0.56
# 3	0.42		0.43
# 4	0.63		0.59
# 5	0.63		0.59
# 6	0.62		0.56
# 7	0.48		0.53
# 8	0.55		0.49
# 9	0.60		0.56
# 10	0.61		0.58
# 11	0.61		0.56
# 12	0.48		0.55
# 13	0.55		0.49
# 14	0.63		0.59
# 15	0.62		0.54
# 16	0.48		0.52
# 17	0.58		0.53
# 18	0.62		0.57
# 19	0.63		0.58
# 20	0.47		0.46
# t = 19 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 23 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.61		0.56
# 2	0.59		0.56
# 3	0.40		0.41
# 4	0.61		0.57
# 5	0.60		0.56
# 6	0.53		0.50
# 7	0.37		0.41
# 8	0.60		0.56
# 9	0.58		0.56
# 10	0.56		0.52
# 11	0.54		0.55
# 12	0.37		0.42
# 13	0.55		0.54
# 14	0.51		0.48
# 15	0.54		0.56
# 16	0.51		0.56
# 17	0.56		0.53
# 18	0.56		0.53
# 19	0.51		0.48
# 20	0.54		0.55
# t = 7 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 24 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.60		0.56
# 2	0.58		0.57
# 3	0.57		0.54
# 4	0.56		0.55
# 5	0.60		0.56
# 6	0.52		0.50
# 7	0.37		0.40
# 8	0.60		0.57
# 9	0.59		0.57
# 10	0.57		0.54
# 11	0.42		0.45
# 12	0.62		0.58
# 13	0.61		0.57
# 14	0.61		0.56
# 15	0.55		0.51
# 16	0.40		0.44
# 17	0.60		0.56
# 18	0.61		0.57
# 19	0.60		0.56
# 20	0.38		0.45
# t = 7 was best iteration with accuracy 0.60
#
# -----------------------------------------------
# 25 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.61		0.58
# 2	0.60		0.56
# 3	0.49		0.53
# 4	0.58		0.53
# 5	0.61		0.56
# 6	0.61		0.57
# 7	0.41		0.43
# 8	0.60		0.59
# 9	0.61		0.58
# 10	0.60		0.56
# 11	0.53		0.57
# 12	0.51		0.44
# 13	0.58		0.53
# 14	0.59		0.57
# 15	0.60		0.53
# 16	0.42		0.45
# 17	0.59		0.56
# 18	0.59		0.57
# 19	0.38		0.41
# 20	0.63		0.59
# t = 20 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 26 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.61		0.58
# 2	0.63		0.58
# 3	0.42		0.44
# 4	0.62		0.58
# 5	0.61		0.58
# 6	0.61		0.58
# 7	0.45		0.47
# 8	0.61		0.57
# 9	0.61		0.57
# 10	0.60		0.56
# 11	0.58		0.56
# 12	0.38		0.41
# 13	0.63		0.59
# 14	0.62		0.58
# 15	0.61		0.58
# 16	0.47		0.50
# 17	0.61		0.57
# 18	0.62		0.57
# 19	0.63		0.58
# 20	0.52		0.47
# t = 2 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 27 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.61		0.58
# 2	0.61		0.58
# 3	0.39		0.42
# 4	0.61		0.58
# 5	0.61		0.58
# 6	0.61		0.58
# 7	0.43		0.49
# 8	0.59		0.55
# 9	0.60		0.58
# 10	0.61		0.58
# 11	0.63		0.57
# 12	0.49		0.52
# 13	0.58		0.51
# 14	0.60		0.56
# 15	0.63		0.58
# 16	0.59		0.52
# 17	0.50		0.53
# 18	0.58		0.53
# 19	0.62		0.57
# 20	0.63		0.59
# t = 20 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 28 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.60		0.56
# 2	0.57		0.56
# 3	0.42		0.43
# 4	0.59		0.59
# 5	0.58		0.57
# 6	0.57		0.53
# 7	0.42		0.51
# 8	0.53		0.48
# 9	0.57		0.54
# 10	0.59		0.56
# 11	0.52		0.49
# 12	0.48		0.55
# 13	0.50		0.46
# 14	0.59		0.54
# 15	0.63		0.58
# 16	0.53		0.51
# 17	0.58		0.57
# 18	0.62		0.58
# 19	0.57		0.52
# 20	0.45		0.49
# t = 15 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 29 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.61		0.56
# 2	0.58		0.56
# 3	0.37		0.41
# 4	0.57		0.56
# 5	0.55		0.52
# 6	0.49		0.50
# 7	0.45		0.46
# 8	0.58		0.57
# 9	0.57		0.55
# 10	0.51		0.48
# 11	0.56		0.60
# 12	0.55		0.52
# 13	0.58		0.54
# 14	0.57		0.55
# 15	0.51		0.48
# 16	0.50		0.57
# 17	0.57		0.52
# 18	0.59		0.55
# 19	0.57		0.55
# 20	0.51		0.47
# t = 3 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 30 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.61		0.57
# 2	0.63		0.58
# 3	0.41		0.42
# 4	0.63		0.58
# 5	0.61		0.58
# 6	0.61		0.57
# 7	0.40		0.42
# 8	0.60		0.57
# 9	0.60		0.57
# 10	0.62		0.58
# 11	0.63		0.58
# 12	0.41		0.43
# 13	0.63		0.58
# 14	0.62		0.58
# 15	0.62		0.57
# 16	0.46		0.45
# 17	0.51		0.46
# 18	0.58		0.53
# 19	0.61		0.58
# 20	0.65		0.60
# t = 20 was best iteration with accuracy 0.60
#
# -----------------------------------------------
# 31 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.60		0.56
# 2	0.57		0.54
# 3	0.37		0.41
# 4	0.61		0.57
# 5	0.61		0.57
# 6	0.60		0.56
# 7	0.56		0.60
# 8	0.57		0.51
# 9	0.59		0.55
# 10	0.60		0.56
# 11	0.59		0.56
# 12	0.37		0.42
# 13	0.63		0.58
# 14	0.62		0.58
# 15	0.61		0.57
# 16	0.57		0.56
# 17	0.39		0.41
# 18	0.61		0.58
# 19	0.58		0.55
# 20	0.44		0.44
# t = 3 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 32 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.61		0.57
# 2	0.59		0.55
# 3	0.43		0.49
# 4	0.58		0.53
# 5	0.59		0.56
# 6	0.60		0.56
# 7	0.57		0.55
# 8	0.37		0.42
# 9	0.62		0.58
# 10	0.62		0.58
# 11	0.61		0.57
# 12	0.46		0.46
# 13	0.52		0.45
# 14	0.56		0.50
# 15	0.64		0.60
# 16	0.48		0.45
# 17	0.45		0.49
# 18	0.64		0.60
# 19	0.59		0.53
# 20	0.39		0.45
# t = 15 was best iteration with accuracy 0.60
#
# -----------------------------------------------
# 33 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.61		0.57
# 2	0.61		0.58
# 3	0.39		0.42
# 4	0.61		0.58
# 5	0.61		0.59
# 6	0.61		0.58
# 7	0.40		0.45
# 8	0.52		0.44
# 9	0.57		0.51
# 10	0.61		0.58
# 11	0.62		0.58
# 12	0.38		0.41
# 13	0.60		0.57
# 14	0.60		0.56
# 15	0.57		0.54
# 16	0.47		0.51
# 17	0.61		0.58
# 18	0.61		0.57
# 19	0.58		0.55
# 20	0.50		0.48
# t = 12 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 34 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.61		0.56
# 2	0.60		0.57
# 3	0.39		0.43
# 4	0.61		0.56
# 5	0.60		0.56
# 6	0.60		0.56
# 7	0.40		0.48
# 8	0.61		0.57
# 9	0.61		0.57
# 10	0.61		0.56
# 11	0.60		0.56
# 12	0.40		0.43
# 13	0.59		0.56
# 14	0.61		0.56
# 15	0.59		0.55
# 16	0.36		0.41
# 17	0.61		0.57
# 18	0.61		0.57
# 19	0.61		0.57
# 20	0.61		0.57
# t = 16 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 35 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.60		0.56
# 2	0.57		0.54
# 3	0.40		0.44
# 4	0.59		0.55
# 5	0.61		0.56
# 6	0.60		0.57
# 7	0.52		0.49
# 8	0.45		0.51
# 9	0.51		0.46
# 10	0.63		0.59
# 11	0.61		0.53
# 12	0.45		0.50
# 13	0.54		0.48
# 14	0.63		0.57
# 15	0.60		0.53
# 16	0.56		0.53
# 17	0.64		0.60
# 18	0.63		0.59
# 19	0.63		0.58
# 20	0.62		0.53
# t = 17 was best iteration with accuracy 0.60
#
# -----------------------------------------------
# 36 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.61		0.58
# 2	0.56		0.53
# 3	0.48		0.55
# 4	0.52		0.47
# 5	0.59		0.55
# 6	0.61		0.58
# 7	0.59		0.54
# 8	0.49		0.55
# 9	0.56		0.50
# 10	0.60		0.58
# 11	0.64		0.60
# 12	0.49		0.48
# 13	0.61		0.59
# 14	0.60		0.58
# 15	0.64		0.60
# 16	0.46		0.46
# 17	0.62		0.59
# 18	0.61		0.58
# 19	0.61		0.58
# 20	0.41		0.44
# t = 11 was best iteration with accuracy 0.60
#
# -----------------------------------------------
# 37 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.60		0.57
# 2	0.57		0.55
# 3	0.38		0.41
# 4	0.61		0.58
# 5	0.61		0.57
# 6	0.60		0.56
# 7	0.57		0.54
# 8	0.36		0.41
# 9	0.61		0.57
# 10	0.60		0.56
# 11	0.59		0.54
# 12	0.50		0.49
# 13	0.59		0.54
# 14	0.60		0.58
# 15	0.50		0.45
# 16	0.41		0.45
# 17	0.53		0.46
# 18	0.61		0.59
# 19	0.61		0.56
# 20	0.45		0.50
# t = 8 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 38 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.61		0.57
# 2	0.61		0.57
# 3	0.39		0.42
# 4	0.59		0.55
# 5	0.60		0.56
# 6	0.59		0.56
# 7	0.55		0.53
# 8	0.61		0.58
# 9	0.60		0.57
# 10	0.60		0.56
# 11	0.48		0.50
# 12	0.40		0.44
# 13	0.60		0.57
# 14	0.61		0.57
# 15	0.60		0.57
# 16	0.48		0.48
# 17	0.60		0.55
# 18	0.56		0.55
# 19	0.52		0.50
# 20	0.48		0.49
# t = 1 was best iteration with accuracy 0.57
#
# -----------------------------------------------
# 39 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.61		0.57
# 2	0.59		0.56
# 3	0.50		0.55
# 4	0.55		0.50
# 5	0.60		0.57
# 6	0.61		0.58
# 7	0.55		0.49
# 8	0.42		0.46
# 9	0.61		0.58
# 10	0.62		0.58
# 11	0.61		0.57
# 12	0.46		0.45
# 13	0.58		0.55
# 14	0.58		0.57
# 15	0.57		0.52
# 16	0.49		0.53
# 17	0.54		0.47
# 18	0.62		0.59
# 19	0.51		0.45
# 20	0.50		0.53
# t = 18 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 40 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.61		0.57
# 2	0.61		0.57
# 3	0.38		0.42
# 4	0.62		0.59
# 5	0.62		0.58
# 6	0.62		0.57
# 7	0.52		0.47
# 8	0.48		0.49
# 9	0.63		0.59
# 10	0.61		0.57
# 11	0.49		0.52
# 12	0.57		0.53
# 13	0.60		0.58
# 14	0.51		0.47
# 15	0.45		0.50
# 16	0.52		0.45
# 17	0.63		0.60
# 18	0.51		0.45
# 19	0.45		0.50
# 20	0.61		0.56
# t = 9 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 41 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.61		0.58
# 2	0.63		0.57
# 3	0.42		0.46
# 4	0.59		0.55
# 5	0.61		0.58
# 6	0.63		0.59
# 7	0.49		0.49
# 8	0.61		0.59
# 9	0.60		0.56
# 10	0.58		0.55
# 11	0.36		0.40
# 12	0.61		0.57
# 13	0.60		0.56
# 14	0.59		0.56
# 15	0.53		0.51
# 16	0.41		0.46
# 17	0.59		0.54
# 18	0.60		0.58
# 19	0.62		0.59
# 20	0.64		0.58
# t = 20 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 42 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.61		0.57
# 2	0.55		0.52
# 3	0.49		0.54
# 4	0.55		0.49
# 5	0.60		0.56
# 6	0.61		0.58
# 7	0.44		0.45
# 8	0.61		0.58
# 9	0.63		0.59
# 10	0.61		0.57
# 11	0.51		0.57
# 12	0.55		0.49
# 13	0.59		0.55
# 14	0.56		0.55
# 15	0.42		0.44
# 16	0.61		0.59
# 17	0.61		0.58
# 18	0.59		0.55
# 19	0.48		0.52
# 20	0.55		0.49
# t = 9 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 43 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.61		0.58
# 2	0.62		0.57
# 3	0.38		0.41
# 4	0.61		0.58
# 5	0.61		0.57
# 6	0.60		0.56
# 7	0.51		0.48
# 8	0.48		0.55
# 9	0.54		0.48
# 10	0.61		0.57
# 11	0.61		0.57
# 12	0.39		0.41
# 13	0.61		0.58
# 14	0.60		0.56
# 15	0.57		0.55
# 16	0.37		0.41
# 17	0.60		0.58
# 18	0.58		0.56
# 19	0.56		0.53
# 20	0.49		0.55
# t = 16 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 44 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.60		0.56
# 2	0.58		0.56
# 3	0.44		0.44
# 4	0.61		0.59
# 5	0.59		0.55
# 6	0.48		0.46
# 7	0.43		0.44
# 8	0.61		0.58
# 9	0.57		0.54
# 10	0.54		0.54
# 11	0.58		0.53
# 12	0.56		0.55
# 13	0.51		0.48
# 14	0.43		0.43
# 15	0.56		0.50
# 16	0.57		0.56
# 17	0.55		0.50
# 18	0.41		0.44
# 19	0.50		0.45
# 20	0.52		0.51
# t = 4 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 45 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.60		0.57
# 2	0.60		0.57
# 3	0.44		0.44
# 4	0.61		0.58
# 5	0.60		0.56
# 6	0.58		0.55
# 7	0.37		0.42
# 8	0.61		0.57
# 9	0.60		0.56
# 10	0.58		0.54
# 11	0.56		0.56
# 12	0.57		0.54
# 13	0.60		0.57
# 14	0.52		0.46
# 15	0.44		0.47
# 16	0.52		0.45
# 17	0.58		0.54
# 18	0.49		0.47
# 19	0.57		0.51
# 20	0.51		0.53
# t = 7 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 46 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.62		0.58
# 2	0.58		0.52
# 3	0.49		0.56
# 4	0.53		0.47
# 5	0.60		0.57
# 6	0.61		0.57
# 7	0.52		0.50
# 8	0.59		0.58
# 9	0.62		0.57
# 10	0.61		0.56
# 11	0.45		0.47
# 12	0.53		0.48
# 13	0.60		0.56
# 14	0.63		0.59
# 15	0.60		0.53
# 16	0.44		0.47
# 17	0.52		0.45
# 18	0.63		0.59
# 19	0.62		0.56
# 20	0.47		0.55
# t = 14 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 47 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.61		0.57
# 2	0.62		0.57
# 3	0.38		0.42
# 4	0.62		0.58
# 5	0.61		0.59
# 6	0.61		0.58
# 7	0.49		0.54
# 8	0.57		0.51
# 9	0.60		0.56
# 10	0.63		0.57
# 11	0.62		0.56
# 12	0.44		0.45
# 13	0.64		0.60
# 14	0.63		0.58
# 15	0.62		0.54
# 16	0.45		0.45
# 17	0.61		0.56
# 18	0.62		0.57
# 19	0.63		0.58
# 20	0.46		0.43
# t = 13 was best iteration with accuracy 0.60
#
# -----------------------------------------------
# 48 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.60		0.56
# 2	0.61		0.57
# 3	0.36		0.40
# 4	0.61		0.57
# 5	0.60		0.56
# 6	0.59		0.56
# 7	0.56		0.53
# 8	0.50		0.56
# 9	0.59		0.54
# 10	0.60		0.56
# 11	0.61		0.56
# 12	0.56		0.53
# 13	0.41		0.46
# 14	0.58		0.53
# 15	0.60		0.56
# 16	0.61		0.57
# 17	0.60		0.52
# 18	0.46		0.49
# 19	0.62		0.58
# 20	0.51		0.46
# t = 3 was best iteration with accuracy 0.60
#
# -----------------------------------------------
# 49 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.61		0.57
# 2	0.63		0.59
# 3	0.50		0.50
# 4	0.63		0.59
# 5	0.58		0.53
# 6	0.41		0.46
# 7	0.52		0.45
# 8	0.59		0.53
# 9	0.63		0.58
# 10	0.55		0.53
# 11	0.57		0.56
# 12	0.62		0.58
# 13	0.59		0.56
# 14	0.47		0.52
# 15	0.53		0.46
# 16	0.52		0.48
# 17	0.61		0.58
# 18	0.62		0.57
# 19	0.41		0.45
# 20	0.60		0.57
# t = 9 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 50 / 100 complete
# -----------------------------------------------
#
# Training accuracy of rank SVM: 0.58
# /Users/Ashtekar15/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.60		0.55
# 2	0.60		0.55
# 3	0.44		0.43
# 4	0.41		0.46
# 5	0.51		0.45
# 6	0.61		0.57
# 7	0.57		0.49
# 8	0.46		0.49
# 9	0.52		0.44
# 10	0.60		0.58
# 11	0.55		0.49
# 12	0.52		0.53
# 13	0.54		0.47
# 14	0.64		0.59
# 15	0.54		0.50
# 16	0.50		0.52
# 17	0.57		0.51
# 18	0.63		0.58
# 19	0.50		0.46
# 20	0.41		0.46
# t = 14 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 51 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.59		0.55
# 2	0.58		0.54
# 3	0.58		0.56
# 4	0.45		0.45
# 5	0.61		0.58
# 6	0.60		0.57
# 7	0.60		0.54
# 8	0.60		0.56
# 9	0.38		0.41
# 10	0.61		0.57
# 11	0.60		0.56
# 12	0.59		0.55
# 13	0.58		0.54
# 14	0.55		0.52
# 15	0.52		0.55
# 16	0.51		0.45
# 17	0.58		0.52
# 18	0.59		0.54
# 19	0.59		0.54
# 20	0.61		0.58
# t = 9 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 52 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.59		0.54
# 2	0.60		0.54
# 3	0.61		0.57
# 4	0.42		0.43
# 5	0.61		0.58
# 6	0.60		0.56
# 7	0.60		0.54
# 8	0.59		0.55
# 9	0.62		0.56
# 10	0.43		0.44
# 11	0.62		0.58
# 12	0.61		0.58
# 13	0.60		0.56
# 14	0.60		0.55
# 15	0.60		0.55
# 16	0.62		0.57
# 17	0.40		0.42
# 18	0.62		0.58
# 19	0.60		0.55
# 20	0.60		0.56
# t = 18 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 53 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.59		0.55
# 2	0.59		0.54
# 3	0.59		0.55
# 4	0.39		0.42
# 5	0.61		0.58
# 6	0.60		0.56
# 7	0.58		0.54
# 8	0.57		0.54
# 9	0.53		0.51
# 10	0.39		0.42
# 11	0.61		0.57
# 12	0.60		0.56
# 13	0.59		0.54
# 14	0.58		0.54
# 15	0.57		0.53
# 16	0.55		0.55
# 17	0.45		0.53
# 18	0.51		0.44
# 19	0.59		0.54
# 20	0.60		0.56
# t = 10 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 54 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.59		0.56
# 2	0.59		0.53
# 3	0.57		0.57
# 4	0.50		0.49
# 5	0.61		0.59
# 6	0.59		0.55
# 7	0.58		0.53
# 8	0.59		0.55
# 9	0.39		0.42
# 10	0.61		0.58
# 11	0.60		0.57
# 12	0.59		0.55
# 13	0.58		0.54
# 14	0.57		0.52
# 15	0.62		0.58
# 16	0.43		0.46
# 17	0.53		0.45
# 18	0.58		0.54
# 19	0.52		0.48
# 20	0.47		0.45
# t = 15 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 55 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.60		0.54
# 2	0.60		0.55
# 3	0.60		0.56
# 4	0.47		0.51
# 5	0.58		0.52
# 6	0.59		0.53
# 7	0.59		0.54
# 8	0.59		0.54
# 9	0.59		0.54
# 10	0.40		0.43
# 11	0.61		0.57
# 12	0.60		0.57
# 13	0.59		0.56
# 14	0.60		0.55
# 15	0.60		0.55
# 16	0.60		0.56
# 17	0.56		0.49
# 18	0.48		0.55
# 19	0.52		0.47
# 20	0.59		0.53
# t = 11 was best iteration with accuracy 0.57
#
# -----------------------------------------------
# 56 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.59		0.55
# 2	0.59		0.54
# 3	0.60		0.56
# 4	0.41		0.42
# 5	0.60		0.58
# 6	0.59		0.56
# 7	0.59		0.55
# 8	0.59		0.54
# 9	0.51		0.48
# 10	0.47		0.54
# 11	0.51		0.45
# 12	0.55		0.51
# 13	0.57		0.54
# 14	0.56		0.52
# 15	0.52		0.49
# 16	0.53		0.57
# 17	0.52		0.44
# 18	0.55		0.51
# 19	0.57		0.54
# 20	0.56		0.52
# t = 5 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 57 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.59		0.54
# 2	0.59		0.54
# 3	0.60		0.56
# 4	0.41		0.42
# 5	0.62		0.58
# 6	0.61		0.58
# 7	0.59		0.54
# 8	0.59		0.55
# 9	0.58		0.53
# 10	0.48		0.55
# 11	0.51		0.45
# 12	0.56		0.50
# 13	0.58		0.53
# 14	0.58		0.54
# 15	0.57		0.54
# 16	0.55		0.52
# 17	0.37		0.41
# 18	0.61		0.58
# 19	0.59		0.56
# 20	0.58		0.55
# t = 17 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 58 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.60		0.54
# 2	0.60		0.56
# 3	0.59		0.53
# 4	0.47		0.52
# 5	0.58		0.52
# 6	0.59		0.54
# 7	0.60		0.55
# 8	0.60		0.56
# 9	0.62		0.56
# 10	0.44		0.43
# 11	0.60		0.56
# 12	0.60		0.55
# 13	0.60		0.55
# 14	0.60		0.56
# 15	0.61		0.56
# 16	0.63		0.56
# 17	0.56		0.55
# 18	0.62		0.58
# 19	0.61		0.58
# 20	0.60		0.57
# t = 16 was best iteration with accuracy 0.56
#
# -----------------------------------------------
# 59 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.60		0.55
# 2	0.60		0.54
# 3	0.63		0.59
# 4	0.46		0.45
# 5	0.62		0.60
# 6	0.61		0.58
# 7	0.59		0.53
# 8	0.63		0.59
# 9	0.55		0.55
# 10	0.59		0.58
# 11	0.61		0.58
# 12	0.60		0.55
# 13	0.62		0.56
# 14	0.52		0.52
# 15	0.57		0.57
# 16	0.62		0.58
# 17	0.59		0.54
# 18	0.63		0.58
# 19	0.55		0.56
# 20	0.60		0.58
# t = 18 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 60 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.59		0.54
# 2	0.60		0.56
# 3	0.62		0.56
# 4	0.44		0.48
# 5	0.59		0.54
# 6	0.60		0.55
# 7	0.60		0.56
# 8	0.60		0.56
# 9	0.62		0.56
# 10	0.47		0.49
# 11	0.58		0.52
# 12	0.59		0.53
# 13	0.60		0.54
# 14	0.59		0.55
# 15	0.60		0.54
# 16	0.62		0.56
# 17	0.41		0.44
# 18	0.60		0.55
# 19	0.60		0.55
# 20	0.59		0.54
# t = 3 was best iteration with accuracy 0.56
#
# -----------------------------------------------
# 61 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.59		0.56
# 2	0.59		0.55
# 3	0.58		0.54
# 4	0.40		0.45
# 5	0.59		0.55
# 6	0.59		0.55
# 7	0.60		0.54
# 8	0.59		0.55
# 9	0.60		0.54
# 10	0.42		0.48
# 11	0.60		0.54
# 12	0.60		0.54
# 13	0.60		0.54
# 14	0.60		0.55
# 15	0.60		0.55
# 16	0.60		0.55
# 17	0.47		0.54
# 18	0.53		0.47
# 19	0.57		0.51
# 20	0.59		0.54
# t = 14 was best iteration with accuracy 0.55
#
# -----------------------------------------------
# 62 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.59		0.55
# 2	0.59		0.53
# 3	0.59		0.56
# 4	0.41		0.43
# 5	0.61		0.58
# 6	0.60		0.56
# 7	0.59		0.55
# 8	0.59		0.54
# 9	0.59		0.55
# 10	0.41		0.42
# 11	0.60		0.57
# 12	0.59		0.55
# 13	0.57		0.54
# 14	0.56		0.52
# 15	0.56		0.56
# 16	0.49		0.53
# 17	0.52		0.46
# 18	0.57		0.53
# 19	0.58		0.54
# 20	0.56		0.53
# t = 5 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 63 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.60		0.55
# 2	0.60		0.55
# 3	0.63		0.56
# 4	0.44		0.48
# 5	0.58		0.52
# 6	0.59		0.53
# 7	0.60		0.54
# 8	0.60		0.55
# 9	0.60		0.55
# 10	0.61		0.56
# 11	0.41		0.45
# 12	0.60		0.56
# 13	0.60		0.55
# 14	0.60		0.55
# 15	0.61		0.56
# 16	0.62		0.56
# 17	0.47		0.53
# 18	0.56		0.50
# 19	0.59		0.53
# 20	0.60		0.56
# t = 3 was best iteration with accuracy 0.56
#
# -----------------------------------------------
# 64 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.59		0.55
# 2	0.59		0.55
# 3	0.59		0.55
# 4	0.37		0.41
# 5	0.62		0.58
# 6	0.61		0.58
# 7	0.60		0.56
# 8	0.60		0.55
# 9	0.60		0.56
# 10	0.60		0.54
# 11	0.47		0.56
# 12	0.53		0.47
# 13	0.58		0.52
# 14	0.60		0.55
# 15	0.61		0.56
# 16	0.62		0.56
# 17	0.47		0.47
# 18	0.60		0.55
# 19	0.60		0.55
# 20	0.60		0.56
# t = 4 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 65 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.59		0.55
# 2	0.59		0.54
# 3	0.59		0.54
# 4	0.39		0.43
# 5	0.59		0.55
# 6	0.59		0.55
# 7	0.59		0.55
# 8	0.59		0.54
# 9	0.58		0.54
# 10	0.56		0.54
# 11	0.40		0.42
# 12	0.59		0.57
# 13	0.59		0.55
# 14	0.56		0.53
# 15	0.52		0.49
# 16	0.55		0.55
# 17	0.60		0.57
# 18	0.60		0.56
# 19	0.58		0.54
# 20	0.57		0.54
# t = 4 was best iteration with accuracy 0.57
#
# -----------------------------------------------
# 66 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.59		0.54
# 2	0.60		0.56
# 3	0.59		0.53
# 4	0.43		0.48
# 5	0.51		0.45
# 6	0.59		0.53
# 7	0.60		0.55
# 8	0.60		0.56
# 9	0.43		0.45
# 10	0.56		0.50
# 11	0.58		0.52
# 12	0.59		0.54
# 13	0.60		0.55
# 14	0.59		0.55
# 15	0.60		0.55
# 16	0.43		0.43
# 17	0.52		0.50
# 18	0.64		0.59
# 19	0.58		0.52
# 20	0.64		0.58
# t = 20 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 67 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.60		0.57
# 2	0.60		0.55
# 3	0.64		0.58
# 4	0.44		0.46
# 5	0.62		0.59
# 6	0.61		0.58
# 7	0.60		0.56
# 8	0.60		0.55
# 9	0.57		0.51
# 10	0.45		0.46
# 11	0.62		0.58
# 12	0.60		0.57
# 13	0.60		0.55
# 14	0.60		0.55
# 15	0.56		0.51
# 16	0.53		0.51
# 17	0.61		0.59
# 18	0.62		0.57
# 19	0.62		0.56
# 20	0.42		0.41
# t = 3 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 68 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.60		0.56
# 2	0.60		0.54
# 3	0.60		0.57
# 4	0.41		0.42
# 5	0.62		0.58
# 6	0.61		0.58
# 7	0.60		0.57
# 8	0.59		0.55
# 9	0.60		0.56
# 10	0.47		0.50
# 11	0.60		0.54
# 12	0.60		0.55
# 13	0.60		0.55
# 14	0.60		0.56
# 15	0.61		0.56
# 16	0.58		0.52
# 17	0.47		0.47
# 18	0.62		0.59
# 19	0.60		0.57
# 20	0.60		0.55
# t = 5 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 69 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.60		0.56
# 2	0.60		0.54
# 3	0.60		0.58
# 4	0.42		0.44
# 5	0.60		0.58
# 6	0.60		0.56
# 7	0.58		0.54
# 8	0.55		0.52
# 9	0.49		0.47
# 10	0.42		0.42
# 11	0.59		0.57
# 12	0.59		0.55
# 13	0.57		0.54
# 14	0.53		0.51
# 15	0.55		0.55
# 16	0.43		0.43
# 17	0.58		0.56
# 18	0.58		0.53
# 19	0.54		0.51
# 20	0.50		0.48
# t = 3 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 70 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.60		0.55
# 2	0.60		0.55
# 3	0.62		0.56
# 4	0.43		0.47
# 5	0.61		0.57
# 6	0.61		0.56
# 7	0.60		0.56
# 8	0.61		0.56
# 9	0.62		0.56
# 10	0.50		0.45
# 11	0.38		0.45
# 12	0.51		0.45
# 13	0.57		0.51
# 14	0.60		0.55
# 15	0.62		0.57
# 16	0.62		0.55
# 17	0.39		0.43
# 18	0.54		0.48
# 19	0.58		0.51
# 20	0.59		0.55
# t = 9 was best iteration with accuracy 0.56
#
# -----------------------------------------------
# 71 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.60		0.56
# 2	0.59		0.54
# 3	0.64		0.58
# 4	0.43		0.44
# 5	0.60		0.57
# 6	0.59		0.56
# 7	0.58		0.54
# 8	0.56		0.53
# 9	0.55		0.55
# 10	0.37		0.43
# 11	0.60		0.57
# 12	0.60		0.56
# 13	0.60		0.55
# 14	0.60		0.54
# 15	0.62		0.57
# 16	0.46		0.48
# 17	0.64		0.59
# 18	0.61		0.58
# 19	0.60		0.56
# 20	0.60		0.55
# t = 3 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 72 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.60		0.56
# 2	0.60		0.55
# 3	0.62		0.56
# 4	0.43		0.47
# 5	0.59		0.54
# 6	0.60		0.55
# 7	0.60		0.55
# 8	0.61		0.56
# 9	0.62		0.56
# 10	0.39		0.41
# 11	0.54		0.48
# 12	0.58		0.53
# 13	0.60		0.55
# 14	0.62		0.56
# 15	0.61		0.53
# 16	0.45		0.45
# 17	0.53		0.46
# 18	0.55		0.49
# 19	0.62		0.56
# 20	0.62		0.55
# t = 9 was best iteration with accuracy 0.56
#
# -----------------------------------------------
# 73 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.59		0.55
# 2	0.58		0.53
# 3	0.62		0.59
# 4	0.56		0.53
# 5	0.61		0.59
# 6	0.54		0.48
# 7	0.62		0.59
# 8	0.59		0.56
# 9	0.56		0.57
# 10	0.58		0.52
# 11	0.61		0.58
# 12	0.59		0.56
# 13	0.50		0.52
# 14	0.61		0.57
# 15	0.57		0.52
# 16	0.59		0.57
# 17	0.54		0.52
# 18	0.60		0.58
# 19	0.60		0.57
# 20	0.60		0.55
# t = 7 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 74 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.59		0.54
# 2	0.59		0.55
# 3	0.55		0.52
# 4	0.49		0.54
# 5	0.52		0.47
# 6	0.58		0.52
# 7	0.60		0.54
# 8	0.60		0.55
# 9	0.60		0.55
# 10	0.41		0.45
# 11	0.60		0.55
# 12	0.60		0.55
# 13	0.60		0.55
# 14	0.60		0.56
# 15	0.60		0.55
# 16	0.48		0.48
# 17	0.60		0.55
# 18	0.60		0.55
# 19	0.60		0.56
# 20	0.61		0.56
# t = 20 was best iteration with accuracy 0.56
#
# -----------------------------------------------
# 75 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.60		0.55
# 2	0.60		0.54
# 3	0.60		0.57
# 4	0.45		0.45
# 5	0.61		0.58
# 6	0.61		0.57
# 7	0.60		0.56
# 8	0.59		0.54
# 9	0.59		0.55
# 10	0.51		0.45
# 11	0.43		0.50
# 12	0.53		0.44
# 13	0.56		0.49
# 14	0.59		0.56
# 15	0.58		0.53
# 16	0.51		0.50
# 17	0.60		0.55
# 18	0.59		0.57
# 19	0.53		0.48
# 20	0.57		0.56
# t = 5 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 76 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.59		0.55
# 2	0.57		0.53
# 3	0.56		0.53
# 4	0.42		0.43
# 5	0.61		0.58
# 6	0.60		0.56
# 7	0.58		0.54
# 8	0.57		0.54
# 9	0.51		0.48
# 10	0.47		0.47
# 11	0.62		0.59
# 12	0.59		0.55
# 13	0.59		0.54
# 14	0.59		0.55
# 15	0.42		0.47
# 16	0.58		0.53
# 17	0.59		0.55
# 18	0.59		0.54
# 19	0.57		0.54
# 20	0.56		0.52
# t = 11 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 77 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.60		0.55
# 2	0.60		0.56
# 3	0.57		0.51
# 4	0.43		0.48
# 5	0.53		0.44
# 6	0.55		0.50
# 7	0.59		0.54
# 8	0.58		0.54
# 9	0.51		0.47
# 10	0.47		0.53
# 11	0.53		0.48
# 12	0.58		0.53
# 13	0.59		0.54
# 14	0.58		0.54
# 15	0.57		0.54
# 16	0.38		0.45
# 17	0.59		0.54
# 18	0.59		0.54
# 19	0.59		0.54
# 20	0.59		0.55
# t = 16 was best iteration with accuracy 0.55
#
# -----------------------------------------------
# 78 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.59		0.55
# 2	0.58		0.54
# 3	0.54		0.52
# 4	0.39		0.42
# 5	0.60		0.56
# 6	0.59		0.55
# 7	0.59		0.54
# 8	0.59		0.54
# 9	0.58		0.54
# 10	0.53		0.50
# 11	0.41		0.47
# 12	0.58		0.52
# 13	0.59		0.53
# 14	0.59		0.54
# 15	0.59		0.54
# 16	0.58		0.54
# 17	0.51		0.49
# 18	0.36		0.39
# 19	0.61		0.57
# 20	0.60		0.56
# t = 18 was best iteration with accuracy 0.61
#
# -----------------------------------------------
# 79 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.60		0.54
# 2	0.60		0.56
# 3	0.56		0.50
# 4	0.41		0.47
# 5	0.53		0.45
# 6	0.57		0.50
# 7	0.62		0.56
# 8	0.61		0.56
# 9	0.47		0.48
# 10	0.56		0.51
# 11	0.64		0.60
# 12	0.52		0.47
# 13	0.49		0.53
# 14	0.55		0.47
# 15	0.64		0.60
# 16	0.53		0.47
# 17	0.48		0.52
# 18	0.53		0.45
# 19	0.64		0.60
# 20	0.50		0.44
# t = 11 was best iteration with accuracy 0.60
#
# -----------------------------------------------
# 80 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.59		0.53
# 2	0.60		0.56
# 3	0.55		0.49
# 4	0.42		0.49
# 5	0.52		0.44
# 6	0.55		0.49
# 7	0.60		0.56
# 8	0.60		0.56
# 9	0.61		0.56
# 10	0.45		0.54
# 11	0.51		0.47
# 12	0.57		0.52
# 13	0.58		0.54
# 14	0.59		0.54
# 15	0.56		0.53
# 16	0.52		0.56
# 17	0.52		0.44
# 18	0.55		0.49
# 19	0.59		0.54
# 20	0.59		0.55
# t = 9 was best iteration with accuracy 0.56
#
# -----------------------------------------------
# 81 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.59		0.54
# 2	0.59		0.54
# 3	0.60		0.57
# 4	0.45		0.45
# 5	0.61		0.58
# 6	0.59		0.55
# 7	0.58		0.54
# 8	0.58		0.54
# 9	0.37		0.42
# 10	0.60		0.57
# 11	0.60		0.56
# 12	0.59		0.56
# 13	0.59		0.54
# 14	0.59		0.55
# 15	0.57		0.54
# 16	0.37		0.43
# 17	0.59		0.55
# 18	0.59		0.55
# 19	0.58		0.54
# 20	0.57		0.54
# t = 16 was best iteration with accuracy 0.57
#
# -----------------------------------------------
# 82 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.59		0.55
# 2	0.60		0.54
# 3	0.58		0.52
# 4	0.49		0.55
# 5	0.52		0.47
# 6	0.57		0.51
# 7	0.60		0.54
# 8	0.60		0.55
# 9	0.60		0.55
# 10	0.44		0.48
# 11	0.54		0.48
# 12	0.57		0.51
# 13	0.60		0.55
# 14	0.60		0.56
# 15	0.62		0.56
# 16	0.43		0.41
# 17	0.48		0.50
# 18	0.60		0.57
# 19	0.60		0.55
# 20	0.60		0.55
# t = 15 was best iteration with accuracy 0.56
#
# -----------------------------------------------
# 83 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.59		0.55
# 2	0.59		0.55
# 3	0.59		0.55
# 4	0.37		0.41
# 5	0.62		0.58
# 6	0.61		0.58
# 7	0.60		0.56
# 8	0.60		0.55
# 9	0.60		0.54
# 10	0.48		0.50
# 11	0.58		0.53
# 12	0.58		0.53
# 13	0.59		0.55
# 14	0.58		0.54
# 15	0.58		0.54
# 16	0.57		0.53
# 17	0.44		0.51
# 18	0.52		0.44
# 19	0.57		0.52
# 20	0.60		0.56
# t = 4 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 84 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.59		0.54
# 2	0.58		0.54
# 3	0.53		0.50
# 4	0.38		0.44
# 5	0.59		0.55
# 6	0.59		0.55
# 7	0.59		0.55
# 8	0.58		0.54
# 9	0.58		0.54
# 10	0.53		0.51
# 11	0.37		0.42
# 12	0.60		0.57
# 13	0.59		0.56
# 14	0.60		0.55
# 15	0.59		0.54
# 16	0.60		0.56
# 17	0.53		0.51
# 18	0.58		0.57
# 19	0.62		0.58
# 20	0.59		0.53
# t = 11 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 85 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.60		0.54
# 2	0.60		0.55
# 3	0.61		0.56
# 4	0.41		0.46
# 5	0.60		0.56
# 6	0.60		0.55
# 7	0.60		0.56
# 8	0.61		0.56
# 9	0.62		0.56
# 10	0.45		0.45
# 11	0.43		0.48
# 12	0.55		0.48
# 13	0.64		0.60
# 14	0.51		0.45
# 15	0.49		0.52
# 16	0.57		0.50
# 17	0.63		0.58
# 18	0.51		0.48
# 19	0.54		0.55
# 20	0.60		0.55
# t = 13 was best iteration with accuracy 0.60
#
# -----------------------------------------------
# 86 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.60		0.55
# 2	0.60		0.56
# 3	0.56		0.49
# 4	0.43		0.50
# 5	0.51		0.44
# 6	0.56		0.50
# 7	0.58		0.54
# 8	0.56		0.54
# 9	0.50		0.48
# 10	0.36		0.40
# 11	0.60		0.57
# 12	0.59		0.54
# 13	0.57		0.53
# 14	0.55		0.51
# 15	0.54		0.54
# 16	0.38		0.44
# 17	0.58		0.54
# 18	0.57		0.54
# 19	0.57		0.53
# 20	0.56		0.52
# t = 10 was best iteration with accuracy 0.60
#
# -----------------------------------------------
# 87 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.59		0.55
# 2	0.59		0.54
# 3	0.59		0.56
# 4	0.42		0.43
# 5	0.62		0.57
# 6	0.60		0.56
# 7	0.59		0.55
# 8	0.60		0.57
# 9	0.57		0.56
# 10	0.55		0.55
# 11	0.62		0.58
# 12	0.58		0.51
# 13	0.62		0.58
# 14	0.58		0.54
# 15	0.54		0.54
# 16	0.60		0.57
# 17	0.55		0.51
# 18	0.58		0.57
# 19	0.56		0.53
# 20	0.57		0.56
# t = 5 was best iteration with accuracy 0.57
#
# -----------------------------------------------
# 88 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.59		0.55
# 2	0.59		0.54
# 3	0.61		0.59
# 4	0.39		0.42
# 5	0.61		0.58
# 6	0.59		0.56
# 7	0.59		0.55
# 8	0.58		0.54
# 9	0.51		0.46
# 10	0.43		0.51
# 11	0.52		0.44
# 12	0.56		0.50
# 13	0.60		0.56
# 14	0.59		0.54
# 15	0.63		0.59
# 16	0.53		0.50
# 17	0.62		0.59
# 18	0.58		0.51
# 19	0.64		0.60
# 20	0.59		0.56
# t = 19 was best iteration with accuracy 0.60
#
# -----------------------------------------------
# 89 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.59		0.54
# 2	0.60		0.56
# 3	0.59		0.53
# 4	0.49		0.56
# 5	0.54		0.48
# 6	0.58		0.53
# 7	0.58		0.54
# 8	0.57		0.53
# 9	0.51		0.47
# 10	0.39		0.46
# 11	0.57		0.52
# 12	0.59		0.53
# 13	0.58		0.54
# 14	0.59		0.55
# 15	0.59		0.54
# 16	0.56		0.52
# 17	0.48		0.55
# 18	0.53		0.48
# 19	0.58		0.52
# 20	0.59		0.56
# t = 10 was best iteration with accuracy 0.54
#
# -----------------------------------------------
# 90 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.60		0.56
# 2	0.60		0.54
# 3	0.60		0.56
# 4	0.39		0.43
# 5	0.61		0.57
# 6	0.59		0.56
# 7	0.59		0.54
# 8	0.58		0.54
# 9	0.58		0.54
# 10	0.55		0.52
# 11	0.43		0.52
# 12	0.52		0.44
# 13	0.57		0.52
# 14	0.59		0.54
# 15	0.55		0.52
# 16	0.58		0.59
# 17	0.56		0.49
# 18	0.55		0.50
# 19	0.59		0.56
# 20	0.52		0.47
# t = 4 was best iteration with accuracy 0.57
#
# -----------------------------------------------
# 91 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.59		0.55
# 2	0.58		0.54
# 3	0.56		0.52
# 4	0.39		0.44
# 5	0.59		0.55
# 6	0.59		0.54
# 7	0.59		0.55
# 8	0.59		0.54
# 9	0.59		0.55
# 10	0.58		0.53
# 11	0.48		0.53
# 12	0.56		0.50
# 13	0.58		0.52
# 14	0.60		0.54
# 15	0.60		0.56
# 16	0.59		0.55
# 17	0.57		0.55
# 18	0.55		0.52
# 19	0.62		0.59
# 20	0.60		0.55
# t = 19 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 92 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.60		0.54
# 2	0.60		0.57
# 3	0.57		0.52
# 4	0.41		0.47
# 5	0.52		0.44
# 6	0.55		0.49
# 7	0.60		0.55
# 8	0.61		0.56
# 9	0.62		0.56
# 10	0.43		0.45
# 11	0.56		0.50
# 12	0.59		0.53
# 13	0.60		0.55
# 14	0.60		0.55
# 15	0.60		0.55
# 16	0.61		0.56
# 17	0.42		0.45
# 18	0.57		0.50
# 19	0.58		0.52
# 20	0.59		0.54
# t = 9 was best iteration with accuracy 0.56
#
# -----------------------------------------------
# 93 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.59		0.54
# 2	0.59		0.54
# 3	0.60		0.56
# 4	0.39		0.42
# 5	0.61		0.58
# 6	0.60		0.57
# 7	0.60		0.56
# 8	0.60		0.55
# 9	0.61		0.56
# 10	0.45		0.45
# 11	0.42		0.46
# 12	0.54		0.48
# 13	0.62		0.58
# 14	0.53		0.48
# 15	0.40		0.45
# 16	0.54		0.45
# 17	0.58		0.52
# 18	0.61		0.56
# 19	0.60		0.54
# 20	0.41		0.47
# t = 13 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 94 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.59		0.55
# 2	0.59		0.54
# 3	0.55		0.51
# 4	0.48		0.56
# 5	0.52		0.47
# 6	0.57		0.52
# 7	0.58		0.54
# 8	0.58		0.54
# 9	0.56		0.52
# 10	0.40		0.47
# 11	0.57		0.51
# 12	0.58		0.52
# 13	0.60		0.54
# 14	0.60		0.55
# 15	0.60		0.55
# 16	0.60		0.54
# 17	0.46		0.52
# 18	0.53		0.47
# 19	0.58		0.51
# 20	0.59		0.54
# t = 10 was best iteration with accuracy 0.53
#
# -----------------------------------------------
# 95 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.59		0.54
# 2	0.59		0.54
# 3	0.60		0.56
# 4	0.39		0.41
# 5	0.62		0.58
# 6	0.60		0.57
# 7	0.60		0.56
# 8	0.60		0.55
# 9	0.62		0.57
# 10	0.53		0.54
# 11	0.63		0.59
# 12	0.61		0.58
# 13	0.60		0.57
# 14	0.60		0.55
# 15	0.60		0.56
# 16	0.62		0.56
# 17	0.49		0.52
# 18	0.58		0.51
# 19	0.59		0.54
# 20	0.60		0.56
# t = 11 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 96 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.59		0.55
# 2	0.59		0.55
# 3	0.59		0.54
# 4	0.47		0.52
# 5	0.57		0.51
# 6	0.59		0.53
# 7	0.59		0.54
# 8	0.59		0.55
# 9	0.60		0.54
# 10	0.45		0.49
# 11	0.58		0.52
# 12	0.59		0.54
# 13	0.59		0.55
# 14	0.59		0.55
# 15	0.59		0.55
# 16	0.47		0.40
# 17	0.53		0.54
# 18	0.61		0.58
# 19	0.59		0.53
# 20	0.60		0.56
# t = 18 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 97 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.59		0.55
# 2	0.59		0.54
# 3	0.59		0.55
# 4	0.38		0.42
# 5	0.60		0.57
# 6	0.60		0.56
# 7	0.60		0.55
# 8	0.60		0.55
# 9	0.61		0.56
# 10	0.43		0.41
# 11	0.46		0.48
# 12	0.59		0.53
# 13	0.63		0.57
# 14	0.44		0.42
# 15	0.49		0.51
# 16	0.59		0.55
# 17	0.61		0.56
# 18	0.60		0.54
# 19	0.43		0.50
# 20	0.52		0.45
# t = 13 was best iteration with accuracy 0.57
#
# -----------------------------------------------
# 98 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.59		0.54
# 2	0.58		0.54
# 3	0.53		0.50
# 4	0.43		0.50
# 5	0.57		0.50
# 6	0.59		0.53
# 7	0.60		0.55
# 8	0.60		0.56
# 9	0.60		0.56
# 10	0.43		0.41
# 11	0.43		0.45
# 12	0.64		0.60
# 13	0.62		0.57
# 14	0.62		0.56
# 15	0.60		0.53
# 16	0.45		0.45
# 17	0.39		0.46
# 18	0.52		0.45
# 19	0.62		0.57
# 20	0.62		0.55
# t = 12 was best iteration with accuracy 0.60
#
# -----------------------------------------------
# 99 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.59		0.54
# 2	0.59		0.54
# 3	0.55		0.53
# 4	0.43		0.50
# 5	0.57		0.52
# 6	0.58		0.53
# 7	0.58		0.54
# 8	0.57		0.54
# 9	0.56		0.52
# 10	0.50		0.47
# 11	0.38		0.46
# 12	0.58		0.53
# 13	0.59		0.54
# 14	0.59		0.54
# 15	0.58		0.54
# 16	0.56		0.53
# 17	0.39		0.45
# 18	0.58		0.53
# 19	0.59		0.54
# 20	0.59		0.54
# t = 11 was best iteration with accuracy 0.54
#
# -----------------------------------------------
# 100 / 100 complete
# -----------------------------------------------

# %%
table_results(svm_arr, tree_arr)
# Out:
# (Performance on test set)
#
# 50 comparisons
# 	acc	sderr
# SVM: 	58.8	0.2
# Tree: 	nan	nan
#
# 200 comparisons
# 	acc	sderr
# SVM: 	57.6	0.4
# Tree: 	nan	nan
