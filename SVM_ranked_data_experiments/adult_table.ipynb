# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_svmlight_file
from sklearn.model_selection import train_test_split
import sys; sys.path.insert(0,'..')
from main import *

# %%
X_train, y_train = load_svmlight_file('../data/adult/a5a.txt', n_features=123)
X_train = X_train.toarray()

X_test, y_test = load_svmlight_file('../data/adult/a5a.t')
X_test = X_test.toarray()

# %%
svm_arr, tree_arr = data_size_experiment(X_train, y_train, X_test, y_test,
                                         experiment_type='table', kernel='linear',
                                         random_state=2081, verbose=True)
# Out:
# Progress:
# Training accuracy of rank SVM: 1.00
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.68		0.63
# 2	0.68		0.64
# 3	0.69		0.66
# /Users/Ashtekar15/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 4	0.68		0.66
# 5	0.69		0.66
# 6	0.68		0.66
# 7	0.69		0.66
# 8	0.69		0.66
# 9	0.68		0.66
# 10	0.68		0.66
# 11	0.68		0.66
# 12	0.68		0.66
# 13	0.69		0.67
# 14	0.68		0.66
# 15	0.69		0.66
# 16	0.69		0.66
# 17	0.68		0.66
# 18	0.68		0.66
# 19	0.69		0.66
# 20	0.69		0.67
# t = 15 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 1 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.63
# 2	0.68		0.64
# 3	0.68		0.65
# 4	0.68		0.65
# 5	0.68		0.65
# 6	0.68		0.65
# 7	0.68		0.65
# 8	0.68		0.66
# 9	0.69		0.66
# 10	0.68		0.66
# 11	0.68		0.65
# 12	0.67		0.66
# 13	0.68		0.66
# 14	0.68		0.66
# 15	0.68		0.66
# 16	0.68		0.66
# 17	0.68		0.66
# 18	0.68		0.66
# 19	0.68		0.65
# 20	0.68		0.66
# t = 9 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 2 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.68		0.65
# 2	0.68		0.66
# 3	0.67		0.66
# 4	0.68		0.66
# 5	0.68		0.66
# 6	0.68		0.66
# 7	0.68		0.66
# 8	0.67		0.66
# 9	0.68		0.66
# 10	0.68		0.66
# 11	0.69		0.66
# 12	0.68		0.66
# 13	0.69		0.66
# 14	0.69		0.66
# 15	0.69		0.66
# 16	0.69		0.66
# 17	0.69		0.67
# 18	0.68		0.67
# 19	0.69		0.66
# 20	0.69		0.66
# t = 13 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 3 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.65
# 2	0.71		0.67
# 3	0.69		0.67
# 4	0.70		0.66
# 5	0.69		0.66
# 6	0.69		0.66
# 7	0.69		0.67
# 8	0.69		0.66
# 9	0.69		0.66
# 10	0.69		0.66
# 11	0.69		0.66
# 12	0.69		0.66
# 13	0.69		0.66
# 14	0.69		0.66
# 15	0.69		0.66
# 16	0.69		0.66
# 17	0.69		0.66
# 18	0.69		0.66
# 19	0.69		0.66
# 20	0.69		0.66
# t = 2 was best iteration with accuracy 0.67
#
# -----------------------------------------------
# 4 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.63
# 2	0.68		0.63
# 3	0.68		0.65
# 4	0.67		0.65
# 5	0.68		0.66
# 6	0.69		0.66
# 7	0.68		0.66
# 8	0.68		0.66
# 9	0.68		0.65
# 10	0.69		0.65
# 11	0.69		0.66
# 12	0.68		0.66
# 13	0.68		0.66
# 14	0.68		0.66
# 15	0.69		0.66
# 16	0.69		0.66
# 17	0.69		0.66
# 18	0.69		0.66
# 19	0.69		0.66
# 20	0.69		0.66
# t = 1 was best iteration with accuracy 0.63
#
# -----------------------------------------------
# 5 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.66
# 2	0.71		0.68
# 3	0.70		0.67
# 4	0.70		0.67
# 5	0.71		0.66
# 6	0.70		0.67
# 7	0.71		0.66
# 8	0.70		0.67
# 9	0.70		0.67
# 10	0.70		0.66
# 11	0.70		0.67
# 12	0.70		0.67
# 13	0.70		0.66
# 14	0.70		0.66
# 15	0.69		0.66
# 16	0.69		0.66
# 17	0.70		0.66
# 18	0.69		0.66
# 19	0.69		0.66
# 20	0.70		0.66
# t = 2 was best iteration with accuracy 0.68
#
# -----------------------------------------------
# 6 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.67		0.64
# 2	0.68		0.65
# 3	0.67		0.66
# 4	0.67		0.65
# 5	0.68		0.65
# 6	0.67		0.66
# 7	0.68		0.66
# 8	0.68		0.66
# 9	0.68		0.66
# 10	0.68		0.66
# 11	0.69		0.66
# 12	0.69		0.66
# 13	0.68		0.66
# 14	0.68		0.66
# 15	0.68		0.66
# 16	0.68		0.66
# 17	0.69		0.66
# 18	0.68		0.66
# 19	0.68		0.66
# 20	0.68		0.66
# t = 17 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 7 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.67		0.62
# 2	0.68		0.64
# 3	0.69		0.65
# 4	0.68		0.66
# 5	0.68		0.65
# 6	0.68		0.66
# 7	0.67		0.66
# 8	0.67		0.66
# 9	0.68		0.65
# 10	0.69		0.66
# 11	0.67		0.66
# 12	0.68		0.66
# 13	0.68		0.66
# 14	0.68		0.66
# 15	0.68		0.66
# 16	0.68		0.66
# 17	0.69		0.66
# 18	0.68		0.66
# 19	0.68		0.66
# 20	0.68		0.66
# t = 10 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 8 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.68		0.63
# 2	0.67		0.64
# 3	0.67		0.65
# 4	0.68		0.65
# 5	0.67		0.65
# 6	0.67		0.65
# 7	0.67		0.65
# 8	0.68		0.65
# 9	0.68		0.65
# 10	0.67		0.65
# 11	0.67		0.66
# 12	0.68		0.65
# 13	0.68		0.66
# 14	0.68		0.66
# 15	0.68		0.66
# 16	0.68		0.66
# 17	0.68		0.66
# 18	0.68		0.66
# 19	0.68		0.66
# 20	0.68		0.66
# t = 12 was best iteration with accuracy 0.65
#
# -----------------------------------------------
# 9 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.65
# 2	0.69		0.64
# 3	0.68		0.65
# 4	0.68		0.66
# 5	0.68		0.66
# 6	0.68		0.66
# 7	0.67		0.66
# 8	0.68		0.66
# 9	0.68		0.66
# 10	0.68		0.66
# 11	0.68		0.66
# 12	0.67		0.66
# 13	0.69		0.66
# 14	0.68		0.66
# 15	0.68		0.66
# 16	0.68		0.66
# 17	0.68		0.66
# 18	0.68		0.66
# 19	0.69		0.66
# 20	0.69		0.66
# t = 2 was best iteration with accuracy 0.64
#
# -----------------------------------------------
# 10 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.67
# 2	0.70		0.66
# 3	0.69		0.67
# 4	0.69		0.67
# 5	0.69		0.66
# 6	0.69		0.66
# 7	0.69		0.66
# 8	0.69		0.67
# 9	0.69		0.66
# 10	0.69		0.66
# 11	0.69		0.66
# 12	0.69		0.67
# 13	0.69		0.66
# 14	0.69		0.66
# 15	0.69		0.66
# 16	0.69		0.66
# 17	0.69		0.66
# 18	0.69		0.66
# 19	0.69		0.66
# 20	0.69		0.66
# t = 1 was best iteration with accuracy 0.67
#
# -----------------------------------------------
# 11 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.67		0.62
# 2	0.67		0.64
# 3	0.67		0.64
# 4	0.67		0.65
# 5	0.68		0.64
# 6	0.68		0.65
# 7	0.67		0.65
# 8	0.67		0.65
# 9	0.68		0.65
# 10	0.68		0.65
# 11	0.68		0.66
# 12	0.68		0.66
# 13	0.67		0.66
# 14	0.67		0.66
# 15	0.68		0.66
# 16	0.68		0.66
# 17	0.68		0.66
# 18	0.67		0.66
# 19	0.68		0.66
# 20	0.68		0.66
# t = 11 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 12 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.68		0.63
# 2	0.67		0.66
# 3	0.68		0.66
# 4	0.69		0.66
# 5	0.68		0.66
# 6	0.68		0.66
# 7	0.69		0.66
# 8	0.68		0.66
# 9	0.69		0.66
# 10	0.68		0.66
# 11	0.68		0.66
# 12	0.69		0.66
# 13	0.68		0.66
# 14	0.68		0.66
# 15	0.68		0.66
# 16	0.68		0.66
# 17	0.68		0.66
# 18	0.69		0.66
# 19	0.68		0.66
# 20	0.68		0.66
# t = 4 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 13 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.67		0.64
# 2	0.67		0.65
# 3	0.68		0.65
# 4	0.68		0.66
# 5	0.68		0.66
# 6	0.68		0.66
# 7	0.67		0.66
# 8	0.68		0.67
# 9	0.68		0.66
# 10	0.69		0.66
# 11	0.69		0.66
# 12	0.69		0.66
# 13	0.69		0.66
# 14	0.69		0.66
# 15	0.69		0.66
# 16	0.68		0.66
# 17	0.69		0.66
# 18	0.68		0.66
# 19	0.68		0.66
# 20	0.68		0.66
# t = 11 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 14 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.68		0.64
# 2	0.68		0.65
# 3	0.68		0.66
# 4	0.68		0.65
# 5	0.68		0.66
# 6	0.68		0.66
# 7	0.69		0.65
# 8	0.69		0.66
# 9	0.68		0.66
# 10	0.69		0.66
# 11	0.68		0.66
# 12	0.68		0.65
# 13	0.69		0.66
# 14	0.68		0.66
# 15	0.68		0.66
# 16	0.68		0.66
# 17	0.69		0.66
# 18	0.69		0.66
# 19	0.69		0.66
# 20	0.69		0.66
# t = 19 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 15 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.68		0.64
# 2	0.68		0.65
# 3	0.68		0.66
# 4	0.68		0.66
# 5	0.67		0.66
# 6	0.68		0.66
# 7	0.69		0.66
# 8	0.68		0.66
# 9	0.69		0.66
# 10	0.69		0.66
# 11	0.69		0.66
# 12	0.69		0.66
# 13	0.69		0.66
# 14	0.68		0.67
# 15	0.68		0.67
# 16	0.68		0.66
# 17	0.68		0.66
# 18	0.69		0.66
# 19	0.69		0.66
# 20	0.68		0.66
# t = 9 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 16 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.65
# 2	0.69		0.66
# 3	0.70		0.66
# 4	0.70		0.66
# 5	0.70		0.66
# 6	0.69		0.66
# 7	0.69		0.66
# 8	0.68		0.66
# 9	0.69		0.66
# 10	0.69		0.66
# 11	0.68		0.66
# 12	0.69		0.66
# 13	0.69		0.66
# 14	0.69		0.66
# 15	0.69		0.66
# 16	0.69		0.66
# 17	0.69		0.66
# 18	0.69		0.66
# 19	0.69		0.66
# 20	0.69		0.66
# t = 4 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 17 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.68		0.64
# 2	0.69		0.66
# 3	0.69		0.66
# 4	0.69		0.66
# 5	0.68		0.67
# 6	0.69		0.67
# 7	0.69		0.67
# 8	0.69		0.66
# 9	0.69		0.67
# 10	0.69		0.66
# 11	0.69		0.66
# 12	0.69		0.66
# 13	0.69		0.66
# 14	0.69		0.66
# 15	0.69		0.66
# 16	0.69		0.66
# 17	0.68		0.66
# 18	0.69		0.67
# 19	0.69		0.67
# 20	0.69		0.66
# t = 4 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 18 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.68		0.63
# 2	0.68		0.65
# 3	0.68		0.65
# 4	0.68		0.65
# 5	0.68		0.65
# 6	0.68		0.66
# 7	0.68		0.66
# 8	0.68		0.66
# 9	0.68		0.66
# 10	0.68		0.65
# 11	0.68		0.66
# 12	0.68		0.66
# 13	0.68		0.66
# 14	0.68		0.66
# 15	0.68		0.66
# 16	0.68		0.66
# 17	0.68		0.66
# 18	0.68		0.66
# 19	0.68		0.66
# 20	0.68		0.66
# t = 1 was best iteration with accuracy 0.63
#
# -----------------------------------------------
# 19 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.66		0.62
# 2	0.67		0.64
# 3	0.67		0.64
# 4	0.67		0.64
# 5	0.67		0.64
# 6	0.67		0.64
# 7	0.67		0.65
# 8	0.67		0.65
# 9	0.67		0.65
# 10	0.67		0.65
# 11	0.68		0.65
# 12	0.68		0.65
# 13	0.67		0.66
# 14	0.68		0.66
# 15	0.68		0.66
# 16	0.68		0.66
# 17	0.67		0.66
# 18	0.67		0.66
# 19	0.68		0.66
# 20	0.68		0.66
# t = 15 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 20 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.66
# 2	0.70		0.67
# 3	0.70		0.67
# 4	0.69		0.66
# 5	0.68		0.67
# 6	0.69		0.66
# 7	0.69		0.66
# 8	0.69		0.66
# 9	0.69		0.67
# 10	0.70		0.66
# 11	0.69		0.67
# 12	0.69		0.67
# 13	0.70		0.67
# 14	0.69		0.67
# 15	0.69		0.66
# 16	0.69		0.66
# 17	0.69		0.66
# 18	0.69		0.66
# 19	0.69		0.66
# 20	0.69		0.66
# t = 10 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 21 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.67		0.62
# 2	0.67		0.64
# 3	0.68		0.65
# 4	0.67		0.65
# 5	0.67		0.66
# 6	0.68		0.65
# 7	0.68		0.65
# 8	0.68		0.66
# 9	0.67		0.66
# 10	0.67		0.66
# 11	0.67		0.66
# 12	0.68		0.66
# 13	0.68		0.66
# 14	0.67		0.66
# 15	0.68		0.66
# 16	0.69		0.66
# 17	0.69		0.66
# 18	0.68		0.65
# 19	0.68		0.66
# 20	0.68		0.66
# t = 16 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 22 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.65
# 2	0.70		0.67
# 3	0.69		0.66
# 4	0.69		0.66
# 5	0.68		0.67
# 6	0.69		0.66
# 7	0.69		0.66
# 8	0.69		0.67
# 9	0.69		0.66
# 10	0.68		0.66
# 11	0.69		0.66
# 12	0.69		0.66
# 13	0.68		0.66
# 14	0.68		0.66
# 15	0.69		0.66
# 16	0.69		0.66
# 17	0.69		0.66
# 18	0.69		0.67
# 19	0.69		0.66
# 20	0.69		0.67
# t = 2 was best iteration with accuracy 0.67
#
# -----------------------------------------------
# 23 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.68		0.65
# 2	0.69		0.65
# 3	0.68		0.66
# 4	0.69		0.66
# 5	0.69		0.66
# 6	0.69		0.66
# 7	0.68		0.66
# 8	0.68		0.66
# 9	0.68		0.66
# 10	0.68		0.66
# 11	0.69		0.66
# 12	0.68		0.66
# 13	0.68		0.66
# 14	0.69		0.66
# 15	0.69		0.66
# 16	0.68		0.66
# 17	0.68		0.66
# 18	0.69		0.66
# 19	0.69		0.66
# 20	0.69		0.66
# t = 14 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 24 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.64
# 2	0.69		0.66
# 3	0.69		0.66
# 4	0.69		0.67
# 5	0.69		0.66
# 6	0.69		0.66
# 7	0.68		0.66
# 8	0.68		0.66
# 9	0.69		0.66
# 10	0.69		0.66
# 11	0.69		0.66
# 12	0.68		0.66
# 13	0.69		0.66
# 14	0.69		0.66
# 15	0.69		0.66
# 16	0.69		0.66
# 17	0.68		0.66
# 18	0.69		0.66
# 19	0.69		0.66
# 20	0.69		0.66
# t = 2 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 25 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.64
# 2	0.67		0.64
# 3	0.68		0.64
# 4	0.68		0.65
# 5	0.68		0.65
# 6	0.68		0.65
# 7	0.67		0.65
# 8	0.68		0.65
# 9	0.67		0.66
# 10	0.67		0.66
# 11	0.68		0.65
# 12	0.68		0.66
# 13	0.67		0.65
# 14	0.67		0.65
# 15	0.68		0.66
# 16	0.67		0.66
# 17	0.67		0.66
# 18	0.68		0.66
# 19	0.68		0.66
# 20	0.68		0.66
# t = 1 was best iteration with accuracy 0.64
#
# -----------------------------------------------
# 26 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.64
# 2	0.69		0.65
# 3	0.68		0.66
# 4	0.68		0.66
# 5	0.68		0.66
# 6	0.68		0.66
# 7	0.69		0.66
# 8	0.68		0.66
# 9	0.68		0.66
# 10	0.69		0.66
# 11	0.68		0.66
# 12	0.69		0.66
# 13	0.69		0.66
# 14	0.68		0.66
# 15	0.68		0.66
# 16	0.68		0.66
# 17	0.68		0.66
# 18	0.68		0.66
# 19	0.68		0.66
# 20	0.69		0.66
# t = 2 was best iteration with accuracy 0.65
#
# -----------------------------------------------
# 27 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.67		0.63
# 2	0.68		0.64
# 3	0.68		0.64
# 4	0.67		0.65
# 5	0.68		0.66
# 6	0.68		0.66
# 7	0.68		0.66
# 8	0.68		0.66
# 9	0.68		0.66
# 10	0.68		0.66
# 11	0.68		0.66
# 12	0.69		0.66
# 13	0.68		0.66
# 14	0.69		0.66
# 15	0.68		0.66
# 16	0.69		0.66
# 17	0.68		0.66
# 18	0.68		0.66
# 19	0.69		0.67
# 20	0.68		0.67
# t = 16 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 28 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.68		0.65
# 2	0.69		0.65
# 3	0.69		0.66
# 4	0.69		0.66
# 5	0.68		0.66
# 6	0.68		0.66
# 7	0.68		0.66
# 8	0.68		0.66
# 9	0.68		0.66
# 10	0.69		0.66
# 11	0.68		0.66
# 12	0.69		0.66
# 13	0.68		0.66
# 14	0.68		0.66
# 15	0.68		0.66
# 16	0.68		0.66
# 17	0.69		0.66
# 18	0.68		0.66
# 19	0.68		0.66
# 20	0.69		0.66
# t = 2 was best iteration with accuracy 0.65
#
# -----------------------------------------------
# 29 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.65
# 2	0.70		0.66
# 3	0.69		0.67
# 4	0.69		0.67
# 5	0.69		0.67
# 6	0.69		0.67
# 7	0.69		0.67
# 8	0.69		0.67
# 9	0.69		0.67
# 10	0.69		0.67
# 11	0.69		0.66
# 12	0.69		0.67
# 13	0.69		0.66
# 14	0.69		0.66
# 15	0.69		0.67
# 16	0.69		0.67
# 17	0.69		0.67
# 18	0.69		0.66
# 19	0.69		0.66
# 20	0.69		0.66
# t = 2 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 30 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.68		0.65
# 2	0.68		0.66
# 3	0.68		0.66
# 4	0.69		0.66
# 5	0.68		0.65
# 6	0.68		0.65
# 7	0.68		0.66
# 8	0.69		0.66
# 9	0.68		0.66
# 10	0.67		0.65
# 11	0.68		0.66
# 12	0.67		0.66
# 13	0.68		0.66
# 14	0.68		0.66
# 15	0.68		0.66
# 16	0.68		0.66
# 17	0.68		0.66
# 18	0.68		0.66
# 19	0.68		0.66
# 20	0.68		0.66
# t = 4 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 31 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.67		0.65
# 2	0.69		0.65
# 3	0.68		0.66
# 4	0.69		0.66
# 5	0.68		0.65
# 6	0.68		0.66
# 7	0.68		0.66
# 8	0.69		0.66
# 9	0.68		0.67
# 10	0.68		0.66
# 11	0.68		0.66
# 12	0.68		0.66
# 13	0.68		0.66
# 14	0.68		0.66
# 15	0.68		0.66
# 16	0.69		0.66
# 17	0.69		0.66
# 18	0.69		0.66
# 19	0.68		0.66
# 20	0.68		0.66
# t = 18 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 32 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.64
# 2	0.69		0.66
# 3	0.68		0.66
# 4	0.68		0.66
# 5	0.67		0.65
# 6	0.68		0.65
# 7	0.68		0.66
# 8	0.68		0.66
# 9	0.68		0.66
# 10	0.68		0.66
# 11	0.68		0.66
# 12	0.69		0.66
# 13	0.69		0.66
# 14	0.69		0.66
# 15	0.69		0.66
# 16	0.68		0.66
# 17	0.68		0.66
# 18	0.69		0.66
# 19	0.69		0.66
# 20	0.68		0.67
# t = 12 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 33 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.68		0.64
# 2	0.69		0.65
# 3	0.69		0.66
# 4	0.69		0.67
# 5	0.69		0.66
# 6	0.69		0.66
# 7	0.69		0.67
# 8	0.69		0.66
# 9	0.68		0.67
# 10	0.69		0.66
# 11	0.69		0.66
# 12	0.69		0.66
# 13	0.69		0.66
# 14	0.69		0.66
# 15	0.68		0.66
# 16	0.69		0.67
# 17	0.68		0.66
# 18	0.69		0.66
# 19	0.69		0.66
# 20	0.69		0.66
# t = 2 was best iteration with accuracy 0.65
#
# -----------------------------------------------
# 34 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.65
# 2	0.70		0.66
# 3	0.69		0.66
# 4	0.69		0.66
# 5	0.70		0.66
# 6	0.69		0.66
# 7	0.69		0.66
# 8	0.69		0.66
# 9	0.69		0.66
# 10	0.69		0.66
# 11	0.69		0.67
# 12	0.69		0.67
# 13	0.69		0.67
# 14	0.69		0.66
# 15	0.69		0.66
# 16	0.68		0.66
# 17	0.68		0.66
# 18	0.69		0.66
# 19	0.68		0.66
# 20	0.68		0.66
# t = 2 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 35 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.66		0.63
# 2	0.69		0.65
# 3	0.69		0.66
# 4	0.69		0.66
# 5	0.69		0.66
# 6	0.69		0.66
# 7	0.69		0.67
# 8	0.69		0.67
# 9	0.69		0.66
# 10	0.69		0.66
# 11	0.69		0.66
# 12	0.70		0.67
# 13	0.69		0.66
# 14	0.69		0.67
# 15	0.69		0.66
# 16	0.69		0.67
# 17	0.69		0.66
# 18	0.69		0.66
# 19	0.68		0.66
# 20	0.68		0.66
# t = 12 was best iteration with accuracy 0.67
#
# -----------------------------------------------
# 36 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.67
# 2	0.69		0.66
# 3	0.68		0.65
# 4	0.68		0.65
# 5	0.69		0.66
# 6	0.68		0.65
# 7	0.69		0.65
# 8	0.68		0.65
# 9	0.67		0.66
# 10	0.68		0.66
# 11	0.68		0.66
# 12	0.68		0.66
# 13	0.67		0.66
# 14	0.68		0.66
# 15	0.67		0.66
# 16	0.67		0.66
# 17	0.67		0.66
# 18	0.67		0.66
# 19	0.68		0.66
# 20	0.68		0.66
# t = 1 was best iteration with accuracy 0.67
#
# -----------------------------------------------
# 37 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.68		0.63
# 2	0.69		0.66
# 3	0.68		0.65
# 4	0.69		0.65
# 5	0.68		0.66
# 6	0.68		0.66
# 7	0.69		0.66
# 8	0.67		0.66
# 9	0.69		0.66
# 10	0.68		0.66
# 11	0.69		0.66
# 12	0.68		0.66
# 13	0.69		0.66
# 14	0.68		0.66
# 15	0.69		0.66
# 16	0.69		0.66
# 17	0.69		0.66
# 18	0.69		0.66
# 19	0.69		0.66
# 20	0.68		0.66
# t = 18 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 38 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.68		0.62
# 2	0.68		0.64
# 3	0.67		0.66
# 4	0.68		0.66
# 5	0.69		0.66
# 6	0.69		0.66
# 7	0.69		0.66
# 8	0.69		0.66
# 9	0.68		0.66
# 10	0.69		0.66
# 11	0.69		0.66
# 12	0.68		0.66
# 13	0.69		0.66
# 14	0.68		0.66
# 15	0.69		0.66
# 16	0.68		0.66
# 17	0.69		0.66
# 18	0.68		0.66
# 19	0.69		0.66
# 20	0.69		0.66
# t = 5 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 39 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.65
# 2	0.71		0.67
# 3	0.69		0.67
# 4	0.69		0.66
# 5	0.69		0.66
# 6	0.70		0.67
# 7	0.71		0.67
# 8	0.70		0.67
# 9	0.70		0.67
# 10	0.69		0.66
# 11	0.69		0.66
# 12	0.69		0.66
# 13	0.68		0.66
# 14	0.68		0.66
# 15	0.69		0.66
# 16	0.69		0.66
# 17	0.69		0.66
# 18	0.68		0.66
# 19	0.69		0.66
# 20	0.69		0.67
# t = 2 was best iteration with accuracy 0.67
#
# -----------------------------------------------
# 40 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.65
# 2	0.69		0.67
# 3	0.70		0.66
# 4	0.69		0.66
# 5	0.69		0.66
# 6	0.70		0.66
# 7	0.69		0.66
# 8	0.69		0.67
# 9	0.69		0.66
# 10	0.69		0.66
# 11	0.69		0.66
# 12	0.69		0.66
# 13	0.69		0.66
# 14	0.69		0.66
# 15	0.69		0.67
# 16	0.69		0.66
# 17	0.69		0.67
# 18	0.69		0.66
# 19	0.68		0.67
# 20	0.69		0.67
# t = 6 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 41 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.68		0.64
# 2	0.69		0.65
# 3	0.68		0.66
# 4	0.69		0.66
# 5	0.69		0.66
# 6	0.69		0.67
# 7	0.69		0.66
# 8	0.69		0.66
# 9	0.68		0.66
# 10	0.68		0.66
# 11	0.68		0.66
# 12	0.68		0.66
# 13	0.69		0.66
# 14	0.69		0.66
# 15	0.69		0.66
# 16	0.69		0.66
# 17	0.69		0.66
# 18	0.68		0.66
# 19	0.69		0.66
# 20	0.69		0.66
# t = 15 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 42 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.67		0.64
# 2	0.68		0.65
# 3	0.68		0.66
# 4	0.68		0.66
# 5	0.68		0.66
# 6	0.69		0.66
# 7	0.68		0.66
# 8	0.68		0.66
# 9	0.69		0.66
# 10	0.69		0.66
# 11	0.68		0.66
# 12	0.69		0.66
# 13	0.68		0.66
# 14	0.69		0.66
# 15	0.69		0.66
# 16	0.69		0.66
# 17	0.68		0.66
# 18	0.69		0.66
# 19	0.69		0.66
# 20	0.69		0.66
# t = 20 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 43 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.66
# 2	0.71		0.66
# 3	0.72		0.66
# 4	0.71		0.66
# 5	0.70		0.66
# 6	0.71		0.66
# 7	0.70		0.66
# 8	0.69		0.66
# 9	0.69		0.66
# 10	0.69		0.66
# 11	0.69		0.66
# 12	0.69		0.66
# 13	0.69		0.66
# 14	0.70		0.67
# 15	0.70		0.67
# 16	0.69		0.67
# 17	0.70		0.67
# 18	0.70		0.66
# 19	0.70		0.66
# 20	0.69		0.66
# t = 3 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 44 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.68		0.64
# 2	0.68		0.65
# 3	0.68		0.65
# 4	0.68		0.66
# 5	0.69		0.66
# 6	0.69		0.66
# 7	0.69		0.66
# 8	0.69		0.66
# 9	0.69		0.66
# 10	0.69		0.66
# 11	0.68		0.66
# 12	0.69		0.66
# 13	0.68		0.66
# 14	0.69		0.66
# 15	0.69		0.66
# 16	0.69		0.66
# 17	0.68		0.66
# 18	0.68		0.66
# 19	0.68		0.66
# 20	0.69		0.66
# t = 5 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 45 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.67		0.63
# 2	0.68		0.65
# 3	0.68		0.66
# 4	0.68		0.66
# 5	0.69		0.66
# 6	0.68		0.66
# 7	0.69		0.66
# 8	0.68		0.66
# 9	0.68		0.66
# 10	0.69		0.66
# 11	0.69		0.66
# 12	0.69		0.66
# 13	0.68		0.66
# 14	0.68		0.66
# 15	0.69		0.66
# 16	0.69		0.66
# 17	0.69		0.67
# 18	0.69		0.66
# 19	0.68		0.66
# 20	0.69		0.66
# t = 16 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 46 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.68		0.64
# 2	0.68		0.65
# 3	0.68		0.64
# 4	0.68		0.65
# 5	0.67		0.66
# 6	0.68		0.66
# 7	0.68		0.65
# 8	0.68		0.66
# 9	0.68		0.66
# 10	0.68		0.66
# 11	0.68		0.66
# 12	0.68		0.66
# 13	0.68		0.66
# 14	0.68		0.66
# 15	0.68		0.66
# 16	0.68		0.66
# 17	0.69		0.66
# 18	0.68		0.66
# 19	0.68		0.66
# 20	0.69		0.66
# t = 17 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 47 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.64
# 2	0.69		0.66
# 3	0.68		0.65
# 4	0.68		0.65
# 5	0.67		0.65
# 6	0.68		0.66
# 7	0.68		0.65
# 8	0.68		0.66
# 9	0.68		0.66
# 10	0.68		0.66
# 11	0.68		0.66
# 12	0.68		0.66
# 13	0.68		0.66
# 14	0.68		0.66
# 15	0.68		0.66
# 16	0.68		0.66
# 17	0.69		0.66
# 18	0.69		0.66
# 19	0.68		0.66
# 20	0.69		0.66
# t = 2 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 48 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.64
# 2	0.69		0.65
# 3	0.69		0.66
# 4	0.69		0.66
# 5	0.69		0.66
# 6	0.69		0.66
# 7	0.69		0.66
# 8	0.68		0.65
# 9	0.69		0.66
# 10	0.69		0.66
# 11	0.69		0.66
# 12	0.68		0.67
# 13	0.69		0.67
# 14	0.69		0.67
# 15	0.69		0.66
# 16	0.68		0.67
# 17	0.68		0.67
# 18	0.69		0.66
# 19	0.69		0.67
# 20	0.69		0.66
# t = 11 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 49 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.66
# 2	0.69		0.66
# 3	0.68		0.66
# 4	0.69		0.66
# 5	0.68		0.66
# 6	0.68		0.67
# 7	0.69		0.66
# 8	0.69		0.66
# 9	0.69		0.66
# 10	0.69		0.67
# 11	0.68		0.67
# 12	0.68		0.67
# 13	0.69		0.67
# 14	0.69		0.66
# 15	0.69		0.66
# 16	0.69		0.66
# 17	0.69		0.66
# 18	0.69		0.66
# 19	0.69		0.66
# 20	0.69		0.66
# t = 1 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 50 / 100 complete
# -----------------------------------------------
#
# Cut at 171 rather than expected 200
# Training accuracy of rank SVM: 0.99
# /Users/Ashtekar15/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.70
# 2	0.70		0.70
# 3	0.71		0.70
# 4	0.71		0.71
# 5	0.71		0.70
# 6	0.71		0.70
# 7	0.71		0.70
# 8	0.71		0.70
# 9	0.70		0.70
# 10	0.70		0.70
# 11	0.70		0.70
# 12	0.70		0.70
# 13	0.71		0.70
# 14	0.71		0.70
# 15	0.71		0.70
# 16	0.70		0.70
# 17	0.71		0.70
# 18	0.71		0.70
# 19	0.71		0.70
# 20	0.71		0.70
# t = 5 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 51 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.67		0.67
# 2	0.69		0.69
# 3	0.70		0.69
# 4	0.70		0.70
# 5	0.70		0.70
# 6	0.70		0.69
# 7	0.70		0.69
# 8	0.70		0.69
# 9	0.70		0.70
# 10	0.70		0.70
# 11	0.70		0.70
# 12	0.70		0.70
# 13	0.70		0.70
# 14	0.71		0.70
# 15	0.70		0.70
# 16	0.71		0.70
# 17	0.70		0.70
# 18	0.70		0.70
# 19	0.71		0.70
# 20	0.70		0.70
# t = 14 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 52 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.68
# 2	0.70		0.69
# 3	0.70		0.69
# 4	0.70		0.69
# 5	0.70		0.69
# 6	0.70		0.69
# 7	0.70		0.69
# 8	0.70		0.69
# 9	0.70		0.70
# 10	0.70		0.70
# 11	0.71		0.70
# 12	0.71		0.70
# 13	0.71		0.70
# 14	0.70		0.70
# 15	0.70		0.70
# 16	0.70		0.70
# 17	0.71		0.70
# 18	0.70		0.70
# 19	0.70		0.70
# 20	0.70		0.70
# t = 12 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 53 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.68
# 2	0.70		0.68
# 3	0.70		0.69
# 4	0.70		0.69
# 5	0.70		0.69
# 6	0.70		0.70
# 7	0.69		0.69
# 8	0.70		0.70
# 9	0.71		0.70
# 10	0.71		0.70
# 11	0.71		0.70
# 12	0.70		0.70
# 13	0.70		0.69
# 14	0.71		0.70
# 15	0.71		0.70
# 16	0.71		0.70
# 17	0.71		0.70
# 18	0.71		0.70
# 19	0.71		0.70
# 20	0.71		0.70
# t = 20 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 54 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.69
# 2	0.70		0.69
# 3	0.69		0.69
# 4	0.70		0.69
# 5	0.70		0.70
# 6	0.70		0.70
# 7	0.70		0.70
# 8	0.70		0.69
# 9	0.70		0.70
# 10	0.69		0.70
# 11	0.70		0.70
# 12	0.70		0.70
# 13	0.70		0.70
# 14	0.70		0.70
# 15	0.70		0.70
# 16	0.70		0.70
# 17	0.70		0.70
# 18	0.70		0.69
# 19	0.70		0.70
# 20	0.71		0.70
# t = 20 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 55 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.69
# 2	0.71		0.70
# 3	0.71		0.70
# 4	0.71		0.70
# 5	0.71		0.70
# 6	0.71		0.70
# 7	0.71		0.70
# 8	0.71		0.70
# 9	0.71		0.70
# 10	0.71		0.70
# 11	0.71		0.70
# 12	0.71		0.70
# 13	0.71		0.70
# 14	0.71		0.70
# 15	0.70		0.70
# 16	0.71		0.70
# 17	0.71		0.70
# 18	0.71		0.70
# 19	0.71		0.70
# 20	0.71		0.70
# t = 5 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 56 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.67
# 2	0.70		0.68
# 3	0.70		0.69
# 4	0.70		0.69
# 5	0.70		0.69
# 6	0.70		0.69
# 7	0.71		0.70
# 8	0.71		0.70
# 9	0.71		0.70
# 10	0.71		0.70
# 11	0.71		0.70
# 12	0.70		0.70
# 13	0.71		0.70
# 14	0.70		0.70
# 15	0.71		0.70
# 16	0.70		0.70
# 17	0.71		0.70
# 18	0.71		0.70
# 19	0.71		0.70
# 20	0.71		0.70
# t = 9 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 57 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.68
# 2	0.70		0.70
# 3	0.70		0.70
# 4	0.70		0.69
# 5	0.70		0.69
# 6	0.71		0.70
# 7	0.71		0.70
# 8	0.71		0.70
# 9	0.71		0.70
# 10	0.70		0.70
# 11	0.71		0.70
# 12	0.71		0.70
# 13	0.71		0.71
# 14	0.71		0.71
# 15	0.71		0.70
# 16	0.70		0.70
# 17	0.71		0.70
# 18	0.70		0.70
# 19	0.70		0.70
# 20	0.70		0.70
# t = 1 was best iteration with accuracy 0.68
#
# -----------------------------------------------
# 58 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.69
# 2	0.70		0.69
# 3	0.69		0.70
# 4	0.69		0.70
# 5	0.71		0.70
# 6	0.71		0.70
# 7	0.71		0.70
# 8	0.71		0.70
# 9	0.71		0.70
# 10	0.71		0.70
# 11	0.71		0.70
# 12	0.70		0.70
# 13	0.70		0.70
# 14	0.70		0.70
# 15	0.70		0.70
# 16	0.70		0.70
# 17	0.71		0.70
# 18	0.71		0.70
# 19	0.71		0.70
# 20	0.71		0.70
# t = 6 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 59 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.68
# 2	0.70		0.69
# 3	0.70		0.70
# 4	0.71		0.70
# 5	0.70		0.69
# 6	0.71		0.69
# 7	0.70		0.69
# 8	0.70		0.69
# 9	0.70		0.70
# 10	0.70		0.70
# 11	0.70		0.70
# 12	0.71		0.70
# 13	0.71		0.70
# 14	0.71		0.69
# 15	0.71		0.70
# 16	0.71		0.70
# 17	0.71		0.70
# 18	0.71		0.70
# 19	0.71		0.70
# 20	0.71		0.70
# t = 15 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 60 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.68		0.67
# 2	0.70		0.68
# 3	0.70		0.70
# 4	0.70		0.70
# 5	0.71		0.70
# 6	0.71		0.70
# 7	0.72		0.70
# 8	0.71		0.70
# 9	0.72		0.71
# 10	0.72		0.70
# 11	0.71		0.71
# 12	0.72		0.70
# 13	0.71		0.70
# 14	0.71		0.70
# 15	0.71		0.70
# 16	0.71		0.70
# 17	0.71		0.70
# 18	0.71		0.70
# 19	0.71		0.70
# 20	0.71		0.70
# t = 10 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 61 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.70
# 2	0.70		0.70
# 3	0.71		0.70
# 4	0.71		0.71
# 5	0.71		0.70
# 6	0.71		0.71
# 7	0.71		0.71
# 8	0.72		0.71
# 9	0.71		0.71
# 10	0.71		0.70
# 11	0.71		0.71
# 12	0.71		0.70
# 13	0.71		0.70
# 14	0.71		0.70
# 15	0.71		0.70
# 16	0.70		0.70
# 17	0.71		0.70
# 18	0.71		0.70
# 19	0.71		0.70
# 20	0.71		0.70
# t = 8 was best iteration with accuracy 0.71
#
# -----------------------------------------------
# 62 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.68
# 2	0.69		0.68
# 3	0.70		0.69
# 4	0.70		0.69
# 5	0.70		0.69
# 6	0.71		0.69
# 7	0.71		0.70
# 8	0.71		0.70
# 9	0.71		0.70
# 10	0.71		0.70
# 11	0.71		0.70
# 12	0.71		0.70
# 13	0.71		0.70
# 14	0.71		0.70
# 15	0.71		0.71
# 16	0.71		0.70
# 17	0.71		0.70
# 18	0.71		0.70
# 19	0.71		0.70
# 20	0.71		0.70
# t = 8 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 63 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.70
# 2	0.70		0.69
# 3	0.72		0.70
# 4	0.71		0.70
# 5	0.71		0.70
# 6	0.71		0.71
# 7	0.71		0.71
# 8	0.71		0.70
# 9	0.71		0.70
# 10	0.71		0.70
# 11	0.71		0.70
# 12	0.71		0.70
# 13	0.71		0.70
# 14	0.71		0.70
# 15	0.71		0.70
# 16	0.71		0.70
# 17	0.71		0.70
# 18	0.71		0.70
# 19	0.71		0.70
# 20	0.71		0.70
# t = 3 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 64 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.69
# 2	0.71		0.69
# 3	0.70		0.69
# 4	0.70		0.69
# 5	0.72		0.70
# 6	0.71		0.70
# 7	0.70		0.70
# 8	0.71		0.70
# 9	0.71		0.71
# 10	0.71		0.71
# 11	0.71		0.71
# 12	0.71		0.70
# 13	0.70		0.70
# 14	0.70		0.70
# 15	0.70		0.70
# 16	0.70		0.70
# 17	0.71		0.70
# 18	0.71		0.70
# 19	0.70		0.70
# 20	0.70		0.70
# t = 5 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 65 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.69
# 2	0.70		0.70
# 3	0.71		0.71
# 4	0.71		0.71
# 5	0.72		0.70
# 6	0.71		0.70
# 7	0.71		0.70
# 8	0.71		0.70
# 9	0.71		0.70
# 10	0.71		0.70
# 11	0.71		0.70
# 12	0.71		0.70
# 13	0.71		0.70
# 14	0.71		0.70
# 15	0.71		0.70
# 16	0.71		0.70
# 17	0.71		0.70
# 18	0.71		0.70
# 19	0.71		0.70
# 20	0.71		0.70
# t = 5 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 66 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.67
# 2	0.70		0.69
# 3	0.70		0.70
# 4	0.70		0.70
# 5	0.71		0.70
# 6	0.71		0.71
# 7	0.71		0.70
# 8	0.71		0.70
# 9	0.71		0.70
# 10	0.71		0.70
# 11	0.71		0.70
# 12	0.71		0.70
# 13	0.71		0.71
# 14	0.71		0.71
# 15	0.70		0.71
# 16	0.71		0.71
# 17	0.71		0.71
# 18	0.71		0.71
# 19	0.71		0.71
# 20	0.71		0.71
# t = 20 was best iteration with accuracy 0.71
#
# -----------------------------------------------
# 67 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.68
# 2	0.70		0.69
# 3	0.70		0.69
# 4	0.70		0.69
# 5	0.70		0.70
# 6	0.70		0.71
# 7	0.70		0.70
# 8	0.71		0.70
# 9	0.70		0.70
# 10	0.70		0.70
# 11	0.70		0.69
# 12	0.71		0.70
# 13	0.71		0.70
# 14	0.70		0.70
# 15	0.71		0.70
# 16	0.71		0.70
# 17	0.70		0.70
# 18	0.70		0.70
# 19	0.71		0.70
# 20	0.71		0.70
# t = 16 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 68 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.68
# 2	0.70		0.69
# 3	0.70		0.69
# 4	0.71		0.70
# 5	0.72		0.71
# 6	0.72		0.71
# 7	0.71		0.70
# 8	0.72		0.70
# 9	0.71		0.70
# 10	0.71		0.70
# 11	0.71		0.70
# 12	0.71		0.70
# 13	0.71		0.70
# 14	0.71		0.70
# 15	0.71		0.70
# 16	0.71		0.70
# 17	0.71		0.70
# 18	0.71		0.70
# 19	0.71		0.70
# 20	0.71		0.70
# t = 6 was best iteration with accuracy 0.71
#
# -----------------------------------------------
# 69 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.67
# 2	0.69		0.67
# 3	0.70		0.69
# 4	0.71		0.70
# 5	0.71		0.70
# 6	0.71		0.70
# 7	0.71		0.70
# 8	0.71		0.70
# 9	0.71		0.70
# 10	0.71		0.70
# 11	0.71		0.70
# 12	0.71		0.70
# 13	0.71		0.69
# 14	0.71		0.69
# 15	0.70		0.70
# 16	0.70		0.70
# 17	0.70		0.70
# 18	0.71		0.70
# 19	0.71		0.70
# 20	0.71		0.70
# t = 7 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 70 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.68
# 2	0.71		0.70
# 3	0.70		0.69
# 4	0.71		0.71
# 5	0.71		0.71
# 6	0.71		0.71
# 7	0.71		0.71
# 8	0.70		0.71
# 9	0.71		0.71
# 10	0.71		0.71
# 11	0.71		0.70
# 12	0.71		0.71
# 13	0.71		0.71
# 14	0.71		0.71
# 15	0.72		0.71
# 16	0.72		0.70
# 17	0.72		0.71
# 18	0.72		0.70
# 19	0.72		0.70
# 20	0.71		0.70
# t = 17 was best iteration with accuracy 0.71
#
# -----------------------------------------------
# 71 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.66
# 2	0.69		0.68
# 3	0.69		0.68
# 4	0.69		0.69
# 5	0.70		0.69
# 6	0.70		0.70
# 7	0.70		0.70
# 8	0.70		0.69
# 9	0.70		0.69
# 10	0.70		0.69
# 11	0.70		0.70
# 12	0.70		0.70
# 13	0.70		0.70
# 14	0.70		0.70
# 15	0.71		0.70
# 16	0.71		0.70
# 17	0.71		0.70
# 18	0.70		0.70
# 19	0.70		0.70
# 20	0.71		0.70
# t = 15 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 72 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.68
# 2	0.71		0.69
# 3	0.70		0.70
# 4	0.70		0.69
# 5	0.70		0.69
# 6	0.70		0.70
# 7	0.70		0.69
# 8	0.70		0.69
# 9	0.71		0.70
# 10	0.70		0.69
# 11	0.70		0.69
# 12	0.70		0.69
# 13	0.70		0.69
# 14	0.70		0.70
# 15	0.70		0.70
# 16	0.70		0.70
# 17	0.70		0.70
# 18	0.71		0.70
# 19	0.71		0.70
# 20	0.71		0.70
# t = 2 was best iteration with accuracy 0.69
#
# -----------------------------------------------
# 73 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.67
# 2	0.70		0.68
# 3	0.69		0.68
# 4	0.70		0.69
# 5	0.70		0.69
# 6	0.71		0.70
# 7	0.70		0.71
# 8	0.70		0.70
# 9	0.71		0.70
# 10	0.71		0.70
# 11	0.70		0.69
# 12	0.70		0.70
# 13	0.70		0.70
# 14	0.70		0.70
# 15	0.70		0.70
# 16	0.70		0.70
# 17	0.70		0.70
# 18	0.70		0.70
# 19	0.70		0.69
# 20	0.71		0.70
# t = 6 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 74 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.69
# 2	0.71		0.70
# 3	0.72		0.71
# 4	0.71		0.70
# 5	0.70		0.70
# 6	0.71		0.70
# 7	0.71		0.70
# 8	0.71		0.70
# 9	0.70		0.70
# 10	0.71		0.71
# 11	0.71		0.71
# 12	0.71		0.70
# 13	0.71		0.70
# 14	0.71		0.70
# 15	0.71		0.71
# 16	0.71		0.71
# 17	0.71		0.71
# 18	0.71		0.71
# 19	0.71		0.71
# 20	0.71		0.71
# t = 3 was best iteration with accuracy 0.71
#
# -----------------------------------------------
# 75 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.68
# 2	0.70		0.69
# 3	0.71		0.71
# 4	0.71		0.70
# 5	0.71		0.69
# 6	0.71		0.70
# 7	0.71		0.70
# 8	0.71		0.70
# 9	0.71		0.70
# 10	0.71		0.70
# 11	0.71		0.70
# 12	0.71		0.70
# 13	0.71		0.70
# 14	0.70		0.70
# 15	0.70		0.70
# 16	0.70		0.70
# 17	0.70		0.70
# 18	0.71		0.70
# 19	0.71		0.70
# 20	0.71		0.70
# t = 12 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 76 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.68		0.65
# 2	0.69		0.68
# 3	0.69		0.68
# 4	0.69		0.68
# 5	0.70		0.69
# 6	0.70		0.69
# 7	0.70		0.69
# 8	0.70		0.69
# 9	0.71		0.69
# 10	0.71		0.69
# 11	0.71		0.70
# 12	0.71		0.69
# 13	0.71		0.70
# 14	0.70		0.70
# 15	0.71		0.70
# 16	0.71		0.69
# 17	0.70		0.70
# 18	0.71		0.69
# 19	0.70		0.69
# 20	0.70		0.69
# t = 10 was best iteration with accuracy 0.69
#
# -----------------------------------------------
# 77 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.70
# 2	0.71		0.71
# 3	0.71		0.71
# 4	0.72		0.71
# 5	0.71		0.70
# 6	0.71		0.70
# 7	0.71		0.69
# 8	0.71		0.70
# 9	0.70		0.69
# 10	0.71		0.70
# 11	0.71		0.70
# 12	0.71		0.70
# 13	0.71		0.70
# 14	0.71		0.70
# 15	0.71		0.70
# 16	0.71		0.70
# 17	0.71		0.70
# 18	0.71		0.70
# 19	0.71		0.70
# 20	0.71		0.71
# t = 4 was best iteration with accuracy 0.71
#
# -----------------------------------------------
# 78 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.70
# 2	0.70		0.70
# 3	0.70		0.69
# 4	0.70		0.69
# 5	0.71		0.70
# 6	0.71		0.70
# 7	0.71		0.70
# 8	0.70		0.70
# 9	0.70		0.70
# 10	0.70		0.70
# 11	0.70		0.70
# 12	0.70		0.69
# 13	0.70		0.69
# 14	0.71		0.69
# 15	0.70		0.69
# 16	0.70		0.69
# 17	0.70		0.69
# 18	0.70		0.70
# 19	0.71		0.69
# 20	0.70		0.69
# t = 5 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 79 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.69
# 2	0.70		0.70
# 3	0.71		0.70
# 4	0.71		0.70
# 5	0.70		0.70
# 6	0.70		0.70
# 7	0.71		0.70
# 8	0.70		0.70
# 9	0.70		0.70
# 10	0.70		0.71
# 11	0.70		0.70
# 12	0.71		0.70
# 13	0.71		0.70
# 14	0.71		0.70
# 15	0.71		0.70
# 16	0.71		0.70
# 17	0.71		0.70
# 18	0.71		0.70
# 19	0.71		0.71
# 20	0.71		0.70
# t = 15 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 80 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.69
# 2	0.70		0.69
# 3	0.71		0.71
# 4	0.70		0.70
# 5	0.70		0.70
# 6	0.70		0.70
# 7	0.70		0.70
# 8	0.70		0.70
# 9	0.70		0.69
# 10	0.70		0.70
# 11	0.71		0.69
# 12	0.71		0.69
# 13	0.71		0.69
# 14	0.71		0.70
# 15	0.71		0.70
# 16	0.71		0.70
# 17	0.71		0.70
# 18	0.71		0.70
# 19	0.71		0.70
# 20	0.71		0.70
# t = 3 was best iteration with accuracy 0.71
#
# -----------------------------------------------
# 81 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.68		0.68
# 2	0.68		0.68
# 3	0.69		0.68
# 4	0.70		0.68
# 5	0.70		0.69
# 6	0.70		0.69
# 7	0.70		0.69
# 8	0.71		0.69
# 9	0.71		0.70
# 10	0.70		0.70
# 11	0.71		0.70
# 12	0.71		0.69
# 13	0.71		0.69
# 14	0.70		0.69
# 15	0.70		0.69
# 16	0.70		0.69
# 17	0.70		0.69
# 18	0.70		0.69
# 19	0.70		0.69
# 20	0.71		0.69
# t = 20 was best iteration with accuracy 0.69
#
# -----------------------------------------------
# 82 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.69
# 2	0.72		0.70
# 3	0.72		0.70
# 4	0.71		0.70
# 5	0.71		0.70
# 6	0.71		0.70
# 7	0.71		0.70
# 8	0.72		0.70
# 9	0.71		0.70
# 10	0.71		0.70
# 11	0.71		0.70
# 12	0.72		0.70
# 13	0.72		0.70
# 14	0.71		0.70
# 15	0.71		0.70
# 16	0.71		0.70
# 17	0.71		0.70
# 18	0.71		0.70
# 19	0.71		0.70
# 20	0.71		0.70
# t = 13 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 83 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.69
# 2	0.71		0.70
# 3	0.71		0.70
# 4	0.70		0.70
# 5	0.71		0.70
# 6	0.71		0.69
# 7	0.70		0.70
# 8	0.70		0.69
# 9	0.71		0.70
# 10	0.70		0.70
# 11	0.71		0.70
# 12	0.70		0.70
# 13	0.71		0.70
# 14	0.71		0.70
# 15	0.71		0.70
# 16	0.71		0.70
# 17	0.71		0.70
# 18	0.71		0.70
# 19	0.71		0.70
# 20	0.71		0.70
# t = 1 was best iteration with accuracy 0.69
#
# -----------------------------------------------
# 84 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.68
# 2	0.70		0.70
# 3	0.70		0.70
# 4	0.71		0.70
# 5	0.71		0.70
# 6	0.71		0.70
# 7	0.71		0.70
# 8	0.71		0.70
# 9	0.71		0.70
# 10	0.71		0.70
# 11	0.71		0.70
# 12	0.71		0.70
# 13	0.70		0.70
# 14	0.70		0.70
# 15	0.70		0.70
# 16	0.70		0.70
# 17	0.70		0.70
# 18	0.70		0.70
# 19	0.70		0.70
# 20	0.71		0.70
# t = 6 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 85 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.69
# 2	0.70		0.70
# 3	0.71		0.69
# 4	0.71		0.70
# 5	0.71		0.69
# 6	0.71		0.70
# 7	0.71		0.70
# 8	0.71		0.70
# 9	0.71		0.70
# 10	0.71		0.70
# 11	0.71		0.70
# 12	0.71		0.70
# 13	0.70		0.70
# 14	0.71		0.70
# 15	0.71		0.70
# 16	0.71		0.70
# 17	0.71		0.70
# 18	0.71		0.70
# 19	0.71		0.70
# 20	0.71		0.70
# t = 5 was best iteration with accuracy 0.69
#
# -----------------------------------------------
# 86 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.68
# 2	0.70		0.70
# 3	0.71		0.69
# 4	0.70		0.69
# 5	0.71		0.70
# 6	0.70		0.69
# 7	0.70		0.69
# 8	0.71		0.69
# 9	0.70		0.69
# 10	0.70		0.69
# 11	0.71		0.69
# 12	0.70		0.70
# 13	0.70		0.70
# 14	0.70		0.70
# 15	0.70		0.70
# 16	0.71		0.70
# 17	0.71		0.70
# 18	0.70		0.70
# 19	0.70		0.70
# 20	0.71		0.70
# t = 3 was best iteration with accuracy 0.69
#
# -----------------------------------------------
# 87 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.71
# 2	0.69		0.71
# 3	0.70		0.71
# 4	0.70		0.70
# 5	0.70		0.70
# 6	0.71		0.70
# 7	0.70		0.70
# 8	0.70		0.70
# 9	0.70		0.70
# 10	0.71		0.71
# 11	0.71		0.71
# 12	0.71		0.70
# 13	0.71		0.70
# 14	0.71		0.70
# 15	0.71		0.70
# 16	0.71		0.70
# 17	0.71		0.70
# 18	0.71		0.70
# 19	0.71		0.70
# 20	0.71		0.70
# t = 13 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 88 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.68
# 2	0.70		0.70
# 3	0.71		0.70
# 4	0.70		0.70
# 5	0.71		0.71
# 6	0.71		0.71
# 7	0.71		0.71
# 8	0.71		0.71
# 9	0.72		0.70
# 10	0.71		0.70
# 11	0.71		0.70
# 12	0.71		0.71
# 13	0.71		0.70
# 14	0.71		0.70
# 15	0.71		0.70
# 16	0.71		0.70
# 17	0.71		0.69
# 18	0.71		0.70
# 19	0.71		0.70
# 20	0.71		0.70
# t = 9 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 89 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.71
# 2	0.71		0.71
# 3	0.70		0.70
# 4	0.71		0.71
# 5	0.71		0.71
# 6	0.71		0.70
# 7	0.71		0.70
# 8	0.71		0.70
# 9	0.71		0.70
# 10	0.70		0.70
# 11	0.71		0.70
# 12	0.71		0.70
# 13	0.71		0.70
# 14	0.71		0.70
# 15	0.71		0.70
# 16	0.71		0.70
# 17	0.71		0.70
# 18	0.71		0.70
# 19	0.71		0.70
# 20	0.71		0.70
# t = 4 was best iteration with accuracy 0.71
#
# -----------------------------------------------
# 90 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.68
# 2	0.70		0.68
# 3	0.70		0.69
# 4	0.70		0.69
# 5	0.71		0.69
# 6	0.71		0.70
# 7	0.70		0.69
# 8	0.70		0.69
# 9	0.71		0.69
# 10	0.71		0.69
# 11	0.70		0.69
# 12	0.70		0.70
# 13	0.70		0.70
# 14	0.70		0.70
# 15	0.70		0.70
# 16	0.71		0.70
# 17	0.71		0.70
# 18	0.71		0.70
# 19	0.71		0.70
# 20	0.71		0.70
# t = 6 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 91 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.68		0.66
# 2	0.70		0.69
# 3	0.70		0.69
# 4	0.70		0.68
# 5	0.70		0.69
# 6	0.70		0.69
# 7	0.70		0.69
# 8	0.70		0.69
# 9	0.70		0.69
# 10	0.70		0.69
# 11	0.70		0.69
# 12	0.71		0.69
# 13	0.70		0.70
# 14	0.70		0.70
# 15	0.70		0.69
# 16	0.70		0.70
# 17	0.70		0.70
# 18	0.70		0.70
# 19	0.71		0.70
# 20	0.71		0.70
# t = 20 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 92 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.68
# 2	0.69		0.69
# 3	0.70		0.68
# 4	0.70		0.69
# 5	0.70		0.68
# 6	0.70		0.68
# 7	0.70		0.69
# 8	0.70		0.69
# 9	0.70		0.70
# 10	0.70		0.70
# 11	0.70		0.70
# 12	0.70		0.70
# 13	0.70		0.70
# 14	0.70		0.70
# 15	0.70		0.70
# 16	0.70		0.70
# 17	0.71		0.70
# 18	0.70		0.70
# 19	0.70		0.70
# 20	0.70		0.70
# t = 17 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 93 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.70
# 2	0.71		0.69
# 3	0.70		0.70
# 4	0.71		0.69
# 5	0.70		0.69
# 6	0.70		0.69
# 7	0.70		0.69
# 8	0.70		0.69
# 9	0.70		0.69
# 10	0.70		0.69
# 11	0.70		0.69
# 12	0.70		0.69
# 13	0.70		0.70
# 14	0.71		0.69
# 15	0.70		0.70
# 16	0.71		0.70
# 17	0.71		0.70
# 18	0.70		0.70
# 19	0.70		0.70
# 20	0.70		0.70
# t = 4 was best iteration with accuracy 0.69
#
# -----------------------------------------------
# 94 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.68
# 2	0.70		0.70
# 3	0.70		0.70
# 4	0.70		0.69
# 5	0.70		0.70
# 6	0.71		0.70
# 7	0.70		0.70
# 8	0.71		0.70
# 9	0.70		0.70
# 10	0.70		0.70
# 11	0.71		0.70
# 12	0.71		0.70
# 13	0.71		0.70
# 14	0.71		0.70
# 15	0.71		0.69
# 16	0.70		0.69
# 17	0.71		0.69
# 18	0.71		0.70
# 19	0.71		0.70
# 20	0.71		0.70
# t = 11 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 95 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.67
# 2	0.69		0.69
# 3	0.70		0.68
# 4	0.70		0.69
# 5	0.70		0.70
# 6	0.70		0.70
# 7	0.70		0.70
# 8	0.70		0.70
# 9	0.70		0.70
# 10	0.70		0.70
# 11	0.70		0.70
# 12	0.70		0.70
# 13	0.70		0.70
# 14	0.70		0.70
# 15	0.70		0.70
# 16	0.70		0.70
# 17	0.70		0.70
# 18	0.70		0.70
# 19	0.70		0.70
# 20	0.71		0.70
# t = 20 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 96 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.70
# 2	0.71		0.71
# 3	0.70		0.72
# 4	0.71		0.70
# 5	0.70		0.70
# 6	0.71		0.70
# 7	0.70		0.69
# 8	0.71		0.70
# 9	0.71		0.70
# 10	0.70		0.70
# 11	0.71		0.70
# 12	0.71		0.70
# 13	0.71		0.70
# 14	0.71		0.70
# 15	0.71		0.70
# 16	0.70		0.70
# 17	0.70		0.70
# 18	0.71		0.70
# 19	0.71		0.70
# 20	0.71		0.70
# t = 1 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 97 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.66
# 2	0.70		0.68
# 3	0.70		0.68
# 4	0.70		0.69
# 5	0.70		0.70
# 6	0.71		0.70
# 7	0.71		0.70
# 8	0.71		0.70
# 9	0.71		0.70
# 10	0.70		0.69
# 11	0.70		0.70
# 12	0.70		0.69
# 13	0.70		0.70
# 14	0.70		0.70
# 15	0.70		0.70
# 16	0.70		0.69
# 17	0.70		0.70
# 18	0.70		0.70
# 19	0.70		0.70
# 20	0.71		0.70
# t = 7 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 98 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.69
# 2	0.71		0.69
# 3	0.71		0.70
# 4	0.71		0.70
# 5	0.71		0.71
# 6	0.71		0.70
# 7	0.71		0.70
# 8	0.71		0.70
# 9	0.71		0.70
# 10	0.71		0.70
# 11	0.71		0.70
# 12	0.71		0.70
# 13	0.71		0.70
# 14	0.71		0.70
# 15	0.71		0.70
# 16	0.71		0.70
# 17	0.71		0.70
# 18	0.71		0.70
# 19	0.71		0.70
# 20	0.71		0.70
# t = 3 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 99 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.66
# 2	0.69		0.67
# 3	0.69		0.68
# 4	0.69		0.68
# 5	0.69		0.69
# 6	0.70		0.69
# 7	0.70		0.70
# 8	0.70		0.70
# 9	0.71		0.70
# 10	0.70		0.70
# 11	0.70		0.70
# 12	0.70		0.70
# 13	0.71		0.70
# 14	0.70		0.70
# 15	0.70		0.70
# 16	0.70		0.69
# 17	0.70		0.70
# 18	0.70		0.70
# 19	0.70		0.70
# 20	0.70		0.70
# t = 9 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 100 / 100 complete
# -----------------------------------------------

# %%
table_results(svm_arr, tree_arr)
# Out:
# (Performance on test set)
#
# 50 comparisons
# 	acc	sderr
# SVM: 	66.0	0.2
# Tree: 	nan	nan
#
# 200 comparisons
# 	acc	sderr
# SVM: 	70.0	0.1
# Tree: 	nan	nan
