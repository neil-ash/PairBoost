# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_svmlight_file
from sklearn.model_selection import train_test_split
import sys; sys.path.insert(0,'..')
from main import *

# %%
X_train, y_train = load_svmlight_file('../data/w8a/w8a.txt')
X_train = X_train.toarray()

X_test, y_test = load_svmlight_file('../data/w8a/w8a.t')
X_test = X_test.toarray()

# %%
svm_arr, tree_arr = data_size_experiment(X_train, y_train, X_test, y_test,
                                         experiment_type='table', kernel='linear',
                                         random_state=107, verbose=True)
# Out:
# Progress:
# Cut at 17 rather than expected 50
# Training accuracy of rank SVM: 1.00
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.45		0.37
# /Users/Ashtekar15/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 2	0.47		0.40
# 3	0.58		0.55
# 4	0.54		0.45
# 5	0.61		0.66
# 6	0.55		0.50
# 7	0.66		0.69
# 8	0.54		0.47
# 9	0.63		0.65
# 10	0.49		0.45
# 11	0.59		0.58
# 12	0.46		0.41
# 13	0.59		0.60
# 14	0.45		0.38
# 15	0.48		0.45
# 16	0.44		0.39
# 17	0.57		0.60
# 18	0.48		0.41
# 19	0.51		0.54
# 20	0.45		0.39
# t = 7 was best iteration with accuracy 0.69
#
# -----------------------------------------------
# 1 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.46		0.40
# 2	0.56		0.54
# 3	0.47		0.44
# 4	0.58		0.58
# 5	0.48		0.44
# 6	0.55		0.55
# 7	0.45		0.37
# 8	0.48		0.45
# /Users/Ashtekar15/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 9	0.46		0.40
# 10	0.49		0.48
# 11	0.45		0.39
# 12	0.60		0.59
# 13	0.45		0.42
# 14	0.61		0.60
# 15	0.42		0.36
# 16	0.58		0.60
# 17	0.48		0.41
# 18	0.54		0.57
# 19	0.50		0.42
# 20	0.56		0.58
# t = 14 was best iteration with accuracy 0.60
#
# -----------------------------------------------
# 2 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.44		0.39
# 2	0.56		0.52
# 3	0.44		0.39
# 4	0.62		0.63
# 5	0.42		0.38
# 6	0.52		0.48
# 7	0.44		0.37
# 8	0.48		0.49
# 9	0.43		0.33
# 10	0.56		0.61
# 11	0.44		0.34
# 12	0.52		0.55
# 13	0.46		0.36
# 14	0.47		0.41
# 15	0.37		0.28
# 16	0.57		0.56
# 17	0.45		0.40
# 18	0.53		0.55
# 19	0.51		0.42
# 20	0.57		0.61
# t = 15 was best iteration with accuracy 0.72
#
# -----------------------------------------------
# 3 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.47		0.38
# 2	0.51		0.48
# 3	0.46		0.42
# 4	0.61		0.63
# 5	0.44		0.38
# 6	0.54		0.53
# 7	0.42		0.38
# 8	0.59		0.62
# 9	0.40		0.39
# 10	0.59		0.60
# 11	0.44		0.39
# 12	0.58		0.59
# 13	0.46		0.37
# 14	0.63		0.64
# 15	0.44		0.36
# 16	0.47		0.44
# 17	0.37		0.34
# 18	0.46		0.40
# 19	0.39		0.36
# 20	0.57		0.52
# t = 17 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 4 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.49		0.41
# 2	0.55		0.53
# 3	0.61		0.53
# 4	0.64		0.71
# 5	0.53		0.45
# 6	0.68		0.69
# 7	0.53		0.48
# 8	0.64		0.68
# 9	0.49		0.44
# 10	0.67		0.67
# 11	0.54		0.50
# 12	0.61		0.63
# 13	0.45		0.42
# 14	0.45		0.38
# 15	0.45		0.39
# 16	0.51		0.51
# 17	0.44		0.38
# 18	0.54		0.55
# 19	0.41		0.36
# 20	0.49		0.46
# t = 6 was best iteration with accuracy 0.69
#
# -----------------------------------------------
# 5 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.42		0.38
# 2	0.43		0.41
# 3	0.43		0.39
# 4	0.55		0.58
# 5	0.37		0.29
# 6	0.33		0.30
# 7	0.32		0.28
# 8	0.33		0.27
# 9	0.36		0.33
# 10	0.32		0.29
# 11	0.27		0.22
# 12	0.26		0.25
# 13	0.32		0.28
# 14	0.50		0.50
# 15	0.36		0.32
# 16	0.31		0.29
# 17	0.34		0.30
# 18	0.46		0.47
# 19	0.27		0.25
# 20	0.29		0.25
# t = 12 was best iteration with accuracy 0.75
#
# -----------------------------------------------
# 6 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.48		0.43
# 2	0.58		0.54
# 3	0.60		0.58
# 4	0.52		0.43
# 5	0.57		0.66
# 6	0.50		0.44
# 7	0.54		0.49
# 8	0.49		0.41
# 9	0.55		0.54
# 10	0.51		0.42
# 11	0.56		0.62
# 12	0.45		0.38
# 13	0.43		0.40
# 14	0.42		0.34
# 15	0.39		0.33
# 16	0.41		0.34
# 17	0.53		0.54
# 18	0.38		0.36
# 19	0.35		0.32
# 20	0.37		0.30
# t = 19 was best iteration with accuracy 0.68
#
# -----------------------------------------------
# 7 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.46		0.39
# 2	0.50		0.46
# 3	0.47		0.44
# 4	0.57		0.54
# 5	0.47		0.43
# 6	0.54		0.49
# 7	0.49		0.44
# 8	0.59		0.62
# 9	0.45		0.39
# 10	0.59		0.62
# 11	0.55		0.49
# 12	0.56		0.53
# 13	0.53		0.44
# 14	0.65		0.67
# 15	0.51		0.46
# 16	0.60		0.65
# 17	0.50		0.45
# 18	0.59		0.60
# 19	0.53		0.49
# 20	0.65		0.67
# t = 14 was best iteration with accuracy 0.67
#
# -----------------------------------------------
# 8 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.48		0.39
# 2	0.55		0.51
# 3	0.45		0.36
# 4	0.56		0.61
# 5	0.48		0.40
# 6	0.50		0.45
# 7	0.51		0.46
# 8	0.59		0.65
# 9	0.53		0.49
# 10	0.67		0.69
# 11	0.58		0.51
# 12	0.69		0.73
# 13	0.59		0.53
# 14	0.80		0.80
# 15	0.63		0.58
# 16	0.66		0.73
# 17	0.55		0.49
# 18	0.76		0.78
# 19	0.68		0.62
# 20	0.69		0.72
# t = 14 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 9 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.46		0.37
# 2	0.49		0.44
# /Users/Ashtekar15/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 3	0.46		0.39
# 4	0.54		0.50
# 5	0.40		0.35
# 6	0.62		0.63
# 7	0.44		0.37
# 8	0.51		0.46
# 9	0.51		0.44
# 10	0.63		0.65
# 11	0.42		0.38
# 12	0.62		0.66
# 13	0.49		0.43
# 14	0.63		0.66
# 15	0.49		0.42
# 16	0.56		0.56
# 17	0.53		0.44
# 18	0.69		0.71
# 19	0.53		0.51
# 20	0.67		0.74
# t = 18 was best iteration with accuracy 0.71
#
# -----------------------------------------------
# 10 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.45		0.38
# 2	0.54		0.49
# 3	0.53		0.50
# 4	0.62		0.60
# 5	0.51		0.46
# 6	0.64		0.62
# 7	0.55		0.49
# 8	0.67		0.68
# 9	0.51		0.44
# 10	0.57		0.62
# 11	0.48		0.42
# 12	0.55		0.53
# 13	0.52		0.45
# 14	0.65		0.66
# 15	0.55		0.46
# 16	0.69		0.72
# 17	0.60		0.53
# 18	0.65		0.66
# 19	0.54		0.51
# 20	0.65		0.64
# t = 16 was best iteration with accuracy 0.72
#
# -----------------------------------------------
# 11 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.45		0.38
# 2	0.48		0.44
# 3	0.47		0.46
# 4	0.44		0.42
# 5	0.46		0.42
# 6	0.46		0.40
# 7	0.40		0.40
# 8	0.60		0.59
# 9	0.52		0.46
# 10	0.56		0.52
# 11	0.67		0.68
# 12	0.51		0.47
# 13	0.57		0.59
# 14	0.50		0.45
# 15	0.61		0.63
# 16	0.53		0.45
# 17	0.61		0.70
# 18	0.48		0.45
# 19	0.62		0.64
# 20	0.51		0.46
# t = 11 was best iteration with accuracy 0.68
#
# -----------------------------------------------
# 12 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.45		0.35
# 2	0.44		0.41
# 3	0.41		0.36
# 4	0.64		0.64
# 5	0.43		0.38
# 6	0.65		0.66
# 7	0.51		0.48
# 8	0.58		0.57
# 9	0.48		0.43
# 10	0.61		0.64
# 11	0.44		0.39
# 12	0.58		0.55
# 13	0.48		0.45
# 14	0.63		0.67
# 15	0.47		0.44
# 16	0.58		0.59
# 17	0.45		0.44
# 18	0.60		0.60
# 19	0.47		0.40
# 20	0.58		0.61
# t = 6 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 13 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.44		0.39
# 2	0.47		0.44
# 3	0.40		0.35
# 4	0.58		0.55
# 5	0.44		0.41
# 6	0.47		0.44
# 7	0.43		0.39
# 8	0.49		0.50
# 9	0.42		0.33
# 10	0.38		0.37
# 11	0.39		0.35
# 12	0.50		0.55
# 13	0.41		0.32
# 14	0.42		0.39
# 15	0.37		0.33
# 16	0.40		0.42
# 17	0.38		0.33
# 18	0.45		0.44
# 19	0.41		0.37
# 20	0.40		0.35
# t = 15 was best iteration with accuracy 0.67
#
# -----------------------------------------------
# 14 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.46		0.38
# 2	0.47		0.41
# 3	0.66		0.67
# 4	0.47		0.40
# 5	0.63		0.63
# 6	0.56		0.51
# 7	0.61		0.65
# 8	0.52		0.47
# 9	0.61		0.66
# 10	0.51		0.46
# 11	0.59		0.64
# 12	0.48		0.41
# 13	0.59		0.62
# 14	0.46		0.41
# 15	0.57		0.59
# 16	0.48		0.39
# 17	0.47		0.45
# 18	0.48		0.41
# 19	0.57		0.57
# 20	0.43		0.37
# t = 3 was best iteration with accuracy 0.67
#
# -----------------------------------------------
# 15 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.45		0.39
# 2	0.52		0.46
# 3	0.52		0.50
# 4	0.46		0.43
# 5	0.52		0.48
# 6	0.48		0.43
# 7	0.49		0.47
# 8	0.40		0.35
# 9	0.45		0.43
# 10	0.42		0.35
# 11	0.44		0.41
# 12	0.39		0.33
# 13	0.41		0.40
# 14	0.40		0.36
# 15	0.58		0.55
# 16	0.44		0.36
# 17	0.50		0.48
# 18	0.46		0.37
# 19	0.62		0.64
# 20	0.45		0.41
# t = 19 was best iteration with accuracy 0.64
#
# -----------------------------------------------
# 16 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.47		0.39
# 2	0.41		0.34
# 3	0.39		0.33
# 4	0.51		0.50
# 5	0.45		0.41
# 6	0.37		0.36
# 7	0.39		0.34
# 8	0.35		0.30
# 9	0.35		0.25
# 10	0.31		0.27
# 11	0.28		0.23
# 12	0.52		0.55
# 13	0.45		0.40
# 14	0.45		0.43
# 15	0.42		0.37
# 16	0.45		0.43
# 17	0.47		0.43
# 18	0.54		0.53
# 19	0.43		0.39
# 20	0.51		0.44
# t = 11 was best iteration with accuracy 0.77
#
# -----------------------------------------------
# 17 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.48		0.37
# 2	0.51		0.49
# 3	0.46		0.39
# 4	0.52		0.54
# 5	0.47		0.44
# 6	0.49		0.47
# 7	0.45		0.41
# 8	0.49		0.49
# 9	0.48		0.43
# 10	0.62		0.64
# 11	0.45		0.38
# 12	0.61		0.62
# 13	0.49		0.42
# 14	0.64		0.61
# 15	0.50		0.42
# 16	0.61		0.62
# 17	0.49		0.42
# 18	0.60		0.62
# 19	0.49		0.47
# 20	0.53		0.49
# t = 14 was best iteration with accuracy 0.61
#
# -----------------------------------------------
# 18 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.45		0.37
# 2	0.49		0.48
# 3	0.48		0.40
# 4	0.59		0.62
# 5	0.54		0.48
# 6	0.71		0.70
# 7	0.52		0.47
# 8	0.64		0.66
# 9	0.49		0.41
# 10	0.58		0.54
# 11	0.52		0.51
# 12	0.67		0.63
# 13	0.52		0.49
# 14	0.64		0.64
# 15	0.51		0.45
# 16	0.55		0.50
# 17	0.52		0.49
# 18	0.65		0.67
# 19	0.49		0.45
# 20	0.65		0.68
# t = 6 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 19 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.45		0.40
# 2	0.48		0.44
# 3	0.41		0.39
# 4	0.60		0.61
# 5	0.41		0.38
# 6	0.59		0.58
# 7	0.45		0.40
# 8	0.57		0.56
# 9	0.43		0.38
# 10	0.45		0.43
# 11	0.41		0.37
# 12	0.58		0.58
# 13	0.39		0.36
# 14	0.61		0.66
# 15	0.40		0.37
# 16	0.65		0.68
# 17	0.45		0.40
# 18	0.57		0.50
# 19	0.49		0.44
# 20	0.59		0.60
# t = 16 was best iteration with accuracy 0.68
#
# -----------------------------------------------
# 20 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.46		0.40
# 2	0.56		0.55
# 3	0.46		0.41
# 4	0.61		0.65
# 5	0.46		0.40
# 6	0.61		0.64
# 7	0.48		0.44
# 8	0.55		0.52
# 9	0.49		0.46
# 10	0.57		0.52
# 11	0.49		0.45
# 12	0.61		0.61
# 13	0.47		0.40
# 14	0.47		0.43
# 15	0.48		0.41
# 16	0.57		0.60
# 17	0.47		0.40
# 18	0.60		0.60
# 19	0.43		0.39
# 20	0.59		0.60
# t = 4 was best iteration with accuracy 0.65
#
# -----------------------------------------------
# 21 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.48		0.43
# 2	0.51		0.47
# 3	0.63		0.66
# 4	0.47		0.45
# 5	0.58		0.62
# 6	0.55		0.47
# 7	0.59		0.58
# 8	0.64		0.60
# 9	0.77		0.80
# 10	0.66		0.57
# 11	0.61		0.71
# 12	0.59		0.52
# 13	0.74		0.78
# 14	0.59		0.56
# 15	0.73		0.76
# 16	0.58		0.52
# 17	0.75		0.79
# 18	0.62		0.56
# 19	0.79		0.79
# 20	0.60		0.54
# t = 19 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 22 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.47		0.37
# 2	0.50		0.44
# 3	0.51		0.50
# 4	0.45		0.39
# 5	0.40		0.36
# 6	0.39		0.34
# 7	0.40		0.37
# 8	0.44		0.38
# 9	0.41		0.39
# 10	0.44		0.35
# 11	0.55		0.57
# 12	0.39		0.33
# 13	0.39		0.36
# 14	0.33		0.28
# 15	0.35		0.30
# 16	0.34		0.29
# 17	0.28		0.25
# 18	0.27		0.25
# 19	0.22		0.26
# 20	0.34		0.28
# t = 19 was best iteration with accuracy 0.74
#
# -----------------------------------------------
# 23 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.49		0.42
# 2	0.57		0.55
# 3	0.47		0.42
# 4	0.66		0.67
# 5	0.54		0.50
# 6	0.61		0.56
# 7	0.60		0.50
# 8	0.65		0.68
# 9	0.55		0.44
# 10	0.58		0.63
# 11	0.50		0.38
# 12	0.57		0.60
# 13	0.44		0.35
# 14	0.58		0.61
# 15	0.45		0.36
# 16	0.62		0.67
# 17	0.52		0.42
# 18	0.60		0.67
# 19	0.53		0.44
# 20	0.63		0.65
# t = 4 was best iteration with accuracy 0.67
#
# -----------------------------------------------
# 24 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.46		0.41
# 2	0.48		0.41
# 3	0.52		0.52
# 4	0.46		0.42
# 5	0.52		0.49
# 6	0.54		0.49
# 7	0.60		0.63
# 8	0.52		0.47
# 9	0.60		0.62
# 10	0.48		0.41
# 11	0.50		0.48
# 12	0.48		0.40
# 13	0.58		0.61
# 14	0.46		0.39
# 15	0.55		0.54
# 16	0.45		0.41
# 17	0.48		0.47
# 18	0.46		0.43
# 19	0.60		0.60
# 20	0.43		0.42
# t = 9 was best iteration with accuracy 0.62
#
# -----------------------------------------------
# 25 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.46		0.40
# 2	0.52		0.49
# 3	0.50		0.43
# 4	0.61		0.63
# 5	0.44		0.39
# 6	0.65		0.66
# 7	0.51		0.48
# 8	0.60		0.56
# 9	0.51		0.46
# 10	0.60		0.62
# 11	0.46		0.40
# 12	0.58		0.59
# 13	0.43		0.41
# 14	0.59		0.59
# 15	0.45		0.38
# 16	0.45		0.42
# 17	0.42		0.35
# 18	0.52		0.56
# 19	0.41		0.33
# 20	0.41		0.38
# t = 6 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 26 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.46		0.40
# 2	0.51		0.49
# 3	0.45		0.38
# 4	0.68		0.68
# 5	0.45		0.40
# 6	0.62		0.63
# 7	0.49		0.45
# 8	0.57		0.54
# 9	0.56		0.51
# 10	0.67		0.70
# 11	0.49		0.43
# 12	0.59		0.66
# 13	0.43		0.37
# 14	0.45		0.42
# 15	0.39		0.35
# 16	0.57		0.57
# 17	0.39		0.35
# 18	0.38		0.33
# 19	0.32		0.31
# 20	0.36		0.34
# t = 19 was best iteration with accuracy 0.69
#
# -----------------------------------------------
# 27 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.47		0.40
# 2	0.57		0.59
# 3	0.43		0.38
# 4	0.56		0.62
# 5	0.41		0.38
# 6	0.52		0.50
# 7	0.47		0.42
# 8	0.60		0.64
# 9	0.44		0.39
# 10	0.49		0.48
# 11	0.43		0.39
# 12	0.43		0.42
# 13	0.40		0.34
# 14	0.44		0.40
# 15	0.37		0.36
# 16	0.54		0.56
# 17	0.41		0.34
# 18	0.44		0.40
# 19	0.41		0.35
# 20	0.48		0.43
# t = 15 was best iteration with accuracy 0.64
#
# -----------------------------------------------
# 28 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.47		0.38
# 2	0.58		0.53
# 3	0.53		0.50
# 4	0.65		0.69
# 5	0.46		0.41
# 6	0.61		0.63
# 7	0.53		0.50
# 8	0.69		0.75
# 9	0.52		0.52
# 10	0.73		0.74
# 11	0.51		0.50
# 12	0.76		0.74
# 13	0.59		0.57
# 14	0.71		0.73
# 15	0.53		0.47
# 16	0.77		0.76
# 17	0.62		0.59
# 18	0.74		0.77
# 19	0.55		0.54
# 20	0.75		0.73
# t = 16 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 29 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.44		0.39
# /Users/Ashtekar15/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 2	0.55		0.49
# 3	0.44		0.39
# 4	0.56		0.63
# 5	0.46		0.40
# 6	0.49		0.46
# 7	0.55		0.52
# 8	0.67		0.68
# 9	0.42		0.38
# 10	0.58		0.56
# 11	0.47		0.44
# 12	0.53		0.50
# 13	0.55		0.49
# 14	0.58		0.55
# 15	0.50		0.44
# 16	0.57		0.64
# 17	0.47		0.41
# 18	0.58		0.61
# 19	0.49		0.42
# 20	0.56		0.59
# t = 8 was best iteration with accuracy 0.68
#
# -----------------------------------------------
# 30 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.49		0.39
# 2	0.54		0.49
# 3	0.48		0.41
# 4	0.63		0.66
# 5	0.45		0.39
# 6	0.49		0.44
# 7	0.38		0.32
# 8	0.51		0.53
# 9	0.43		0.33
# 10	0.57		0.57
# 11	0.45		0.35
# 12	0.46		0.45
# 13	0.43		0.38
# 14	0.55		0.56
# 15	0.44		0.37
# 16	0.43		0.43
# 17	0.41		0.37
# 18	0.44		0.45
# 19	0.40		0.33
# 20	0.51		0.50
# t = 4 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 31 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.49		0.42
# 2	0.55		0.56
# 3	0.43		0.35
# 4	0.62		0.66
# 5	0.50		0.46
# 6	0.71		0.71
# 7	0.57		0.52
# 8	0.72		0.73
# 9	0.55		0.49
# 10	0.73		0.72
# 11	0.58		0.54
# 12	0.71		0.71
# 13	0.63		0.55
# 14	0.72		0.77
# 15	0.61		0.51
# 16	0.67		0.72
# 17	0.57		0.49
# 18	0.67		0.69
# 19	0.55		0.50
# 20	0.68		0.70
# t = 10 was best iteration with accuracy 0.72
#
# -----------------------------------------------
# 32 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.43		0.38
# 2	0.48		0.46
# 3	0.49		0.42
# 4	0.64		0.68
# 5	0.45		0.42
# 6	0.49		0.45
# 7	0.43		0.38
# 8	0.42		0.40
# 9	0.39		0.32
# 10	0.49		0.46
# 11	0.45		0.40
# 12	0.53		0.53
# 13	0.43		0.35
# 14	0.61		0.61
# 15	0.48		0.42
# 16	0.63		0.65
# 17	0.45		0.37
# 18	0.63		0.67
# 19	0.51		0.47
# 20	0.63		0.63
# t = 4 was best iteration with accuracy 0.68
#
# -----------------------------------------------
# 33 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.43		0.37
# 2	0.45		0.41
# 3	0.44		0.41
# 4	0.56		0.54
# 5	0.46		0.43
# 6	0.46		0.43
# 7	0.45		0.38
# 8	0.55		0.57
# 9	0.47		0.38
# 10	0.46		0.43
# 11	0.45		0.37
# 12	0.59		0.66
# 13	0.50		0.39
# 14	0.52		0.49
# 15	0.48		0.43
# 16	0.50		0.52
# 17	0.47		0.38
# 18	0.58		0.60
# 19	0.47		0.41
# 20	0.56		0.53
# t = 12 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 34 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.48		0.39
# 2	0.50		0.45
# /Users/Ashtekar15/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 3	0.49		0.43
# 4	0.57		0.59
# 5	0.45		0.40
# 6	0.48		0.47
# 7	0.44		0.41
# 8	0.52		0.54
# 9	0.45		0.41
# 10	0.45		0.41
# 11	0.34		0.31
# 12	0.45		0.46
# 13	0.40		0.37
# 14	0.53		0.55
# 15	0.42		0.37
# 16	0.41		0.38
# 17	0.38		0.35
# 18	0.36		0.36
# 19	0.39		0.33
# 20	0.41		0.39
# t = 11 was best iteration with accuracy 0.69
#
# -----------------------------------------------
# 35 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.48		0.41
# 2	0.57		0.52
# 3	0.55		0.45
# 4	0.63		0.68
# 5	0.48		0.44
# 6	0.64		0.67
# 7	0.45		0.35
# 8	0.55		0.58
# 9	0.57		0.52
# 10	0.71		0.74
# 11	0.54		0.52
# 12	0.75		0.77
# 13	0.65		0.60
# 14	0.74		0.77
# 15	0.56		0.53
# 16	0.69		0.73
# 17	0.59		0.54
# 18	0.76		0.79
# 19	0.59		0.55
# 20	0.73		0.71
# t = 18 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 36 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.46		0.38
# 2	0.49		0.44
# 3	0.49		0.46
# 4	0.43		0.36
# 5	0.52		0.53
# 6	0.45		0.41
# 7	0.44		0.36
# 8	0.45		0.41
# 9	0.43		0.40
# 10	0.42		0.39
# 11	0.58		0.60
# 12	0.48		0.40
# 13	0.54		0.54
# 14	0.42		0.33
# 15	0.47		0.44
# 16	0.41		0.36
# 17	0.55		0.56
# 18	0.41		0.38
# 19	0.43		0.38
# 20	0.41		0.38
# t = 16 was best iteration with accuracy 0.64
#
# -----------------------------------------------
# 37 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.47		0.42
# 2	0.49		0.47
# 3	0.47		0.41
# 4	0.63		0.65
# 5	0.46		0.46
# 6	0.53		0.50
# 7	0.51		0.48
# 8	0.64		0.66
# 9	0.49		0.45
# 10	0.51		0.46
# 11	0.51		0.47
# 12	0.62		0.59
# 13	0.47		0.47
# /Users/Ashtekar15/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 14	0.59		0.60
# 15	0.51		0.46
# 16	0.62		0.61
# 17	0.49		0.40
# 18	0.60		0.61
# 19	0.51		0.44
# 20	0.57		0.60
# t = 8 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 38 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.47		0.38
# 2	0.54		0.50
# 3	0.46		0.46
# 4	0.57		0.55
# 5	0.44		0.40
# 6	0.47		0.42
# 7	0.45		0.38
# 8	0.46		0.42
# 9	0.42		0.41
# 10	0.55		0.57
# 11	0.43		0.40
# 12	0.62		0.58
# 13	0.49		0.46
# 14	0.56		0.52
# 15	0.47		0.42
# 16	0.58		0.65
# 17	0.52		0.50
# 18	0.58		0.59
# 19	0.45		0.40
# 20	0.42		0.40
# t = 12 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 39 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.47		0.37
# 2	0.50		0.47
# 3	0.55		0.50
# 4	0.61		0.62
# 5	0.50		0.45
# 6	0.61		0.64
# 7	0.54		0.47
# 8	0.58		0.55
# 9	0.47		0.42
# 10	0.61		0.65
# 11	0.46		0.40
# 12	0.53		0.52
# 13	0.50		0.43
# 14	0.53		0.50
# 15	0.51		0.46
# 16	0.57		0.56
# 17	0.47		0.42
# 18	0.52		0.48
# 19	0.48		0.42
# 20	0.49		0.43
# t = 10 was best iteration with accuracy 0.65
#
# -----------------------------------------------
# 40 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.46		0.39
# 2	0.51		0.47
# 3	0.45		0.40
# 4	0.56		0.60
# 5	0.45		0.40
# 6	0.47		0.45
# 7	0.49		0.42
# 8	0.63		0.66
# 9	0.47		0.42
# 10	0.60		0.59
# 11	0.48		0.42
# 12	0.65		0.66
# 13	0.47		0.38
# 14	0.64		0.67
# 15	0.52		0.45
# 16	0.62		0.65
# 17	0.54		0.50
# 18	0.68		0.69
# 19	0.55		0.50
# 20	0.66		0.70
# t = 18 was best iteration with accuracy 0.69
#
# -----------------------------------------------
# 41 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.45		0.39
# 2	0.51		0.43
# 3	0.49		0.46
# 4	0.61		0.66
# 5	0.48		0.43
# 6	0.58		0.55
# 7	0.77		0.77
# 8	0.59		0.54
# 9	0.72		0.73
# 10	0.56		0.55
# 11	0.71		0.74
# 12	0.52		0.48
# 13	0.67		0.72
# 14	0.58		0.52
# 15	0.67		0.71
# 16	0.59		0.52
# 17	0.61		0.68
# 18	0.51		0.44
# 19	0.62		0.57
# 20	0.61		0.57
# t = 7 was best iteration with accuracy 0.77
#
# -----------------------------------------------
# 42 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.45		0.39
# 2	0.55		0.50
# 3	0.54		0.49
# 4	0.61		0.64
# 5	0.44		0.37
# 6	0.51		0.44
# 7	0.43		0.36
# 8	0.57		0.58
# 9	0.43		0.41
# 10	0.59		0.61
# 11	0.49		0.42
# 12	0.61		0.66
# 13	0.42		0.36
# 14	0.52		0.48
# 15	0.47		0.40
# 16	0.59		0.61
# 17	0.46		0.41
# 18	0.54		0.50
# 19	0.49		0.43
# 20	0.62		0.62
# t = 20 was best iteration with accuracy 0.62
#
# -----------------------------------------------
# 43 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.47		0.40
# 2	0.50		0.48
# 3	0.39		0.37
# 4	0.53		0.52
# 5	0.42		0.42
# 6	0.47		0.45
# 7	0.42		0.36
# 8	0.51		0.52
# 9	0.42		0.37
# 10	0.39		0.38
# 11	0.39		0.31
# 12	0.33		0.34
# 13	0.39		0.31
# 14	0.42		0.42
# 15	0.38		0.28
# 16	0.55		0.54
# 17	0.41		0.32
# 18	0.41		0.38
# 19	0.40		0.34
# 20	0.33		0.31
# t = 20 was best iteration with accuracy 0.69
#
# -----------------------------------------------
# 44 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.46		0.39
# 2	0.49		0.45
# 3	0.43		0.37
# 4	0.56		0.61
# 5	0.43		0.37
# 6	0.45		0.45
# 7	0.48		0.42
# 8	0.55		0.56
# 9	0.44		0.35
# 10	0.46		0.43
# 11	0.42		0.37
# 12	0.49		0.41
# 13	0.46		0.39
# 14	0.55		0.58
# 15	0.46		0.41
# 16	0.49		0.43
# 17	0.45		0.38
# 18	0.46		0.43
# 19	0.44		0.38
# 20	0.57		0.57
# t = 11 was best iteration with accuracy 0.63
#
# -----------------------------------------------
# 45 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.45		0.38
# 2	0.44		0.44
# 3	0.41		0.33
# 4	0.57		0.62
# 5	0.43		0.38
# 6	0.50		0.51
# 7	0.43		0.37
# /Users/Ashtekar15/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 8	0.50		0.46
# 9	0.42		0.35
# 10	0.48		0.43
# 11	0.41		0.34
# 12	0.43		0.40
# 13	0.36		0.30
# 14	0.51		0.53
# 15	0.35		0.35
# 16	0.34		0.32
# 17	0.33		0.28
# 18	0.29		0.24
# 19	0.29		0.27
# 20	0.46		0.47
# t = 19 was best iteration with accuracy 0.73
#
# -----------------------------------------------
# 46 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.47		0.39
# 2	0.51		0.44
# /Users/Ashtekar15/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 3	0.52		0.50
# 4	0.47		0.40
# 5	0.45		0.41
# 6	0.49		0.45
# 7	0.37		0.34
# 8	0.59		0.59
# 9	0.44		0.38
# 10	0.55		0.55
# 11	0.44		0.39
# 12	0.60		0.56
# 13	0.42		0.38
# 14	0.46		0.43
# 15	0.44		0.37
# 16	0.57		0.58
# 17	0.45		0.38
# 18	0.51		0.51
# 19	0.45		0.38
# 20	0.61		0.64
# t = 7 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 47 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.49		0.41
# 2	0.72		0.71
# 3	0.51		0.46
# 4	0.66		0.65
# 5	0.51		0.47
# 6	0.59		0.57
# 7	0.65		0.62
# 8	0.75		0.78
# 9	0.50		0.52
# 10	0.48		0.43
# 11	0.40		0.39
# 12	0.41		0.37
# 13	0.41		0.33
# 14	0.46		0.40
# 15	0.44		0.40
# 16	0.48		0.47
# 17	0.44		0.40
# 18	0.48		0.51
# 19	0.38		0.35
# 20	0.39		0.33
# t = 8 was best iteration with accuracy 0.78
#
# -----------------------------------------------
# 48 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.45		0.39
# 2	0.47		0.42
# 3	0.42		0.35
# 4	0.58		0.63
# 5	0.45		0.37
# 6	0.47		0.42
# 7	0.36		0.34
# 8	0.52		0.53
# 9	0.38		0.33
# 10	0.42		0.38
# 11	0.37		0.34
# 12	0.45		0.41
# 13	0.41		0.34
# 14	0.47		0.42
# 15	0.37		0.31
# 16	0.48		0.49
# 17	0.36		0.30
# 18	0.39		0.32
# 19	0.37		0.32
# 20	0.32		0.30
# t = 20 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 49 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.45		0.39
# 2	0.49		0.45
# 3	0.43		0.37
# 4	0.60		0.59
# 5	0.44		0.35
# 6	0.60		0.59
# 7	0.45		0.42
# 8	0.60		0.56
# 9	0.46		0.40
# 10	0.57		0.60
# 11	0.46		0.38
# 12	0.52		0.52
# 13	0.50		0.43
# 14	0.59		0.59
# 15	0.48		0.40
# 16	0.64		0.64
# 17	0.49		0.41
# 18	0.63		0.64
# 19	0.49		0.44
# 20	0.67		0.70
# t = 20 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 50 / 100 complete
# -----------------------------------------------
#
# Cut at 21 rather than expected 200
# Training accuracy of rank SVM: 1.00
# /Users/Ashtekar15/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.47		0.40
# 2	0.52		0.40
# 3	0.52		0.50
# 4	0.55		0.52
# 5	0.48		0.43
# 6	0.62		0.59
# 7	0.54		0.47
# 8	0.57		0.56
# 9	0.55		0.47
# 10	0.59		0.54
# 11	0.58		0.52
# 12	0.69		0.67
# 13	0.48		0.44
# 14	0.54		0.46
# 15	0.53		0.49
# 16	0.61		0.54
# 17	0.54		0.50
# 18	0.68		0.67
# 19	0.54		0.51
# 20	0.70		0.65
# t = 20 was best iteration with accuracy 0.65
#
# -----------------------------------------------
# 51 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.46		0.38
# 2	0.48		0.44
# 3	0.50		0.42
# 4	0.49		0.43
# 5	0.58		0.59
# 6	0.49		0.45
# 7	0.49		0.41
# 8	0.51		0.45
# 9	0.53		0.42
# 10	0.56		0.51
# 11	0.47		0.41
# 12	0.52		0.52
# 13	0.48		0.39
# 14	0.51		0.46
# 15	0.46		0.39
# 16	0.47		0.47
# 17	0.46		0.38
# 18	0.54		0.58
# 19	0.47		0.40
# 20	0.49		0.43
# t = 5 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 52 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.43		0.37
# 2	0.43		0.38
# 3	0.43		0.38
# 4	0.43		0.39
# 5	0.47		0.37
# 6	0.37		0.34
# 7	0.39		0.35
# 8	0.34		0.29
# 9	0.35		0.30
# 10	0.32		0.27
# 11	0.37		0.29
# 12	0.49		0.50
# 13	0.39		0.36
# 14	0.42		0.34
# 15	0.37		0.34
# 16	0.39		0.33
# 17	0.36		0.31
# 18	0.43		0.35
# 19	0.51		0.50
# 20	0.42		0.32
# t = 10 was best iteration with accuracy 0.73
#
# -----------------------------------------------
# 53 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.44		0.39
# 2	0.45		0.42
# 3	0.43		0.39
# 4	0.51		0.48
# 5	0.45		0.38
# 6	0.54		0.49
# 7	0.54		0.47
# 8	0.54		0.47
# 9	0.64		0.66
# 10	0.51		0.50
# 11	0.69		0.70
# 12	0.52		0.50
# 13	0.61		0.57
# 14	0.58		0.53
# 15	0.64		0.67
# 16	0.49		0.45
# 17	0.67		0.67
# 18	0.54		0.50
# 19	0.71		0.69
# 20	0.53		0.44
# t = 19 was best iteration with accuracy 0.69
#
# -----------------------------------------------
# 54 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.45		0.38
# 2	0.45		0.40
# 3	0.47		0.40
# 4	0.46		0.41
# 5	0.55		0.58
# 6	0.44		0.41
# 7	0.45		0.40
# 8	0.40		0.36
# 9	0.39		0.33
# 10	0.38		0.36
# 11	0.41		0.42
# 12	0.44		0.37
# 13	0.45		0.41
# 14	0.42		0.36
# 15	0.45		0.44
# 16	0.44		0.37
# 17	0.45		0.40
# 18	0.40		0.35
# 19	0.42		0.38
# 20	0.42		0.36
# t = 10 was best iteration with accuracy 0.64
#
# -----------------------------------------------
# 55 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.45		0.40
# 2	0.44		0.40
# 3	0.44		0.40
# 4	0.45		0.44
# 5	0.44		0.38
# 6	0.51		0.48
# 7	0.49		0.43
# 8	0.52		0.46
# 9	0.51		0.43
# 10	0.65		0.64
# 11	0.49		0.43
# 12	0.56		0.53
# 13	0.50		0.44
# 14	0.64		0.66
# 15	0.47		0.40
# 16	0.59		0.59
# 17	0.47		0.42
# 18	0.42		0.39
# 19	0.47		0.41
# 20	0.51		0.48
# t = 10 was best iteration with accuracy 0.64
#
# -----------------------------------------------
# 56 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.45		0.38
# 2	0.46		0.39
# 3	0.49		0.42
# 4	0.53		0.48
# 5	0.58		0.60
# 6	0.49		0.42
# 7	0.48		0.45
# 8	0.42		0.33
# 9	0.43		0.40
# 10	0.41		0.36
# 11	0.45		0.43
# 12	0.45		0.38
# 13	0.47		0.40
# 14	0.44		0.38
# 15	0.48		0.44
# 16	0.46		0.36
# 17	0.58		0.60
# 18	0.45		0.38
# 19	0.49		0.43
# 20	0.49		0.43
# t = 10 was best iteration with accuracy 0.64
#
# -----------------------------------------------
# 57 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.43		0.36
# 2	0.45		0.38
# 3	0.37		0.40
# 4	0.43		0.35
# 5	0.43		0.39
# 6	0.43		0.39
# 7	0.35		0.34
# 8	0.40		0.33
# 9	0.43		0.40
# 10	0.43		0.36
# 11	0.39		0.35
# 12	0.39		0.36
# 13	0.39		0.35
# 14	0.36		0.32
# 15	0.39		0.39
# 16	0.44		0.35
# 17	0.39		0.35
# 18	0.39		0.31
# 19	0.36		0.30
# 20	0.33		0.32
# t = 20 was best iteration with accuracy 0.68
#
# -----------------------------------------------
# 58 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.45		0.40
# 2	0.48		0.41
# 3	0.48		0.43
# 4	0.50		0.39
# 5	0.43		0.38
# 6	0.42		0.35
# 7	0.41		0.38
# 8	0.44		0.37
# 9	0.40		0.38
# 10	0.42		0.34
# 11	0.48		0.42
# 12	0.40		0.36
# 13	0.52		0.53
# 14	0.39		0.34
# 15	0.36		0.34
# 16	0.38		0.35
# 17	0.37		0.31
# 18	0.38		0.32
# 19	0.30		0.30
# 20	0.37		0.27
# t = 19 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 59 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.44		0.38
# 2	0.45		0.39
# 3	0.45		0.39
# 4	0.45		0.40
# 5	0.49		0.44
# 6	0.47		0.39
# 7	0.46		0.39
# 8	0.46		0.42
# 9	0.49		0.43
# 10	0.47		0.42
# 11	0.59		0.59
# 12	0.48		0.45
# 13	0.51		0.45
# 14	0.53		0.44
# 15	0.57		0.51
# 16	0.58		0.52
# 17	0.64		0.67
# 18	0.55		0.49
# 19	0.65		0.65
# 20	0.50		0.47
# t = 19 was best iteration with accuracy 0.65
#
# -----------------------------------------------
# 60 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.44		0.38
# 2	0.45		0.40
# 3	0.44		0.37
# 4	0.47		0.44
# 5	0.44		0.41
# 6	0.50		0.46
# 7	0.47		0.43
# 8	0.51		0.44
# 9	0.48		0.42
# 10	0.56		0.50
# 11	0.46		0.42
# 12	0.62		0.58
# 13	0.47		0.44
# 14	0.49		0.44
# 15	0.48		0.45
# 16	0.48		0.45
# 17	0.46		0.41
# 18	0.59		0.54
# 19	0.47		0.45
# 20	0.51		0.44
# t = 12 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 61 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.45		0.39
# 2	0.46		0.37
# 3	0.46		0.39
# 4	0.48		0.41
# 5	0.47		0.44
# 6	0.61		0.60
# 7	0.56		0.52
# 8	0.61		0.57
# 9	0.61		0.56
# 10	0.74		0.73
# 11	0.55		0.48
# 12	0.62		0.66
# 13	0.50		0.45
# 14	0.67		0.69
# 15	0.54		0.47
# 16	0.71		0.70
# 17	0.53		0.48
# 18	0.64		0.68
# 19	0.53		0.47
# 20	0.68		0.68
# t = 10 was best iteration with accuracy 0.73
#
# -----------------------------------------------
# 62 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.44		0.37
# 2	0.44		0.36
# 3	0.41		0.39
# 4	0.54		0.52
# 5	0.42		0.39
# 6	0.45		0.43
# 7	0.45		0.40
# 8	0.46		0.40
# 9	0.46		0.40
# 10	0.49		0.45
# 11	0.44		0.41
# 12	0.43		0.40
# 13	0.41		0.39
# 14	0.54		0.50
# 15	0.44		0.37
# 16	0.43		0.40
# 17	0.40		0.38
# 18	0.40		0.33
# 19	0.41		0.37
# 20	0.44		0.37
# t = 18 was best iteration with accuracy 0.67
#
# -----------------------------------------------
# 63 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.42		0.38
# 2	0.45		0.40
# 3	0.45		0.37
# 4	0.49		0.42
# 5	0.49		0.46
# 6	0.48		0.41
# 7	0.48		0.44
# 8	0.46		0.41
# 9	0.48		0.48
# 10	0.47		0.42
# 11	0.61		0.61
# 12	0.53		0.46
# 13	0.65		0.65
# 14	0.50		0.43
# 15	0.50		0.45
# 16	0.48		0.44
# 17	0.49		0.43
# 18	0.50		0.43
# 19	0.61		0.57
# 20	0.47		0.43
# t = 13 was best iteration with accuracy 0.65
#
# -----------------------------------------------
# 64 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.44		0.38
# 2	0.45		0.40
# 3	0.47		0.44
# 4	0.40		0.36
# 5	0.41		0.37
# 6	0.38		0.35
# 7	0.42		0.38
# 8	0.42		0.37
# 9	0.55		0.57
# 10	0.46		0.39
# 11	0.45		0.40
# 12	0.44		0.39
# 13	0.42		0.39
# 14	0.45		0.39
# 15	0.60		0.58
# 16	0.53		0.45
# 17	0.55		0.49
# 18	0.61		0.53
# 19	0.68		0.66
# 20	0.55		0.47
# t = 19 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 65 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.44		0.35
# 2	0.45		0.39
# 3	0.45		0.41
# 4	0.49		0.42
# 5	0.44		0.40
# 6	0.49		0.48
# 7	0.44		0.38
# 8	0.44		0.37
# 9	0.45		0.42
# 10	0.48		0.42
# 11	0.45		0.40
# 12	0.52		0.48
# 13	0.48		0.43
# 14	0.49		0.44
# 15	0.51		0.42
# 16	0.52		0.45
# 17	0.57		0.52
# 18	0.53		0.49
# 19	0.65		0.63
# 20	0.45		0.40
# t = 19 was best iteration with accuracy 0.63
#
# -----------------------------------------------
# 66 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.45		0.38
# 2	0.48		0.41
# 3	0.50		0.44
# 4	0.51		0.46
# 5	0.52		0.45
# 6	0.57		0.59
# 7	0.50		0.44
# 8	0.50		0.44
# 9	0.45		0.40
# 10	0.51		0.47
# 11	0.48		0.41
# 12	0.51		0.44
# 13	0.50		0.42
# 14	0.55		0.52
# 15	0.49		0.41
# 16	0.54		0.55
# 17	0.47		0.36
# 18	0.61		0.65
# 19	0.44		0.35
# 20	0.44		0.44
# t = 18 was best iteration with accuracy 0.65
#
# -----------------------------------------------
# 67 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.43		0.37
# 2	0.46		0.40
# 3	0.38		0.34
# 4	0.57		0.58
# 5	0.43		0.36
# 6	0.43		0.39
# 7	0.42		0.36
# 8	0.41		0.35
# 9	0.40		0.30
# 10	0.38		0.32
# 11	0.42		0.33
# 12	0.45		0.37
# 13	0.44		0.37
# 14	0.44		0.39
# 15	0.43		0.37
# 16	0.45		0.41
# 17	0.44		0.38
# 18	0.43		0.40
# 19	0.47		0.43
# 20	0.45		0.39
# t = 3 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 68 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.46		0.38
# 2	0.45		0.39
# 3	0.47		0.41
# 4	0.43		0.41
# 5	0.45		0.42
# 6	0.44		0.38
# 7	0.44		0.40
# 8	0.42		0.37
# 9	0.46		0.42
# 10	0.44		0.38
# 11	0.45		0.41
# 12	0.45		0.39
# 13	0.48		0.41
# 14	0.45		0.39
# 15	0.48		0.43
# 16	0.47		0.39
# 17	0.42		0.40
# 18	0.44		0.38
# 19	0.44		0.39
# 20	0.42		0.37
# t = 17 was best iteration with accuracy 0.60
#
# -----------------------------------------------
# 69 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.49		0.40
# 2	0.49		0.44
# 3	0.54		0.50
# 4	0.56		0.50
# 5	0.68		0.69
# 6	0.49		0.45
# 7	0.57		0.49
# 8	0.53		0.48
# 9	0.69		0.67
# 10	0.53		0.46
# 11	0.65		0.65
# 12	0.50		0.45
# 13	0.60		0.61
# 14	0.46		0.42
# 15	0.52		0.46
# 16	0.47		0.41
# 17	0.53		0.50
# 18	0.43		0.38
# 19	0.45		0.39
# 20	0.43		0.39
# t = 9 was best iteration with accuracy 0.67
#
# -----------------------------------------------
# 70 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.43		0.37
# 2	0.44		0.38
# 3	0.44		0.41
# 4	0.48		0.43
# 5	0.60		0.60
# 6	0.42		0.37
# 7	0.42		0.42
# 8	0.41		0.33
# 9	0.40		0.36
# 10	0.38		0.33
# 11	0.43		0.41
# 12	0.41		0.32
# 13	0.38		0.37
# /Users/Ashtekar15/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 14	0.36		0.33
# 15	0.39		0.35
# 16	0.37		0.33
# 17	0.36		0.31
# 18	0.37		0.33
# 19	0.35		0.32
# 20	0.34		0.33
# t = 20 was best iteration with accuracy 0.67
#
# -----------------------------------------------
# 71 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.45		0.38
# 2	0.47		0.40
# 3	0.47		0.42
# 4	0.56		0.55
# 5	0.43		0.40
# 6	0.42		0.40
# 7	0.45		0.39
# 8	0.45		0.40
# 9	0.42		0.36
# 10	0.42		0.37
# 11	0.59		0.56
# 12	0.45		0.38
# 13	0.45		0.42
# 14	0.42		0.36
# 15	0.53		0.54
# 16	0.43		0.38
# 17	0.44		0.42
# 18	0.39		0.32
# 19	0.35		0.31
# 20	0.36		0.29
# t = 19 was best iteration with accuracy 0.69
#
# -----------------------------------------------
# 72 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.42		0.36
# 2	0.44		0.38
# 3	0.45		0.38
# 4	0.41		0.34
# 5	0.41		0.38
# 6	0.42		0.33
# 7	0.42		0.37
# 8	0.41		0.36
# 9	0.35		0.33
# 10	0.40		0.37
# 11	0.50		0.47
# 12	0.41		0.37
# 13	0.43		0.38
# /Users/Ashtekar15/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 14	0.45		0.38
# 15	0.41		0.40
# 16	0.41		0.33
# 17	0.54		0.54
# 18	0.42		0.34
# 19	0.43		0.37
# 20	0.38		0.34
# t = 9 was best iteration with accuracy 0.67
#
# -----------------------------------------------
# 73 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.45		0.39
# 2	0.45		0.39
# 3	0.47		0.41
# 4	0.47		0.42
# 5	0.47		0.50
# 6	0.47		0.39
# 7	0.51		0.49
# 8	0.48		0.42
# 9	0.52		0.49
# 10	0.45		0.40
# 11	0.49		0.49
# 12	0.45		0.38
# 13	0.47		0.48
# 14	0.42		0.35
# 15	0.42		0.42
# 16	0.40		0.33
# 17	0.45		0.46
# 18	0.40		0.33
# 19	0.41		0.41
# 20	0.36		0.34
# t = 20 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 74 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.45		0.38
# 2	0.48		0.38
# 3	0.54		0.50
# 4	0.49		0.44
# 5	0.57		0.55
# 6	0.47		0.39
# 7	0.52		0.47
# 8	0.50		0.45
# 9	0.60		0.61
# 10	0.49		0.41
# 11	0.49		0.49
# 12	0.54		0.46
# 13	0.58		0.58
# 14	0.50		0.42
# 15	0.48		0.46
# 16	0.46		0.41
# 17	0.46		0.43
# 18	0.48		0.43
# 19	0.51		0.48
# 20	0.51		0.44
# t = 9 was best iteration with accuracy 0.61
#
# -----------------------------------------------
# 75 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.46		0.38
# 2	0.48		0.38
# 3	0.52		0.52
# 4	0.48		0.41
# 5	0.54		0.52
# 6	0.50		0.43
# 7	0.54		0.50
# 8	0.51		0.47
# 9	0.59		0.60
# 10	0.49		0.42
# 11	0.49		0.46
# 12	0.45		0.37
# 13	0.46		0.43
# 14	0.42		0.37
# 15	0.38		0.36
# 16	0.43		0.36
# 17	0.40		0.40
# 18	0.39		0.35
# 19	0.41		0.39
# 20	0.43		0.37
# t = 15 was best iteration with accuracy 0.64
#
# -----------------------------------------------
# 76 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.45		0.39
# 2	0.48		0.43
# 3	0.52		0.46
# 4	0.47		0.45
# 5	0.56		0.56
# 6	0.49		0.44
# 7	0.51		0.47
# 8	0.50		0.43
# /Users/Ashtekar15/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 9	0.52		0.46
# 10	0.48		0.43
# 11	0.58		0.61
# 12	0.50		0.44
# 13	0.57		0.59
# 14	0.47		0.41
# 15	0.47		0.45
# 16	0.45		0.37
# 17	0.49		0.43
# 18	0.48		0.38
# 19	0.59		0.62
# 20	0.48		0.40
# t = 19 was best iteration with accuracy 0.62
#
# -----------------------------------------------
# 77 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.44		0.38
# 2	0.45		0.38
# 3	0.50		0.44
# 4	0.66		0.68
# 5	0.45		0.40
# 6	0.58		0.56
# 7	0.59		0.52
# 8	0.63		0.59
# 9	0.70		0.62
# 10	0.85		0.86
# 11	0.55		0.49
# 12	0.75		0.76
# 13	0.63		0.56
# 14	0.80		0.81
# 15	0.61		0.53
# 16	0.74		0.78
# 17	0.59		0.53
# 18	0.74		0.76
# 19	0.55		0.49
# 20	0.75		0.75
# t = 10 was best iteration with accuracy 0.86
#
# -----------------------------------------------
# 78 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.45		0.38
# 2	0.47		0.40
# 3	0.48		0.43
# 4	0.52		0.45
# 5	0.56		0.59
# 6	0.48		0.39
# 7	0.52		0.48
# 8	0.53		0.46
# 9	0.57		0.53
# 10	0.60		0.55
# 11	0.58		0.60
# 12	0.47		0.40
# 13	0.48		0.41
# 14	0.51		0.43
# 15	0.52		0.45
# 16	0.47		0.40
# 17	0.56		0.56
# 18	0.45		0.38
# 19	0.40		0.34
# 20	0.39		0.35
# t = 20 was best iteration with accuracy 0.65
#
# -----------------------------------------------
# 79 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.44		0.38
# 2	0.46		0.38
# 3	0.46		0.39
# 4	0.39		0.37
# 5	0.44		0.35
# 6	0.39		0.34
# 7	0.37		0.34
# 8	0.34		0.29
# 9	0.42		0.35
# 10	0.41		0.39
# 11	0.40		0.34
# 12	0.40		0.36
# 13	0.40		0.37
# 14	0.43		0.40
# 15	0.57		0.55
# 16	0.43		0.39
# 17	0.43		0.38
# 18	0.42		0.37
# 19	0.43		0.40
# 20	0.44		0.35
# t = 8 was best iteration with accuracy 0.71
#
# -----------------------------------------------
# 80 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.44		0.39
# 2	0.49		0.42
# 3	0.51		0.46
# 4	0.69		0.70
# 5	0.50		0.44
# 6	0.55		0.51
# 7	0.54		0.46
# 8	0.58		0.53
# 9	0.50		0.48
# 10	0.66		0.68
# 11	0.56		0.53
# 12	0.70		0.71
# 13	0.57		0.51
# 14	0.75		0.75
# 15	0.55		0.48
# 16	0.75		0.75
# 17	0.63		0.56
# 18	0.80		0.78
# 19	0.57		0.52
# 20	0.77		0.76
# t = 18 was best iteration with accuracy 0.78
#
# -----------------------------------------------
# 81 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.45		0.39
# 2	0.47		0.41
# 3	0.48		0.40
# 4	0.50		0.44
# 5	0.53		0.47
# 6	0.54		0.46
# 7	0.56		0.58
# 8	0.49		0.43
# 9	0.54		0.52
# 10	0.54		0.47
# 11	0.58		0.65
# 12	0.48		0.41
# 13	0.55		0.48
# 14	0.55		0.49
# 15	0.68		0.67
# 16	0.41		0.38
# 17	0.57		0.50
# 18	0.55		0.47
# 19	0.62		0.57
# 20	0.56		0.47
# t = 15 was best iteration with accuracy 0.67
#
# -----------------------------------------------
# 82 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.46		0.39
# 2	0.47		0.41
# 3	0.50		0.43
# 4	0.59		0.57
# 5	0.48		0.50
# 6	0.52		0.46
# 7	0.55		0.49
# 8	0.50		0.42
# 9	0.58		0.55
# 10	0.59		0.51
# 11	0.64		0.59
# 12	0.58		0.54
# 13	0.68		0.67
# 14	0.50		0.46
# 15	0.53		0.51
# 16	0.53		0.46
# 17	0.59		0.52
# 18	0.54		0.48
# 19	0.68		0.68
# 20	0.52		0.45
# t = 13 was best iteration with accuracy 0.67
#
# -----------------------------------------------
# 83 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.46		0.37
# 2	0.47		0.40
# 3	0.48		0.43
# 4	0.59		0.59
# 5	0.45		0.41
# 6	0.50		0.42
# 7	0.47		0.39
# 8	0.47		0.42
# 9	0.43		0.38
# 10	0.45		0.41
# 11	0.43		0.40
# 12	0.49		0.46
# 13	0.43		0.39
# 14	0.50		0.46
# 15	0.46		0.42
# 16	0.49		0.45
# 17	0.45		0.40
# 18	0.45		0.40
# 19	0.46		0.42
# 20	0.50		0.46
# t = 4 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 84 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.46		0.38
# 2	0.48		0.42
# 3	0.50		0.44
# 4	0.51		0.45
# 5	0.58		0.55
# 6	0.47		0.42
# 7	0.50		0.46
# 8	0.45		0.40
# 9	0.50		0.43
# /Users/Ashtekar15/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 10	0.51		0.46
# 11	0.48		0.38
# 12	0.50		0.48
# 13	0.50		0.39
# 14	0.47		0.41
# 15	0.54		0.45
# 16	0.54		0.50
# 17	0.47		0.47
# 18	0.58		0.59
# 19	0.56		0.52
# 20	0.70		0.67
# t = 20 was best iteration with accuracy 0.67
#
# -----------------------------------------------
# 85 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.46		0.39
# 2	0.46		0.39
# 3	0.45		0.41
# 4	0.52		0.46
# 5	0.45		0.44
# 6	0.48		0.44
# 7	0.50		0.44
# 8	0.54		0.45
# 9	0.57		0.50
# 10	0.59		0.53
# 11	0.57		0.47
# 12	0.64		0.61
# 13	0.53		0.48
# 14	0.61		0.65
# 15	0.48		0.43
# 16	0.52		0.47
# 17	0.55		0.46
# 18	0.56		0.48
# 19	0.59		0.52
# 20	0.62		0.57
# t = 12 was best iteration with accuracy 0.61
#
# -----------------------------------------------
# 86 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.48		0.40
# 2	0.48		0.41
# 3	0.50		0.42
# 4	0.54		0.45
# 5	0.56		0.48
# 6	0.44		0.42
# 7	0.61		0.60
# 8	0.46		0.43
# 9	0.54		0.46
# 10	0.46		0.44
# 11	0.47		0.45
# 12	0.45		0.41
# 13	0.52		0.47
# 14	0.46		0.42
# 15	0.48		0.42
# 16	0.43		0.35
# 17	0.57		0.56
# 18	0.45		0.38
# 19	0.45		0.39
# 20	0.42		0.38
# t = 7 was best iteration with accuracy 0.60
#
# -----------------------------------------------
# 87 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.42		0.37
# 2	0.43		0.37
# 3	0.42		0.37
# 4	0.43		0.38
# 5	0.42		0.36
# 6	0.42		0.34
# 7	0.44		0.39
# 8	0.42		0.37
# 9	0.45		0.36
# 10	0.43		0.38
# 11	0.45		0.38
# 12	0.44		0.37
# 13	0.43		0.39
# 14	0.44		0.40
# 15	0.52		0.52
# 16	0.42		0.39
# 17	0.49		0.46
# 18	0.41		0.38
# 19	0.45		0.40
# 20	0.42		0.37
# t = 18 was best iteration with accuracy 0.62
#
# -----------------------------------------------
# 88 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.45		0.37
# 2	0.45		0.39
# 3	0.48		0.41
# /Users/Ashtekar15/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 4	0.50		0.45
# 5	0.51		0.43
# 6	0.63		0.62
# 7	0.53		0.45
# 8	0.57		0.54
# 9	0.57		0.46
# 10	0.60		0.57
# 11	0.61		0.51
# 12	0.76		0.77
# 13	0.50		0.45
# 14	0.59		0.54
# 15	0.67		0.61
# 16	0.69		0.69
# 17	0.54		0.51
# 18	0.70		0.68
# 19	0.60		0.57
# 20	0.71		0.68
# t = 12 was best iteration with accuracy 0.77
#
# -----------------------------------------------
# 89 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.42		0.36
# 2	0.43		0.37
# 3	0.39		0.36
# 4	0.43		0.41
# 5	0.42		0.37
# 6	0.52		0.48
# 7	0.43		0.38
# 8	0.48		0.41
# 9	0.43		0.35
# 10	0.48		0.43
# 11	0.47		0.40
# 12	0.54		0.51
# 13	0.47		0.43
# 14	0.49		0.49
# 15	0.50		0.45
# 16	0.53		0.50
# /Users/Ashtekar15/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 17	0.51		0.45
# 18	0.54		0.46
# 19	0.56		0.46
# 20	0.57		0.48
# t = 3 was best iteration with accuracy 0.64
#
# -----------------------------------------------
# 90 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.43		0.38
# 2	0.44		0.38
# 3	0.47		0.40
# 4	0.53		0.46
# 5	0.50		0.47
# 6	0.60		0.57
# 7	0.47		0.47
# 8	0.57		0.49
# 9	0.48		0.47
# 10	0.64		0.62
# 11	0.55		0.50
# 12	0.63		0.64
# 13	0.52		0.49
# 14	0.70		0.67
# 15	0.54		0.48
# 16	0.65		0.64
# 17	0.48		0.46
# 18	0.68		0.70
# 19	0.55		0.50
# 20	0.63		0.55
# t = 14 was best iteration with accuracy 0.67
#
# -----------------------------------------------
# 91 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.45		0.38
# 2	0.49		0.42
# 3	0.54		0.47
# 4	0.59		0.53
# 5	0.49		0.48
# 6	0.55		0.52
# 7	0.52		0.46
# 8	0.56		0.48
# 9	0.51		0.48
# 10	0.62		0.59
# 11	0.45		0.44
# 12	0.52		0.51
# 13	0.49		0.45
# 14	0.61		0.59
# 15	0.46		0.42
# 16	0.51		0.44
# 17	0.50		0.41
# 18	0.51		0.43
# 19	0.46		0.41
# 20	0.54		0.49
# t = 10 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 92 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.46		0.39
# 2	0.46		0.38
# 3	0.48		0.41
# 4	0.45		0.36
# 5	0.48		0.45
# 6	0.46		0.37
# 7	0.52		0.45
# 8	0.46		0.40
# 9	0.48		0.41
# 10	0.46		0.40
# 11	0.52		0.49
# 12	0.45		0.42
# 13	0.59		0.55
# 14	0.48		0.42
# 15	0.54		0.47
# 16	0.45		0.43
# 17	0.52		0.49
# 18	0.45		0.38
# 19	0.47		0.42
# 20	0.43		0.40
# t = 13 was best iteration with accuracy 0.55
#
# -----------------------------------------------
# 93 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.44		0.39
# 2	0.45		0.39
# 3	0.46		0.42
# 4	0.51		0.45
# 5	0.46		0.41
# 6	0.56		0.59
# 7	0.44		0.41
# 8	0.47		0.44
# 9	0.45		0.38
# 10	0.59		0.59
# 11	0.48		0.39
# 12	0.48		0.44
# 13	0.47		0.42
# 14	0.55		0.50
# 15	0.52		0.47
# 16	0.64		0.61
# 17	0.53		0.44
# 18	0.57		0.53
# 19	0.51		0.45
# 20	0.63		0.62
# t = 16 was best iteration with accuracy 0.61
#
# -----------------------------------------------
# 94 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.44		0.37
# 2	0.45		0.40
# 3	0.44		0.36
# 4	0.44		0.37
# 5	0.40		0.37
# 6	0.47		0.43
# 7	0.60		0.59
# 8	0.49		0.46
# 9	0.55		0.49
# 10	0.52		0.48
# 11	0.60		0.54
# 12	0.52		0.50
# 13	0.59		0.55
# 14	0.52		0.46
# 15	0.68		0.65
# 16	0.49		0.45
# 17	0.67		0.67
# 18	0.51		0.46
# 19	0.57		0.54
# 20	0.53		0.45
# t = 15 was best iteration with accuracy 0.65
#
# -----------------------------------------------
# 95 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.45		0.38
# 2	0.44		0.38
# 3	0.46		0.40
# 4	0.48		0.40
# 5	0.44		0.42
# 6	0.48		0.45
# 7	0.49		0.42
# 8	0.51		0.49
# 9	0.48		0.42
# 10	0.60		0.60
# 11	0.45		0.40
# 12	0.46		0.42
# 13	0.45		0.39
# 14	0.42		0.39
# 15	0.40		0.36
# 16	0.41		0.36
# 17	0.40		0.34
# 18	0.36		0.31
# 19	0.41		0.34
# 20	0.48		0.45
# t = 18 was best iteration with accuracy 0.69
#
# -----------------------------------------------
# 96 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.47		0.39
# 2	0.49		0.41
# 3	0.49		0.44
# 4	0.58		0.62
# 5	0.47		0.42
# 6	0.52		0.46
# 7	0.49		0.45
# 8	0.55		0.51
# 9	0.47		0.43
# 10	0.61		0.61
# 11	0.46		0.40
# 12	0.47		0.42
# 13	0.45		0.39
# 14	0.45		0.38
# 15	0.44		0.38
# 16	0.47		0.41
# 17	0.46		0.40
# 18	0.48		0.45
# 19	0.43		0.41
# 20	0.57		0.55
# t = 10 was best iteration with accuracy 0.61
#
# -----------------------------------------------
# 97 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.42		0.37
# 2	0.44		0.40
# 3	0.41		0.37
# 4	0.39		0.33
# 5	0.53		0.55
# 6	0.39		0.31
# 7	0.38		0.35
# 8	0.36		0.35
# 9	0.36		0.32
# 10	0.34		0.33
# 11	0.38		0.34
# 12	0.34		0.30
# 13	0.33		0.28
# 14	0.37		0.32
# 15	0.42		0.38
# 16	0.37		0.30
# 17	0.38		0.31
# 18	0.36		0.33
# 19	0.44		0.41
# 20	0.41		0.36
# t = 13 was best iteration with accuracy 0.72
#
# -----------------------------------------------
# 98 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.46		0.38
# 2	0.47		0.40
# 3	0.46		0.40
# 4	0.48		0.42
# 5	0.65		0.63
# 6	0.46		0.40
# 7	0.48		0.47
# 8	0.44		0.39
# 9	0.51		0.47
# 10	0.48		0.43
# 11	0.62		0.63
# 12	0.47		0.43
# 13	0.61		0.61
# 14	0.47		0.41
# 15	0.59		0.54
# 16	0.51		0.45
# 17	0.59		0.57
# 18	0.54		0.48
# 19	0.65		0.68
# 20	0.52		0.45
# t = 19 was best iteration with accuracy 0.68
#
# -----------------------------------------------
# 99 / 100 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.44		0.37
# 2	0.41		0.37
# 3	0.43		0.37
# 4	0.42		0.37
# 5	0.42		0.36
# 6	0.48		0.47
# 7	0.45		0.37
# 8	0.56		0.56
# 9	0.48		0.40
# 10	0.49		0.47
# 11	0.47		0.43
# 12	0.47		0.45
# 13	0.44		0.38
# 14	0.49		0.40
# 15	0.47		0.39
# 16	0.48		0.44
# 17	0.47		0.41
# 18	0.56		0.60
# 19	0.44		0.37
# 20	0.44		0.38
# t = 2 was best iteration with accuracy 0.63
#
# -----------------------------------------------
# 100 / 100 complete
# -----------------------------------------------

# %%
table_results(svm_arr, tree_arr)
# Out:
# (Performance on test set)
#
# 50 comparisons
# 	acc	sderr
# SVM: 	68.8	1.1
# Tree: 	nan	nan
#
# 200 comparisons
# 	acc	sderr
# SVM: 	65.8	1.2
# Tree: 	nan	nan
