# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_svmlight_file
from sklearn.model_selection import train_test_split
import sys; sys.path.insert(0,'..')
from main import *

# %%
X_train, y_train = load_svmlight_file('../data/ijcnn1/ijcnn1.tr')
X_train = X_train.toarray()

X_test, y_test = load_svmlight_file('../data/ijcnn1/ijcnn1.t')
X_test = X_test.toarray()

# %%
svm_arr, tree_arr, ls_base = data_size_experiment(X_train, y_train, X_test, y_test,
                                                  rank=True, rounded=True, 
                                                  plots_or_table='ratio',
                                                  random_state=2, verbose=True)
# Out:
# Progress:
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.56		0.65
# 2	0.35		0.28
# 3	0.60		0.57
# 4	0.42		0.47
# 5	0.61		0.57
# 6	0.40		0.43
# 7	0.61		0.58
# 8	0.40		0.43
# 9	0.61		0.58
# 10	0.44		0.47
# 11	0.62		0.60
# 12	0.34		0.38
# 13	0.45		0.63
# 14	0.47		0.31
# 15	0.60		0.79
# 16	0.50		0.33
# 17	0.63		0.82
# 18	0.44		0.33
# 19	0.48		0.65
# 20	0.51		0.45
# t = 17 was best iteration
#
#
# Linear SVM Accuracy for n=100: 0.902
# -----------------------------------------------
# 1 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.60		0.54
# 2	0.43		0.55
# 3	0.55		0.46
# 4	0.49		0.45
# 5	0.74		0.80
# 6	0.47		0.41
# 7	0.67		0.71
# 8	0.65		0.71
# 9	0.50		0.52
# 10	0.46		0.64
# 11	0.54		0.40
# 12	0.54		0.72
# 13	0.53		0.52
# 14	0.43		0.56
# 15	0.53		0.54
# 16	0.52		0.55
# 17	0.48		0.54
# 18	0.62		0.66
# 19	0.47		0.54
# 20	0.56		0.63
# t = 5 was best iteration
#
#
# Linear SVM Accuracy for n=100: 0.902
# -----------------------------------------------
# 2 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.58		0.55
# 2	0.47		0.47
# 3	0.55		0.56
# 4	0.45		0.50
# 5	0.57		0.59
# 6	0.45		0.50
# 7	0.60		0.59
# 8	0.41		0.47
# 9	0.60		0.58
# 10	0.48		0.50
# 11	0.57		0.62
# 12	0.39		0.42
# 13	0.35		0.45
# 14	0.42		0.44
# 15	0.42		0.40
# 16	0.54		0.48
# 17	0.44		0.50
# 18	0.54		0.49
# 19	0.45		0.52
# 20	0.56		0.50
# t = 11 was best iteration
#
#
# Linear SVM Accuracy for n=100: 0.902
# -----------------------------------------------
# 3 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.55		0.50
# 2	0.38		0.46
# 3	0.53		0.45
# 4	0.53		0.58
# 5	0.45		0.42
# 6	0.54		0.59
# 7	0.54		0.50
# 8	0.41		0.43
# 9	0.63		0.52
# 10	0.52		0.53
# 11	0.55		0.52
# 12	0.47		0.57
# 13	0.54		0.50
# 14	0.61		0.66
# 15	0.64		0.59
# 16	0.60		0.67
# 17	0.37		0.36
# 18	0.59		0.59
# 19	0.40		0.47
# 20	0.53		0.56
# t = 16 was best iteration
#
#
# Linear SVM Accuracy for n=100: 0.902
# -----------------------------------------------
# 4 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.58		0.57
# 2	0.44		0.42
# 3	0.48		0.44
# 4	0.56		0.61
# 5	0.52		0.51
# 6	0.51		0.59
# 7	0.55		0.51
# 8	0.50		0.62
# 9	0.64		0.70
# 10	0.45		0.55
# 11	0.60		0.65
# 12	0.43		0.52
# 13	0.63		0.64
# 14	0.54		0.60
# 15	0.74		0.71
# 16	0.75		0.79
# 17	0.62		0.54
# 18	0.65		0.75
# 19	0.48		0.57
# 20	0.54		0.58
# t = 16 was best iteration
#
#
# Linear SVM Accuracy for n=100: 0.902
# -----------------------------------------------
# 5 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.53		0.45
# 2	0.49		0.55
# 3	0.48		0.44
# 4	0.54		0.59
# 5	0.49		0.49
# 6	0.50		0.55
# 7	0.44		0.49
# 8	0.49		0.67
# 9	0.54		0.49
# 10	0.61		0.76
# 11	0.60		0.55
# 12	0.51		0.66
# 13	0.54		0.51
# 14	0.52		0.61
# 15	0.56		0.54
# 16	0.47		0.54
# 17	0.56		0.54
# 18	0.51		0.60
# 19	0.57		0.56
# 20	0.48		0.62
# t = 10 was best iteration
#
#
# Linear SVM Accuracy for n=100: 0.902
# -----------------------------------------------
# 6 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.47		0.48
# 2	0.46		0.49
# 3	0.48		0.43
# 4	0.52		0.49
# 5	0.50		0.52
# 6	0.51		0.49
# 7	0.50		0.52
# 8	0.50		0.48
# 9	0.51		0.54
# 10	0.50		0.48
# 11	0.54		0.58
# 12	0.45		0.47
# 13	0.60		0.65
# 14	0.47		0.48
# 15	0.55		0.63
# 16	0.46		0.48
# 17	0.58		0.65
# 18	0.49		0.48
# 19	0.55		0.67
# 20	0.47		0.55
# t = 19 was best iteration
#
#
# Linear SVM Accuracy for n=100: 0.902
# -----------------------------------------------
# 7 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.59		0.61
# 2	0.42		0.42
# 3	0.66		0.64
# 4	0.79		0.79
# 5	0.85		0.82
# 6	0.89		0.88
# 7	0.87		0.85
# 8	0.87		0.88
# 9	0.83		0.73
# 10	0.74		0.77
# 11	0.49		0.56
# 12	0.58		0.61
# 13	0.49		0.51
# 14	0.55		0.58
# 15	0.49		0.52
# 16	0.53		0.57
# 17	0.49		0.52
# 18	0.54		0.58
# 19	0.49		0.51
# 20	0.63		0.64
# t = 8 was best iteration
#
#
# Linear SVM Accuracy for n=100: 0.902
# -----------------------------------------------
# 8 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.46		0.41
# 2	0.45		0.59
# 3	0.54		0.45
# 4	0.44		0.54
# 5	0.57		0.48
# 6	0.44		0.53
# 7	0.57		0.50
# 8	0.52		0.58
# 9	0.60		0.59
# 10	0.53		0.54
# 11	0.63		0.70
# 12	0.56		0.65
# 13	0.47		0.44
# 14	0.56		0.64
# 15	0.53		0.54
# 16	0.55		0.64
# 17	0.47		0.50
# 18	0.54		0.63
# 19	0.47		0.49
# 20	0.52		0.65
# t = 11 was best iteration
#
#
# Linear SVM Accuracy for n=100: 0.902
# -----------------------------------------------
# 9 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.59		0.59
# 2	0.35		0.45
# 3	0.67		0.59
# 4	0.36		0.46
# 5	0.62		0.60
# 6	0.67		0.66
# 7	0.52		0.63
# 8	0.50		0.48
# 9	0.52		0.57
# 10	0.50		0.53
# 11	0.51		0.59
# 12	0.62		0.63
# 13	0.47		0.59
# 14	0.62		0.61
# 15	0.51		0.58
# 16	0.58		0.58
# 17	0.54		0.61
# 18	0.54		0.55
# 19	0.57		0.63
# 20	0.59		0.57
# t = 6 was best iteration
#
#
# Linear SVM Accuracy for n=100: 0.902
# -----------------------------------------------
# 10 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.90		0.85
# 2	0.90		0.86
# 3	0.92		0.89
# 4	0.92		0.89
# 5	0.83		0.82
# 6	0.60		0.62
# 7	0.47		0.46
# 8	0.61		0.66
# 9	0.55		0.56
# 10	0.76		0.78
# 11	0.78		0.75
# 12	0.76		0.76
# 13	0.78		0.79
# 14	0.76		0.66
# 15	0.73		0.70
# 16	0.68		0.70
# 17	0.50		0.43
# 18	0.57		0.54
# 19	0.46		0.36
# 20	0.52		0.53
# t = 3 was best iteration
#
#
# Linear SVM Accuracy for n=200: 0.912
# -----------------------------------------------
# 11 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.91		0.81
# 2	0.90		0.87
# 3	0.92		0.88
# 4	0.91		0.88
# 5	0.89		0.90
# 6	0.69		0.73
# 7	0.52		0.49
# 8	0.69		0.77
# 9	0.68		0.61
# 10	0.64		0.72
# 11	0.60		0.62
# 12	0.72		0.63
# 13	0.73		0.70
# 14	0.43		0.41
# 15	0.65		0.61
# 16	0.41		0.39
# 17	0.58		0.49
# 18	0.42		0.48
# 19	0.35		0.38
# 20	0.28		0.34
# t = 5 was best iteration
#
#
# Linear SVM Accuracy for n=200: 0.912
# -----------------------------------------------
# 12 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.90		0.77
# 2	0.92		0.87
# 3	0.91		0.87
# 4	0.91		0.87
# 5	0.93		0.88
# 6	0.89		0.90
# 7	0.56		0.61
# 8	0.50		0.50
# 9	0.54		0.56
# 10	0.60		0.58
# 11	0.69		0.67
# 12	0.66		0.76
# 13	0.55		0.45
# 14	0.38		0.36
# 15	0.46		0.49
# 16	0.28		0.33
# 17	0.18		0.23
# 18	0.12		0.20
# 19	0.19		0.20
# 20	0.41		0.33
# t = 6 was best iteration
#
#
# Linear SVM Accuracy for n=200: 0.912
# -----------------------------------------------
# 13 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.90		0.78
# 2	0.90		0.88
# 3	0.91		0.88
# 4	0.88		0.90
# 5	0.60		0.55
# 6	0.56		0.60
# 7	0.75		0.76
# 8	0.83		0.79
# 9	0.71		0.66
# 10	0.61		0.66
# 11	0.56		0.51
# 12	0.56		0.59
# 13	0.47		0.52
# 14	0.67		0.61
# 15	0.68		0.64
# 16	0.71		0.64
# 17	0.73		0.67
# 18	0.69		0.63
# 19	0.66		0.51
# 20	0.40		0.42
# t = 4 was best iteration
#
#
# Linear SVM Accuracy for n=200: 0.912
# -----------------------------------------------
# 14 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.91		0.85
# 2	0.91		0.87
# 3	0.93		0.86
# 4	0.89		0.89
# 5	0.82		0.83
# 6	0.72		0.80
# 7	0.79		0.72
# 8	0.85		0.85
# 9	0.91		0.85
# 10	0.91		0.88
# 11	0.93		0.86
# 12	0.84		0.80
# 13	0.53		0.45
# 14	0.58		0.61
# 15	0.60		0.63
# 16	0.78		0.78
# 17	0.73		0.58
# 18	0.58		0.61
# 19	0.56		0.61
# 20	0.64		0.58
# t = 4 was best iteration
#
#
# Linear SVM Accuracy for n=200: 0.912
# -----------------------------------------------
# 15 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.89		0.84
# 2	0.92		0.88
# 3	0.90		0.89
# 4	0.88		0.88
# 5	0.65		0.69
# 6	0.45		0.46
# 7	0.58		0.66
# 8	0.53		0.52
# 9	0.65		0.62
# 10	0.76		0.72
# 11	0.69		0.66
# 12	0.71		0.60
# 13	0.72		0.62
# 14	0.62		0.50
# 15	0.44		0.41
# 16	0.45		0.41
# 17	0.36		0.28
# 18	0.42		0.38
# 19	0.24		0.27
# 20	0.14		0.21
# t = 3 was best iteration
#
#
# Linear SVM Accuracy for n=200: 0.912
# -----------------------------------------------
# 16 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.84		0.84
# 2	0.89		0.86
# 3	0.75		0.66
# 4	0.64		0.70
# 5	0.60		0.53
# 6	0.72		0.73
# 7	0.77		0.74
# 8	0.80		0.83
# 9	0.71		0.57
# 10	0.54		0.61
# 11	0.60		0.53
# 12	0.58		0.47
# 13	0.24		0.20
# 14	0.48		0.47
# 15	0.32		0.40
# 16	0.20		0.28
# 17	0.15		0.22
# 18	0.12		0.13
# 19	0.21		0.29
# 20	0.35		0.37
# t = 18 was best iteration
#
#
# Linear SVM Accuracy for n=200: 0.912
# -----------------------------------------------
# 17 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.90		0.82
# 2	0.91		0.86
# 3	0.94		0.89
# 4	0.91		0.90
# 5	0.89		0.90
# 6	0.58		0.61
# 7	0.78		0.76
# 8	0.69		0.71
# 9	0.78		0.75
# 10	0.78		0.74
# 11	0.54		0.51
# 12	0.53		0.52
# 13	0.52		0.59
# 14	0.58		0.58
# 15	0.70		0.64
# 16	0.62		0.57
# 17	0.62		0.62
# 18	0.56		0.53
# 19	0.53		0.50
# 20	0.49		0.43
# t = 5 was best iteration
#
#
# Linear SVM Accuracy for n=200: 0.912
# -----------------------------------------------
# 18 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.92		0.86
# 2	0.93		0.86
# 3	0.92		0.87
# 4	0.93		0.89
# 5	0.91		0.89
# 6	0.91		0.91
# 7	0.89		0.89
# 8	0.71		0.86
# 9	0.68		0.56
# 10	0.81		0.79
# 11	0.85		0.79
# 12	0.91		0.87
# 13	0.88		0.90
# 14	0.82		0.73
# 15	0.85		0.86
# 16	0.90		0.85
# 17	0.92		0.86
# 18	0.92		0.87
# 19	0.91		0.86
# 20	0.90		0.88
# t = 6 was best iteration
#
#
# Linear SVM Accuracy for n=200: 0.912
# -----------------------------------------------
# 19 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.90		0.82
# 2	0.89		0.84
# 3	0.87		0.80
# 4	0.89		0.87
# 5	0.91		0.88
# 6	0.73		0.79
# 7	0.52		0.45
# 8	0.80		0.74
# 9	0.66		0.68
# 10	0.71		0.67
# 11	0.80		0.72
# 12	0.71		0.73
# 13	0.53		0.62
# 14	0.56		0.51
# 15	0.49		0.54
# 16	0.49		0.48
# 17	0.40		0.44
# 18	0.27		0.26
# 19	0.20		0.19
# 20	0.21		0.25
# t = 5 was best iteration
#
#
# Linear SVM Accuracy for n=200: 0.912
# -----------------------------------------------
# 20 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.86		0.81
# 2	0.90		0.85
# 3	0.69		0.60
# 4	0.51		0.53
# 5	0.56		0.61
# 6	0.60		0.73
# 7	0.65		0.58
# 8	0.58		0.57
# 9	0.47		0.47
# 10	0.53		0.53
# 11	0.47		0.45
# 12	0.53		0.55
# 13	0.44		0.41
# 14	0.51		0.51
# 15	0.45		0.41
# 16	0.46		0.47
# 17	0.41		0.41
# 18	0.32		0.42
# 19	0.38		0.32
# 20	0.34		0.45
# t = 2 was best iteration
#
#
# Linear SVM Accuracy for n=400: 0.910
# -----------------------------------------------
# 21 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.86		0.83
# 2	0.90		0.83
# 3	0.55		0.53
# 4	0.53		0.59
# 5	0.58		0.59
# 6	0.46		0.50
# 7	0.56		0.50
# 8	0.47		0.52
# 9	0.57		0.48
# 10	0.46		0.48
# 11	0.55		0.50
# 12	0.47		0.52
# 13	0.54		0.55
# 14	0.46		0.52
# 15	0.44		0.29
# 16	0.42		0.50
# 17	0.55		0.49
# 18	0.46		0.49
# 19	0.53		0.49
# 20	0.46		0.49
# t = 1 was best iteration
#
#
# Linear SVM Accuracy for n=400: 0.910
# -----------------------------------------------
# 22 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.87		0.82
# 2	0.89		0.88
# 3	0.69		0.63
# 4	0.54		0.66
# 5	0.76		0.80
# 6	0.73		0.82
# 7	0.57		0.51
# 8	0.47		0.50
# 9	0.54		0.48
# 10	0.49		0.53
# 11	0.48		0.47
# 12	0.30		0.36
# 13	0.15		0.12
# 14	0.16		0.19
# 15	0.28		0.23
# 16	0.28		0.36
# 17	0.21		0.31
# 18	0.18		0.25
# 19	0.20		0.21
# 20	0.10		0.15
# t = 2 was best iteration
#
#
# Linear SVM Accuracy for n=400: 0.910
# -----------------------------------------------
# 23 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.87		0.83
# 2	0.81		0.77
# 3	0.55		0.53
# 4	0.56		0.65
# 5	0.58		0.51
# 6	0.45		0.50
# 7	0.55		0.50
# 8	0.46		0.50
# 9	0.61		0.56
# 10	0.49		0.54
# 11	0.53		0.44
# 12	0.47		0.48
# 13	0.54		0.50
# 14	0.44		0.48
# 15	0.50		0.51
# 16	0.30		0.32
# 17	0.26		0.28
# 18	0.43		0.47
# 19	0.32		0.34
# 20	0.29		0.37
# t = 1 was best iteration
#
#
# Linear SVM Accuracy for n=400: 0.910
# -----------------------------------------------
# 24 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.88		0.82
# 2	0.91		0.85
# 3	0.71		0.64
# 4	0.56		0.61
# 5	0.47		0.41
# 6	0.54		0.59
# 7	0.46		0.38
# 8	0.56		0.61
# 9	0.46		0.38
# 10	0.56		0.62
# 11	0.46		0.33
# 12	0.23		0.50
# 13	0.28		0.16
# 14	0.41		0.58
# 15	0.24		0.25
# 16	0.12		0.15
# 17	0.10		0.13
# 18	0.32		0.44
# 19	0.40		0.29
# 20	0.23		0.34
# t = 17 was best iteration
#
#
# Linear SVM Accuracy for n=400: 0.910
# -----------------------------------------------
# 25 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.87		0.84
# 2	0.90		0.89
# 3	0.75		0.63
# 4	0.61		0.67
# 5	0.76		0.74
# 6	0.71		0.60
# 7	0.74		0.75
# 8	0.64		0.59
# 9	0.48		0.49
# 10	0.60		0.61
# 11	0.58		0.59
# 12	0.50		0.52
# 13	0.56		0.51
# 14	0.43		0.39
# 15	0.52		0.52
# 16	0.54		0.54
# 17	0.41		0.40
# 18	0.35		0.38
# 19	0.43		0.53
# 20	0.31		0.31
# t = 2 was best iteration
#
#
# Linear SVM Accuracy for n=400: 0.910
# -----------------------------------------------
# 26 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.88		0.82
# 2	0.88		0.81
# 3	0.92		0.87
# 4	0.54		0.61
# 5	0.56		0.51
# 6	0.55		0.57
# 7	0.57		0.54
# 8	0.45		0.54
# 9	0.56		0.47
# 10	0.46		0.54
# 11	0.56		0.48
# 12	0.51		0.58
# 13	0.45		0.44
# 14	0.46		0.45
# 15	0.46		0.39
# 16	0.52		0.55
# 17	0.41		0.36
# 18	0.37		0.49
# 19	0.26		0.30
# 20	0.20		0.20
# t = 3 was best iteration
#
#
# Linear SVM Accuracy for n=400: 0.910
# -----------------------------------------------
# 27 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.86		0.83
# 2	0.87		0.79
# 3	0.74		0.74
# 4	0.60		0.66
# 5	0.49		0.41
# 6	0.58		0.64
# 7	0.64		0.52
# 8	0.45		0.37
# 9	0.43		0.54
# 10	0.42		0.41
# 11	0.54		0.61
# 12	0.54		0.40
# 13	0.64		0.70
# 14	0.50		0.44
# 15	0.35		0.46
# 16	0.40		0.44
# 17	0.60		0.53
# 18	0.28		0.40
# 19	0.14		0.17
# 20	0.13		0.14
# t = 20 was best iteration
#
#
# Linear SVM Accuracy for n=400: 0.910
# -----------------------------------------------
# 28 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.87		0.82
# 2	0.88		0.85
# 3	0.74		0.66
# 4	0.54		0.61
# 5	0.61		0.60
# 6	0.68		0.68
# 7	0.68		0.66
# 8	0.57		0.59
# 9	0.56		0.52
# 10	0.48		0.51
# 11	0.56		0.51
# 12	0.45		0.50
# 13	0.53		0.49
# 14	0.45		0.51
# 15	0.53		0.48
# 16	0.43		0.45
# 17	0.39		0.37
# 18	0.27		0.31
# 19	0.56		0.48
# 20	0.37		0.44
# t = 2 was best iteration
#
#
# Linear SVM Accuracy for n=400: 0.910
# -----------------------------------------------
# 29 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.88		0.82
# 2	0.90		0.87
# 3	0.62		0.54
# 4	0.53		0.56
# 5	0.70		0.67
# 6	0.57		0.64
# 7	0.62		0.54
# 8	0.48		0.50
# 9	0.56		0.52
# 10	0.45		0.53
# 11	0.54		0.58
# 12	0.49		0.56
# 13	0.48		0.43
# 14	0.43		0.45
# 15	0.46		0.45
# 16	0.49		0.49
# 17	0.22		0.28
# 18	0.10		0.14
# 19	0.10		0.10
# 20	0.29		0.42
# t = 19 was best iteration
#
#
# Linear SVM Accuracy for n=400: 0.910
# -----------------------------------------------
# 30 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.88		0.86
# 2	0.90		0.86
# 3	0.90		0.87
# 4	0.49		0.67
# 5	0.55		0.58
# 6	0.65		0.63
# 7	0.72		0.67
# 8	0.52		0.54
# 9	0.51		0.48
# 10	0.41		0.42
# 11	0.21		0.25
# 12	0.14		0.16
# 13	0.10		0.12
# 14	0.36		0.24
# 15	0.11		0.15
# 16	0.12		0.10
# 17	0.34		0.43
# 18	0.11		0.15
# 19	0.10		0.11
# 20	0.10		0.10
# t = 20 was best iteration
#
#
# Linear SVM Accuracy for n=800: 0.920
# -----------------------------------------------
# 31 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.87		0.88
# 2	0.90		0.87
# 3	0.91		0.86
# 4	0.89		0.90
# 5	0.60		0.44
# 6	0.47		0.50
# 7	0.57		0.57
# 8	0.38		0.41
# 9	0.30		0.27
# 10	0.29		0.37
# 11	0.55		0.49
# 12	0.19		0.20
# 13	0.11		0.14
# 14	0.10		0.10
# 15	0.10		0.10
# 16	0.10		0.10
# 17	0.11		0.14
# 18	0.10		0.10
# 19	0.10		0.10
# 20	0.10		0.10
# t = 15 was best iteration
#
#
# Linear SVM Accuracy for n=800: 0.920
# -----------------------------------------------
# 32 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.87		0.86
# 2	0.90		0.86
# 3	0.90		0.93
# 4	0.67		0.58
# 5	0.55		0.56
# 6	0.50		0.48
# 7	0.37		0.39
# 8	0.41		0.40
# 9	0.51		0.51
# 10	0.27		0.25
# 11	0.12		0.16
# 12	0.10		0.10
# 13	0.37		0.38
# 14	0.17		0.18
# 15	0.11		0.16
# 16	0.10		0.10
# 17	0.12		0.13
# 18	0.11		0.13
# 19	0.10		0.11
# 20	0.10		0.10
# t = 3 was best iteration
#
#
# Linear SVM Accuracy for n=800: 0.920
# -----------------------------------------------
# 33 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.89		0.87
# 2	0.90		0.88
# 3	0.91		0.87
# 4	0.90		0.90
# 5	0.55		0.57
# 6	0.54		0.55
# 7	0.59		0.60
# 8	0.43		0.41
# 9	0.57		0.57
# 10	0.32		0.31
# 11	0.28		0.23
# 12	0.14		0.14
# 13	0.10		0.13
# 14	0.19		0.18
# 15	0.48		0.50
# 16	0.14		0.18
# 17	0.10		0.12
# 18	0.10		0.10
# 19	0.31		0.24
# 20	0.20		0.20
# t = 18 was best iteration
#
#
# Linear SVM Accuracy for n=800: 0.920
# -----------------------------------------------
# 34 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.88		0.87
# 2	0.90		0.86
# 3	0.91		0.91
# 4	0.87		0.84
# 5	0.62		0.59
# 6	0.75		0.72
# 7	0.78		0.75
# 8	0.82		0.80
# 9	0.85		0.81
# 10	0.54		0.53
# 11	0.57		0.50
# 12	0.47		0.41
# 13	0.42		0.47
# 14	0.50		0.50
# 15	0.41		0.42
# 16	0.24		0.23
# 17	0.15		0.19
# 18	0.12		0.13
# 19	0.10		0.10
# 20	0.24		0.34
# t = 3 was best iteration
#
#
# Linear SVM Accuracy for n=800: 0.920
# -----------------------------------------------
# 35 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.86		0.89
# 2	0.91		0.85
# 3	0.90		0.90
# 4	0.56		0.45
# 5	0.65		0.75
# 6	0.46		0.37
# 7	0.38		0.42
# 8	0.49		0.45
# 9	0.29		0.32
# 10	0.16		0.20
# 11	0.12		0.15
# 12	0.10		0.10
# 13	0.39		0.47
# 14	0.38		0.32
# 15	0.40		0.43
# 16	0.16		0.20
# 17	0.11		0.14
# 18	0.10		0.11
# 19	0.10		0.10
# 20	0.11		0.11
# t = 12 was best iteration
#
#
# Linear SVM Accuracy for n=800: 0.920
# -----------------------------------------------
# 36 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.88		0.87
# 2	0.91		0.88
# 3	0.90		0.89
# 4	0.71		0.69
# 5	0.55		0.59
# 6	0.58		0.56
# 7	0.35		0.34
# 8	0.42		0.43
# 9	0.18		0.15
# 10	0.15		0.16
# 11	0.15		0.23
# 12	0.13		0.13
# 13	0.11		0.12
# 14	0.10		0.10
# 15	0.10		0.10
# 16	0.14		0.16
# 17	0.10		0.10
# 18	0.10		0.10
# 19	0.10		0.11
# 20	0.10		0.12
# t = 15 was best iteration
#
#
# Linear SVM Accuracy for n=800: 0.920
# -----------------------------------------------
# 37 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.87		0.86
# 2	0.90		0.87
# 3	0.91		0.89
# 4	0.85		0.86
# 5	0.66		0.67
# 6	0.59		0.51
# 7	0.53		0.47
# 8	0.40		0.35
# 9	0.42		0.45
# 10	0.20		0.13
# 11	0.47		0.65
# 12	0.30		0.28
# 13	0.19		0.26
# 14	0.14		0.20
# 15	0.10		0.10
# 16	0.40		0.43
# 17	0.18		0.17
# 18	0.14		0.20
# 19	0.14		0.13
# 20	0.10		0.12
# t = 15 was best iteration
#
#
# Linear SVM Accuracy for n=800: 0.920
# -----------------------------------------------
# 38 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.86		0.88
# 2	0.90		0.87
# 3	0.91		0.91
# 4	0.67		0.65
# 5	0.47		0.45
# 6	0.62		0.54
# 7	0.54		0.55
# 8	0.38		0.32
# 9	0.43		0.54
# 10	0.43		0.43
# 11	0.25		0.30
# 12	0.14		0.16
# 13	0.11		0.14
# 14	0.10		0.11
# 15	0.10		0.10
# 16	0.12		0.14
# 17	0.10		0.11
# 18	0.10		0.10
# 19	0.10		0.10
# 20	0.13		0.14
# t = 3 was best iteration
#
#
# Linear SVM Accuracy for n=800: 0.920
# -----------------------------------------------
# 39 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.88		0.89
# 2	0.90		0.89
# 3	0.90		0.90
# 4	0.90		0.91
# 5	0.72		0.77
# 6	0.66		0.64
# 7	0.71		0.71
# 8	0.74		0.69
# 9	0.46		0.52
# 10	0.58		0.55
# 11	0.45		0.46
# 12	0.18		0.23
# 13	0.12		0.12
# 14	0.37		0.47
# 15	0.14		0.14
# 16	0.10		0.12
# 17	0.10		0.10
# 18	0.22		0.26
# 19	0.12		0.16
# 20	0.10		0.11
# t = 4 was best iteration
#
#
# Linear SVM Accuracy for n=800: 0.920
# -----------------------------------------------
# 40 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.84		0.87
# 2	0.88		0.87
# 3	0.89		0.87
# 4	0.90		0.88
# 5	0.90		0.89
# 6	0.90		0.87
# 7	0.91		0.92
# 8	0.73		0.74
# 9	0.43		0.44
# 10	0.39		0.42
# 11	0.17		0.19
# 12	0.27		0.27
# 13	0.30		0.26
# 14	0.13		0.23
# 15	0.10		0.14
# 16	0.09		0.10
# 17	0.09		0.10
# 18	0.36		0.39
# 19	0.13		0.15
# 20	0.10		0.15
# t = 7 was best iteration
#
#
# Linear SVM Accuracy for n=1200: 0.920
# -----------------------------------------------
# 41 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.86		0.88
# 2	0.89		0.87
# 3	0.89		0.88
# 4	0.90		0.89
# 5	0.91		0.88
# 6	0.91		0.90
# 7	0.91		0.91
# 8	0.89		0.80
# 9	0.53		0.71
# 10	0.51		0.63
# 11	0.37		0.45
# 12	0.26		0.32
# 13	0.15		0.21
# 14	0.38		0.42
# 15	0.29		0.27
# 16	0.12		0.19
# 17	0.10		0.15
# 18	0.09		0.10
# 19	0.09		0.10
# 20	0.16		0.14
# t = 7 was best iteration
#
#
# Linear SVM Accuracy for n=1200: 0.920
# -----------------------------------------------
# 42 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.84		0.87
# 2	0.88		0.87
# 3	0.90		0.88
# 4	0.91		0.88
# 5	0.91		0.92
# 6	0.91		0.91
# 7	0.64		0.74
# 8	0.63		0.62
# 9	0.69		0.64
# 10	0.71		0.68
# 11	0.77		0.78
# 12	0.77		0.70
# 13	0.55		0.60
# 14	0.52		0.47
# 15	0.35		0.34
# 16	0.12		0.24
# 17	0.16		0.11
# 18	0.37		0.53
# 19	0.10		0.14
# 20	0.09		0.11
# t = 5 was best iteration
#
#
# Linear SVM Accuracy for n=1200: 0.920
# -----------------------------------------------
# 43 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.84		0.87
# 2	0.88		0.88
# 3	0.89		0.88
# 4	0.90		0.89
# 5	0.90		0.87
# 6	0.91		0.92
# 7	0.91		0.92
# 8	0.63		0.83
# 9	0.58		0.39
# 10	0.68		0.63
# 11	0.74		0.68
# 12	0.76		0.73
# 13	0.82		0.77
# 14	0.74		0.74
# 15	0.51		0.48
# 16	0.53		0.54
# 17	0.36		0.37
# 18	0.24		0.36
# 19	0.16		0.22
# 20	0.11		0.16
# t = 7 was best iteration
#
#
# Linear SVM Accuracy for n=1200: 0.920
# -----------------------------------------------
# 44 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.83		0.87
# 2	0.88		0.87
# 3	0.90		0.86
# 4	0.91		0.87
# 5	0.91		0.92
# 6	0.91		0.87
# 7	0.51		0.72
# 8	0.53		0.37
# 9	0.30		0.47
# 10	0.35		0.26
# 11	0.15		0.19
# 12	0.10		0.16
# 13	0.09		0.10
# 14	0.34		0.35
# 15	0.10		0.13
# 16	0.09		0.10
# 17	0.12		0.11
# 18	0.11		0.13
# 19	0.09		0.12
# 20	0.09		0.10
# t = 5 was best iteration
#
#
# Linear SVM Accuracy for n=1200: 0.920
# -----------------------------------------------
# 45 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.85		0.87
# 2	0.89		0.86
# 3	0.89		0.88
# 4	0.90		0.88
# 5	0.91		0.88
# 6	0.91		0.91
# 7	0.91		0.91
# 8	0.75		0.60
# 9	0.61		0.67
# 10	0.61		0.62
# 11	0.53		0.55
# 12	0.47		0.49
# 13	0.43		0.45
# 14	0.39		0.41
# 15	0.30		0.31
# 16	0.20		0.35
# 17	0.38		0.28
# 18	0.46		0.54
# 19	0.21		0.36
# 20	0.14		0.22
# t = 6 was best iteration
#
#
# Linear SVM Accuracy for n=1200: 0.920
# -----------------------------------------------
# 46 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.84		0.87
# 2	0.89		0.87
# 3	0.90		0.89
# 4	0.90		0.89
# 5	0.91		0.92
# 6	0.91		0.90
# 7	0.53		0.54
# 8	0.55		0.49
# 9	0.27		0.33
# 10	0.13		0.21
# 11	0.09		0.10
# 12	0.44		0.50
# 13	0.15		0.26
# 14	0.11		0.18
# 15	0.10		0.14
# 16	0.09		0.12
# 17	0.09		0.10
# 18	0.09		0.10
# 19	0.09		0.10
# 20	0.21		0.29
# t = 5 was best iteration
#
#
# Linear SVM Accuracy for n=1200: 0.920
# -----------------------------------------------
# 47 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.84		0.87
# 2	0.88		0.87
# 3	0.90		0.88
# 4	0.90		0.89
# 5	0.91		0.89
# 6	0.91		0.92
# 7	0.90		0.87
# 8	0.55		0.55
# 9	0.45		0.45
# 10	0.28		0.36
# 11	0.17		0.25
# 12	0.10		0.14
# 13	0.22		0.23
# 14	0.51		0.50
# 15	0.15		0.23
# 16	0.12		0.18
# 17	0.10		0.14
# 18	0.09		0.11
# 19	0.09		0.10
# 20	0.09		0.10
# t = 6 was best iteration
#
#
# Linear SVM Accuracy for n=1200: 0.920
# -----------------------------------------------
# 48 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.85		0.86
# 2	0.90		0.89
# 3	0.90		0.89
# 4	0.91		0.87
# 5	0.91		0.91
# 6	0.91		0.90
# 7	0.57		0.57
# 8	0.46		0.52
# 9	0.30		0.36
# 10	0.16		0.27
# 11	0.10		0.12
# 12	0.09		0.17
# 13	0.39		0.31
# 14	0.13		0.14
# 15	0.10		0.13
# 16	0.09		0.10
# 17	0.09		0.10
# 18	0.31		0.38
# 19	0.10		0.18
# 20	0.09		0.10
# t = 5 was best iteration
#
#
# Linear SVM Accuracy for n=1200: 0.920
# -----------------------------------------------
# 49 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.86		0.88
# 2	0.89		0.88
# 3	0.90		0.89
# 4	0.91		0.89
# 5	0.91		0.89
# 6	0.91		0.91
# 7	0.88		0.76
# 8	0.60		0.61
# 9	0.52		0.58
# 10	0.40		0.41
# 11	0.28		0.33
# 12	0.45		0.41
# 13	0.20		0.24
# 14	0.10		0.16
# 15	0.09		0.10
# 16	0.27		0.36
# 17	0.11		0.18
# 18	0.09		0.10
# 19	0.09		0.10
# 20	0.20		0.25
# t = 6 was best iteration
#
#
# Linear SVM Accuracy for n=1200: 0.920
# -----------------------------------------------
# 50 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.86		0.84
# 2	0.90		0.86
# 3	0.90		0.87
# 4	0.89		0.90
# 5	0.65		0.63
# 6	0.58		0.37
# 7	0.47		0.34
# 8	0.31		0.24
# 9	0.15		0.16
# 10	0.48		0.48
# 11	0.48		0.50
# 12	0.16		0.14
# 13	0.10		0.10
# 14	0.32		0.19
# 15	0.17		0.13
# 16	0.12		0.12
# 17	0.11		0.11
# 18	0.10		0.10
# 19	0.10		0.10
# 20	0.10		0.10
# t = 13 was best iteration
#
#
# Linear SVM Accuracy for n=1600: 0.920
# -----------------------------------------------
# 51 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.87		0.82
# 2	0.90		0.85
# 3	0.90		0.89
# 4	0.90		0.90
# 5	0.66		0.61
# 6	0.72		0.65
# 7	0.71		0.57
# 8	0.78		0.69
# 9	0.77		0.65
# 10	0.38		0.48
# 11	0.56		0.51
# 12	0.20		0.17
# 13	0.20		0.21
# 14	0.13		0.13
# 15	0.11		0.12
# 16	0.15		0.14
# 17	0.14		0.15
# 18	0.11		0.10
# 19	0.10		0.10
# 20	0.11		0.10
# t = 19 was best iteration
#
#
# Linear SVM Accuracy for n=1600: 0.920
# -----------------------------------------------
# 52 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.86		0.82
# 2	0.90		0.86
# 3	0.90		0.88
# 4	0.61		0.72
# 5	0.57		0.51
# 6	0.54		0.33
# 7	0.48		0.34
# 8	0.36		0.30
# 9	0.25		0.23
# 10	0.12		0.11
# 11	0.54		0.53
# 12	0.36		0.30
# 13	0.15		0.17
# 14	0.10		0.10
# 15	0.43		0.48
# 16	0.18		0.21
# 17	0.10		0.10
# 18	0.11		0.10
# 19	0.12		0.14
# 20	0.10		0.11
# t = 14 was best iteration
#
#
# Linear SVM Accuracy for n=1600: 0.920
# -----------------------------------------------
# 53 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.86		0.84
# 2	0.89		0.87
# 3	0.90		0.85
# 4	0.90		0.87
# 5	0.77		0.86
# 6	0.60		0.41
# 7	0.65		0.44
# 8	0.66		0.56
# 9	0.63		0.49
# 10	0.40		0.43
# 11	0.50		0.50
# 12	0.22		0.23
# 13	0.11		0.13
# 14	0.10		0.10
# 15	0.13		0.11
# 16	0.25		0.30
# 17	0.10		0.12
# 18	0.10		0.10
# 19	0.10		0.10
# 20	0.11		0.11
# t = 14 was best iteration
#
#
# Linear SVM Accuracy for n=1600: 0.920
# -----------------------------------------------
# 54 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.87		0.84
# 2	0.90		0.87
# 3	0.90		0.90
# 4	0.77		0.79
# 5	0.60		0.58
# 6	0.69		0.57
# 7	0.80		0.70
# 8	0.89		0.86
# 9	0.56		0.45
# 10	0.51		0.56
# 11	0.40		0.34
# 12	0.24		0.20
# 13	0.15		0.15
# 14	0.10		0.10
# 15	0.12		0.19
# 16	0.42		0.33
# 17	0.18		0.15
# 18	0.11		0.13
# 19	0.10		0.10
# 20	0.17		0.15
# t = 19 was best iteration
#
#
# Linear SVM Accuracy for n=1600: 0.920
# -----------------------------------------------
# 55 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.86		0.82
# 2	0.90		0.86
# 3	0.90		0.90
# 4	0.55		0.45
# 5	0.59		0.61
# 6	0.44		0.37
# 7	0.38		0.32
# 8	0.34		0.28
# 9	0.29		0.24
# 10	0.22		0.20
# 11	0.16		0.15
# 12	0.11		0.12
# 13	0.11		0.11
# 14	0.53		0.47
# 15	0.21		0.19
# 16	0.13		0.14
# 17	0.10		0.11
# 18	0.10		0.10
# 19	0.24		0.27
# 20	0.20		0.25
# t = 3 was best iteration
#
#
# Linear SVM Accuracy for n=1600: 0.920
# -----------------------------------------------
# 56 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.86		0.82
# 2	0.90		0.87
# 3	0.90		0.90
# 4	0.81		0.81
# 5	0.60		0.54
# 6	0.63		0.54
# 7	0.67		0.58
# 8	0.66		0.56
# 9	0.58		0.41
# 10	0.51		0.56
# 11	0.43		0.32
# 12	0.18		0.16
# 13	0.10		0.10
# 14	0.20		0.24
# 15	0.28		0.26
# 16	0.10		0.12
# 17	0.10		0.10
# 18	0.10		0.10
# 19	0.10		0.10
# 20	0.20		0.24
# t = 3 was best iteration
#
#
# Linear SVM Accuracy for n=1600: 0.920
# -----------------------------------------------
# 57 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.86		0.83
# 2	0.89		0.84
# 3	0.90		0.84
# 4	0.90		0.90
# 5	0.59		0.29
# 6	0.59		0.62
# 7	0.41		0.27
# 8	0.52		0.60
# 9	0.17		0.15
# 10	0.10		0.11
# 11	0.11		0.11
# 12	0.45		0.44
# 13	0.16		0.15
# 14	0.13		0.14
# 15	0.11		0.12
# 16	0.10		0.10
# 17	0.10		0.10
# 18	0.23		0.19
# 19	0.10		0.11
# 20	0.10		0.10
# t = 4 was best iteration
#
#
# Linear SVM Accuracy for n=1600: 0.920
# -----------------------------------------------
# 58 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.87		0.83
# 2	0.90		0.86
# 3	0.89		0.91
# 4	0.63		0.74
# 5	0.54		0.47
# 6	0.44		0.26
# 7	0.32		0.23
# 8	0.11		0.10
# 9	0.41		0.49
# 10	0.39		0.30
# 11	0.15		0.17
# 12	0.10		0.10
# 13	0.10		0.10
# 14	0.49		0.45
# 15	0.15		0.17
# 16	0.12		0.13
# 17	0.11		0.12
# 18	0.10		0.10
# 19	0.10		0.10
# 20	0.10		0.10
# t = 3 was best iteration
#
#
# Linear SVM Accuracy for n=1600: 0.920
# -----------------------------------------------
# 59 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.87		0.84
# 2	0.90		0.85
# 3	0.90		0.86
# 4	0.90		0.91
# 5	0.43		0.52
# 6	0.58		0.49
# 7	0.21		0.27
# 8	0.24		0.21
# 9	0.37		0.38
# 10	0.11		0.11
# 11	0.15		0.14
# 12	0.17		0.15
# 13	0.10		0.10
# 14	0.10		0.10
# 15	0.10		0.10
# 16	0.10		0.10
# 17	0.10		0.10
# 18	0.10		0.10
# 19	0.10		0.10
# 20	0.10		0.10
# t = 4 was best iteration
#
#
# Linear SVM Accuracy for n=1600: 0.920
# -----------------------------------------------
# 60 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.86		0.85
# 2	0.88		0.86
# 3	0.90		0.87
# 4	0.90		0.87
# 5	0.91		0.88
# 6	0.90		0.89
# 7	0.90		0.92
# 8	0.90		0.90
# 9	0.55		0.57
# 10	0.38		0.33
# 11	0.15		0.18
# 12	0.12		0.14
# 13	0.10		0.13
# 14	0.10		0.11
# 15	0.10		0.10
# 16	0.10		0.10
# 17	0.44		0.31
# 18	0.27		0.20
# 19	0.16		0.18
# 20	0.13		0.15
# t = 7 was best iteration
#
#
# Linear SVM Accuracy for n=3200: 0.926
# -----------------------------------------------
# 61 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.85		0.82
# 2	0.88		0.84
# 3	0.90		0.87
# 4	0.90		0.87
# 5	0.91		0.87
# 6	0.90		0.91
# 7	0.90		0.90
# 8	0.83		0.69
# 9	0.64		0.68
# 10	0.65		0.62
# 11	0.62		0.55
# 12	0.58		0.51
# 13	0.52		0.45
# 14	0.41		0.36
# 15	0.30		0.28
# 16	0.19		0.18
# 17	0.10		0.13
# 18	0.18		0.16
# 19	0.54		0.62
# 20	0.33		0.39
# t = 6 was best iteration
#
#
# Linear SVM Accuracy for n=3200: 0.926
# -----------------------------------------------
# 62 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.86		0.82
# 2	0.88		0.85
# 3	0.89		0.84
# 4	0.90		0.86
# 5	0.91		0.87
# 6	0.90		0.88
# 7	0.90		0.92
# 8	0.83		0.86
# 9	0.53		0.41
# 10	0.53		0.40
# 11	0.51		0.34
# 12	0.48		0.33
# 13	0.47		0.35
# 14	0.44		0.35
# 15	0.38		0.31
# 16	0.32		0.27
# 17	0.23		0.21
# 18	0.13		0.15
# 19	0.10		0.10
# 20	0.26		0.40
# t = 7 was best iteration
#
#
# Linear SVM Accuracy for n=3200: 0.926
# -----------------------------------------------
# 63 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.87		0.85
# 2	0.88		0.86
# 3	0.89		0.87
# 4	0.90		0.87
# 5	0.91		0.88
# 6	0.90		0.88
# 7	0.90		0.91
# 8	0.90		0.92
# 9	0.81		0.77
# 10	0.55		0.53
# 11	0.49		0.42
# 12	0.29		0.25
# 13	0.19		0.20
# 14	0.15		0.17
# 15	0.12		0.14
# 16	0.10		0.13
# 17	0.10		0.11
# 18	0.10		0.10
# 19	0.10		0.10
# 20	0.31		0.25
# t = 8 was best iteration
#
#
# Linear SVM Accuracy for n=3200: 0.926
# -----------------------------------------------
# 64 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.86		0.84
# 2	0.88		0.85
# 3	0.90		0.86
# 4	0.90		0.86
# 5	0.91		0.87
# 6	0.90		0.89
# 7	0.90		0.92
# 8	0.90		0.88
# 9	0.40		0.43
# 10	0.44		0.40
# 11	0.38		0.31
# 12	0.25		0.22
# 13	0.18		0.19
# 14	0.14		0.16
# 15	0.11		0.14
# 16	0.10		0.10
# 17	0.10		0.09
# 18	0.47		0.42
# 19	0.33		0.29
# 20	0.25		0.25
# t = 7 was best iteration
#
#
# Linear SVM Accuracy for n=3200: 0.926
# -----------------------------------------------
# 65 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.86		0.83
# 2	0.89		0.84
# 3	0.90		0.86
# 4	0.90		0.88
# 5	0.91		0.88
# 6	0.90		0.88
# 7	0.90		0.93
# 8	0.78		0.73
# 9	0.52		0.52
# 10	0.48		0.46
# 11	0.28		0.29
# 12	0.18		0.21
# 13	0.14		0.16
# 14	0.11		0.14
# 15	0.10		0.11
# 16	0.10		0.10
# 17	0.10		0.11
# 18	0.29		0.24
# 19	0.15		0.15
# 20	0.12		0.14
# t = 7 was best iteration
#
#
# Linear SVM Accuracy for n=3200: 0.926
# -----------------------------------------------
# 66 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.87		0.82
# 2	0.88		0.84
# 3	0.90		0.86
# 4	0.90		0.88
# 5	0.91		0.88
# 6	0.91		0.89
# 7	0.90		0.90
# 8	0.61		0.57
# 9	0.57		0.54
# 10	0.52		0.44
# 11	0.39		0.33
# 12	0.32		0.30
# 13	0.26		0.27
# 14	0.22		0.22
# 15	0.16		0.18
# 16	0.13		0.15
# 17	0.10		0.12
# 18	0.10		0.10
# 19	0.20		0.28
# 20	0.45		0.33
# t = 18 was best iteration
#
#
# Linear SVM Accuracy for n=3200: 0.926
# -----------------------------------------------
# 67 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.86		0.84
# 2	0.88		0.84
# 3	0.89		0.86
# 4	0.90		0.87
# 5	0.91		0.87
# 6	0.91		0.89
# 7	0.90		0.92
# 8	0.78		0.70
# 9	0.59		0.59
# 10	0.52		0.51
# 11	0.35		0.31
# 12	0.23		0.23
# 13	0.17		0.20
# 14	0.15		0.17
# 15	0.12		0.14
# 16	0.10		0.13
# 17	0.10		0.11
# 18	0.10		0.10
# 19	0.10		0.10
# 20	0.41		0.38
# t = 7 was best iteration
#
#
# Linear SVM Accuracy for n=3200: 0.926
# -----------------------------------------------
# 68 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.86		0.84
# 2	0.88		0.85
# 3	0.90		0.87
# 4	0.91		0.88
# 5	0.91		0.89
# 6	0.90		0.91
# 7	0.90		0.90
# 8	0.65		0.64
# 9	0.49		0.44
# 10	0.40		0.34
# 11	0.20		0.21
# 12	0.14		0.17
# 13	0.11		0.14
# 14	0.10		0.12
# 15	0.10		0.10
# 16	0.10		0.10
# 17	0.42		0.41
# 18	0.16		0.18
# 19	0.11		0.14
# 20	0.10		0.13
# t = 6 was best iteration
#
#
# Linear SVM Accuracy for n=3200: 0.926
# -----------------------------------------------
# 69 / 70 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.87		0.85
# 2	0.89		0.88
# 3	0.90		0.88
# 4	0.90		0.88
# 5	0.91		0.89
# 6	0.90		0.92
# 7	0.90		0.91
# 8	0.83		0.76
# 9	0.56		0.56
# 10	0.53		0.45
# 11	0.34		0.27
# 12	0.23		0.21
# 13	0.18		0.19
# 14	0.13		0.16
# 15	0.11		0.14
# 16	0.10		0.11
# 17	0.10		0.10
# 18	0.10		0.10
# 19	0.48		0.62
# 20	0.28		0.36
# t = 6 was best iteration
#
#
# Linear SVM Accuracy for n=3200: 0.926
# -----------------------------------------------
# 70 / 70 complete
# -----------------------------------------------

# %%
# np.save('temp_arrays/n/ijcnn1', svm_arr)

# %%
ls_base = 1 - np.array([0.902, 0.912, 0.910, 0.920, 0.920, 0.920, 0.926])

# %%
from matplotlib import pyplot as plt

plt.style.use('seaborn-whitegrid')
plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams['figure.figsize'] = [5, 3]

arr = svm_arr
scale = 1

fig = plt.figure()
ax = fig.add_subplot()

NUM_REPEATS = 10

x = np.array([50, 100, 200, 400, 600, 800, 1600]) * 2
y = np.mean(arr, axis=1)

sderr = np.std(arr, axis=1)
sderr = sderr / np.sqrt(NUM_REPEATS)

ax.plot(x, y[:, 1], c='C1')
ax.fill_between(x, y[:, 1] - (sderr[:, 1] * scale), y[:, 1] + (sderr[:, 1] * scale),
             facecolors='C1', alpha=0.5)
ax.scatter(x, y[:, 1], label='PairBoost', c='C1')

ax.plot(x, ls_base, c='black')
ax.scatter(x, ls_base, label='Supervised Baseline', c='black')

ax.set_xlabel('n')
ax.set_ylabel('Classification Error')

# handles, labels = ax.get_legend_handles_labels()
ax.legend(frameon=True ,shadow=True, fancybox=True, framealpha=1.0)

fig.savefig('final_plots/n/ijcnn1.pdf', bbox_inches='tight')
