# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import sys; sys.path.insert(0,'..')
from main import *

# %%
data = pd.read_csv('../data/banana/banana.csv')
X = data[['V1', 'V2']].values
y = data['Class'].values

# Since classes are 1, 2
y = (y - 1) * 2 - 1

# %%
# from matplotlib import pyplot as plt
# plt.scatter(X[:, 0], X[:, 1], c=y, alpha=0.5, cmap='RdYlGn')

# %%
svm_arr, tree_arr = data_size_experiment(X, y, rank=True, rounded=True, plots_or_table='table', verbose=True)
# Out:
# Progress:
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.57		0.51
# 2	0.38		0.47
# 3	0.61		0.53
# 4	0.62		0.53
# 5	0.55		0.57
# 6	0.61		0.52
# 7	0.58		0.51
# 8	0.46		0.41
# 9	0.60		0.62
# 10	0.50		0.44
# 11	0.46		0.43
# 12	0.56		0.52
# 13	0.46		0.41
# 14	0.41		0.46
# 15	0.42		0.39
# 16	0.44		0.39
# 17	0.42		0.39
# 18	0.44		0.39
# 19	0.40		0.39
# 20	0.46		0.41
# t = 9 was best iteration
# Done!
#
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.72
# 2	0.29		0.30
# 3	0.71		0.71
# 4	0.71		0.71
# 5	0.60		0.58
# 6	0.66		0.63
# 7	0.69		0.67
# 8	0.65		0.62
# 9	0.68		0.65
# 10	0.63		0.61
# 11	0.62		0.59
# 12	0.63		0.61
# 13	0.62		0.58
# 14	0.62		0.58
# 15	0.60		0.56
# 16	0.59		0.56
# 17	0.59		0.56
# 18	0.57		0.55
# 19	0.58		0.53
# 20	0.58		0.55
# t = 1 was best iteration
# Done!
#
# 1
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.59		0.52
# ...

# %%
table_results(svm_arr, tree_arr)
# Out:
# (Performance on test set)
#
# 50 comparisons
# 	acc	std
# SVM: 	0.60	0.01
# Tree: 	0.68	0.02
#
# 200 comparisons
# 	acc	std
# SVM: 	0.61	0.01
# Tree: 	0.83	0.02
