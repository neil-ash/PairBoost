# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import sys; sys.path.insert(0,'..')
from main import *

# %%
data = pd.read_csv('../data/magic/magic04.data')
X = data.iloc[:, :-1].values
y  = data.iloc[:, -1].values

# %%
# Convert labels to -1, 1 and scale features
y = np.array([-1.0 if yi == 'g' else 1.0 for yi in y])

scaler = MinMaxScaler(feature_range=(0, 1))

for i in range(X.shape[1]):
    X[:, i] = scaler.fit_transform(X[:, i].reshape(-1, 1)).ravel()

# %%
svm_arr, tree_arr = data_size_experiment(X, y, rank=True, random_state=None, verbose=True)
# Out:
# Progress:
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.790		0.780
# 2	0.479		0.480
# 3	0.436		0.454
# 4	0.693		0.696
# 5	0.460		0.468
# 6	0.574		0.526
# 7	0.711		0.718
# 8	0.393		0.346
# 9	0.616		0.620
# 10	0.367		0.338
# 11	0.367		0.338
# 12	0.367		0.338
# 13	0.396		0.370
# 14	0.367		0.338
# 15	0.367		0.338
# 16	0.367		0.338
# 17	0.449		0.416
# 18	0.367		0.338
# 19	0.367		0.338
# 20	0.367		0.338
# Done!
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.836		0.804
# 2	0.164		0.202
# 3	0.836		0.800
# 4	0.164		0.202
# 5	0.836		0.798
# 6	0.164		0.200
# 7	0.836		0.798
# 8	0.836		0.800
# 9	0.164		0.200
# 10	0.834		0.794
# 11	0.834		0.796
# 12	0.834		0.792
# 13	0.834		0.794
# 14	0.834		0.794
# 15	0.834		0.794
# 16	0.834		0.792
# 17	0.834		0.794
# 18	0.834		0.794
# 19	0.847		0.796
# 20	0.849		0.800
# Done!
# 1
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.790		0.774
# 2	0.619		0.600
# 3	0.447		0.456
# 4	0.629		0.584
# 5	0.710		0.724
# 6	0.326		0.304
# 7	0.724		0.738
# 8	0.367		0.338
# 9	0.367		0.338
# 10	0.364		0.342
# 11	0.500		0.484
# 12	0.367		0.338
# 13	0.367		0.338
# 14	0.367		0.338
# 15	0.367		0.338
# 16	0.367		0.338
# 17	0.367		0.338
# 18	0.367		0.338
# 19	0.367		0.338
# 20	0.367		0.338
# Done!
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.839		0.804
# 2	0.164		0.200
# 3	0.836		0.794
# 4	0.164		0.204
# 5	0.833		0.792
# 6	0.833		0.788
# 7	0.836		0.792
# 8	0.836		0.792
# 9	0.836		0.792
# 10	0.797		0.768
# 11	0.850		0.796
# 12	0.809		0.766
# 13	0.839		0.784
# 14	0.763		0.724
# 15	0.820		0.734
# 16	0.767		0.700
# 17	0.747		0.670
# 18	0.643		0.642
# 19	0.536		0.560
# 20	0.544		0.572
# Done!
# 2
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.787		0.778
# 2	0.571		0.558
# 3	0.410		0.424
# 4	0.656		0.640
# 5	0.709		0.740
# 6	0.359		0.316
# 7	0.713		0.746
# 8	0.369		0.340
# 9	0.379		0.350
# 10	0.367		0.344
# 11	0.367		0.338
# 12	0.367		0.338
# 13	0.367		0.338
# 14	0.367		0.338
# 15	0.367		0.338
# 16	0.367		0.338
# 17	0.367		0.338
# 18	0.367		0.338
# 19	0.367		0.338
# 20	0.367		0.338
# Done!
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.841		0.802
# 2	0.164		0.198
# 3	0.841		0.802
# 4	0.167		0.192
# 5	0.841		0.800
# 6	0.167		0.202
# 7	0.841		0.800
# 8	0.169		0.202
# 9	0.841		0.800
# 10	0.164		0.200
# 11	0.841		0.800
# 12	0.166		0.200
# 13	0.841		0.802
# 14	0.164		0.204
# 15	0.837		0.794
# 16	0.837		0.794
# 17	0.836		0.796
# 18	0.836		0.800
# 19	0.834		0.802
# 20	0.837		0.798
# Done!
# 3
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.797		0.784
# 2	0.754		0.716
# 3	0.463		0.492
# 4	0.261		0.254
# 5	0.774		0.768
# 6	0.379		0.350
# 7	0.367		0.338
# 8	0.367		0.338
# 9	0.344		0.316
# 10	0.687		0.678
# 11	0.601		0.608
# 12	0.387		0.362
# 13	0.367		0.338
# 14	0.367		0.338
# 15	0.364		0.338
# 16	0.611		0.608
# 17	0.393		0.370
# 18	0.367		0.338
# 19	0.367		0.338
# 20	0.367		0.338
# Done!
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.836		0.782
# 2	0.164		0.218
# 3	0.834		0.780
# 4	0.834		0.780
# 5	0.834		0.778
# 6	0.834		0.778
# 7	0.834		0.778
# 8	0.834		0.778
# 9	0.834		0.778
# 10	0.834		0.778
# 11	0.834		0.778
# 12	0.834		0.780
# 13	0.834		0.778
# 14	0.836		0.778
# 15	0.844		0.778
# 16	0.846		0.782
# 17	0.846		0.782
# 18	0.843		0.774
# 19	0.846		0.780
# 20	0.841		0.780
# Done!
# 4
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.799		0.774
# 2	0.691		0.666
# 3	0.379		0.386
# 4	0.659		0.640
# 5	0.740		0.750
# 6	0.357		0.334
# 7	0.731		0.754
# 8	0.357		0.316
# 9	0.624		0.666
# 10	0.351		0.312
# 11	0.467		0.458
# 12	0.367		0.338
# 13	0.367		0.338
# 14	0.367		0.338
# 15	0.367		0.338
# 16	0.367		0.338
# 17	0.367		0.338
# 18	0.367		0.338
# 19	0.367		0.338
# 20	0.367		0.338
# Done!
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.829		0.802
# 2	0.171		0.192
# 3	0.821		0.798
# 4	0.821		0.798
# 5	0.850		0.802
# 6	0.839		0.798
# 7	0.849		0.800
# 8	0.846		0.800
# 9	0.857		0.798
# 10	0.843		0.796
# 11	0.857		0.802
# 12	0.831		0.794
# 13	0.857		0.780
# 14	0.846		0.794
# 15	0.864		0.776
# 16	0.843		0.770
# 17	0.840		0.756
# 18	0.836		0.742
# 19	0.843		0.748
# 20	0.824		0.752
# Done!
# 5
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.787		0.770
# 2	0.603		0.570
# 3	0.449		0.436
# 4	0.570		0.538
# 5	0.649		0.658
# 6	0.387		0.364
# 7	0.614		0.610
# 8	0.367		0.338
# 9	0.367		0.338
# 10	0.367		0.336
# 11	0.367		0.338
# 12	0.367		0.338
# 13	0.367		0.338
# 14	0.367		0.338
# 15	0.367		0.338
# 16	0.367		0.338
# 17	0.367		0.338
# 18	0.367		0.338
# 19	0.367		0.338
# 20	0.367		0.338
# Done!
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.821		0.788
# 2	0.209		0.238
# 3	0.820		0.794
# 4	0.211		0.232
# 5	0.820		0.794
# 6	0.211		0.232
# 7	0.821		0.792
# 8	0.189		0.202
# 9	0.803		0.770
# 10	0.803		0.770
# 11	0.667		0.644
# 12	0.781		0.722
# 13	0.506		0.472
# 14	0.651		0.610
# 15	0.563		0.514
# 16	0.451		0.438
# 17	0.510		0.478
# 18	0.457		0.438
# 19	0.467		0.440
# 20	0.460		0.466
# Done!
# 6
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.791		0.770
# 2	0.521		0.506
# 3	0.461		0.484
# 4	0.646		0.626
# 5	0.563		0.560
# 6	0.424		0.400
# 7	0.614		0.638
# 8	0.367		0.344
# 9	0.429		0.404
# 10	0.367		0.338
# 11	0.370		0.338
# 12	0.367		0.338
# 13	0.367		0.338
# 14	0.367		0.338
# 15	0.367		0.338
# 16	0.367		0.338
# 17	0.367		0.338
# 18	0.367		0.338
# 19	0.367		0.338
# 20	0.367		0.338
# Done!
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.834		0.800
# 2	0.166		0.198
# 3	0.834		0.802
# 4	0.167		0.198
# 5	0.834		0.800
# 6	0.796		0.754
# 7	0.849		0.802
# 8	0.846		0.806
# 9	0.856		0.798
# 10	0.819		0.770
# 11	0.856		0.784
# 12	0.829		0.762
# 13	0.844		0.780
# 14	0.807		0.740
# 15	0.729		0.694
# 16	0.773		0.710
# 17	0.350		0.374
# 18	0.650		0.624
# 19	0.350		0.376
# 20	0.654		0.620
# Done!
# 7
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.794		0.768
# 2	0.660		0.628
# 3	0.530		0.532
# 4	0.336		0.310
# 5	0.729		0.748
# 6	0.367		0.338
# 7	0.367		0.338
# 8	0.377		0.348
# 9	0.370		0.338
# 10	0.367		0.338
# 11	0.367		0.338
# 12	0.367		0.338
# 13	0.367		0.338
# 14	0.367		0.338
# 15	0.367		0.338
# 16	0.367		0.338
# 17	0.367		0.338
# 18	0.367		0.338
# 19	0.367		0.338
# 20	0.367		0.338
# Done!
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.821		0.794
# 2	0.176		0.202
# 3	0.817		0.796
# 4	0.817		0.796
# 5	0.836		0.788
# 6	0.833		0.782
# 7	0.849		0.794
# 8	0.849		0.788
# 9	0.846		0.800
# 10	0.847		0.800
# 11	0.844		0.796
# 12	0.836		0.798
# 13	0.850		0.798
# 14	0.841		0.794
# 15	0.840		0.796
# 16	0.839		0.786
# 17	0.834		0.790
# 18	0.836		0.780
# 19	0.841		0.766
# 20	0.831		0.766
# Done!
# 8
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.786		0.766
# 2	0.643		0.612
# 3	0.416		0.426
# 4	0.651		0.620
# 5	0.736		0.750
# 6	0.301		0.292
# 7	0.733		0.748
# 8	0.371		0.340
# 9	0.367		0.338
# 10	0.367		0.338
# 11	0.367		0.338
# 12	0.383		0.366
# 13	0.367		0.338
# 14	0.367		0.338
# 15	0.367		0.338
# 16	0.366		0.338
# 17	0.369		0.338
# 18	0.367		0.338
# 19	0.367		0.338
# 20	0.367		0.338
# Done!
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.829		0.776
# 2	0.170		0.212
# 3	0.827		0.774
# 4	0.827		0.774
# 5	0.827		0.774
# 6	0.833		0.798
# 7	0.834		0.790
# 8	0.841		0.794
# 9	0.839		0.788
# 10	0.836		0.798
# 11	0.839		0.792
# 12	0.841		0.792
# 13	0.843		0.794
# 14	0.849		0.792
# 15	0.847		0.784
# 16	0.847		0.794
# 17	0.846		0.792
# 18	0.851		0.790
# 19	0.846		0.786
# 20	0.851		0.790
# Done!
# 9
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.786		0.772
# 2	0.553		0.510
# 3	0.430		0.462
# 4	0.654		0.612
# 5	0.756		0.758
# 6	0.367		0.334
# 7	0.730		0.758
# 8	0.444		0.442
# 9	0.367		0.338
# 10	0.367		0.338
# 11	0.367		0.338
# 12	0.456		0.438
# 13	0.367		0.338
# 14	0.367		0.338
# 15	0.367		0.338
# 16	0.367		0.338
# 17	0.363		0.334
# 18	0.367		0.338
# 19	0.367		0.338
# 20	0.367		0.338
# Done!
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.837		0.798
# 2	0.167		0.198
# 3	0.837		0.786
# 4	0.633		0.664
# 5	0.633		0.664
# 6	0.633		0.664
# 7	0.633		0.664
# 8	0.633		0.664
# 9	0.633		0.664
# 10	0.633		0.664
# 11	0.633		0.664
# 12	0.633		0.664
# 13	0.633		0.664
# 14	0.633		0.664
# 15	0.633		0.664
# 16	0.633		0.664
# 17	0.633		0.664
# 18	0.633		0.664
# 19	0.633		0.664
# 20	0.633		0.664
# Done!
# 10

# %%
svm_arr, tree_arr
# Out:
# (array([[[0.63285714, 0.662     ],
#          [0.63285714, 0.662     ],
#          [0.63285714, 0.662     ],
#          [0.63285714, 0.662     ],
#          [0.63285714, 0.662     ],
#          [0.63285714, 0.662     ],
#          [0.63285714, 0.662     ],
#          [0.63285714, 0.662     ],
#          [0.63285714, 0.662     ],
#          [0.63285714, 0.662     ]]]),
#  array([[[0.15142857, 0.2       ],
#          [0.45571429, 0.428     ],
#          [0.16285714, 0.202     ],
#          [0.15857143, 0.22      ],
#          [0.17571429, 0.248     ],
#          [0.54      , 0.534     ],
#          [0.34571429, 0.38      ],
#          [0.16857143, 0.234     ],
#          [0.14857143, 0.21      ],
#          [0.36714286, 0.336     ]]]))

# %%
np.min(svm_arr[:, :, 1]), np.min(tree_arr[:, :, 1])
# Out:
# (0.6619999999999999, 0.19999999999999996)
