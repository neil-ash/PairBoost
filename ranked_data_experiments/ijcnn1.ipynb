# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_svmlight_file
from sklearn.model_selection import train_test_split
import sys; sys.path.insert(0,'..')
from main import *

# %%
X_train, y_train = load_svmlight_file('../data/ijcnn1/ijcnn1.tr')
X_train = X_train.toarray()

X_test, y_test = load_svmlight_file('../data/ijcnn1/ijcnn1.t')
X_test = X_test.toarray()

# %%
svm_arr, tree_arr = data_size_experiment(X_train, y_train, rank=True, random_state=None, verbose=True)
# Out:
# Progress:
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.743		0.740
# 2	0.354		0.374
# 3	0.707		0.690
# 4	0.754		0.766
# 5	0.491		0.480
# 6	0.657		0.652
# 7	0.757		0.752
# 8	0.476		0.500
# 9	0.586		0.576
# 10	0.633		0.620
# 11	0.377		0.396
# 12	0.480		0.466
# 13	0.370		0.390
# 14	0.521		0.494
# 15	0.331		0.338
# 16	0.496		0.482
# 17	0.477		0.494
# 18	0.519		0.504
# 19	0.477		0.492
# 20	0.519		0.504
# Done!
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.690		0.634
# 2	0.316		0.362
# 3	0.686		0.636
# 4	0.689		0.644
# 5	0.771		0.744
# 6	0.720		0.686
# 7	0.787		0.746
# 8	0.793		0.716
# 9	0.847		0.794
# 10	0.867		0.786
# 11	0.887		0.822
# 12	0.883		0.812
# 13	0.883		0.836
# 14	0.884		0.824
# 15	0.884		0.836
# 16	0.903		0.840
# 17	0.917		0.844
# 18	0.919		0.842
# 19	0.916		0.828
# 20	0.917		0.834
# Done!
# 1
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.746		0.736
# 2	0.286		0.318
# 3	0.737		0.710
# 4	0.799		0.796
# 5	0.639		0.632
# 6	0.591		0.620
# 7	0.787		0.772
# 8	0.483		0.498
# 9	0.649		0.646
# 10	0.407		0.412
# 11	0.604		0.592
# 12	0.704		0.714
# 13	0.709		0.730
# 14	0.466		0.512
# 15	0.663		0.652
# 16	0.449		0.460
# 17	0.606		0.578
# 18	0.484		0.472
# 19	0.513		0.502
# 20	0.476		0.464
# Done!
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.736		0.688
# 2	0.267		0.314
# 3	0.733		0.682
# 4	0.267		0.314
# 5	0.730		0.676
# 6	0.730		0.676
# 7	0.730		0.676
# 8	0.730		0.676
# 9	0.730		0.676
# 10	0.434		0.420
# 11	0.704		0.642
# 12	0.437		0.418
# 13	0.657		0.618
# 14	0.456		0.440
# 15	0.600		0.580
# 16	0.386		0.370
# 17	0.531		0.510
# 18	0.293		0.298
# 19	0.449		0.440
# 20	0.394		0.404
# Done!
# 2
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.743		0.732
# 2	0.303		0.322
# 3	0.717		0.704
# 4	0.753		0.746
# 5	0.584		0.588
# 6	0.647		0.638
# 7	0.779		0.772
# 8	0.479		0.470
# 9	0.573		0.590
# 10	0.474		0.486
# 11	0.524		0.498
# 12	0.406		0.426
# 13	0.491		0.480
# 14	0.463		0.472
# 15	0.493		0.480
# 16	0.346		0.354
# 17	0.500		0.480
# 18	0.401		0.406
# 19	0.496		0.474
# 20	0.356		0.346
# Done!
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.710		0.654
# 2	0.283		0.344
# 3	0.699		0.654
# 4	0.701		0.654
# 5	0.711		0.640
# 6	0.724		0.634
# 7	0.720		0.636
# 8	0.624		0.544
# 9	0.524		0.486
# 10	0.436		0.420
# 11	0.434		0.428
# 12	0.331		0.332
# 13	0.316		0.328
# 14	0.241		0.286
# 15	0.247		0.290
# 16	0.147		0.210
# 17	0.131		0.194
# 18	0.111		0.180
# 19	0.107		0.166
# 20	0.096		0.158
# Done!
# 3
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.736		0.728
# 2	0.316		0.316
# 3	0.706		0.684
# 4	0.641		0.642
# 5	0.526		0.512
# 6	0.541		0.562
# 7	0.550		0.520
# 8	0.513		0.538
# 9	0.523		0.494
# 10	0.511		0.536
# 11	0.507		0.478
# 12	0.486		0.502
# 13	0.484		0.456
# 14	0.337		0.350
# 15	0.236		0.208
# 16	0.454		0.424
# 17	0.293		0.258
# 18	0.326		0.330
# 19	0.299		0.266
# 20	0.357		0.372
# Done!
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.754		0.716
# 2	0.259		0.282
# 3	0.750		0.716
# 4	0.759		0.734
# 5	0.759		0.734
# 6	0.867		0.798
# 7	0.890		0.824
# 8	0.921		0.862
# 9	0.926		0.862
# 10	0.934		0.874
# 11	0.937		0.870
# 12	0.936		0.884
# 13	0.937		0.886
# 14	0.939		0.900
# 15	0.944		0.888
# 16	0.950		0.894
# 17	0.947		0.894
# 18	0.941		0.904
# 19	0.936		0.902
# 20	0.937		0.902
# Done!
# 4
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.743		0.732
# 2	0.319		0.334
# 3	0.694		0.690
# 4	0.720		0.728
# 5	0.509		0.478
# 6	0.633		0.676
# 7	0.741		0.700
# 8	0.511		0.560
# 9	0.613		0.586
# 10	0.587		0.618
# 11	0.533		0.524
# 12	0.546		0.568
# 13	0.540		0.530
# 14	0.550		0.570
# 15	0.564		0.540
# 16	0.583		0.608
# 17	0.517		0.498
# 18	0.593		0.610
# 19	0.499		0.476
# 20	0.597		0.610
# Done!
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.684		0.642
# 2	0.307		0.324
# 3	0.684		0.642
# 4	0.311		0.334
# 5	0.683		0.644
# 6	0.684		0.644
# 7	0.800		0.748
# 8	0.800		0.746
# 9	0.807		0.760
# 10	0.801		0.756
# 11	0.834		0.784
# 12	0.814		0.780
# 13	0.826		0.778
# 14	0.830		0.788
# 15	0.837		0.774
# 16	0.837		0.784
# 17	0.840		0.780
# 18	0.830		0.778
# 19	0.844		0.774
# 20	0.831		0.772
# Done!
# 5
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.751		0.742
# 2	0.307		0.318
# 3	0.733		0.708
# 4	0.773		0.774
# 5	0.576		0.550
# 6	0.669		0.694
# 7	0.810		0.810
# 8	0.576		0.578
# 9	0.576		0.544
# 10	0.710		0.718
# 11	0.519		0.504
# 12	0.580		0.606
# 13	0.503		0.490
# 14	0.540		0.538
# 15	0.534		0.494
# 16	0.534		0.576
# 17	0.386		0.368
# 18	0.493		0.520
# 19	0.431		0.390
# 20	0.473		0.464
# Done!
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.746		0.696
# 2	0.263		0.310
# 3	0.737		0.692
# 4	0.270		0.326
# 5	0.737		0.690
# 6	0.271		0.326
# 7	0.730		0.674
# 8	0.273		0.326
# 9	0.730		0.674
# 10	0.271		0.326
# 11	0.736		0.688
# 12	0.273		0.328
# 13	0.731		0.684
# 14	0.731		0.684
# 15	0.731		0.684
# 16	0.739		0.684
# 17	0.731		0.684
# 18	0.734		0.684
# 19	0.694		0.670
# 20	0.464		0.466
# Done!
# 6
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.741		0.728
# 2	0.321		0.336
# 3	0.720		0.706
# 4	0.757		0.748
# 5	0.567		0.538
# 6	0.569		0.606
# 7	0.680		0.684
# 8	0.434		0.446
# 9	0.639		0.626
# 10	0.420		0.446
# 11	0.514		0.520
# 12	0.377		0.400
# 13	0.444		0.434
# 14	0.341		0.342
# 15	0.419		0.394
# 16	0.286		0.294
# 17	0.297		0.288
# 18	0.383		0.382
# 19	0.331		0.324
# 20	0.316		0.328
# Done!
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.679		0.634
# 2	0.329		0.378
# 3	0.679		0.636
# 4	0.334		0.384
# 5	0.673		0.630
# 6	0.911		0.916
# 7	0.911		0.916
# 8	0.911		0.916
# 9	0.911		0.916
# 10	0.911		0.916
# 11	0.911		0.916
# 12	0.911		0.916
# 13	0.911		0.916
# 14	0.911		0.916
# 15	0.911		0.916
# 16	0.911		0.916
# 17	0.911		0.916
# 18	0.911		0.916
# 19	0.911		0.916
# 20	0.911		0.916
# Done!
# 7
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.731		0.730
# 2	0.340		0.336
# 3	0.704		0.686
# 4	0.764		0.794
# 5	0.566		0.552
# 6	0.523		0.572
# 7	0.614		0.586
# 8	0.443		0.484
# 9	0.609		0.582
# 10	0.471		0.502
# 11	0.593		0.560
# 12	0.583		0.600
# 13	0.526		0.510
# 14	0.544		0.566
# 15	0.514		0.480
# 16	0.520		0.546
# 17	0.511		0.478
# 18	0.514		0.530
# 19	0.500		0.460
# 20	0.491		0.504
# Done!
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.700		0.634
# 2	0.303		0.368
# 3	0.701		0.636
# 4	0.910		0.914
# 5	0.910		0.914
# 6	0.910		0.914
# 7	0.910		0.914
# 8	0.910		0.914
# 9	0.910		0.914
# 10	0.910		0.914
# 11	0.910		0.914
# 12	0.910		0.914
# 13	0.910		0.914
# 14	0.910		0.914
# 15	0.910		0.914
# 16	0.910		0.914
# 17	0.910		0.914
# 18	0.910		0.914
# 19	0.910		0.914
# 20	0.910		0.914
# Done!
# 8
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.746		0.734
# 2	0.333		0.330
# 3	0.710		0.694
# 4	0.689		0.712
# 5	0.464		0.448
# 6	0.581		0.618
# 7	0.514		0.476
# 8	0.409		0.456
# 9	0.551		0.494
# 10	0.323		0.336
# 11	0.451		0.412
# 12	0.350		0.380
# 13	0.450		0.410
# 14	0.403		0.448
# 15	0.443		0.412
# 16	0.474		0.494
# 17	0.379		0.378
# 18	0.226		0.236
# 19	0.427		0.396
# 20	0.187		0.182
# Done!
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.684		0.630
# 2	0.317		0.370
# 3	0.683		0.632
# 4	0.331		0.380
# 5	0.331		0.380
# 6	0.751		0.714
# 7	0.751		0.712
# 8	0.803		0.746
# 9	0.814		0.750
# 10	0.839		0.778
# 11	0.833		0.756
# 12	0.824		0.754
# 13	0.840		0.766
# 14	0.844		0.772
# 15	0.850		0.772
# 16	0.851		0.768
# 17	0.856		0.772
# 18	0.840		0.750
# 19	0.837		0.730
# 20	0.853		0.748
# Done!
# 9
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.740		0.732
# 2	0.311		0.318
# 3	0.721		0.696
# 4	0.744		0.732
# 5	0.526		0.510
# 6	0.636		0.632
# 7	0.781		0.762
# 8	0.576		0.568
# 9	0.651		0.600
# 10	0.726		0.722
# 11	0.499		0.496
# 12	0.594		0.590
# 13	0.599		0.614
# 14	0.530		0.522
# 15	0.609		0.590
# 16	0.434		0.450
# 17	0.574		0.558
# 18	0.463		0.462
# 19	0.541		0.510
# 20	0.470		0.474
# Done!
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 4
# t	Train		Test
# 1	0.701		0.644
# 2	0.286		0.334
# 3	0.700		0.646
# 4	0.703		0.660
# 5	0.703		0.650
# 6	0.797		0.730
# 7	0.774		0.704
# 8	0.771		0.704
# 9	0.799		0.738
# 10	0.806		0.752
# 11	0.810		0.760
# 12	0.824		0.768
# 13	0.824		0.770
# 14	0.839		0.780
# 15	0.843		0.776
# 16	0.839		0.774
# 17	0.844		0.772
# 18	0.844		0.782
# 19	0.831		0.768
# 20	0.833		0.770
# Done!
# 10

# %%
np.min(svm_arr[:, :, 1]), np.min(tree_arr[:, :, 1])
# Out:
# (0.39, 0.08399999999999996)

# %%
svm_arr, tree_arr
# Out:
# (array([[[0.48142857, 0.496     ],
#          [0.52428571, 0.536     ],
#          [0.64428571, 0.654     ],
#          [0.64285714, 0.628     ],
#          [0.40285714, 0.39      ],
#          [0.52714286, 0.536     ],
#          [0.68428571, 0.672     ],
#          [0.50857143, 0.496     ],
#          [0.81285714, 0.818     ],
#          [0.53      , 0.526     ]]]),
#  array([[[0.08285714, 0.166     ],
#          [0.60571429, 0.596     ],
#          [0.90428571, 0.842     ],
#          [0.06285714, 0.098     ],
#          [0.16857143, 0.228     ],
#          [0.53571429, 0.534     ],
#          [0.08857143, 0.084     ],
#          [0.09      , 0.086     ],
#          [0.14714286, 0.252     ],
#          [0.16714286, 0.23      ]]]))

# %%
baselines(X_train, y_train, X_test, y_test)
# Out:
# BASELINES ACCURACIES
# Guess Majority:	 0.905
# KNN:		 0.963
# Linear SVM:	 0.913
# Random Forest:	 0.905
# XGBoost:	 0.937
