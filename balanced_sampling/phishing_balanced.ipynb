# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_svmlight_file
from sklearn.model_selection import train_test_split
import sys; sys.path.insert(0,'..')
from main import *

# %%
X, y = load_svmlight_file('../data/phishing/phishing.txt')
X = X.toarray()

# Convert labels from {0, 1} to {-1, 1}
y = y * 2 - 1

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.5, stratify=y, 
                                                    shuffle=True, random_state=1)

# %%
SL, DH, PB = prior_comparison_experiment(X_train, y_train, X_test, y_test, prior=0.5)
# Out:
# ----- SU -----
# Estimated prior: 0.54
#
# SL
# SU accuracy: 0.54
#
# DH
# SU accuracy: 0.50
#
# ----- PairBoost -----
# PRELIMINARY
# Training accuracy of supervised SVM: 0.93
#
# GENERATE W
# [[-1. -1.]
#  [-1.  1.]
#  [ 1. -1.]
#  [ 1.  1.]] [143 110 126 121]
# Training accuracy of pairwise rank SVM: 0.95
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.90
# 2	0.93		0.90
# 3	0.93		0.90
# 4	0.93		0.90
# 5	0.93		0.90
# 6	0.93		0.90
# 7	0.93		0.90
# 8	0.93		0.90
# 9	0.93		0.90
# 10	0.93		0.90
# 11	0.93		0.90
# 12	0.93		0.90
# 13	0.93		0.90
# 14	0.93		0.90
# 15	0.93		0.90
# 16	0.93		0.90
# 17	0.93		0.90
# 18	0.93		0.90
# 19	0.93		0.90
# 20	0.93		0.90
# t = 1 was best iteration with accuracy 0.90
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.90
# 2	0.92		0.90
# 3	0.93		0.90
# 4	0.93		0.90
# 5	0.93		0.90
# 6	0.93		0.90
# 7	0.93		0.90
# 8	0.93		0.90
# 9	0.93		0.90
# 10	0.93		0.90
# 11	0.93		0.90
# 12	0.93		0.90
# 13	0.93		0.90
# 14	0.93		0.90
# 15	0.93		0.90
# 16	0.93		0.90
# 17	0.93		0.90
# 18	0.93		0.90
# 19	0.93		0.90
# 20	0.93		0.90
# t = 1 was best iteration with accuracy 0.90
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.94		0.90
# 2	0.93		0.90
# 3	0.93		0.90
# 4	0.93		0.90
# 5	0.93		0.90
# 6	0.93		0.90
# 7	0.93		0.90
# 8	0.93		0.90
# 9	0.93		0.90
# 10	0.93		0.90
# 11	0.93		0.90
# 12	0.93		0.90
# 13	0.93		0.90
# 14	0.93		0.90
# 15	0.93		0.90
# 16	0.93		0.90
# 17	0.93		0.90
# 18	0.93		0.90
# 19	0.93		0.90
# 20	0.93		0.90
# t = 1 was best iteration with accuracy 0.90
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.92		0.90
# 2	0.93		0.90
# 3	0.93		0.90
# 4	0.93		0.90
# 5	0.93		0.90
# 6	0.93		0.90
# 7	0.93		0.90
# 8	0.93		0.90
# 9	0.94		0.90
# 10	0.93		0.90
# 11	0.93		0.90
# 12	0.93		0.90
# 13	0.93		0.90
# 14	0.93		0.90
# 15	0.93		0.90
# 16	0.93		0.90
# 17	0.93		0.90
# 18	0.93		0.90
# 19	0.93		0.90
# 20	0.93		0.90
# t = 9 was best iteration with accuracy 0.90
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.90
# 2	0.93		0.89
# 3	0.93		0.90
# 4	0.93		0.90
# 5	0.93		0.90
# 6	0.93		0.90
# 7	0.94		0.90
# 8	0.93		0.90
# 9	0.93		0.90
# 10	0.93		0.90
# 11	0.93		0.90
# 12	0.93		0.90
# 13	0.93		0.90
# 14	0.93		0.90
# 15	0.93		0.90
# 16	0.93		0.90
# 17	0.93		0.90
# 18	0.93		0.90
# 19	0.93		0.90
# 20	0.93		0.90
# t = 7 was best iteration with accuracy 0.90
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.91
# 2	0.93		0.90
# 3	0.93		0.90
# 4	0.93		0.90
# 5	0.93		0.90
# 6	0.93		0.90
# 7	0.93		0.90
# 8	0.93		0.90
# 9	0.93		0.90
# 10	0.93		0.90
# 11	0.93		0.90
# 12	0.93		0.90
# 13	0.93		0.90
# 14	0.93		0.90
# 15	0.93		0.90
# 16	0.93		0.90
# 17	0.93		0.90
# 18	0.93		0.90
# 19	0.93		0.90
# 20	0.93		0.90
# t = 1 was best iteration with accuracy 0.91
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.90
# 2	0.93		0.90
# 3	0.93		0.90
# 4	0.93		0.90
# 5	0.93		0.90
# 6	0.93		0.90
# 7	0.93		0.90
# 8	0.93		0.90
# 9	0.93		0.90
# 10	0.93		0.90
# 11	0.93		0.90
# 12	0.93		0.90
# 13	0.93		0.90
# 14	0.93		0.90
# 15	0.93		0.90
# 16	0.93		0.90
# 17	0.93		0.90
# 18	0.93		0.90
# 19	0.93		0.90
# 20	0.93		0.90
# t = 16 was best iteration with accuracy 0.90
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.91
# 2	0.93		0.90
# 3	0.93		0.90
# 4	0.93		0.90
# 5	0.93		0.90
# 6	0.93		0.90
# 7	0.93		0.90
# 8	0.93		0.90
# 9	0.93		0.90
# 10	0.93		0.90
# 11	0.93		0.90
# 12	0.93		0.90
# 13	0.93		0.90
# 14	0.93		0.90
# 15	0.93		0.90
# 16	0.93		0.90
# 17	0.93		0.90
# 18	0.93		0.90
# 19	0.93		0.90
# 20	0.93		0.90
# t = 6 was best iteration with accuracy 0.90
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.90
# 2	0.93		0.89
# 3	0.93		0.90
# 4	0.93		0.90
# 5	0.93		0.90
# 6	0.93		0.90
# 7	0.93		0.89
# 8	0.93		0.89
# 9	0.93		0.89
# 10	0.93		0.89
# 11	0.93		0.90
# 12	0.93		0.90
# 13	0.93		0.90
# 14	0.93		0.90
# 15	0.93		0.90
# 16	0.93		0.90
# 17	0.93		0.90
# 18	0.93		0.90
# 19	0.93		0.90
# 20	0.93		0.90
# t = 1 was best iteration with accuracy 0.90
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.90
# 2	0.93		0.90
# 3	0.93		0.90
# 4	0.93		0.90
# 5	0.93		0.90
# 6	0.92		0.90
# 7	0.93		0.90
# 8	0.93		0.90
# 9	0.93		0.90
# 10	0.93		0.90
# 11	0.93		0.90
# 12	0.93		0.90
# 13	0.93		0.90
# 14	0.93		0.90
# 15	0.93		0.90
# 16	0.93		0.90
# 17	0.93		0.90
# 18	0.93		0.90
# 19	0.93		0.90
# 20	0.93		0.90
# t = 1 was best iteration with accuracy 0.90

# %%
prior_results(SL, DH, PB)
# Out:
# SL: 0.536
# DH: 0.500
# PB: 0.902
