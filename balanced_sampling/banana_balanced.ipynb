# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import sys; sys.path.insert(0,'..')
from main import *

# %%
data = pd.read_csv('../data/banana/banana.csv')
X = data[['V1', 'V2']].values
y = data['Class'].values

# Since classes are 1, 2
y = (y - 1) * 2 - 1

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.5, stratify=y, 
                                                    shuffle=True, random_state=1)

# %%
SL, DH, PB = prior_comparison_experiment(X_train, y_train, X_test, y_test, prior=0.5)
# Out:
# ----- SU -----
# Estimated prior: 0.54
#
# SL
# SU accuracy: 0.59
#
# DH
# SU accuracy: 0.50
#
# ----- PairBoost -----
# PRELIMINARY
# Training accuracy of supervised SVM: 0.50
#
# GENERATE W
# [[-1. -1.]
#  [-1.  1.]
#  [ 1. -1.]
#  [ 1.  1.]] [131 113 109 147]
# Training accuracy of pairwise rank SVM: 1.00
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.50		0.48
# 2	0.50		0.49
# 3	0.50		0.49
# 4	0.50		0.49
# 5	0.50		0.49
# 6	0.50		0.49
# 7	0.50		0.49
# 8	0.50		0.49
# 9	0.50		0.49
# 10	0.50		0.49
# 11	0.50		0.49
# 12	0.50		0.49
# 13	0.50		0.49
# 14	0.50		0.49
# 15	0.50		0.49
# 16	0.50		0.49
# 17	0.50		0.49
# 18	0.50		0.49
# 19	0.50		0.49
# 20	0.50		0.49
# t = 3 was best iteration with accuracy 0.51
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.50		0.49
# 2	0.50		0.49
# 3	0.50		0.49
# 4	0.50		0.49
# 5	0.50		0.48
# 6	0.50		0.48
# 7	0.50		0.48
# 8	0.50		0.48
# 9	0.50		0.49
# 10	0.50		0.49
# 11	0.50		0.49
# 12	0.50		0.49
# 13	0.50		0.49
# 14	0.50		0.49
# 15	0.50		0.49
# 16	0.50		0.49
# 17	0.50		0.49
# 18	0.50		0.49
# 19	0.50		0.49
# 20	0.50		0.49
# t = 1 was best iteration with accuracy 0.51
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.50		0.48
# 2	0.50		0.48
# 3	0.50		0.48
# 4	0.50		0.49
# 5	0.50		0.48
# 6	0.50		0.49
# 7	0.50		0.49
# 8	0.50		0.49
# 9	0.50		0.49
# 10	0.50		0.49
# 11	0.50		0.49
# 12	0.50		0.49
# 13	0.50		0.49
# 14	0.50		0.49
# 15	0.50		0.49
# 16	0.50		0.49
# 17	0.50		0.49
# 18	0.50		0.49
# 19	0.50		0.49
# 20	0.50		0.49
# t = 10 was best iteration with accuracy 0.51
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.50		0.48
# 2	0.50		0.49
# 3	0.50		0.49
# 4	0.50		0.49
# 5	0.50		0.49
# 6	0.50		0.49
# 7	0.50		0.49
# 8	0.50		0.49
# 9	0.50		0.49
# 10	0.50		0.49
# 11	0.50		0.49
# 12	0.50		0.49
# 13	0.50		0.49
# 14	0.50		0.49
# 15	0.50		0.49
# 16	0.50		0.49
# 17	0.50		0.49
# 18	0.50		0.49
# 19	0.50		0.49
# 20	0.50		0.49
# t = 2 was best iteration with accuracy 0.51
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.50		0.49
# 2	0.50		0.48
# 3	0.50		0.48
# 4	0.50		0.48
# 5	0.50		0.49
# 6	0.50		0.49
# 7	0.50		0.49
# 8	0.50		0.49
# 9	0.50		0.49
# 10	0.50		0.49
# 11	0.50		0.49
# 12	0.50		0.49
# 13	0.50		0.49
# 14	0.50		0.49
# 15	0.50		0.49
# 16	0.50		0.49
# 17	0.50		0.49
# 18	0.50		0.49
# 19	0.50		0.49
# 20	0.50		0.49
# t = 6 was best iteration with accuracy 0.51
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.50		0.49
# 2	0.50		0.49
# 3	0.50		0.49
# 4	0.50		0.49
# 5	0.50		0.49
# 6	0.50		0.49
# 7	0.50		0.49
# 8	0.50		0.49
# 9	0.50		0.49
# 10	0.50		0.49
# 11	0.50		0.49
# 12	0.50		0.49
# 13	0.50		0.49
# 14	0.50		0.49
# 15	0.50		0.49
# 16	0.50		0.49
# 17	0.50		0.49
# 18	0.50		0.49
# 19	0.50		0.49
# 20	0.50		0.49
# t = 1 was best iteration with accuracy 0.51
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.49		0.50
# 2	0.50		0.49
# 3	0.50		0.49
# 4	0.50		0.49
# 5	0.50		0.49
# 6	0.50		0.49
# 7	0.50		0.49
# 8	0.50		0.49
# 9	0.50		0.49
# 10	0.50		0.49
# 11	0.50		0.49
# 12	0.50		0.49
# 13	0.50		0.49
# 14	0.50		0.49
# 15	0.50		0.49
# 16	0.50		0.49
# 17	0.50		0.49
# 18	0.50		0.49
# 19	0.50		0.49
# 20	0.50		0.49
# t = 1 was best iteration with accuracy 0.50
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.51		0.50
# 2	0.50		0.50
# 3	0.50		0.49
# 4	0.50		0.49
# 5	0.50		0.49
# 6	0.50		0.49
# 7	0.50		0.49
# 8	0.50		0.49
# 9	0.50		0.49
# 10	0.50		0.49
# 11	0.50		0.49
# 12	0.50		0.49
# 13	0.50		0.49
# 14	0.50		0.49
# 15	0.50		0.49
# 16	0.50		0.49
# 17	0.50		0.49
# 18	0.50		0.49
# 19	0.50		0.49
# 20	0.50		0.49
# t = 1 was best iteration with accuracy 0.50
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.50		0.49
# 2	0.50		0.49
# 3	0.50		0.49
# 4	0.50		0.49
# 5	0.50		0.49
# 6	0.50		0.49
# 7	0.50		0.49
# 8	0.50		0.49
# 9	0.50		0.49
# 10	0.50		0.49
# 11	0.50		0.49
# 12	0.50		0.49
# 13	0.50		0.49
# 14	0.50		0.49
# 15	0.50		0.49
# 16	0.50		0.49
# 17	0.50		0.49
# 18	0.50		0.49
# 19	0.50		0.49
# 20	0.50		0.49
# t = 2 was best iteration with accuracy 0.51
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.50		0.49
# 2	0.50		0.49
# 3	0.50		0.49
# 4	0.50		0.48
# 5	0.50		0.48
# 6	0.50		0.48
# 7	0.50		0.48
# 8	0.50		0.48
# 9	0.50		0.49
# 10	0.50		0.49
# 11	0.50		0.49
# 12	0.50		0.49
# 13	0.50		0.49
# 14	0.50		0.49
# 15	0.50		0.49
# 16	0.50		0.49
# 17	0.50		0.49
# 18	0.50		0.49
# 19	0.50		0.49
# 20	0.50		0.49
# t = 1 was best iteration with accuracy 0.51

# %%
prior_results(SL, DH, PB)
# Out:
# SL: 0.586
# DH: 0.500
# PB: 0.511
