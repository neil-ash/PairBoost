# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import sys; sys.path.insert(0,'..')
from main import *

# %%
data = pd.read_csv('../data/magic/magic04.data')
X = data.iloc[:, :-1].values
y  = data.iloc[:, -1].values

# %%
# Convert labels to -1, 1 and scale features
y = np.array([-1.0 if yi == 'g' else 1.0 for yi in y])

scaler = MinMaxScaler(feature_range=(0, 1))

for i in range(X.shape[1]):
    X[:, i] = scaler.fit_transform(X[:, i].reshape(-1, 1)).ravel()
    
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.5, stratify=y, 
                                                    shuffle=True, random_state=1)

# %%
svm_arr, tree_arr = data_size_experiment(X_train, y_train, X_test, y_test,
                                         experiment_type='table', kernel='linear',
                                         random_state=1, verbose=True)
# Out:
# PRELIMINARY
# Training accuracy of supervised SVM: 0.78
#
# GENERATE W
# [[-1. -1.]
#  [-1.  1.]
#  [ 1. -1.]
#  [ 1.  1.]] [19  6 17  8]
# Training accuracy of pairwise rank SVM: 0.88
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.51		0.73		0.76
# 2	0.47		0.74		0.77
# 3	0.47		0.74		0.77
# 4	0.50		0.74		0.77
# 5	0.49		0.74		0.77
# 6	0.49		0.74		0.77
# 7	0.49		0.74		0.77
# 8	0.50		0.74		0.77
# 9	0.47		0.74		0.77
# 10	0.46		0.74		0.77
# 11	0.52		0.74		0.77
# 12	0.46		0.74		0.77
# 13	0.48		0.74		0.77
# 14	0.50		0.74		0.77
# 15	0.47		0.73		0.77
# 16	0.49		0.73		0.77
# 17	0.49		0.73		0.77
# 18	0.52		0.73		0.77
# 19	0.50		0.73		0.77
# 20	0.51		0.73		0.77
# t = 3 was best iteration with accuracy 0.77
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.49		0.73		0.76
# 2	0.32		0.51		0.46
# 3	0.37		0.73		0.73
# 4	0.53		0.73		0.73
# 5	0.41		0.71		0.73
# 6	0.46		0.71		0.72
# 7	0.42		0.71		0.72
# 8	0.43		0.71		0.73
# 9	0.49		0.71		0.73
# 10	0.53		0.72		0.73
# 11	0.49		0.72		0.73
# 12	0.49		0.73		0.73
# 13	0.48		0.72		0.74
# 14	0.50		0.73		0.74
# 15	0.45		0.73		0.75
# 16	0.49		0.73		0.73
# 17	0.47		0.73		0.73
# 18	0.46		0.73		0.74
# 19	0.46		0.73		0.73
# 20	0.47		0.73		0.74
# t = 17 was best iteration with accuracy 0.73
#
# -----------------------------------------------
# 1 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.50		0.74		0.78
# 2	0.49		0.73		0.78
# 3	0.51		0.74		0.78
# 4	0.48		0.73		0.78
# 5	0.51		0.73		0.78
# 6	0.46		0.74		0.78
# 7	0.51		0.74		0.77
# 8	0.48		0.74		0.78
# 9	0.46		0.74		0.78
# 10	0.52		0.74		0.78
# 11	0.49		0.74		0.78
# 12	0.48		0.74		0.78
# 13	0.49		0.74		0.78
# 14	0.50		0.74		0.78
# 15	0.51		0.74		0.78
# 16	0.49		0.74		0.77
# 17	0.50		0.73		0.78
# 18	0.47		0.74		0.77
# 19	0.45		0.74		0.78
# 20	0.47		0.74		0.78
# t = 1 was best iteration with accuracy 0.78
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.49		0.74		0.75
# 2	0.35		0.48		0.44
# 3	0.38		0.70		0.70
# 4	0.49		0.70		0.73
# 5	0.37		0.69		0.70
# 6	0.43		0.69		0.70
# 7	0.44		0.66		0.68
# 8	0.45		0.70		0.70
# 9	0.43		0.70		0.70
# 10	0.41		0.70		0.69
# 11	0.45		0.67		0.68
# 12	0.42		0.67		0.68
# 13	0.46		0.65		0.66
# 14	0.46		0.67		0.67
# 15	0.42		0.66		0.65
# 16	0.51		0.69		0.67
# 17	0.46		0.71		0.68
# 18	0.48		0.71		0.68
# 19	0.49		0.71		0.68
# 20	0.45		0.69		0.67
# t = 1 was best iteration with accuracy 0.75
#
# -----------------------------------------------
# 2 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.49		0.74		0.78
# 2	0.47		0.74		0.78
# 3	0.50		0.74		0.78
# 4	0.51		0.74		0.78
# 5	0.47		0.74		0.78
# 6	0.46		0.74		0.78
# 7	0.52		0.74		0.78
# 8	0.50		0.74		0.78
# 9	0.50		0.74		0.77
# 10	0.52		0.74		0.78
# 11	0.50		0.74		0.77
# 12	0.46		0.74		0.78
# 13	0.48		0.74		0.78
# 14	0.47		0.74		0.78
# 15	0.49		0.74		0.78
# 16	0.49		0.74		0.77
# 17	0.45		0.74		0.77
# 18	0.49		0.74		0.77
# 19	0.49		0.74		0.77
# 20	0.51		0.74		0.78
# t = 1 was best iteration with accuracy 0.78
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.47		0.72		0.75
# 2	0.37		0.40		0.38
# 3	0.42		0.72		0.72
# 4	0.49		0.72		0.72
# 5	0.36		0.65		0.66
# 6	0.47		0.72		0.72
# 7	0.45		0.71		0.72
# 8	0.45		0.68		0.70
# 9	0.40		0.68		0.71
# 10	0.50		0.67		0.67
# 11	0.47		0.70		0.71
# 12	0.40		0.65		0.66
# 13	0.46		0.68		0.67
# 14	0.43		0.68		0.67
# 15	0.47		0.69		0.68
# 16	0.47		0.71		0.69
# 17	0.46		0.71		0.70
# 18	0.46		0.71		0.70
# 19	0.46		0.71		0.71
# 20	0.46		0.72		0.71
# t = 6 was best iteration with accuracy 0.72
#
# -----------------------------------------------
# 3 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.52		0.74		0.77
# 2	0.52		0.74		0.77
# 3	0.50		0.74		0.77
# 4	0.50		0.74		0.77
# 5	0.51		0.74		0.77
# 6	0.48		0.74		0.77
# 7	0.49		0.74		0.77
# 8	0.50		0.74		0.77
# 9	0.43		0.74		0.77
# 10	0.47		0.74		0.77
# 11	0.44		0.74		0.77
# 12	0.46		0.74		0.77
# 13	0.52		0.74		0.77
# 14	0.53		0.74		0.77
# 15	0.48		0.74		0.77
# 16	0.52		0.74		0.77
# 17	0.48		0.74		0.77
# 18	0.48		0.74		0.77
# 19	0.48		0.74		0.77
# 20	0.49		0.74		0.77
# t = 4 was best iteration with accuracy 0.77
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.49		0.73		0.77
# 2	0.33		0.40		0.34
# 3	0.40		0.73		0.74
# 4	0.49		0.36		0.33
# 5	0.43		0.75		0.73
# 6	0.45		0.75		0.73
# 7	0.45		0.68		0.71
# 8	0.49		0.74		0.71
# 9	0.45		0.73		0.71
# 10	0.47		0.74		0.73
# 11	0.49		0.73		0.73
# 12	0.46		0.74		0.73
# 13	0.47		0.74		0.74
# 14	0.43		0.74		0.75
# 15	0.47		0.74		0.75
# 16	0.46		0.74		0.74
# 17	0.47		0.73		0.75
# 18	0.46		0.73		0.74
# 19	0.49		0.74		0.74
# 20	0.50		0.73		0.74
# t = 5 was best iteration with accuracy 0.73
#
# -----------------------------------------------
# 4 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.52		0.73		0.77
# 2	0.50		0.73		0.77
# 3	0.53		0.74		0.77
# 4	0.48		0.74		0.77
# 5	0.51		0.73		0.77
# 6	0.47		0.74		0.77
# 7	0.49		0.74		0.77
# 8	0.49		0.73		0.77
# 9	0.48		0.73		0.77
# 10	0.49		0.73		0.77
# 11	0.47		0.73		0.77
# 12	0.45		0.74		0.77
# 13	0.50		0.73		0.77
# 14	0.52		0.73		0.78
# 15	0.48		0.73		0.77
# 16	0.49		0.73		0.77
# 17	0.49		0.73		0.77
# 18	0.47		0.73		0.77
# 19	0.51		0.73		0.77
# 20	0.51		0.73		0.77
# t = 3 was best iteration with accuracy 0.77
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.50		0.72		0.75
# 2	0.33		0.46		0.43
# 3	0.41		0.72		0.71
# 4	0.48		0.72		0.71
# 5	0.39		0.70		0.69
# 6	0.49		0.73		0.71
# 7	0.42		0.71		0.69
# 8	0.47		0.73		0.71
# 9	0.47		0.72		0.70
# 10	0.46		0.72		0.71
# 11	0.46		0.72		0.70
# 12	0.43		0.72		0.71
# 13	0.45		0.71		0.71
# 14	0.48		0.72		0.71
# 15	0.45		0.72		0.71
# 16	0.43		0.72		0.71
# 17	0.43		0.72		0.71
# 18	0.47		0.72		0.71
# 19	0.43		0.72		0.71
# 20	0.43		0.72		0.71
# t = 8 was best iteration with accuracy 0.71
#
# -----------------------------------------------
# 5 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.50		0.74		0.77
# 2	0.48		0.74		0.77
# 3	0.51		0.73		0.77
# 4	0.51		0.73		0.77
# 5	0.49		0.73		0.77
# 6	0.49		0.73		0.77
# 7	0.49		0.73		0.77
# 8	0.49		0.73		0.77
# 9	0.48		0.73		0.77
# 10	0.50		0.73		0.77
# 11	0.51		0.73		0.77
# 12	0.48		0.73		0.77
# 13	0.46		0.74		0.78
# 14	0.48		0.74		0.78
# 15	0.51		0.74		0.78
# 16	0.47		0.74		0.78
# 17	0.49		0.74		0.78
# 18	0.49		0.74		0.78
# 19	0.49		0.74		0.78
# 20	0.50		0.74		0.78
# t = 1 was best iteration with accuracy 0.77
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.50		0.73		0.75
# 2	0.33		0.50		0.49
# 3	0.38		0.70		0.71
# 4	0.49		0.67		0.70
# 5	0.40		0.71		0.70
# 6	0.53		0.66		0.66
# 7	0.42		0.70		0.69
# 8	0.47		0.65		0.65
# 9	0.50		0.73		0.73
# 10	0.45		0.65		0.65
# 11	0.45		0.65		0.64
# 12	0.49		0.55		0.52
# 13	0.50		0.64		0.58
# 14	0.40		0.70		0.68
# 15	0.45		0.71		0.69
# 16	0.45		0.71		0.67
# 17	0.43		0.71		0.70
# 18	0.45		0.75		0.73
# 19	0.44		0.75		0.74
# 20	0.43		0.74		0.74
# t = 18 was best iteration with accuracy 0.73
#
# -----------------------------------------------
# 6 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.47		0.73		0.77
# 2	0.47		0.74		0.77
# 3	0.50		0.74		0.77
# 4	0.46		0.74		0.77
# 5	0.49		0.74		0.77
# 6	0.45		0.74		0.77
# 7	0.49		0.74		0.77
# 8	0.52		0.74		0.77
# 9	0.51		0.74		0.77
# 10	0.49		0.74		0.77
# 11	0.46		0.74		0.77
# 12	0.48		0.74		0.77
# 13	0.47		0.74		0.77
# 14	0.48		0.74		0.77
# 15	0.50		0.74		0.77
# 16	0.47		0.74		0.77
# 17	0.49		0.74		0.77
# 18	0.51		0.74		0.77
# 19	0.53		0.74		0.77
# 20	0.50		0.74		0.77
# t = 3 was best iteration with accuracy 0.77
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.52		0.73		0.75
# 2	0.37		0.45		0.44
# 3	0.39		0.73		0.72
# 4	0.49		0.73		0.72
# 5	0.39		0.73		0.72
# 6	0.45		0.75		0.74
# 7	0.48		0.75		0.75
# 8	0.43		0.67		0.68
# 9	0.46		0.74		0.74
# 10	0.44		0.73		0.76
# 11	0.46		0.74		0.76
# 12	0.41		0.73		0.76
# 13	0.47		0.73		0.75
# 14	0.48		0.72		0.73
# 15	0.43		0.71		0.72
# 16	0.45		0.68		0.68
# 17	0.44		0.68		0.68
# 18	0.45		0.69		0.70
# 19	0.47		0.66		0.67
# 20	0.43		0.70		0.72
# t = 7 was best iteration with accuracy 0.75
#
# -----------------------------------------------
# 7 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.47		0.74		0.77
# 2	0.54		0.74		0.77
# 3	0.49		0.74		0.77
# 4	0.46		0.74		0.77
# 5	0.51		0.73		0.78
# 6	0.47		0.73		0.77
# 7	0.49		0.74		0.77
# 8	0.49		0.73		0.77
# 9	0.48		0.73		0.77
# 10	0.49		0.74		0.77
# 11	0.51		0.73		0.77
# 12	0.46		0.74		0.77
# 13	0.45		0.73		0.77
# 14	0.47		0.73		0.77
# 15	0.48		0.73		0.77
# 16	0.51		0.73		0.77
# 17	0.50		0.74		0.78
# 18	0.52		0.73		0.77
# 19	0.50		0.74		0.78
# 20	0.53		0.74		0.78
# t = 4 was best iteration with accuracy 0.77
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.50		0.74		0.76
# 2	0.39		0.74		0.76
# 3	0.42		0.72		0.73
# 4	0.44		0.72		0.74
# 5	0.48		0.71		0.72
# 6	0.52		0.69		0.70
# 7	0.39		0.69		0.70
# 8	0.45		0.69		0.72
# 9	0.43		0.68		0.71
# 10	0.43		0.70		0.70
# 11	0.47		0.67		0.70
# 12	0.48		0.70		0.71
# 13	0.47		0.69		0.69
# 14	0.43		0.66		0.68
# 15	0.46		0.68		0.67
# 16	0.38		0.67		0.68
# 17	0.46		0.67		0.67
# 18	0.43		0.69		0.67
# 19	0.50		0.69		0.68
# 20	0.47		0.69		0.69
# t = 1 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 8 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.51		0.73		0.77
# 2	0.46		0.73		0.77
# 3	0.49		0.73		0.78
# 4	0.49		0.73		0.78
# 5	0.53		0.73		0.78
# 6	0.51		0.74		0.78
# 7	0.46		0.74		0.78
# 8	0.50		0.74		0.77
# 9	0.46		0.74		0.78
# 10	0.48		0.74		0.78
# 11	0.47		0.74		0.78
# 12	0.51		0.74		0.78
# 13	0.46		0.74		0.78
# 14	0.51		0.74		0.78
# 15	0.48		0.74		0.78
# 16	0.51		0.74		0.78
# 17	0.48		0.74		0.78
# 18	0.49		0.74		0.78
# 19	0.50		0.74		0.78
# 20	0.48		0.74		0.78
# t = 6 was best iteration with accuracy 0.78
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.51		0.74		0.76
# 2	0.40		0.41		0.38
# 3	0.45		0.73		0.74
# 4	0.42		0.27		0.25
# 5	0.50		0.73		0.76
# 6	0.43		0.73		0.76
# 7	0.44		0.69		0.71
# 8	0.45		0.70		0.71
# 9	0.52		0.71		0.74
# 10	0.45		0.71		0.71
# 11	0.43		0.71		0.70
# 12	0.46		0.71		0.70
# 13	0.41		0.71		0.69
# 14	0.48		0.71		0.68
# 15	0.47		0.68		0.68
# 16	0.47		0.67		0.68
# 17	0.44		0.68		0.67
# 18	0.49		0.65		0.65
# 19	0.47		0.67		0.64
# 20	0.38		0.67		0.66
# t = 1 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 9 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.48		0.73		0.77
# 2	0.49		0.74		0.77
# 3	0.47		0.74		0.77
# 4	0.47		0.74		0.77
# 5	0.47		0.74		0.77
# 6	0.50		0.74		0.77
# 7	0.49		0.74		0.77
# 8	0.51		0.74		0.77
# 9	0.49		0.74		0.77
# 10	0.47		0.74		0.77
# 11	0.46		0.74		0.77
# 12	0.45		0.74		0.77
# 13	0.49		0.74		0.77
# 14	0.49		0.74		0.77
# 15	0.45		0.74		0.77
# 16	0.49		0.74		0.77
# 17	0.49		0.74		0.77
# 18	0.52		0.74		0.77
# 19	0.48		0.74		0.77
# 20	0.47		0.74		0.77
# t = 20 was best iteration with accuracy 0.77
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.48		0.72		0.73
# 2	0.34		0.44		0.42
# 3	0.38		0.66		0.64
# 4	0.44		0.66		0.64
# 5	0.44		0.73		0.71
# 6	0.46		0.73		0.71
# 7	0.48		0.72		0.71
# 8	0.46		0.69		0.69
# 9	0.46		0.73		0.71
# 10	0.51		0.73		0.73
# 11	0.45		0.73		0.71
# 12	0.45		0.73		0.73
# 13	0.45		0.75		0.73
# 14	0.46		0.74		0.73
# 15	0.47		0.74		0.73
# 16	0.46		0.73		0.74
# 17	0.46		0.74		0.74
# 18	0.47		0.73		0.74
# 19	0.44		0.74		0.74
# 20	0.45		0.74		0.74
# t = 13 was best iteration with accuracy 0.73
#
# -----------------------------------------------
# 10 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.49		0.73		0.77
# 2	0.50		0.74		0.77
# 3	0.51		0.74		0.77
# 4	0.51		0.74		0.77
# 5	0.48		0.74		0.77
# 6	0.53		0.74		0.77
# 7	0.49		0.74		0.77
# 8	0.48		0.74		0.77
# 9	0.47		0.74		0.77
# 10	0.51		0.74		0.77
# 11	0.47		0.74		0.77
# 12	0.51		0.74		0.77
# 13	0.48		0.74		0.77
# 14	0.50		0.74		0.77
# 15	0.48		0.74		0.77
# 16	0.50		0.74		0.77
# 17	0.49		0.74		0.77
# 18	0.47		0.74		0.77
# 19	0.51		0.74		0.77
# 20	0.50		0.74		0.77
# t = 4 was best iteration with accuracy 0.77
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.51		0.73		0.78
# 2	0.35		0.38		0.34
# 3	0.45		0.73		0.73
# 4	0.49		0.55		0.51
# 5	0.38		0.70		0.72
# 6	0.48		0.72		0.71
# 7	0.49		0.71		0.72
# 8	0.44		0.72		0.71
# 9	0.47		0.72		0.72
# 10	0.45		0.72		0.72
# 11	0.46		0.72		0.72
# 12	0.53		0.72		0.73
# 13	0.47		0.72		0.73
# 14	0.43		0.73		0.73
# 15	0.47		0.73		0.73
# 16	0.45		0.73		0.72
# 17	0.42		0.73		0.72
# 18	0.44		0.73		0.72
# 19	0.45		0.72		0.72
# 20	0.43		0.72		0.72
# t = 1 was best iteration with accuracy 0.78
#
# -----------------------------------------------
# 11 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.49		0.74		0.77
# 2	0.50		0.73		0.77
# 3	0.45		0.73		0.77
# 4	0.51		0.73		0.77
# 5	0.49		0.74		0.77
# 6	0.48		0.73		0.77
# 7	0.52		0.73		0.78
# 8	0.49		0.73		0.78
# 9	0.48		0.73		0.78
# 10	0.49		0.73		0.78
# 11	0.46		0.74		0.78
# 12	0.51		0.74		0.78
# 13	0.47		0.74		0.78
# 14	0.47		0.74		0.78
# 15	0.47		0.74		0.78
# 16	0.49		0.74		0.78
# 17	0.48		0.74		0.78
# 18	0.45		0.74		0.78
# 19	0.52		0.74		0.78
# 20	0.48		0.74		0.78
# t = 1 was best iteration with accuracy 0.77
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.47		0.75		0.77
# 2	0.33		0.40		0.39
# 3	0.44		0.73		0.72
# 4	0.51		0.28		0.29
# 5	0.48		0.75		0.77
# 6	0.46		0.75		0.77
# 7	0.53		0.75		0.77
# 8	0.47		0.75		0.77
# 9	0.49		0.75		0.76
# 10	0.49		0.76		0.76
# 11	0.49		0.76		0.76
# 12	0.50		0.75		0.76
# 13	0.50		0.75		0.76
# 14	0.49		0.76		0.76
# 15	0.46		0.76		0.75
# 16	0.45		0.75		0.75
# 17	0.45		0.76		0.75
# 18	0.47		0.76		0.75
# 19	0.43		0.76		0.75
# 20	0.49		0.75		0.75
# t = 15 was best iteration with accuracy 0.75
#
# -----------------------------------------------
# 12 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.52		0.73		0.76
# 2	0.51		0.73		0.78
# 3	0.48		0.73		0.78
# 4	0.49		0.74		0.78
# 5	0.51		0.74		0.78
# 6	0.52		0.74		0.78
# 7	0.53		0.74		0.78
# 8	0.51		0.74		0.78
# 9	0.50		0.74		0.78
# 10	0.50		0.74		0.78
# 11	0.45		0.74		0.78
# 12	0.45		0.74		0.78
# 13	0.50		0.74		0.78
# 14	0.51		0.74		0.78
# 15	0.51		0.74		0.78
# 16	0.50		0.74		0.78
# 17	0.49		0.74		0.77
# 18	0.47		0.74		0.78
# 19	0.53		0.74		0.78
# 20	0.53		0.74		0.78
# t = 15 was best iteration with accuracy 0.78
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.46		0.73		0.76
# 2	0.35		0.42		0.38
# 3	0.47		0.72		0.73
# 4	0.50		0.72		0.73
# 5	0.35		0.71		0.72
# 6	0.51		0.69		0.70
# 7	0.45		0.71		0.72
# 8	0.45		0.71		0.72
# 9	0.46		0.71		0.73
# 10	0.42		0.72		0.73
# 11	0.47		0.71		0.72
# 12	0.42		0.71		0.71
# 13	0.44		0.69		0.71
# 14	0.45		0.70		0.71
# 15	0.47		0.68		0.69
# 16	0.46		0.67		0.68
# 17	0.48		0.65		0.67
# 18	0.45		0.67		0.66
# 19	0.46		0.67		0.69
# 20	0.49		0.70		0.69
# t = 1 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 13 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.49		0.73		0.77
# 2	0.51		0.73		0.77
# 3	0.50		0.74		0.78
# 4	0.49		0.74		0.77
# 5	0.47		0.74		0.77
# 6	0.50		0.74		0.77
# 7	0.48		0.74		0.77
# 8	0.44		0.74		0.77
# 9	0.52		0.74		0.77
# 10	0.46		0.74		0.77
# 11	0.52		0.74		0.77
# 12	0.47		0.74		0.77
# 13	0.47		0.74		0.77
# 14	0.49		0.74		0.77
# 15	0.48		0.74		0.77
# 16	0.49		0.74		0.77
# 17	0.48		0.74		0.77
# 18	0.50		0.74		0.77
# 19	0.50		0.74		0.77
# 20	0.51		0.74		0.77
# t = 5 was best iteration with accuracy 0.77
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.53		0.73		0.76
# 2	0.37		0.39		0.36
# 3	0.41		0.72		0.75
# 4	0.36		0.72		0.75
# 5	0.42		0.70		0.71
# 6	0.47		0.69		0.70
# 7	0.39		0.70		0.69
# 8	0.50		0.70		0.71
# 9	0.44		0.69		0.69
# 10	0.52		0.68		0.68
# 11	0.40		0.68		0.68
# 12	0.47		0.59		0.61
# 13	0.41		0.68		0.68
# 14	0.49		0.67		0.68
# 15	0.42		0.66		0.67
# 16	0.48		0.65		0.66
# 17	0.48		0.64		0.67
# 18	0.44		0.66		0.65
# 19	0.46		0.66		0.66
# 20	0.47		0.66		0.67
# t = 1 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 14 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.48		0.73		0.77
# 2	0.50		0.73		0.78
# 3	0.51		0.74		0.77
# 4	0.43		0.74		0.77
# 5	0.48		0.74		0.77
# 6	0.47		0.74		0.77
# 7	0.49		0.74		0.77
# 8	0.49		0.74		0.77
# 9	0.52		0.74		0.77
# 10	0.48		0.74		0.77
# 11	0.48		0.74		0.77
# 12	0.51		0.74		0.77
# 13	0.49		0.74		0.77
# 14	0.48		0.74		0.77
# 15	0.48		0.74		0.77
# 16	0.48		0.74		0.77
# 17	0.49		0.74		0.77
# 18	0.52		0.74		0.77
# 19	0.51		0.74		0.77
# 20	0.50		0.74		0.77
# t = 4 was best iteration with accuracy 0.77
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.46		0.73		0.75
# 2	0.39		0.39		0.39
# 3	0.44		0.70		0.68
# 4	0.45		0.73		0.75
# 5	0.42		0.75		0.73
# 6	0.45		0.74		0.73
# 7	0.46		0.71		0.71
# 8	0.45		0.67		0.69
# 9	0.44		0.64		0.64
# 10	0.43		0.70		0.70
# 11	0.42		0.65		0.64
# 12	0.49		0.66		0.69
# 13	0.48		0.67		0.68
# 14	0.48		0.68		0.70
# 15	0.51		0.73		0.71
# 16	0.48		0.73		0.72
# 17	0.48		0.74		0.73
# 18	0.46		0.73		0.73
# 19	0.46		0.73		0.73
# 20	0.47		0.73		0.73
# t = 5 was best iteration with accuracy 0.73
#
# -----------------------------------------------
# 15 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.52		0.73		0.76
# 2	0.50		0.73		0.77
# 3	0.50		0.73		0.78
# 4	0.49		0.74		0.78
# 5	0.49		0.74		0.78
# 6	0.46		0.74		0.78
# 7	0.47		0.74		0.78
# 8	0.48		0.74		0.77
# 9	0.52		0.74		0.77
# 10	0.49		0.74		0.78
# 11	0.51		0.74		0.78
# 12	0.53		0.74		0.78
# 13	0.49		0.74		0.78
# 14	0.49		0.74		0.77
# 15	0.47		0.74		0.78
# 16	0.49		0.74		0.77
# 17	0.48		0.74		0.77
# 18	0.49		0.74		0.77
# 19	0.48		0.74		0.77
# 20	0.48		0.74		0.77
# t = 4 was best iteration with accuracy 0.78
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.52		0.73		0.75
# 2	0.33		0.73		0.75
# 3	0.52		0.37		0.39
# 4	0.33		0.37		0.39
# 5	0.35		0.37		0.39
# 6	0.34		0.37		0.39
# 7	0.33		0.37		0.39
# 8	0.38		0.65		0.65
# 9	0.38		0.65		0.65
# 10	0.37		0.69		0.70
# 11	0.30		0.69		0.70
# 12	0.35		0.71		0.70
# 13	0.34		0.71		0.71
# 14	0.33		0.72		0.71
# 15	0.35		0.71		0.71
# 16	0.37		0.72		0.72
# 17	0.35		0.72		0.72
# 18	0.38		0.73		0.72
# 19	0.39		0.73		0.72
# 20	0.41		0.73		0.73
# t = 1 was best iteration with accuracy 0.75
#
# -----------------------------------------------
# 16 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.53		0.74		0.77
# 2	0.50		0.74		0.77
# 3	0.50		0.74		0.77
# 4	0.52		0.74		0.77
# 5	0.48		0.74		0.77
# 6	0.53		0.74		0.77
# 7	0.47		0.74		0.77
# 8	0.48		0.73		0.77
# 9	0.51		0.73		0.77
# 10	0.47		0.73		0.77
# 11	0.49		0.74		0.77
# 12	0.47		0.73		0.77
# 13	0.48		0.73		0.77
# 14	0.48		0.74		0.77
# 15	0.50		0.74		0.77
# 16	0.50		0.74		0.77
# 17	0.50		0.74		0.77
# 18	0.49		0.73		0.78
# 19	0.45		0.73		0.78
# 20	0.45		0.74		0.78
# t = 1 was best iteration with accuracy 0.77
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.49		0.74		0.76
# 2	0.34		0.74		0.76
# 3	0.42		0.72		0.71
# 4	0.49		0.73		0.74
# 5	0.43		0.67		0.68
# 6	0.50		0.66		0.67
# 7	0.39		0.67		0.68
# 8	0.50		0.70		0.71
# 9	0.47		0.70		0.70
# 10	0.49		0.72		0.71
# 11	0.44		0.71		0.71
# 12	0.47		0.72		0.71
# 13	0.47		0.71		0.70
# 14	0.45		0.71		0.70
# 15	0.47		0.70		0.70
# 16	0.43		0.69		0.70
# 17	0.43		0.66		0.68
# 18	0.50		0.66		0.67
# 19	0.51		0.61		0.62
# 20	0.45		0.66		0.67
# t = 1 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 17 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.48		0.73		0.76
# 2	0.50		0.73		0.77
# 3	0.50		0.73		0.78
# 4	0.46		0.74		0.78
# 5	0.48		0.74		0.78
# 6	0.47		0.74		0.78
# 7	0.47		0.74		0.77
# 8	0.48		0.74		0.77
# 9	0.54		0.74		0.77
# 10	0.46		0.74		0.78
# 11	0.50		0.74		0.78
# 12	0.53		0.74		0.78
# 13	0.55		0.74		0.78
# 14	0.48		0.74		0.78
# 15	0.53		0.74		0.78
# 16	0.48		0.74		0.78
# 17	0.51		0.74		0.78
# 18	0.46		0.74		0.78
# 19	0.48		0.74		0.78
# 20	0.49		0.74		0.78
# t = 6 was best iteration with accuracy 0.78
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.47		0.73		0.76
# 2	0.36		0.41		0.38
# 3	0.43		0.73		0.72
# 4	0.53		0.66		0.66
# 5	0.40		0.71		0.70
# 6	0.46		0.71		0.71
# 7	0.49		0.71		0.71
# 8	0.50		0.72		0.72
# 9	0.49		0.73		0.71
# 10	0.48		0.72		0.71
# 11	0.45		0.73		0.73
# 12	0.48		0.72		0.73
# 13	0.45		0.73		0.73
# 14	0.49		0.72		0.72
# 15	0.46		0.72		0.73
# 16	0.47		0.72		0.72
# 17	0.51		0.72		0.72
# 18	0.48		0.71		0.72
# 19	0.47		0.72		0.72
# 20	0.47		0.72		0.72
# t = 1 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 18 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.50		0.73		0.76
# 2	0.56		0.73		0.78
# 3	0.47		0.73		0.78
# 4	0.48		0.74		0.78
# 5	0.47		0.74		0.78
# 6	0.52		0.74		0.78
# 7	0.49		0.74		0.78
# 8	0.49		0.74		0.78
# 9	0.46		0.74		0.78
# 10	0.47		0.74		0.78
# 11	0.48		0.74		0.77
# 12	0.50		0.74		0.78
# 13	0.49		0.74		0.78
# 14	0.47		0.74		0.78
# 15	0.44		0.74		0.78
# 16	0.45		0.74		0.78
# 17	0.47		0.74		0.78
# 18	0.46		0.74		0.78
# 19	0.52		0.74		0.78
# 20	0.48		0.74		0.78
# t = 4 was best iteration with accuracy 0.78
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.50		0.73		0.77
# 2	0.36		0.36		0.36
# 3	0.43		0.71		0.71
# 4	0.47		0.71		0.71
# 5	0.38		0.72		0.71
# 6	0.43		0.72		0.71
# 7	0.47		0.74		0.73
# 8	0.51		0.75		0.74
# 9	0.44		0.74		0.73
# 10	0.46		0.73		0.71
# 11	0.43		0.73		0.71
# 12	0.49		0.73		0.71
# 13	0.47		0.73		0.72
# 14	0.47		0.73		0.71
# 15	0.45		0.71		0.71
# 16	0.46		0.72		0.71
# 17	0.47		0.71		0.70
# 18	0.47		0.70		0.69
# 19	0.45		0.70		0.69
# 20	0.44		0.69		0.68
# t = 8 was best iteration with accuracy 0.74
#
# -----------------------------------------------
# 19 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.55		0.73		0.76
# 2	0.46		0.73		0.77
# 3	0.45		0.73		0.77
# 4	0.47		0.74		0.77
# 5	0.48		0.74		0.78
# 6	0.46		0.74		0.78
# 7	0.49		0.74		0.77
# 8	0.49		0.74		0.77
# 9	0.52		0.74		0.78
# 10	0.52		0.74		0.77
# 11	0.49		0.74		0.77
# 12	0.46		0.74		0.77
# 13	0.47		0.74		0.77
# 14	0.50		0.74		0.77
# 15	0.50		0.74		0.77
# 16	0.49		0.74		0.77
# 17	0.47		0.74		0.78
# 18	0.48		0.74		0.78
# 19	0.45		0.74		0.77
# 20	0.46		0.74		0.78
# t = 10 was best iteration with accuracy 0.77
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.52		0.73		0.77
# 2	0.36		0.43		0.40
# 3	0.40		0.72		0.74
# 4	0.52		0.63		0.62
# 5	0.35		0.71		0.74
# 6	0.42		0.70		0.73
# 7	0.48		0.75		0.75
# 8	0.49		0.75		0.76
# 9	0.47		0.74		0.74
# 10	0.46		0.73		0.75
# 11	0.49		0.74		0.76
# 12	0.47		0.73		0.74
# 13	0.47		0.73		0.74
# 14	0.49		0.74		0.75
# 15	0.51		0.73		0.74
# 16	0.39		0.73		0.75
# 17	0.47		0.73		0.75
# 18	0.46		0.73		0.75
# 19	0.47		0.73		0.75
# 20	0.46		0.73		0.75
# t = 7 was best iteration with accuracy 0.75
#
# -----------------------------------------------
# 20 / 40 complete
# -----------------------------------------------
#
# PRELIMINARY
# Training accuracy of supervised SVM: 0.78
#
# GENERATE W
# [[-1. -1.]
#  [-1.  1.]
#  [ 1. -1.]
#  [ 1.  1.]] [80 44 51 25]
# Training accuracy of pairwise rank SVM: 0.97
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.48		0.76		0.79
# 2	0.50		0.77		0.80
# 3	0.50		0.76		0.80
# 4	0.49		0.76		0.80
# 5	0.48		0.76		0.80
# 6	0.49		0.77		0.80
# 7	0.45		0.76		0.79
# 8	0.51		0.77		0.80
# 9	0.45		0.76		0.80
# 10	0.49		0.76		0.80
# 11	0.51		0.76		0.80
# 12	0.45		0.76		0.80
# 13	0.50		0.76		0.80
# 14	0.48		0.76		0.79
# 15	0.46		0.76		0.79
# 16	0.48		0.76		0.79
# 17	0.43		0.76		0.80
# 18	0.47		0.76		0.80
# 19	0.48		0.77		0.79
# 20	0.47		0.77		0.80
# t = 6 was best iteration with accuracy 0.80
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.48		0.73		0.78
# 2	0.44		0.73		0.78
# 3	0.48		0.74		0.78
# 4	0.47		0.74		0.78
# 5	0.47		0.74		0.78
# 6	0.49		0.75		0.79
# 7	0.49		0.77		0.78
# 8	0.45		0.77		0.79
# 9	0.47		0.77		0.78
# 10	0.51		0.76		0.79
# 11	0.46		0.77		0.78
# 12	0.43		0.77		0.79
# 13	0.50		0.77		0.79
# 14	0.49		0.76		0.79
# 15	0.48		0.77		0.79
# 16	0.45		0.76		0.79
# 17	0.48		0.77		0.79
# 18	0.47		0.77		0.78
# 19	0.48		0.77		0.79
# 20	0.48		0.77		0.79
# t = 17 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 21 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.51		0.76		0.79
# 2	0.47		0.77		0.79
# 3	0.50		0.76		0.80
# 4	0.48		0.77		0.80
# 5	0.48		0.76		0.79
# 6	0.47		0.77		0.79
# 7	0.47		0.77		0.80
# 8	0.46		0.76		0.79
# 9	0.47		0.76		0.79
# 10	0.47		0.76		0.80
# 11	0.46		0.76		0.79
# 12	0.45		0.76		0.80
# 13	0.50		0.76		0.79
# 14	0.45		0.76		0.79
# 15	0.47		0.76		0.79
# 16	0.48		0.76		0.79
# 17	0.44		0.76		0.79
# 18	0.49		0.76		0.79
# 19	0.48		0.76		0.79
# 20	0.48		0.76		0.79
# t = 2 was best iteration with accuracy 0.79
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.49		0.74		0.77
# 2	0.41		0.28		0.24
# 3	0.48		0.74		0.77
# 4	0.43		0.74		0.77
# 5	0.47		0.74		0.77
# 6	0.50		0.75		0.78
# 7	0.44		0.75		0.77
# 8	0.48		0.74		0.78
# 9	0.42		0.75		0.78
# 10	0.45		0.76		0.77
# 11	0.47		0.76		0.78
# 12	0.51		0.77		0.78
# 13	0.47		0.76		0.78
# 14	0.49		0.76		0.78
# 15	0.49		0.76		0.78
# 16	0.47		0.77		0.78
# 17	0.47		0.77		0.78
# 18	0.43		0.78		0.78
# 19	0.48		0.78		0.78
# 20	0.48		0.77		0.78
# t = 19 was best iteration with accuracy 0.78
#
# -----------------------------------------------
# 22 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.51		0.76		0.79
# 2	0.47		0.76		0.79
# 3	0.50		0.77		0.79
# 4	0.48		0.77		0.79
# 5	0.49		0.76		0.80
# 6	0.52		0.76		0.80
# 7	0.49		0.76		0.80
# 8	0.48		0.76		0.80
# 9	0.50		0.77		0.80
# 10	0.48		0.76		0.79
# 11	0.50		0.76		0.80
# 12	0.49		0.76		0.79
# 13	0.48		0.76		0.80
# 14	0.49		0.76		0.79
# 15	0.53		0.76		0.79
# 16	0.47		0.76		0.79
# 17	0.50		0.76		0.80
# 18	0.50		0.76		0.80
# 19	0.49		0.76		0.80
# 20	0.45		0.76		0.79
# t = 3 was best iteration with accuracy 0.79
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.49		0.73		0.78
# 2	0.39		0.30		0.27
# 3	0.49		0.74		0.77
# 4	0.48		0.74		0.77
# 5	0.48		0.74		0.77
# 6	0.50		0.75		0.78
# 7	0.49		0.77		0.79
# 8	0.49		0.75		0.78
# 9	0.49		0.78		0.79
# 10	0.51		0.76		0.78
# 11	0.43		0.77		0.79
# 12	0.50		0.76		0.78
# 13	0.47		0.77		0.80
# 14	0.46		0.76		0.79
# 15	0.47		0.76		0.79
# 16	0.45		0.77		0.80
# 17	0.48		0.77		0.80
# 18	0.47		0.77		0.80
# 19	0.49		0.77		0.80
# 20	0.47		0.78		0.79
# t = 20 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 23 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.51		0.76		0.79
# 2	0.48		0.76		0.79
# 3	0.49		0.76		0.79
# 4	0.47		0.76		0.79
# 5	0.45		0.76		0.80
# 6	0.46		0.76		0.80
# 7	0.49		0.76		0.79
# 8	0.48		0.77		0.80
# 9	0.45		0.77		0.80
# 10	0.50		0.76		0.80
# 11	0.47		0.76		0.80
# 12	0.51		0.76		0.80
# 13	0.49		0.76		0.80
# 14	0.49		0.76		0.80
# 15	0.47		0.76		0.80
# 16	0.51		0.76		0.80
# 17	0.48		0.76		0.80
# 18	0.48		0.76		0.80
# 19	0.49		0.76		0.80
# 20	0.50		0.76		0.80
# t = 8 was best iteration with accuracy 0.80
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.50		0.74		0.78
# 2	0.39		0.29		0.24
# 3	0.49		0.75		0.78
# 4	0.49		0.75		0.78
# 5	0.50		0.77		0.78
# 6	0.48		0.77		0.79
# 7	0.48		0.77		0.79
# 8	0.43		0.77		0.79
# 9	0.45		0.77		0.79
# 10	0.45		0.76		0.79
# 11	0.45		0.77		0.79
# 12	0.49		0.77		0.79
# 13	0.44		0.77		0.79
# 14	0.47		0.77		0.79
# 15	0.46		0.77		0.79
# 16	0.44		0.77		0.79
# 17	0.44		0.77		0.79
# 18	0.47		0.77		0.79
# 19	0.46		0.77		0.79
# 20	0.53		0.77		0.79
# t = 11 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 24 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.45		0.76		0.79
# 2	0.53		0.76		0.79
# 3	0.51		0.76		0.80
# 4	0.48		0.77		0.80
# 5	0.46		0.76		0.80
# 6	0.51		0.76		0.80
# 7	0.47		0.76		0.80
# 8	0.47		0.76		0.80
# 9	0.50		0.77		0.80
# 10	0.47		0.76		0.80
# 11	0.47		0.76		0.80
# 12	0.49		0.76		0.80
# 13	0.48		0.76		0.80
# 14	0.47		0.76		0.80
# 15	0.51		0.76		0.80
# 16	0.46		0.76		0.80
# 17	0.44		0.76		0.80
# 18	0.48		0.76		0.80
# 19	0.47		0.76		0.80
# 20	0.47		0.76		0.80
# t = 4 was best iteration with accuracy 0.80
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.47		0.74		0.77
# 2	0.42		0.74		0.77
# 3	0.47		0.74		0.78
# 4	0.47		0.74		0.78
# 5	0.50		0.75		0.78
# 6	0.49		0.75		0.79
# 7	0.48		0.78		0.78
# 8	0.47		0.76		0.79
# 9	0.49		0.76		0.79
# 10	0.48		0.77		0.79
# 11	0.50		0.77		0.79
# 12	0.48		0.77		0.79
# 13	0.50		0.77		0.80
# 14	0.51		0.77		0.79
# 15	0.52		0.78		0.80
# 16	0.47		0.78		0.80
# 17	0.48		0.77		0.79
# 18	0.46		0.78		0.79
# 19	0.46		0.78		0.79
# 20	0.49		0.78		0.79
# t = 15 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 25 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.48		0.76		0.78
# 2	0.48		0.77		0.79
# 3	0.48		0.77		0.80
# 4	0.49		0.77		0.79
# 5	0.50		0.77		0.79
# 6	0.50		0.76		0.80
# 7	0.52		0.77		0.80
# 8	0.46		0.77		0.79
# 9	0.47		0.76		0.80
# 10	0.49		0.76		0.80
# 11	0.49		0.76		0.80
# 12	0.50		0.76		0.79
# 13	0.47		0.76		0.80
# 14	0.48		0.76		0.79
# 15	0.50		0.76		0.79
# 16	0.48		0.76		0.80
# 17	0.49		0.76		0.79
# 18	0.45		0.76		0.79
# 19	0.46		0.76		0.79
# 20	0.49		0.76		0.79
# t = 5 was best iteration with accuracy 0.79
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.50		0.74		0.78
# 2	0.41		0.74		0.78
# 3	0.46		0.75		0.78
# 4	0.44		0.75		0.78
# 5	0.44		0.75		0.78
# 6	0.50		0.76		0.78
# 7	0.47		0.75		0.78
# 8	0.46		0.76		0.78
# 9	0.51		0.75		0.79
# 10	0.45		0.76		0.78
# 11	0.48		0.77		0.78
# 12	0.45		0.77		0.78
# 13	0.48		0.77		0.78
# 14	0.51		0.77		0.78
# 15	0.50		0.77		0.78
# 16	0.50		0.77		0.78
# 17	0.49		0.77		0.78
# 18	0.50		0.77		0.79
# 19	0.49		0.77		0.79
# 20	0.44		0.77		0.79
# t = 13 was best iteration with accuracy 0.78
#
# -----------------------------------------------
# 26 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.49		0.76		0.79
# 2	0.48		0.76		0.79
# 3	0.47		0.76		0.79
# 4	0.49		0.76		0.80
# 5	0.49		0.76		0.79
# 6	0.48		0.76		0.79
# 7	0.51		0.76		0.80
# 8	0.45		0.76		0.79
# 9	0.51		0.76		0.79
# 10	0.51		0.76		0.80
# 11	0.43		0.76		0.80
# 12	0.51		0.76		0.80
# 13	0.44		0.76		0.80
# 14	0.49		0.76		0.80
# 15	0.51		0.76		0.80
# 16	0.47		0.76		0.80
# 17	0.49		0.76		0.80
# 18	0.47		0.76		0.80
# 19	0.48		0.76		0.80
# 20	0.48		0.76		0.80
# t = 9 was best iteration with accuracy 0.79
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.47		0.74		0.78
# 2	0.39		0.74		0.78
# 3	0.48		0.75		0.78
# 4	0.48		0.75		0.78
# 5	0.49		0.75		0.78
# 6	0.49		0.77		0.79
# 7	0.51		0.76		0.79
# 8	0.48		0.77		0.79
# 9	0.50		0.77		0.79
# 10	0.46		0.77		0.79
# 11	0.46		0.77		0.79
# 12	0.46		0.78		0.79
# 13	0.50		0.77		0.79
# 14	0.50		0.77		0.80
# 15	0.47		0.77		0.79
# 16	0.42		0.76		0.79
# 17	0.47		0.76		0.79
# 18	0.48		0.77		0.79
# 19	0.46		0.77		0.79
# 20	0.49		0.76		0.79
# t = 12 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 27 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.49		0.75		0.78
# 2	0.47		0.76		0.79
# 3	0.51		0.76		0.79
# 4	0.48		0.76		0.80
# 5	0.52		0.76		0.80
# 6	0.46		0.76		0.80
# 7	0.50		0.76		0.79
# 8	0.48		0.76		0.80
# 9	0.47		0.77		0.80
# 10	0.48		0.76		0.80
# 11	0.48		0.76		0.80
# 12	0.53		0.76		0.80
# 13	0.50		0.76		0.80
# 14	0.48		0.76		0.80
# 15	0.45		0.76		0.80
# 16	0.50		0.76		0.80
# 17	0.50		0.76		0.80
# 18	0.49		0.76		0.80
# 19	0.48		0.76		0.80
# 20	0.50		0.76		0.80
# t = 9 was best iteration with accuracy 0.80
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.48		0.74		0.77
# 2	0.44		0.74		0.77
# 3	0.48		0.74		0.78
# 4	0.48		0.74		0.78
# 5	0.48		0.75		0.78
# 6	0.47		0.76		0.79
# 7	0.51		0.76		0.79
# 8	0.47		0.76		0.79
# 9	0.47		0.76		0.79
# 10	0.49		0.77		0.79
# 11	0.47		0.76		0.79
# 12	0.49		0.77		0.79
# 13	0.50		0.77		0.79
# 14	0.47		0.76		0.78
# 15	0.48		0.77		0.79
# 16	0.46		0.77		0.79
# 17	0.50		0.77		0.79
# 18	0.52		0.77		0.79
# 19	0.46		0.78		0.79
# 20	0.49		0.77		0.79
# t = 19 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 28 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.50		0.76		0.79
# 2	0.50		0.76		0.79
# 3	0.48		0.76		0.80
# 4	0.49		0.76		0.80
# 5	0.49		0.77		0.80
# 6	0.46		0.76		0.80
# 7	0.47		0.76		0.80
# 8	0.47		0.77		0.80
# 9	0.49		0.76		0.80
# 10	0.48		0.76		0.80
# 11	0.49		0.76		0.80
# 12	0.45		0.76		0.80
# 13	0.51		0.76		0.80
# 14	0.50		0.76		0.80
# 15	0.49		0.76		0.80
# 16	0.48		0.76		0.79
# 17	0.48		0.76		0.80
# 18	0.51		0.76		0.80
# 19	0.47		0.76		0.79
# 20	0.52		0.76		0.79
# t = 5 was best iteration with accuracy 0.80
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.50		0.73		0.77
# 2	0.39		0.29		0.25
# 3	0.51		0.73		0.77
# 4	0.44		0.73		0.77
# 5	0.48		0.77		0.78
# 6	0.50		0.74		0.78
# 7	0.49		0.76		0.78
# 8	0.47		0.74		0.77
# 9	0.51		0.77		0.77
# 10	0.48		0.76		0.78
# 11	0.45		0.77		0.78
# 12	0.48		0.76		0.78
# 13	0.46		0.77		0.78
# 14	0.50		0.76		0.78
# 15	0.46		0.77		0.79
# 16	0.49		0.77		0.79
# 17	0.50		0.76		0.78
# 18	0.45		0.76		0.79
# 19	0.47		0.76		0.78
# 20	0.46		0.76		0.79
# t = 5 was best iteration with accuracy 0.78
#
# -----------------------------------------------
# 29 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.47		0.76		0.79
# 2	0.48		0.76		0.80
# 3	0.47		0.76		0.79
# 4	0.46		0.76		0.79
# 5	0.52		0.76		0.79
# 6	0.49		0.76		0.79
# 7	0.45		0.76		0.79
# 8	0.44		0.76		0.79
# 9	0.47		0.76		0.80
# 10	0.46		0.76		0.80
# 11	0.45		0.76		0.80
# 12	0.53		0.76		0.80
# 13	0.48		0.76		0.80
# 14	0.48		0.76		0.79
# 15	0.45		0.76		0.79
# 16	0.50		0.76		0.79
# 17	0.50		0.76		0.79
# 18	0.45		0.76		0.79
# 19	0.46		0.76		0.79
# 20	0.48		0.76		0.79
# t = 7 was best iteration with accuracy 0.79
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.50		0.74		0.78
# 2	0.44		0.28		0.23
# 3	0.47		0.74		0.77
# 4	0.48		0.74		0.77
# 5	0.47		0.75		0.78
# 6	0.50		0.75		0.78
# 7	0.48		0.76		0.79
# 8	0.48		0.77		0.79
# 9	0.48		0.78		0.80
# 10	0.49		0.78		0.79
# 11	0.49		0.78		0.79
# 12	0.48		0.77		0.79
# 13	0.48		0.77		0.79
# 14	0.44		0.77		0.79
# 15	0.46		0.78		0.80
# 16	0.46		0.78		0.79
# 17	0.48		0.78		0.80
# 18	0.51		0.77		0.79
# 19	0.47		0.77		0.79
# 20	0.46		0.77		0.79
# t = 17 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 30 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.50		0.77		0.79
# 2	0.47		0.76		0.79
# 3	0.53		0.76		0.79
# 4	0.49		0.76		0.79
# 5	0.50		0.76		0.79
# 6	0.52		0.76		0.80
# 7	0.48		0.76		0.79
# 8	0.48		0.76		0.79
# 9	0.50		0.76		0.79
# 10	0.46		0.76		0.79
# 11	0.49		0.76		0.79
# 12	0.46		0.76		0.79
# 13	0.47		0.76		0.79
# 14	0.45		0.77		0.79
# 15	0.45		0.76		0.79
# 16	0.49		0.76		0.79
# 17	0.48		0.76		0.79
# 18	0.50		0.76		0.79
# 19	0.46		0.76		0.79
# 20	0.49		0.76		0.79
# t = 1 was best iteration with accuracy 0.79
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.50		0.74		0.77
# 2	0.42		0.74		0.77
# 3	0.51		0.74		0.77
# 4	0.46		0.74		0.77
# 5	0.46		0.74		0.77
# 6	0.49		0.75		0.77
# 7	0.45		0.75		0.77
# 8	0.53		0.74		0.77
# 9	0.48		0.76		0.78
# 10	0.49		0.76		0.78
# 11	0.42		0.76		0.78
# 12	0.48		0.77		0.78
# 13	0.48		0.77		0.78
# 14	0.50		0.76		0.78
# 15	0.48		0.77		0.78
# 16	0.48		0.77		0.79
# 17	0.46		0.77		0.79
# 18	0.51		0.77		0.79
# 19	0.50		0.77		0.79
# 20	0.47		0.77		0.79
# t = 19 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 31 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.48		0.75		0.78
# 2	0.45		0.76		0.79
# 3	0.47		0.77		0.79
# 4	0.45		0.77		0.79
# 5	0.51		0.77		0.80
# 6	0.47		0.77		0.80
# 7	0.50		0.77		0.80
# 8	0.46		0.77		0.80
# 9	0.50		0.76		0.80
# 10	0.51		0.76		0.80
# 11	0.49		0.76		0.80
# 12	0.46		0.76		0.80
# 13	0.49		0.76		0.79
# 14	0.49		0.76		0.80
# 15	0.49		0.76		0.79
# 16	0.47		0.76		0.79
# 17	0.48		0.76		0.80
# 18	0.52		0.76		0.80
# 19	0.47		0.76		0.79
# 20	0.45		0.76		0.79
# t = 3 was best iteration with accuracy 0.79
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.49		0.74		0.77
# 2	0.43		0.74		0.77
# 3	0.48		0.75		0.77
# 4	0.46		0.75		0.77
# 5	0.49		0.75		0.77
# 6	0.46		0.76		0.78
# 7	0.49		0.76		0.79
# 8	0.45		0.74		0.79
# 9	0.49		0.76		0.79
# 10	0.43		0.76		0.79
# 11	0.48		0.77		0.79
# 12	0.50		0.76		0.79
# 13	0.48		0.76		0.79
# 14	0.49		0.76		0.79
# 15	0.51		0.76		0.79
# 16	0.48		0.77		0.79
# 17	0.50		0.76		0.79
# 18	0.49		0.77		0.79
# 19	0.47		0.76		0.78
# 20	0.47		0.76		0.78
# t = 11 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 32 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.50		0.76		0.79
# 2	0.51		0.77		0.80
# 3	0.47		0.77		0.79
# 4	0.48		0.77		0.79
# 5	0.51		0.77		0.79
# 6	0.48		0.76		0.79
# 7	0.48		0.76		0.79
# 8	0.49		0.76		0.79
# 9	0.49		0.76		0.79
# 10	0.49		0.76		0.79
# 11	0.47		0.76		0.79
# 12	0.50		0.76		0.79
# 13	0.50		0.76		0.79
# 14	0.47		0.76		0.79
# 15	0.52		0.76		0.79
# 16	0.50		0.76		0.80
# 17	0.46		0.76		0.79
# 18	0.48		0.76		0.79
# 19	0.48		0.76		0.80
# 20	0.52		0.76		0.80
# t = 2 was best iteration with accuracy 0.80
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.47		0.74		0.77
# 2	0.38		0.29		0.25
# 3	0.48		0.73		0.78
# 4	0.49		0.73		0.78
# 5	0.50		0.74		0.77
# 6	0.48		0.77		0.78
# 7	0.50		0.77		0.78
# 8	0.50		0.77		0.79
# 9	0.45		0.78		0.79
# 10	0.47		0.77		0.79
# 11	0.49		0.77		0.78
# 12	0.48		0.78		0.78
# 13	0.51		0.78		0.79
# 14	0.47		0.77		0.79
# 15	0.49		0.78		0.78
# 16	0.46		0.78		0.79
# 17	0.48		0.78		0.79
# 18	0.46		0.77		0.79
# 19	0.48		0.78		0.79
# 20	0.49		0.77		0.79
# t = 16 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 33 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.47		0.76		0.78
# 2	0.48		0.76		0.79
# 3	0.49		0.76		0.80
# 4	0.48		0.77		0.80
# 5	0.48		0.76		0.79
# 6	0.48		0.76		0.79
# 7	0.48		0.77		0.80
# 8	0.52		0.76		0.80
# 9	0.49		0.76		0.79
# 10	0.49		0.76		0.80
# 11	0.48		0.76		0.79
# 12	0.50		0.76		0.79
# 13	0.48		0.76		0.80
# 14	0.49		0.77		0.80
# 15	0.49		0.76		0.80
# 16	0.48		0.76		0.80
# 17	0.51		0.76		0.80
# 18	0.46		0.77		0.80
# 19	0.48		0.76		0.80
# 20	0.47		0.77		0.80
# t = 4 was best iteration with accuracy 0.80
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.50		0.74		0.77
# 2	0.44		0.74		0.77
# 3	0.52		0.74		0.77
# 4	0.45		0.75		0.77
# 5	0.47		0.75		0.78
# 6	0.49		0.75		0.76
# 7	0.48		0.75		0.77
# 8	0.45		0.75		0.76
# 9	0.50		0.76		0.78
# 10	0.50		0.77		0.78
# 11	0.48		0.76		0.78
# 12	0.46		0.76		0.78
# 13	0.49		0.77		0.78
# 14	0.48		0.77		0.79
# 15	0.47		0.76		0.78
# 16	0.47		0.76		0.78
# 17	0.49		0.77		0.78
# 18	0.48		0.77		0.78
# 19	0.50		0.77		0.78
# 20	0.50		0.77		0.78
# t = 20 was best iteration with accuracy 0.78
#
# -----------------------------------------------
# 34 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.51		0.75		0.78
# 2	0.51		0.76		0.79
# 3	0.47		0.76		0.79
# 4	0.47		0.76		0.79
# 5	0.49		0.76		0.80
# 6	0.48		0.76		0.80
# 7	0.48		0.77		0.80
# 8	0.51		0.77		0.80
# 9	0.46		0.77		0.80
# 10	0.46		0.77		0.80
# 11	0.49		0.77		0.80
# 12	0.49		0.77		0.80
# 13	0.53		0.77		0.80
# 14	0.51		0.76		0.80
# 15	0.47		0.76		0.80
# 16	0.47		0.76		0.80
# 17	0.50		0.76		0.80
# 18	0.46		0.76		0.80
# 19	0.47		0.76		0.80
# 20	0.45		0.76		0.80
# t = 7 was best iteration with accuracy 0.80
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.54		0.74		0.78
# 2	0.38		0.74		0.78
# 3	0.49		0.71		0.69
# 4	0.43		0.75		0.79
# 5	0.47		0.77		0.78
# 6	0.49		0.76		0.79
# 7	0.47		0.77		0.79
# 8	0.42		0.78		0.78
# 9	0.46		0.78		0.78
# 10	0.47		0.78		0.79
# 11	0.46		0.78		0.79
# 12	0.48		0.78		0.79
# 13	0.47		0.77		0.79
# 14	0.48		0.78		0.79
# 15	0.49		0.77		0.80
# 16	0.48		0.77		0.79
# 17	0.47		0.77		0.80
# 18	0.47		0.77		0.79
# 19	0.45		0.77		0.79
# 20	0.46		0.77		0.79
# t = 8 was best iteration with accuracy 0.78
#
# -----------------------------------------------
# 35 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.51		0.75		0.79
# 2	0.46		0.76		0.79
# 3	0.43		0.76		0.79
# 4	0.48		0.76		0.80
# 5	0.45		0.76		0.80
# 6	0.46		0.76		0.80
# 7	0.47		0.76		0.80
# 8	0.49		0.76		0.80
# 9	0.49		0.76		0.80
# 10	0.46		0.76		0.80
# 11	0.48		0.76		0.80
# 12	0.50		0.76		0.80
# 13	0.47		0.76		0.80
# 14	0.47		0.76		0.80
# 15	0.49		0.76		0.80
# 16	0.46		0.76		0.80
# 17	0.48		0.76		0.80
# 18	0.50		0.76		0.80
# 19	0.50		0.76		0.80
# 20	0.49		0.76		0.80
# t = 3 was best iteration with accuracy 0.79
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.48		0.74		0.78
# 2	0.42		0.74		0.78
# 3	0.49		0.73		0.76
# 4	0.51		0.73		0.76
# 5	0.51		0.74		0.77
# 6	0.47		0.78		0.78
# 7	0.47		0.76		0.78
# 8	0.48		0.77		0.77
# 9	0.44		0.76		0.77
# 10	0.47		0.76		0.77
# 11	0.47		0.76		0.77
# 12	0.48		0.77		0.78
# 13	0.50		0.77		0.78
# 14	0.45		0.76		0.79
# 15	0.45		0.77		0.78
# 16	0.47		0.77		0.79
# 17	0.47		0.77		0.79
# 18	0.48		0.77		0.79
# 19	0.48		0.77		0.79
# 20	0.48		0.78		0.79
# t = 6 was best iteration with accuracy 0.78
#
# -----------------------------------------------
# 36 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.50		0.76		0.79
# 2	0.49		0.76		0.79
# 3	0.47		0.76		0.80
# 4	0.48		0.76		0.79
# 5	0.46		0.76		0.80
# 6	0.49		0.76		0.80
# 7	0.49		0.77		0.80
# 8	0.49		0.76		0.80
# 9	0.49		0.76		0.80
# 10	0.47		0.76		0.80
# 11	0.48		0.76		0.80
# 12	0.51		0.76		0.80
# 13	0.47		0.76		0.80
# 14	0.49		0.76		0.80
# 15	0.48		0.76		0.80
# 16	0.50		0.76		0.80
# 17	0.46		0.76		0.80
# 18	0.48		0.76		0.80
# 19	0.52		0.76		0.80
# 20	0.49		0.76		0.80
# t = 7 was best iteration with accuracy 0.80
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.47		0.74		0.78
# 2	0.42		0.74		0.78
# 3	0.50		0.75		0.79
# 4	0.49		0.75		0.79
# 5	0.48		0.75		0.78
# 6	0.47		0.75		0.79
# 7	0.49		0.75		0.78
# 8	0.49		0.75		0.79
# 9	0.49		0.75		0.79
# 10	0.48		0.76		0.79
# 11	0.48		0.76		0.79
# 12	0.48		0.76		0.79
# 13	0.45		0.76		0.79
# 14	0.49		0.76		0.79
# 15	0.49		0.76		0.79
# 16	0.46		0.76		0.79
# 17	0.53		0.76		0.79
# 18	0.48		0.77		0.79
# 19	0.48		0.77		0.79
# 20	0.47		0.77		0.79
# t = 19 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 37 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.49		0.77		0.79
# 2	0.49		0.76		0.79
# 3	0.49		0.76		0.79
# 4	0.49		0.76		0.79
# 5	0.47		0.76		0.79
# 6	0.47		0.76		0.79
# 7	0.48		0.77		0.79
# 8	0.45		0.76		0.79
# 9	0.47		0.76		0.79
# 10	0.47		0.76		0.79
# 11	0.50		0.76		0.80
# 12	0.51		0.76		0.80
# 13	0.48		0.76		0.80
# 14	0.51		0.76		0.80
# 15	0.47		0.76		0.80
# 16	0.47		0.76		0.79
# 17	0.47		0.76		0.79
# 18	0.49		0.76		0.79
# 19	0.49		0.76		0.79
# 20	0.50		0.76		0.79
# t = 1 was best iteration with accuracy 0.79
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.51		0.75		0.79
# 2	0.40		0.75		0.79
# 3	0.47		0.73		0.70
# 4	0.48		0.75		0.78
# 5	0.49		0.75		0.78
# 6	0.48		0.75		0.78
# 7	0.51		0.75		0.78
# 8	0.50		0.76		0.79
# 9	0.47		0.75		0.78
# 10	0.47		0.76		0.79
# 11	0.48		0.77		0.79
# 12	0.47		0.75		0.78
# 13	0.46		0.77		0.78
# 14	0.46		0.76		0.79
# 15	0.47		0.77		0.79
# 16	0.49		0.76		0.79
# 17	0.49		0.77		0.79
# 18	0.50		0.77		0.79
# 19	0.49		0.77		0.79
# 20	0.49		0.77		0.79
# t = 18 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 38 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.50		0.76		0.79
# 2	0.45		0.76		0.80
# 3	0.49		0.77		0.80
# 4	0.49		0.77		0.79
# 5	0.48		0.77		0.80
# 6	0.46		0.76		0.79
# 7	0.48		0.76		0.79
# 8	0.48		0.76		0.79
# 9	0.48		0.76		0.80
# 10	0.48		0.76		0.80
# 11	0.48		0.76		0.80
# 12	0.51		0.76		0.80
# 13	0.50		0.76		0.80
# 14	0.50		0.76		0.80
# 15	0.50		0.76		0.80
# 16	0.48		0.76		0.80
# 17	0.51		0.76		0.80
# 18	0.50		0.76		0.80
# 19	0.48		0.76		0.80
# 20	0.45		0.76		0.80
# t = 3 was best iteration with accuracy 0.80
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.48		0.74		0.78
# 2	0.44		0.74		0.78
# 3	0.48		0.75		0.78
# 4	0.48		0.75		0.78
# 5	0.48		0.75		0.78
# 6	0.49		0.76		0.79
# 7	0.46		0.76		0.78
# 8	0.41		0.77		0.79
# 9	0.45		0.77		0.79
# 10	0.47		0.76		0.79
# 11	0.47		0.76		0.80
# 12	0.45		0.77		0.79
# 13	0.47		0.77		0.79
# 14	0.46		0.77		0.79
# 15	0.47		0.77		0.78
# 16	0.48		0.78		0.78
# 17	0.46		0.78		0.78
# 18	0.47		0.78		0.78
# 19	0.45		0.78		0.78
# 20	0.49		0.78		0.78
# t = 17 was best iteration with accuracy 0.78
#
# -----------------------------------------------
# 39 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.35
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.49		0.76		0.78
# 2	0.49		0.77		0.80
# 3	0.49		0.76		0.80
# 4	0.46		0.76		0.79
# 5	0.49		0.77		0.79
# 6	0.48		0.76		0.79
# 7	0.48		0.76		0.79
# 8	0.48		0.76		0.80
# 9	0.43		0.77		0.79
# 10	0.50		0.77		0.79
# 11	0.50		0.76		0.79
# 12	0.48		0.76		0.79
# 13	0.48		0.76		0.79
# 14	0.47		0.76		0.79
# 15	0.44		0.76		0.79
# 16	0.46		0.76		0.79
# 17	0.49		0.76		0.79
# 18	0.49		0.76		0.79
# 19	0.50		0.76		0.79
# 20	0.46		0.76		0.79
# t = 2 was best iteration with accuracy 0.80
#
# WITH CLASS PRIOR 0.35
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.49		0.74		0.78
# 2	0.44		0.74		0.78
# 3	0.51		0.75		0.78
# 4	0.50		0.75		0.78
# 5	0.47		0.75		0.78
# 6	0.49		0.77		0.79
# 7	0.47		0.77		0.79
# 8	0.45		0.77		0.79
# 9	0.47		0.77		0.79
# 10	0.45		0.76		0.79
# 11	0.49		0.78		0.79
# 12	0.45		0.77		0.79
# 13	0.47		0.77		0.79
# 14	0.46		0.77		0.79
# 15	0.44		0.78		0.79
# 16	0.43		0.77		0.79
# 17	0.46		0.77		0.79
# 18	0.49		0.77		0.79
# 19	0.46		0.77		0.79
# 20	0.45		0.77		0.79
# t = 11 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 40 / 40 complete
# -----------------------------------------------

# %%
table_results(svm_arr, tree_arr)
# Out:
# (Performance on test set)
#
# 50 comparisons
# 	acc	sderr
# SVM: 	77.4	0.1
# Tree: 	74.6	0.4
#
# 200 comparisons
# 	acc	sderr
# SVM: 	79.5	0.1
# Tree: 	78.7	0.1
