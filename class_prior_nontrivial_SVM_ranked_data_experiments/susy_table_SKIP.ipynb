# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_svmlight_file
from sklearn.model_selection import train_test_split
import sys; sys.path.insert(0,'..')
from main import *

# %%
X = np.load('../data/susy/X.npy', allow_pickle=True)
y = np.load('../data/susy/y.npy', allow_pickle=True)

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.5, stratify=y, 
                                                    shuffle=True, random_state=1)

# %%
svm_arr, tree_arr = data_size_experiment(X_train, y_train, X_test, y_test,
                                         experiment_type='table', kernel='linear',
                                         random_state=1, verbose=True)
# Out:
# PRELIMINARY
# Training accuracy of supervised SVM: 0.79
#
# GENERATE W
# [[-1. -1.]
#  [-1.  1.]
#  [ 1. -1.]
#  [ 1.  1.]] [12  9 21  8]
# Training accuracy of pairwise rank SVM: 0.98
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.70
# 2	0.72		0.71
# 3	0.73		0.71
# 4	0.73		0.70
# 5	0.73		0.71
# 6	0.73		0.71
# 7	0.73		0.71
# 8	0.73		0.71
# 9	0.73		0.71
# 10	0.73		0.71
# 11	0.73		0.71
# 12	0.73		0.71
# 13	0.73		0.71
# 14	0.73		0.71
# 15	0.73		0.71
# 16	0.73		0.71
# 17	0.73		0.71
# 18	0.73		0.71
# 19	0.73		0.71
# 20	0.73		0.71
# t = 5 was best iteration with accuracy 0.71
#
# -----------------------------------------------
# 1 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.73		0.70
# 2	0.72		0.71
# 3	0.73		0.71
# 4	0.73		0.71
# 5	0.73		0.71
# 6	0.73		0.71
# 7	0.73		0.71
# 8	0.73		0.71
# 9	0.73		0.71
# 10	0.73		0.71
# 11	0.73		0.71
# 12	0.73		0.71
# 13	0.73		0.71
# 14	0.73		0.71
# 15	0.73		0.71
# 16	0.73		0.71
# 17	0.73		0.71
# 18	0.73		0.71
# 19	0.73		0.71
# 20	0.73		0.71
# t = 7 was best iteration with accuracy 0.71
#
# -----------------------------------------------
# 2 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.73		0.70
# 2	0.72		0.71
# 3	0.73		0.71
# 4	0.73		0.71
# 5	0.73		0.71
# 6	0.73		0.71
# 7	0.73		0.71
# 8	0.73		0.71
# 9	0.73		0.71
# 10	0.73		0.71
# 11	0.73		0.71
# 12	0.73		0.71
# 13	0.73		0.71
# 14	0.73		0.71
# 15	0.73		0.71
# 16	0.73		0.71
# 17	0.73		0.71
# 18	0.73		0.71
# 19	0.73		0.71
# 20	0.73		0.71
# t = 19 was best iteration with accuracy 0.71
#
# -----------------------------------------------
# 3 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.71
# 2	0.73		0.71
# 3	0.73		0.71
# 4	0.73		0.71
# 5	0.73		0.71
# 6	0.72		0.71
# 7	0.72		0.70
# 8	0.73		0.71
# 9	0.73		0.70
# 10	0.73		0.70
# 11	0.73		0.70
# 12	0.73		0.70
# 13	0.73		0.70
# 14	0.73		0.70
# 15	0.73		0.70
# 16	0.73		0.70
# 17	0.73		0.70
# 18	0.73		0.70
# 19	0.73		0.70
# 20	0.73		0.70
# t = 3 was best iteration with accuracy 0.71
#
# -----------------------------------------------
# 4 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.71
# 2	0.73		0.71
# 3	0.73		0.71
# 4	0.73		0.71
# 5	0.73		0.71
# 6	0.73		0.71
# 7	0.73		0.71
# 8	0.73		0.71
# 9	0.73		0.71
# 10	0.73		0.71
# 11	0.73		0.71
# 12	0.73		0.71
# 13	0.73		0.71
# 14	0.73		0.71
# 15	0.73		0.71
# 16	0.73		0.71
# 17	0.73		0.71
# 18	0.73		0.71
# 19	0.73		0.71
# 20	0.73		0.71
# t = 4 was best iteration with accuracy 0.71
#
# -----------------------------------------------
# 5 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.71
# 2	0.72		0.72
# 3	0.72		0.71
# 4	0.72		0.71
# 5	0.73		0.71
# 6	0.73		0.71
# /Users/Ashtekar15/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 7	0.73		0.71
# 8	0.73		0.71
# 9	0.73		0.71
# 10	0.72		0.71
# 11	0.72		0.71
# 12	0.72		0.71
# 13	0.72		0.71
# 14	0.72		0.70
# 15	0.73		0.71
# 16	0.73		0.71
# 17	0.73		0.71
# 18	0.73		0.71
# 19	0.73		0.71
# 20	0.73		0.71
# t = 16 was best iteration with accuracy 0.71
#
# -----------------------------------------------
# 6 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.70
# 2	0.73		0.71
# 3	0.73		0.71
# 4	0.73		0.71
# 5	0.73		0.70
# 6	0.73		0.71
# 7	0.73		0.71
# 8	0.73		0.71
# 9	0.73		0.71
# 10	0.73		0.71
# 11	0.73		0.71
# 12	0.73		0.71
# 13	0.73		0.71
# 14	0.73		0.71
# 15	0.73		0.71
# 16	0.73		0.71
# 17	0.73		0.71
# 18	0.73		0.71
# 19	0.73		0.71
# 20	0.73		0.71
# t = 16 was best iteration with accuracy 0.71
#
# -----------------------------------------------
# 7 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.73		0.71
# 2	0.73		0.71
# 3	0.73		0.71
# 4	0.73		0.71
# 5	0.73		0.71
# 6	0.73		0.71
# 7	0.73		0.71
# 8	0.73		0.71
# 9	0.73		0.71
# 10	0.73		0.71
# 11	0.73		0.71
# 12	0.73		0.71
# 13	0.73		0.71
# 14	0.73		0.70
# 15	0.73		0.70
# 16	0.73		0.70
# 17	0.73		0.70
# 18	0.73		0.70
# 19	0.73		0.71
# 20	0.73		0.71
# t = 3 was best iteration with accuracy 0.71
#
# -----------------------------------------------
# 8 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.70
# 2	0.72		0.70
# 3	0.72		0.70
# 4	0.73		0.71
# 5	0.72		0.70
# 6	0.72		0.70
# 7	0.73		0.70
# 8	0.73		0.70
# 9	0.73		0.70
# 10	0.73		0.71
# 11	0.73		0.71
# 12	0.73		0.71
# 13	0.73		0.71
# 14	0.73		0.71
# 15	0.73		0.71
# 16	0.73		0.71
# 17	0.73		0.71
# 18	0.73		0.71
# 19	0.73		0.71
# 20	0.73		0.71
# t = 8 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 9 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.73		0.71
# 2	0.73		0.70
# 3	0.73		0.71
# 4	0.73		0.70
# 5	0.73		0.70
# 6	0.73		0.70
# 7	0.73		0.70
# 8	0.73		0.70
# 9	0.73		0.70
# 10	0.73		0.70
# 11	0.73		0.70
# 12	0.73		0.70
# 13	0.73		0.70
# 14	0.73		0.71
# 15	0.73		0.71
# 16	0.73		0.71
# 17	0.73		0.71
# 18	0.73		0.71
# 19	0.73		0.71
# 20	0.73		0.71
# t = 7 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 10 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.73		0.72
# 2	0.73		0.71
# 3	0.73		0.71
# 4	0.73		0.71
# 5	0.73		0.71
# 6	0.73		0.71
# 7	0.73		0.71
# 8	0.73		0.71
# 9	0.73		0.71
# 10	0.73		0.71
# 11	0.73		0.71
# 12	0.73		0.71
# 13	0.73		0.71
# 14	0.73		0.71
# 15	0.73		0.71
# 16	0.73		0.71
# 17	0.73		0.71
# 18	0.73		0.71
# 19	0.73		0.71
# 20	0.73		0.71
# t = 3 was best iteration with accuracy 0.71
#
# -----------------------------------------------
# 11 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.73		0.71
# 2	0.73		0.71
# 3	0.73		0.71
# 4	0.73		0.71
# 5	0.73		0.71
# 6	0.73		0.71
# 7	0.73		0.71
# 8	0.73		0.71
# 9	0.73		0.70
# 10	0.73		0.71
# 11	0.73		0.71
# 12	0.73		0.71
# 13	0.73		0.71
# 14	0.73		0.71
# 15	0.73		0.71
# 16	0.73		0.71
# 17	0.73		0.71
# 18	0.73		0.71
# 19	0.73		0.71
# 20	0.73		0.71
# t = 13 was best iteration with accuracy 0.71
#
# -----------------------------------------------
# 12 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.70
# 2	0.73		0.71
# 3	0.73		0.71
# 4	0.73		0.70
# 5	0.73		0.71
# 6	0.73		0.71
# 7	0.73		0.71
# 8	0.73		0.71
# 9	0.73		0.71
# 10	0.73		0.71
# 11	0.73		0.71
# 12	0.73		0.71
# 13	0.73		0.71
# 14	0.73		0.71
# 15	0.73		0.71
# 16	0.73		0.71
# 17	0.73		0.71
# 18	0.73		0.71
# 19	0.73		0.71
# 20	0.73		0.71
# t = 4 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 13 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.73		0.71
# 2	0.73		0.71
# 3	0.73		0.71
# 4	0.73		0.71
# 5	0.73		0.71
# 6	0.73		0.71
# 7	0.73		0.71
# 8	0.73		0.71
# 9	0.73		0.71
# 10	0.73		0.71
# 11	0.73		0.71
# 12	0.73		0.71
# 13	0.73		0.71
# 14	0.73		0.71
# 15	0.73		0.71
# 16	0.73		0.71
# 17	0.73		0.71
# 18	0.73		0.71
# 19	0.73		0.71
# 20	0.73		0.71
# t = 15 was best iteration with accuracy 0.71
#
# -----------------------------------------------
# 14 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.73		0.70
# 2	0.73		0.70
# 3	0.73		0.71
# 4	0.73		0.70
# 5	0.73		0.70
# 6	0.73		0.70
# 7	0.73		0.70
# 8	0.73		0.70
# 9	0.73		0.70
# /Users/Ashtekar15/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 10	0.73		0.70
# 11	0.73		0.70
# 12	0.73		0.70
# 13	0.73		0.70
# 14	0.73		0.70
# 15	0.73		0.70
# 16	0.73		0.70
# 17	0.73		0.70
# 18	0.73		0.70
# 19	0.73		0.70
# 20	0.73		0.70
# t = 16 was best iteration with accuracy 0.70
#
# -----------------------------------------------
# 15 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.70
# 2	0.72		0.70
# 3	0.73		0.70
# 4	0.72		0.70
# 5	0.73		0.71
# 6	0.73		0.71
# 7	0.73		0.71
# 8	0.73		0.71
# 9	0.73		0.71
# 10	0.73		0.70
# 11	0.73		0.71
# 12	0.73		0.71
# 13	0.73		0.71
# 14	0.73		0.71
# 15	0.73		0.71
# 16	0.73		0.71
# 17	0.73		0.71
# 18	0.73		0.71
# 19	0.73		0.71
# 20	0.73		0.71
# t = 11 was best iteration with accuracy 0.71
#
# -----------------------------------------------
# 16 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.73		0.71
# 2	0.72		0.71
# 3	0.73		0.70
# 4	0.73		0.70
# 5	0.73		0.70
# 6	0.73		0.71
# 7	0.73		0.71
# 8	0.73		0.71
# 9	0.73		0.71
# 10	0.73		0.71
# 11	0.73		0.71
# 12	0.73		0.71
# 13	0.73		0.71
# 14	0.73		0.71
# 15	0.73		0.71
# 16	0.73		0.71
# 17	0.73		0.71
# 18	0.73		0.71
# 19	0.73		0.71
# 20	0.73		0.71
# t = 13 was best iteration with accuracy 0.71
#
# -----------------------------------------------
# 17 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.73		0.71
# 2	0.72		0.70
# 3	0.73		0.70
# 4	0.73		0.70
# 5	0.73		0.70
# 6	0.73		0.70
# 7	0.73		0.71
# 8	0.73		0.71
# 9	0.73		0.71
# 10	0.73		0.71
# 11	0.73		0.71
# 12	0.73		0.71
# 13	0.73		0.71
# 14	0.73		0.71
# 15	0.73		0.71
# 16	0.73		0.71
# 17	0.73		0.71
# 18	0.73		0.71
# 19	0.73		0.71
# 20	0.73		0.71
# t = 14 was best iteration with accuracy 0.71
#
# -----------------------------------------------
# 18 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.71
# 2	0.73		0.71
# 3	0.73		0.71
# 4	0.73		0.71
# 5	0.72		0.71
# 6	0.73		0.71
# 7	0.73		0.71
# 8	0.73		0.71
# 9	0.73		0.71
# 10	0.73		0.71
# 11	0.73		0.71
# 12	0.73		0.71
# 13	0.73		0.71
# 14	0.73		0.71
# 15	0.73		0.71
# 16	0.73		0.71
# 17	0.73		0.71
# 18	0.73		0.71
# 19	0.73		0.71
# 20	0.73		0.71
# t = 3 was best iteration with accuracy 0.71
#
# -----------------------------------------------
# 19 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.73		0.70
# 2	0.73		0.70
# 3	0.73		0.71
# 4	0.73		0.71
# 5	0.73		0.71
# 6	0.73		0.71
# 7	0.73		0.71
# 8	0.73		0.71
# 9	0.73		0.71
# 10	0.73		0.71
# 11	0.73		0.71
# 12	0.73		0.71
# 13	0.73		0.71
# 14	0.73		0.71
# 15	0.73		0.71
# 16	0.73		0.71
# 17	0.73		0.71
# 18	0.73		0.71
# 19	0.73		0.71
# 20	0.73		0.71
# t = 10 was best iteration with accuracy 0.71
#
# -----------------------------------------------
# 20 / 40 complete
# -----------------------------------------------
#
# PRELIMINARY
# Training accuracy of supervised SVM: 0.78
#
# GENERATE W
# [[-1. -1.]
#  [-1.  1.]
#  [ 1. -1.]
#  [ 1.  1.]] [50 58 48 44]
# Training accuracy of pairwise rank SVM: 0.97
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.79		0.76
# 2	0.78		0.76
# 3	0.78		0.76
# 4	0.78		0.76
# 5	0.78		0.76
# 6	0.79		0.76
# 7	0.79		0.76
# 8	0.78		0.76
# 9	0.78		0.76
# 10	0.78		0.76
# 11	0.78		0.76
# 12	0.78		0.76
# 13	0.78		0.77
# 14	0.78		0.77
# 15	0.79		0.77
# 16	0.78		0.77
# 17	0.78		0.76
# 18	0.78		0.77
# 19	0.78		0.76
# 20	0.78		0.76
# t = 7 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 21 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.78		0.77
# 2	0.78		0.76
# 3	0.78		0.77
# 4	0.79		0.77
# 5	0.79		0.77
# 6	0.79		0.77
# 7	0.78		0.77
# 8	0.78		0.76
# 9	0.78		0.76
# 10	0.78		0.76
# 11	0.78		0.76
# 12	0.78		0.76
# 13	0.78		0.76
# 14	0.78		0.76
# 15	0.78		0.77
# 16	0.78		0.77
# 17	0.78		0.76
# 18	0.78		0.76
# 19	0.78		0.77
# 20	0.79		0.76
# t = 4 was best iteration with accuracy 0.77
#
# -----------------------------------------------
# 22 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.79		0.75
# 2	0.78		0.76
# 3	0.78		0.77
# 4	0.78		0.77
# 5	0.78		0.77
# 6	0.78		0.77
# 7	0.78		0.77
# 8	0.78		0.76
# 9	0.78		0.76
# 10	0.78		0.77
# 11	0.78		0.77
# 12	0.78		0.77
# 13	0.78		0.77
# 14	0.78		0.77
# 15	0.78		0.77
# 16	0.78		0.77
# 17	0.78		0.77
# 18	0.78		0.77
# 19	0.78		0.77
# 20	0.78		0.77
# t = 1 was best iteration with accuracy 0.75
#
# -----------------------------------------------
# 23 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.79		0.75
# 2	0.78		0.74
# 3	0.78		0.75
# 4	0.78		0.76
# /Users/Ashtekar15/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 5	0.79		0.76
# 6	0.78		0.76
# 7	0.78		0.76
# 8	0.78		0.76
# 9	0.78		0.76
# 10	0.78		0.76
# 11	0.78		0.76
# 12	0.79		0.76
# 13	0.79		0.76
# 14	0.79		0.77
# /Users/Ashtekar15/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 15	0.79		0.76
# 16	0.78		0.76
# 17	0.78		0.76
# 18	0.78		0.76
# 19	0.78		0.76
# 20	0.78		0.76
# t = 1 was best iteration with accuracy 0.75
#
# -----------------------------------------------
# 24 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.79		0.76
# 2	0.78		0.77
# 3	0.79		0.77
# 4	0.78		0.76
# 5	0.78		0.76
# 6	0.78		0.77
# 7	0.78		0.77
# 8	0.78		0.77
# 9	0.78		0.77
# 10	0.78		0.77
# 11	0.78		0.77
# 12	0.78		0.77
# 13	0.78		0.77
# 14	0.78		0.77
# 15	0.78		0.77
# 16	0.78		0.77
# 17	0.78		0.77
# 18	0.78		0.77
# 19	0.78		0.77
# 20	0.78		0.77
# t = 3 was best iteration with accuracy 0.77
#
# -----------------------------------------------
# 25 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.79		0.76
# 2	0.78		0.75
# 3	0.78		0.76
# 4	0.79		0.76
# 5	0.78		0.77
# 6	0.79		0.77
# 7	0.79		0.76
# 8	0.78		0.76
# 9	0.78		0.76
# 10	0.78		0.76
# 11	0.78		0.76
# 12	0.78		0.76
# 13	0.78		0.76
# 14	0.78		0.76
# 15	0.78		0.76
# 16	0.78		0.76
# 17	0.78		0.76
# 18	0.78		0.76
# 19	0.78		0.76
# 20	0.78		0.76
# t = 6 was best iteration with accuracy 0.77
#
# -----------------------------------------------
# 26 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.78		0.77
# 2	0.78		0.76
# 3	0.78		0.76
# 4	0.78		0.76
# 5	0.79		0.76
# 6	0.78		0.76
# 7	0.78		0.76
# 8	0.78		0.76
# 9	0.78		0.76
# 10	0.78		0.76
# 11	0.78		0.76
# 12	0.79		0.76
# 13	0.78		0.76
# 14	0.78		0.76
# 15	0.78		0.76
# 16	0.78		0.76
# 17	0.78		0.76
# 18	0.78		0.76
# 19	0.78		0.76
# 20	0.78		0.76
# t = 5 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 27 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.79		0.75
# 2	0.78		0.76
# 3	0.78		0.76
# 4	0.78		0.76
# 5	0.78		0.76
# 6	0.78		0.76
# 7	0.78		0.76
# 8	0.78		0.76
# 9	0.78		0.76
# 10	0.78		0.76
# 11	0.78		0.76
# 12	0.78		0.76
# 13	0.78		0.76
# 14	0.78		0.76
# 15	0.78		0.76
# 16	0.78		0.76
# 17	0.78		0.76
# 18	0.78		0.76
# 19	0.78		0.76
# 20	0.78		0.76
# t = 1 was best iteration with accuracy 0.75
#
# -----------------------------------------------
# 28 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.78		0.76
# 2	0.79		0.77
# 3	0.78		0.77
# 4	0.79		0.77
# 5	0.79		0.77
# 6	0.79		0.77
# 7	0.79		0.77
# 8	0.79		0.77
# 9	0.79		0.77
# 10	0.79		0.77
# 11	0.78		0.77
# 12	0.78		0.77
# 13	0.78		0.77
# 14	0.79		0.77
# 15	0.79		0.76
# 16	0.79		0.77
# 17	0.78		0.76
# 18	0.78		0.77
# 19	0.78		0.77
# 20	0.78		0.76
# t = 4 was best iteration with accuracy 0.77
#
# -----------------------------------------------
# 29 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.79		0.76
# 2	0.78		0.76
# 3	0.78		0.76
# 4	0.78		0.76
# 5	0.78		0.76
# 6	0.78		0.76
# 7	0.78		0.76
# 8	0.78		0.76
# 9	0.78		0.76
# 10	0.78		0.76
# 11	0.78		0.76
# 12	0.78		0.76
# 13	0.78		0.76
# 14	0.78		0.76
# 15	0.78		0.76
# 16	0.78		0.76
# 17	0.78		0.76
# 18	0.78		0.76
# 19	0.78		0.76
# 20	0.78		0.76
# t = 1 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 30 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.78		0.76
# 2	0.78		0.75
# 3	0.78		0.76
# 4	0.78		0.76
# 5	0.78		0.76
# 6	0.78		0.76
# 7	0.78		0.76
# 8	0.78		0.76
# 9	0.78		0.76
# 10	0.78		0.76
# 11	0.78		0.76
# 12	0.78		0.76
# 13	0.78		0.76
# 14	0.78		0.76
# 15	0.78		0.76
# 16	0.78		0.76
# 17	0.78		0.76
# 18	0.78		0.76
# 19	0.78		0.76
# 20	0.78		0.76
# t = 1 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 31 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.79		0.76
# 2	0.78		0.76
# 3	0.78		0.76
# 4	0.78		0.76
# 5	0.78		0.77
# 6	0.79		0.77
# 7	0.79		0.77
# 8	0.79		0.76
# 9	0.79		0.76
# 10	0.78		0.76
# 11	0.78		0.76
# 12	0.78		0.76
# 13	0.79		0.77
# 14	0.78		0.76
# 15	0.79		0.76
# 16	0.78		0.76
# 17	0.78		0.76
# 18	0.78		0.76
# 19	0.78		0.76
# 20	0.78		0.76
# t = 1 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 32 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.78		0.77
# 2	0.78		0.77
# 3	0.79		0.77
# 4	0.78		0.77
# 5	0.78		0.77
# 6	0.78		0.76
# 7	0.78		0.77
# 8	0.78		0.76
# 9	0.78		0.76
# 10	0.78		0.76
# 11	0.78		0.76
# 12	0.78		0.76
# 13	0.78		0.76
# 14	0.78		0.76
# 15	0.78		0.76
# 16	0.78		0.76
# 17	0.78		0.76
# 18	0.78		0.76
# 19	0.78		0.76
# 20	0.78		0.76
# t = 3 was best iteration with accuracy 0.77
#
# -----------------------------------------------
# 33 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.78		0.76
# 2	0.78		0.76
# 3	0.78		0.77
# 4	0.79		0.77
# 5	0.78		0.77
# 6	0.78		0.77
# 7	0.78		0.76
# 8	0.78		0.77
# 9	0.78		0.77
# 10	0.78		0.76
# 11	0.78		0.76
# 12	0.78		0.76
# 13	0.78		0.76
# 14	0.78		0.76
# 15	0.78		0.76
# 16	0.78		0.76
# 17	0.78		0.76
# 18	0.78		0.76
# 19	0.78		0.76
# 20	0.78		0.76
# t = 4 was best iteration with accuracy 0.77
#
# -----------------------------------------------
# 34 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.79		0.76
# 2	0.78		0.76
# 3	0.78		0.76
# 4	0.78		0.76
# 5	0.79		0.76
# 6	0.78		0.76
# 7	0.78		0.76
# 8	0.78		0.76
# 9	0.78		0.76
# 10	0.78		0.77
# 11	0.78		0.76
# 12	0.78		0.77
# 13	0.78		0.77
# 14	0.78		0.76
# 15	0.78		0.76
# 16	0.78		0.76
# 17	0.78		0.76
# 18	0.78		0.76
# 19	0.78		0.76
# 20	0.78		0.76
# t = 1 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 35 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.78		0.76
# 2	0.79		0.76
# 3	0.78		0.77
# 4	0.78		0.77
# 5	0.79		0.77
# 6	0.79		0.76
# 7	0.78		0.76
# 8	0.79		0.76
# 9	0.79		0.76
# 10	0.79		0.77
# 11	0.79		0.76
# 12	0.79		0.76
# 13	0.79		0.76
# 14	0.79		0.76
# 15	0.78		0.77
# 16	0.79		0.76
# 17	0.79		0.76
# 18	0.78		0.76
# 19	0.78		0.77
# 20	0.78		0.76
# t = 9 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 36 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.79		0.77
# 2	0.78		0.77
# 3	0.79		0.77
# 4	0.78		0.77
# 5	0.79		0.76
# 6	0.78		0.77
# 7	0.78		0.77
# 8	0.78		0.77
# 9	0.78		0.77
# 10	0.78		0.77
# 11	0.78		0.77
# 12	0.78		0.76
# 13	0.78		0.76
# 14	0.78		0.76
# 15	0.78		0.76
# 16	0.78		0.76
# 17	0.78		0.76
# 18	0.78		0.76
# 19	0.78		0.76
# 20	0.78		0.76
# t = 1 was best iteration with accuracy 0.77
#
# -----------------------------------------------
# 37 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.78		0.76
# 2	0.78		0.76
# 3	0.79		0.77
# 4	0.78		0.77
# 5	0.78		0.77
# 6	0.78		0.76
# 7	0.78		0.76
# 8	0.78		0.76
# 9	0.78		0.76
# 10	0.78		0.76
# 11	0.78		0.76
# 12	0.78		0.76
# 13	0.79		0.76
# 14	0.78		0.76
# 15	0.78		0.77
# 16	0.78		0.77
# 17	0.79		0.76
# 18	0.78		0.76
# 19	0.78		0.77
# 20	0.78		0.76
# t = 3 was best iteration with accuracy 0.77
#
# -----------------------------------------------
# 38 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.79		0.76
# /Users/Ashtekar15/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 2	0.78		0.76
# 3	0.78		0.77
# 4	0.78		0.77
# 5	0.78		0.77
# 6	0.78		0.77
# 7	0.78		0.77
# 8	0.78		0.77
# 9	0.79		0.77
# 10	0.78		0.77
# 11	0.79		0.77
# 12	0.79		0.76
# 13	0.79		0.77
# 14	0.79		0.77
# 15	0.79		0.77
# 16	0.79		0.77
# 17	0.79		0.77
# 18	0.79		0.77
# 19	0.79		0.77
# 20	0.79		0.76
# t = 14 was best iteration with accuracy 0.77
#
# -----------------------------------------------
# 39 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.78		0.77
# 2	0.78		0.77
# 3	0.78		0.77
# 4	0.78		0.77
# 5	0.78		0.77
# 6	0.78		0.77
# 7	0.78		0.77
# 8	0.78		0.77
# 9	0.78		0.76
# 10	0.78		0.76
# 11	0.78		0.76
# 12	0.78		0.76
# 13	0.78		0.76
# 14	0.78		0.76
# 15	0.78		0.76
# 16	0.78		0.76
# 17	0.78		0.76
# 18	0.78		0.76
# 19	0.78		0.76
# 20	0.78		0.76
# t = 11 was best iteration with accuracy 0.76
#
# -----------------------------------------------
# 40 / 40 complete
# -----------------------------------------------

# %%
table_results(svm_arr, tree_arr)
# Out:
# (Performance on test set)
#
# 50 comparisons
# 	acc	sderr
# SVM: 	70.8	0.1
# Tree: 	nan	nan
#
# 200 comparisons
# 	acc	sderr
# SVM: 	76.2	0.1
# Tree: 	nan	nan

# %%
eq1 = np.sum(y == 1) / y.size
max(eq1, 1 - eq1)
# Out:
# 0.5418000000000001
