# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import sys; sys.path.insert(0,'..')
from main import *

# %%
data = pd.read_csv('../data/banana/banana.csv')
X = data[['V1', 'V2']].values
y = data['Class'].values

# Since classes are 1, 2
y = (y - 1) * 2 - 1

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.5, stratify=y, 
                                                    shuffle=True, random_state=1)

# %%
svm_arr, tree_arr = data_size_experiment(X_train, y_train, X_test, y_test,
                                         experiment_type='table', kernel='linear',
                                         random_state=379, verbose=True)
# Out:
# PRELIMINARY
# Training accuracy of supervised SVM: 0.57
#
# GENERATE W
# [[-1 -1]
#  [-1  1]
#  [ 1 -1]
#  [ 1  1]] [17 13 12  8]
# Training accuracy of pairwise rank SVM: 1.00
#
# WITH CLASS PRIOR 0.43
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.51		0.48		0.45
# 2	0.52		0.48		0.45
# 3	0.49		0.48		0.45
# 4	0.51		0.49		0.46
# 5	0.50		0.49		0.46
# 6	0.49		0.49		0.46
# 7	0.47		0.49		0.46
# 8	0.46		0.48		0.46
# 9	0.47		0.49		0.46
# 10	0.48		0.49		0.46
# 11	0.51		0.49		0.46
# 12	0.49		0.49		0.46
# 13	0.48		0.49		0.46
# 14	0.53		0.49		0.46
# 15	0.46		0.49		0.46
# 16	0.48		0.49		0.46
# 17	0.48		0.49		0.46
# 18	0.45		0.49		0.46
# 19	0.52		0.49		0.46
# 20	0.47		0.49		0.46
# t = 2 was best iteration with accuracy 0.55
#
# WITH CLASS PRIOR 0.43
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.46		0.54		0.51
# 2	0.52		0.54		0.51
# 3	0.49		0.54		0.51
# 4	0.47		0.52		0.49
# 5	0.52		0.49		0.48
# 6	0.44		0.53		0.49
# 7	0.53		0.55		0.52
# 8	0.51		0.52		0.48
# 9	0.51		0.54		0.51
# 10	0.49		0.53		0.51
# 11	0.50		0.53		0.50
# 12	0.51		0.53		0.50
# 13	0.46		0.53		0.50
# 14	0.45		0.52		0.48
# 15	0.47		0.54		0.50
# 16	0.49		0.53		0.48
# 17	0.51		0.52		0.48
# 18	0.48		0.52		0.48
# 19	0.48		0.53		0.50
# 20	0.49		0.53		0.49
# t = 7 was best iteration with accuracy 0.52
#
# -----------------------------------------------
# 1 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.43
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.45		0.48		0.45
# 2	0.51		0.49		0.46
# 3	0.48		0.49		0.46
# 4	0.46		0.49		0.46
# 5	0.49		0.49		0.46
# 6	0.48		0.49		0.46
# 7	0.47		0.49		0.46
# 8	0.48		0.49		0.46
# 9	0.50		0.49		0.46
# 10	0.48		0.49		0.46
# 11	0.47		0.49		0.46
# 12	0.50		0.49		0.46
# 13	0.48		0.49		0.46
# 14	0.49		0.49		0.46
# 15	0.49		0.49		0.46
# 16	0.49		0.49		0.46
# 17	0.46		0.49		0.46
# 18	0.51		0.49		0.46
# 19	0.52		0.49		0.46
# 20	0.47		0.49		0.46
# t = 1 was best iteration with accuracy 0.55
#
# WITH CLASS PRIOR 0.43
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.45		0.54		0.50
# 2	0.54		0.54		0.50
# 3	0.51		0.47		0.48
# 4	0.46		0.50		0.46
# 5	0.47		0.51		0.48
# 6	0.49		0.54		0.50
# 7	0.48		0.53		0.49
# 8	0.50		0.53		0.50
# 9	0.47		0.54		0.50
# 10	0.53		0.54		0.51
# 11	0.50		0.53		0.50
# 12	0.46		0.52		0.48
# 13	0.52		0.52		0.49
# 14	0.51		0.52		0.49
# 15	0.52		0.53		0.50
# 16	0.48		0.51		0.48
# 17	0.50		0.52		0.49
# 18	0.52		0.52		0.48
# 19	0.50		0.53		0.50
# 20	0.48		0.51		0.48
# t = 1 was best iteration with accuracy 0.50
#
# -----------------------------------------------
# 2 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.43
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.50		0.50		0.46
# 2	0.49		0.50		0.47
# 3	0.49		0.49		0.46
# 4	0.49		0.49		0.46
# 5	0.51		0.49		0.46
# 6	0.49		0.50		0.47
# 7	0.51		0.49		0.46
# 8	0.50		0.49		0.46
# 9	0.53		0.49		0.46
# 10	0.52		0.49		0.46
# 11	0.45		0.49		0.46
# 12	0.52		0.49		0.46
# 13	0.50		0.49		0.46
# 14	0.49		0.49		0.46
# 15	0.48		0.49		0.46
# 16	0.49		0.49		0.46
# 17	0.43		0.49		0.46
# 18	0.49		0.49		0.46
# 19	0.47		0.49		0.46
# 20	0.49		0.49		0.46
# t = 4 was best iteration with accuracy 0.54
#
# WITH CLASS PRIOR 0.43
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.47		0.52		0.49
# 2	0.53		0.52		0.49
# 3	0.51		0.52		0.49
# 4	0.50		0.53		0.48
# 5	0.51		0.53		0.48
# 6	0.50		0.53		0.48
# 7	0.49		0.51		0.47
# 8	0.48		0.54		0.51
# 9	0.50		0.54		0.50
# 10	0.49		0.53		0.48
# 11	0.52		0.55		0.50
# 12	0.50		0.53		0.48
# 13	0.49		0.53		0.48
# 14	0.48		0.54		0.49
# 15	0.49		0.53		0.47
# 16	0.52		0.53		0.48
# 17	0.46		0.54		0.49
# 18	0.51		0.53		0.49
# 19	0.52		0.53		0.48
# 20	0.49		0.52		0.47
# t = 11 was best iteration with accuracy 0.50
#
# -----------------------------------------------
# 3 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.43
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.50		0.51		0.47
# 2	0.45		0.51		0.47
# 3	0.49		0.50		0.46
# 4	0.50		0.50		0.46
# 5	0.49		0.50		0.46
# 6	0.47		0.50		0.46
# 7	0.48		0.50		0.46
# 8	0.47		0.49		0.46
# 9	0.50		0.49		0.46
# 10	0.50		0.49		0.46
# 11	0.49		0.49		0.46
# 12	0.50		0.49		0.46
# 13	0.47		0.49		0.46
# 14	0.49		0.49		0.46
# 15	0.48		0.49		0.46
# 16	0.47		0.49		0.46
# 17	0.48		0.49		0.46
# 18	0.50		0.49		0.46
# 19	0.49		0.49		0.46
# 20	0.48		0.49		0.46
# t = 1 was best iteration with accuracy 0.53
#
# WITH CLASS PRIOR 0.43
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.47		0.44		0.41
# 2	0.50		0.44		0.41
# 3	0.49		0.47		0.40
# 4	0.50		0.47		0.43
# 5	0.51		0.52		0.48
# 6	0.47		0.53		0.47
# 7	0.50		0.56		0.52
# 8	0.50		0.53		0.48
# 9	0.49		0.54		0.51
# 10	0.50		0.53		0.50
# 11	0.50		0.55		0.51
# 12	0.48		0.54		0.48
# 13	0.49		0.54		0.50
# 14	0.47		0.53		0.49
# 15	0.51		0.53		0.50
# 16	0.48		0.53		0.49
# 17	0.49		0.53		0.48
# 18	0.49		0.52		0.47
# 19	0.51		0.53		0.49
# 20	0.49		0.53		0.50
# t = 1 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 4 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.43
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.51		0.48		0.45
# 2	0.47		0.48		0.45
# 3	0.47		0.49		0.46
# 4	0.49		0.49		0.46
# 5	0.49		0.49		0.46
# 6	0.51		0.49		0.45
# 7	0.48		0.49		0.46
# 8	0.45		0.49		0.46
# 9	0.49		0.49		0.46
# 10	0.48		0.49		0.46
# 11	0.50		0.49		0.46
# 12	0.50		0.49		0.46
# 13	0.50		0.49		0.46
# 14	0.49		0.49		0.46
# 15	0.49		0.49		0.46
# 16	0.50		0.49		0.46
# 17	0.49		0.49		0.46
# 18	0.50		0.49		0.46
# 19	0.47		0.49		0.46
# 20	0.47		0.49		0.46
# t = 2 was best iteration with accuracy 0.55
#
# WITH CLASS PRIOR 0.43
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.53		0.49		0.46
# 2	0.48		0.49		0.46
# 3	0.49		0.49		0.46
# 4	0.47		0.53		0.51
# 5	0.52		0.49		0.46
# 6	0.47		0.51		0.49
# 7	0.51		0.52		0.48
# 8	0.44		0.51		0.47
# 9	0.50		0.50		0.47
# 10	0.46		0.52		0.47
# 11	0.46		0.53		0.49
# 12	0.53		0.52		0.48
# 13	0.47		0.53		0.49
# 14	0.52		0.53		0.48
# 15	0.48		0.52		0.49
# 16	0.48		0.52		0.48
# 17	0.48		0.53		0.50
# 18	0.47		0.51		0.48
# 19	0.45		0.52		0.47
# 20	0.50		0.51		0.47
# t = 17 was best iteration with accuracy 0.50
#
# -----------------------------------------------
# 5 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.43
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.51		0.51		0.46
# 2	0.49		0.50		0.46
# 3	0.48		0.49		0.46
# 4	0.47		0.49		0.46
# 5	0.48		0.49		0.46
# 6	0.51		0.50		0.46
# 7	0.45		0.50		0.46
# 8	0.49		0.49		0.46
# 9	0.48		0.50		0.46
# 10	0.45		0.49		0.46
# 11	0.50		0.49		0.46
# 12	0.46		0.49		0.46
# 13	0.51		0.49		0.46
# 14	0.48		0.49		0.46
# 15	0.54		0.49		0.46
# 16	0.48		0.49		0.46
# 17	0.48		0.49		0.46
# 18	0.47		0.49		0.46
# 19	0.48		0.49		0.46
# 20	0.48		0.49		0.46
# t = 3 was best iteration with accuracy 0.54
#
# WITH CLASS PRIOR 0.43
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.50		0.47		0.44
# 2	0.51		0.47		0.44
# 3	0.50		0.47		0.44
# 4	0.50		0.55		0.48
# 5	0.51		0.50		0.45
# 6	0.48		0.52		0.48
# 7	0.48		0.51		0.46
# 8	0.48		0.52		0.48
# 9	0.51		0.52		0.47
# 10	0.49		0.54		0.48
# 11	0.53		0.51		0.47
# 12	0.47		0.52		0.47
# 13	0.52		0.52		0.48
# 14	0.51		0.54		0.49
# 15	0.49		0.52		0.48
# 16	0.49		0.54		0.49
# 17	0.48		0.54		0.49
# 18	0.51		0.52		0.49
# 19	0.50		0.54		0.49
# 20	0.48		0.53		0.49
# t = 4 was best iteration with accuracy 0.52
#
# -----------------------------------------------
# 6 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.43
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.48		0.50		0.47
# 2	0.46		0.49		0.46
# 3	0.47		0.49		0.46
# 4	0.48		0.49		0.46
# 5	0.47		0.49		0.46
# 6	0.45		0.49		0.46
# 7	0.46		0.49		0.46
# 8	0.50		0.49		0.46
# 9	0.51		0.49		0.46
# 10	0.47		0.49		0.46
# 11	0.51		0.49		0.46
# 12	0.49		0.49		0.46
# 13	0.48		0.49		0.46
# 14	0.49		0.49		0.46
# 15	0.45		0.49		0.46
# 16	0.50		0.49		0.46
# 17	0.46		0.49		0.46
# 18	0.49		0.49		0.46
# 19	0.49		0.49		0.46
# 20	0.45		0.49		0.46
# t = 6 was best iteration with accuracy 0.54
#
# WITH CLASS PRIOR 0.43
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.51		0.47		0.43
# 2	0.51		0.47		0.43
# 3	0.51		0.47		0.43
# 4	0.48		0.49		0.44
# 5	0.47		0.50		0.47
# 6	0.48		0.49		0.44
# 7	0.45		0.52		0.48
# 8	0.45		0.52		0.48
# 9	0.51		0.53		0.48
# 10	0.50		0.53		0.49
# 11	0.49		0.52		0.48
# 12	0.46		0.52		0.49
# 13	0.49		0.52		0.48
# 14	0.51		0.53		0.49
# 15	0.45		0.53		0.48
# 16	0.51		0.53		0.47
# 17	0.46		0.53		0.47
# 18	0.47		0.53		0.47
# 19	0.51		0.53		0.48
# 20	0.48		0.53		0.49
# t = 1 was best iteration with accuracy 0.57
#
# -----------------------------------------------
# 7 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.43
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.47		0.50		0.47
# 2	0.47		0.49		0.46
# 3	0.48		0.49		0.46
# 4	0.48		0.49		0.46
# 5	0.49		0.49		0.46
# 6	0.48		0.49		0.46
# 7	0.50		0.49		0.46
# 8	0.50		0.49		0.46
# 9	0.47		0.49		0.46
# 10	0.48		0.49		0.46
# 11	0.49		0.49		0.46
# 12	0.50		0.49		0.46
# 13	0.50		0.49		0.46
# 14	0.52		0.49		0.46
# 15	0.52		0.49		0.46
# 16	0.43		0.49		0.46
# 17	0.47		0.49		0.46
# 18	0.43		0.49		0.46
# 19	0.43		0.49		0.46
# 20	0.49		0.49		0.46
# t = 4 was best iteration with accuracy 0.54
#
# WITH CLASS PRIOR 0.43
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.48		0.55		0.50
# 2	0.54		0.55		0.50
# 3	0.47		0.55		0.52
# 4	0.48		0.52		0.49
# 5	0.48		0.53		0.50
# 6	0.48		0.55		0.52
# 7	0.52		0.53		0.50
# 8	0.47		0.51		0.48
# 9	0.47		0.54		0.50
# 10	0.53		0.52		0.49
# 11	0.47		0.54		0.50
# 12	0.49		0.54		0.50
# 13	0.48		0.53		0.50
# 14	0.47		0.52		0.48
# 15	0.50		0.53		0.50
# 16	0.46		0.52		0.48
# 17	0.52		0.53		0.49
# 18	0.48		0.54		0.49
# 19	0.47		0.53		0.49
# 20	0.48		0.53		0.49
# t = 1 was best iteration with accuracy 0.50
#
# -----------------------------------------------
# 8 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.43
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.48		0.49		0.45
# 2	0.47		0.49		0.47
# 3	0.49		0.49		0.46
# 4	0.47		0.49		0.46
# 5	0.47		0.49		0.46
# 6	0.48		0.49		0.46
# 7	0.51		0.49		0.46
# 8	0.49		0.49		0.46
# 9	0.48		0.49		0.46
# 10	0.47		0.49		0.46
# 11	0.50		0.49		0.46
# 12	0.51		0.49		0.46
# 13	0.46		0.49		0.46
# 14	0.49		0.49		0.46
# 15	0.49		0.49		0.46
# 16	0.49		0.49		0.46
# 17	0.49		0.49		0.46
# 18	0.47		0.49		0.46
# 19	0.46		0.49		0.46
# 20	0.46		0.49		0.46
# t = 14 was best iteration with accuracy 0.54
#
# WITH CLASS PRIOR 0.43
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.44		0.49		0.46
# 2	0.50		0.49		0.46
# 3	0.53		0.55		0.52
# 4	0.47		0.52		0.51
# 5	0.47		0.52		0.51
# 6	0.51		0.53		0.50
# 7	0.49		0.52		0.50
# 8	0.53		0.53		0.49
# 9	0.49		0.53		0.50
# 10	0.53		0.53		0.50
# 11	0.50		0.53		0.48
# 12	0.50		0.52		0.48
# 13	0.51		0.53		0.48
# 14	0.46		0.53		0.50
# 15	0.49		0.53		0.48
# 16	0.49		0.53		0.50
# 17	0.50		0.53		0.49
# 18	0.50		0.53		0.50
# 19	0.48		0.53		0.49
# 20	0.53		0.52		0.49
# t = 3 was best iteration with accuracy 0.52
#
# -----------------------------------------------
# 9 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.43
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.48		0.49		0.46
# 2	0.45		0.49		0.46
# 3	0.46		0.49		0.46
# 4	0.50		0.49		0.46
# 5	0.50		0.49		0.46
# 6	0.46		0.49		0.46
# 7	0.47		0.49		0.46
# 8	0.49		0.49		0.46
# 9	0.47		0.49		0.46
# 10	0.49		0.49		0.46
# 11	0.49		0.49		0.46
# 12	0.51		0.49		0.46
# 13	0.47		0.49		0.46
# 14	0.50		0.49		0.46
# 15	0.48		0.49		0.46
# 16	0.48		0.49		0.46
# 17	0.52		0.49		0.46
# 18	0.46		0.49		0.46
# 19	0.50		0.49		0.46
# 20	0.47		0.49		0.46
# t = 2 was best iteration with accuracy 0.54
#
# WITH CLASS PRIOR 0.43
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.50		0.55		0.53
# 2	0.46		0.55		0.53
# 3	0.50		0.55		0.53
# 4	0.46		0.52		0.50
# 5	0.52		0.54		0.52
# 6	0.50		0.53		0.51
# 7	0.52		0.52		0.49
# 8	0.48		0.54		0.50
# 9	0.47		0.54		0.50
# 10	0.49		0.53		0.49
# 11	0.47		0.52		0.49
# 12	0.44		0.52		0.50
# 13	0.47		0.53		0.49
# 14	0.48		0.53		0.51
# 15	0.50		0.51		0.49
# 16	0.52		0.53		0.49
# 17	0.52		0.53		0.50
# 18	0.51		0.53		0.50
# 19	0.49		0.53		0.48
# 20	0.47		0.52		0.50
# t = 1 was best iteration with accuracy 0.53
#
# -----------------------------------------------
# 10 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.43
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.47		0.49		0.44
# 2	0.52		0.49		0.46
# 3	0.50		0.49		0.46
# 4	0.50		0.49		0.46
# 5	0.48		0.49		0.46
# 6	0.48		0.49		0.46
# 7	0.43		0.49		0.46
# 8	0.46		0.49		0.46
# 9	0.46		0.49		0.46
# 10	0.49		0.49		0.46
# 11	0.51		0.49		0.46
# 12	0.48		0.49		0.46
# 13	0.49		0.49		0.46
# 14	0.50		0.49		0.46
# 15	0.47		0.49		0.46
# 16	0.48		0.49		0.46
# 17	0.48		0.49		0.46
# 18	0.48		0.49		0.46
# 19	0.49		0.49		0.46
# 20	0.52		0.49		0.46
# t = 2 was best iteration with accuracy 0.54
#
# WITH CLASS PRIOR 0.43
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.47		0.49		0.47
# 2	0.46		0.49		0.47
# 3	0.51		0.52		0.49
# 4	0.48		0.51		0.47
# 5	0.53		0.50		0.47
# 6	0.51		0.51		0.47
# 7	0.47		0.54		0.49
# 8	0.50		0.50		0.47
# 9	0.46		0.53		0.49
# 10	0.52		0.53		0.49
# 11	0.50		0.53		0.49
# 12	0.48		0.53		0.48
# 13	0.52		0.53		0.49
# 14	0.52		0.52		0.48
# 15	0.47		0.53		0.49
# 16	0.49		0.54		0.49
# 17	0.51		0.54		0.50
# 18	0.49		0.53		0.49
# 19	0.46		0.53		0.48
# 20	0.44		0.53		0.49
# t = 7 was best iteration with accuracy 0.51
#
# -----------------------------------------------
# 11 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.43
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.47		0.50		0.47
# 2	0.49		0.50		0.46
# 3	0.50		0.50		0.46
# 4	0.50		0.50		0.46
# 5	0.48		0.50		0.46
# 6	0.48		0.50		0.46
# 7	0.51		0.50		0.46
# 8	0.50		0.50		0.46
# 9	0.48		0.49		0.45
# 10	0.51		0.49		0.46
# 11	0.48		0.49		0.46
# 12	0.50		0.49		0.46
# 13	0.49		0.49		0.46
# 14	0.49		0.49		0.46
# 15	0.50		0.49		0.46
# 16	0.45		0.49		0.46
# 17	0.51		0.49		0.46
# 18	0.49		0.49		0.46
# 19	0.48		0.49		0.46
# 20	0.52		0.49		0.46
# t = 9 was best iteration with accuracy 0.55
#
# WITH CLASS PRIOR 0.43
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.46		0.51		0.47
# 2	0.51		0.51		0.47
# 3	0.49		0.52		0.47
# 4	0.49		0.47		0.42
# 5	0.48		0.50		0.44
# 6	0.44		0.50		0.46
# 7	0.49		0.53		0.49
# 8	0.48		0.53		0.51
# 9	0.52		0.54		0.49
# 10	0.51		0.53		0.50
# 11	0.47		0.53		0.49
# 12	0.47		0.52		0.47
# 13	0.45		0.53		0.48
# 14	0.47		0.53		0.48
# 15	0.52		0.54		0.48
# 16	0.47		0.54		0.49
# 17	0.50		0.53		0.48
# 18	0.50		0.54		0.49
# 19	0.48		0.54		0.49
# 20	0.49		0.55		0.50
# t = 20 was best iteration with accuracy 0.50
#
# -----------------------------------------------
# 12 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.43
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.46		0.49		0.46
# 2	0.49		0.49		0.46
# 3	0.50		0.49		0.47
# 4	0.49		0.50		0.46
# 5	0.47		0.50		0.47
# 6	0.56		0.49		0.46
# 7	0.47		0.50		0.47
# 8	0.51		0.50		0.47
# 9	0.49		0.50		0.47
# 10	0.46		0.50		0.47
# 11	0.47		0.50		0.47
# 12	0.46		0.50		0.46
# 13	0.48		0.50		0.47
# 14	0.49		0.50		0.47
# 15	0.51		0.50		0.47
# 16	0.45		0.50		0.47
# 17	0.47		0.50		0.47
# 18	0.47		0.50		0.47
# 19	0.48		0.50		0.47
# 20	0.50		0.50		0.47
# t = 1 was best iteration with accuracy 0.54
#
# WITH CLASS PRIOR 0.43
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.48		0.53		0.50
# 2	0.49		0.53		0.50
# 3	0.50		0.57		0.55
# 4	0.46		0.54		0.49
# 5	0.44		0.49		0.45
# 6	0.46		0.50		0.48
# 7	0.47		0.51		0.48
# 8	0.44		0.52		0.48
# 9	0.47		0.51		0.47
# 10	0.47		0.51		0.47
# 11	0.50		0.50		0.47
# 12	0.46		0.52		0.46
# 13	0.50		0.50		0.47
# 14	0.46		0.52		0.47
# 15	0.47		0.51		0.48
# 16	0.46		0.51		0.48
# 17	0.46		0.52		0.48
# 18	0.51		0.52		0.48
# 19	0.49		0.52		0.48
# 20	0.45		0.51		0.47
# t = 3 was best iteration with accuracy 0.55
#
# -----------------------------------------------
# 13 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.43
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.47		0.49		0.46
# 2	0.51		0.49		0.45
# 3	0.49		0.49		0.47
# 4	0.48		0.49		0.46
# 5	0.47		0.49		0.46
# 6	0.49		0.49		0.46
# 7	0.46		0.50		0.47
# 8	0.50		0.49		0.47
# 9	0.48		0.49		0.46
# 10	0.49		0.49		0.46
# 11	0.46		0.49		0.46
# 12	0.46		0.49		0.46
# 13	0.43		0.49		0.46
# 14	0.48		0.49		0.46
# 15	0.48		0.49		0.46
# 16	0.48		0.49		0.46
# 17	0.51		0.49		0.46
# 18	0.51		0.49		0.46
# 19	0.49		0.49		0.46
# 20	0.48		0.49		0.46
# t = 2 was best iteration with accuracy 0.55
#
# WITH CLASS PRIOR 0.43
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.51		0.53		0.49
# 2	0.54		0.53		0.49
# 3	0.49		0.52		0.49
# 4	0.49		0.54		0.48
# 5	0.47		0.52		0.48
# 6	0.51		0.51		0.46
# 7	0.50		0.51		0.46
# 8	0.49		0.53		0.47
# 9	0.53		0.52		0.46
# 10	0.47		0.54		0.48
# 11	0.51		0.52		0.47
# 12	0.47		0.52		0.47
# 13	0.48		0.52		0.46
# 14	0.51		0.52		0.47
# 15	0.52		0.52		0.47
# 16	0.51		0.52		0.47
# 17	0.47		0.51		0.47
# 18	0.50		0.53		0.47
# 19	0.51		0.53		0.48
# 20	0.54		0.54		0.48
# t = 4 was best iteration with accuracy 0.52
#
# -----------------------------------------------
# 14 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.43
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.47		0.49		0.46
# 2	0.47		0.49		0.46
# 3	0.45		0.49		0.46
# 4	0.53		0.50		0.46
# 5	0.48		0.49		0.45
# 6	0.46		0.49		0.46
# 7	0.47		0.49		0.46
# 8	0.47		0.49		0.46
# 9	0.46		0.49		0.46
# 10	0.49		0.49		0.46
# 11	0.48		0.49		0.46
# 12	0.47		0.49		0.46
# 13	0.47		0.50		0.46
# 14	0.46		0.49		0.46
# 15	0.47		0.49		0.46
# 16	0.52		0.49		0.46
# 17	0.49		0.49		0.46
# 18	0.50		0.49		0.46
# 19	0.49		0.49		0.46
# 20	0.49		0.49		0.46
# t = 3 was best iteration with accuracy 0.54
#
# WITH CLASS PRIOR 0.43
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.48		0.54		0.50
# 2	0.50		0.54		0.50
# 3	0.48		0.54		0.50
# 4	0.48		0.49		0.46
# 5	0.49		0.54		0.51
# 6	0.51		0.52		0.49
# 7	0.47		0.52		0.49
# 8	0.49		0.51		0.49
# 9	0.50		0.51		0.47
# 10	0.49		0.50		0.49
# 11	0.50		0.53		0.48
# 12	0.46		0.54		0.52
# 13	0.52		0.52		0.49
# 14	0.52		0.54		0.51
# 15	0.51		0.52		0.49
# 16	0.47		0.54		0.50
# 17	0.47		0.53		0.49
# 18	0.51		0.52		0.49
# 19	0.50		0.53		0.49
# 20	0.52		0.52		0.48
# t = 12 was best iteration with accuracy 0.52
#
# -----------------------------------------------
# 15 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.43
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.50		0.49		0.46
# 2	0.45		0.49		0.46
# 3	0.48		0.49		0.45
# 4	0.53		0.49		0.45
# 5	0.47		0.49		0.45
# 6	0.49		0.49		0.46
# 7	0.46		0.49		0.46
# 8	0.51		0.49		0.46
# 9	0.50		0.49		0.46
# 10	0.50		0.49		0.46
# 11	0.51		0.49		0.46
# 12	0.51		0.49		0.46
# 13	0.53		0.49		0.46
# 14	0.47		0.49		0.46
# 15	0.50		0.49		0.46
# 16	0.49		0.49		0.46
# 17	0.50		0.49		0.46
# 18	0.47		0.49		0.46
# 19	0.49		0.49		0.46
# 20	0.46		0.49		0.46
# t = 3 was best iteration with accuracy 0.55
#
# WITH CLASS PRIOR 0.43
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.49		0.48		0.44
# 2	0.48		0.48		0.44
# 3	0.50		0.48		0.44
# 4	0.53		0.53		0.49
# 5	0.51		0.53		0.49
# 6	0.49		0.51		0.47
# 7	0.51		0.52		0.48
# 8	0.51		0.53		0.49
# 9	0.48		0.53		0.50
# 10	0.50		0.54		0.50
# 11	0.53		0.54		0.51
# 12	0.52		0.54		0.51
# 13	0.52		0.55		0.50
# 14	0.54		0.54		0.50
# 15	0.49		0.54		0.50
# 16	0.53		0.55		0.50
# 17	0.51		0.54		0.50
# 18	0.49		0.55		0.50
# 19	0.52		0.54		0.49
# 20	0.47		0.53		0.49
# t = 16 was best iteration with accuracy 0.50
#
# -----------------------------------------------
# 16 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.43
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.49		0.49		0.44
# 2	0.49		0.49		0.46
# 3	0.46		0.49		0.46
# 4	0.49		0.49		0.46
# 5	0.48		0.49		0.46
# 6	0.47		0.49		0.46
# 7	0.50		0.49		0.46
# 8	0.48		0.49		0.46
# 9	0.51		0.49		0.46
# 10	0.47		0.49		0.46
# 11	0.47		0.49		0.46
# 12	0.51		0.49		0.46
# 13	0.51		0.49		0.46
# 14	0.45		0.49		0.46
# 15	0.47		0.49		0.46
# 16	0.48		0.49		0.46
# 17	0.49		0.49		0.46
# 18	0.47		0.49		0.46
# 19	0.47		0.49		0.46
# 20	0.49		0.49		0.46
# t = 16 was best iteration with accuracy 0.54
#
# WITH CLASS PRIOR 0.43
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.49		0.53		0.50
# 2	0.50		0.53		0.50
# 3	0.47		0.53		0.50
# 4	0.48		0.50		0.47
# 5	0.50		0.53		0.50
# 6	0.46		0.50		0.47
# 7	0.47		0.52		0.49
# 8	0.47		0.52		0.52
# 9	0.47		0.51		0.47
# 10	0.47		0.53		0.49
# 11	0.48		0.52		0.48
# 12	0.52		0.52		0.49
# 13	0.48		0.52		0.47
# 14	0.46		0.52		0.48
# 15	0.48		0.54		0.49
# 16	0.49		0.53		0.50
# 17	0.46		0.53		0.49
# 18	0.50		0.53		0.48
# 19	0.51		0.53		0.49
# 20	0.54		0.54		0.50
# t = 15 was best iteration with accuracy 0.51
#
# -----------------------------------------------
# 17 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.43
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.48		0.49		0.46
# 2	0.45		0.49		0.46
# 3	0.47		0.49		0.46
# 4	0.48		0.49		0.46
# 5	0.50		0.49		0.46
# 6	0.49		0.49		0.46
# 7	0.47		0.49		0.46
# 8	0.45		0.49		0.46
# 9	0.51		0.49		0.46
# 10	0.46		0.49		0.46
# 11	0.45		0.49		0.46
# 12	0.47		0.49		0.46
# 13	0.51		0.49		0.46
# 14	0.50		0.49		0.46
# 15	0.46		0.49		0.46
# 16	0.48		0.49		0.46
# 17	0.48		0.49		0.46
# 18	0.48		0.49		0.46
# 19	0.47		0.49		0.46
# 20	0.49		0.49		0.46
# t = 1 was best iteration with accuracy 0.54
#
# WITH CLASS PRIOR 0.43
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.48		0.50		0.46
# 2	0.46		0.50		0.46
# 3	0.51		0.58		0.56
# 4	0.49		0.53		0.50
# 5	0.52		0.52		0.48
# 6	0.50		0.52		0.50
# 7	0.48		0.51		0.47
# 8	0.52		0.52		0.49
# 9	0.51		0.52		0.49
# 10	0.49		0.53		0.50
# 11	0.50		0.52		0.47
# 12	0.49		0.52		0.50
# 13	0.52		0.52		0.49
# 14	0.47		0.52		0.49
# 15	0.47		0.52		0.49
# 16	0.53		0.54		0.50
# 17	0.51		0.53		0.50
# 18	0.52		0.53		0.50
# 19	0.50		0.54		0.51
# 20	0.52		0.53		0.50
# t = 3 was best iteration with accuracy 0.56
#
# -----------------------------------------------
# 18 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.43
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.49		0.49		0.45
# 2	0.51		0.49		0.46
# 3	0.48		0.49		0.46
# 4	0.44		0.49		0.46
# 5	0.49		0.50		0.46
# 6	0.45		0.50		0.46
# 7	0.50		0.50		0.47
# 8	0.52		0.49		0.46
# 9	0.47		0.49		0.46
# 10	0.49		0.49		0.46
# 11	0.49		0.49		0.46
# 12	0.50		0.49		0.46
# 13	0.47		0.49		0.46
# 14	0.48		0.49		0.46
# 15	0.49		0.49		0.46
# 16	0.50		0.49		0.46
# 17	0.49		0.49		0.46
# 18	0.49		0.49		0.46
# 19	0.51		0.49		0.46
# 20	0.47		0.49		0.46
# t = 1 was best iteration with accuracy 0.55
#
# WITH CLASS PRIOR 0.43
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.52		0.53		0.50
# 2	0.53		0.53		0.50
# 3	0.48		0.53		0.50
# 4	0.54		0.56		0.54
# 5	0.50		0.51		0.46
# 6	0.52		0.55		0.52
# 7	0.48		0.54		0.51
# 8	0.47		0.53		0.49
# 9	0.47		0.53		0.49
# 10	0.48		0.53		0.50
# 11	0.48		0.54		0.49
# 12	0.47		0.54		0.50
# 13	0.52		0.54		0.48
# 14	0.55		0.54		0.48
# 15	0.51		0.53		0.49
# 16	0.51		0.53		0.48
# 17	0.50		0.53		0.48
# 18	0.50		0.54		0.50
# 19	0.49		0.54		0.49
# 20	0.51		0.54		0.50
# t = 4 was best iteration with accuracy 0.54
#
# -----------------------------------------------
# 19 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.43
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.49		0.49		0.46
# 2	0.51		0.49		0.46
# 3	0.48		0.49		0.46
# 4	0.49		0.49		0.46
# 5	0.48		0.49		0.46
# 6	0.45		0.49		0.46
# 7	0.49		0.49		0.46
# 8	0.51		0.49		0.46
# 9	0.50		0.49		0.46
# 10	0.48		0.49		0.46
# 11	0.45		0.49		0.46
# 12	0.49		0.49		0.46
# 13	0.52		0.49		0.46
# 14	0.48		0.49		0.46
# 15	0.50		0.49		0.46
# 16	0.52		0.49		0.46
# 17	0.47		0.49		0.46
# 18	0.45		0.49		0.46
# 19	0.54		0.49		0.46
# 20	0.48		0.49		0.46
# t = 1 was best iteration with accuracy 0.54
#
# WITH CLASS PRIOR 0.43
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.51		0.53		0.50
# 2	0.50		0.53		0.50
# 3	0.53		0.53		0.50
# 4	0.52		0.52		0.47
# 5	0.51		0.52		0.48
# 6	0.50		0.52		0.47
# 7	0.49		0.51		0.47
# 8	0.49		0.53		0.47
# 9	0.48		0.53		0.48
# 10	0.49		0.53		0.48
# 11	0.48		0.53		0.48
# 12	0.48		0.53		0.48
# 13	0.51		0.53		0.48
# 14	0.49		0.53		0.49
# 15	0.49		0.52		0.48
# 16	0.49		0.51		0.47
# 17	0.49		0.52		0.47
# 18	0.48		0.52		0.47
# 19	0.48		0.53		0.48
# 20	0.49		0.52		0.48
# t = 1 was best iteration with accuracy 0.50
#
# -----------------------------------------------
# 20 / 40 complete
# -----------------------------------------------
#
# PRELIMINARY
# Training accuracy of supervised SVM: 0.55
#
# GENERATE W
# [[-1 -1]
#  [-1  1]
#  [ 1 -1]
#  [ 1  1]] [61 54 41 44]
# Training accuracy of pairwise rank SVM: 0.97
#
# WITH CLASS PRIOR 0.45
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.50		0.64		0.57
# 2	0.49		0.64		0.57
# 3	0.50		0.64		0.57
# 4	0.49		0.64		0.57
# 5	0.47		0.64		0.57
# 6	0.51		0.64		0.57
# 7	0.47		0.64		0.57
# 8	0.51		0.64		0.57
# 9	0.51		0.64		0.57
# 10	0.48		0.64		0.57
# 11	0.49		0.64		0.57
# 12	0.50		0.64		0.57
# 13	0.49		0.64		0.57
# 14	0.48		0.64		0.57
# 15	0.49		0.64		0.57
# 16	0.46		0.64		0.57
# 17	0.48		0.64		0.57
# 18	0.51		0.64		0.57
# 19	0.49		0.64		0.57
# 20	0.51		0.64		0.57
# t = 1 was best iteration with accuracy 0.57
#
# WITH CLASS PRIOR 0.45
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.53		0.56		0.48
# 2	0.47		0.56		0.48
# 3	0.48		0.61		0.56
# 4	0.49		0.60		0.54
# 5	0.50		0.61		0.55
# 6	0.50		0.62		0.56
# 7	0.48		0.61		0.55
# 8	0.50		0.61		0.56
# 9	0.50		0.61		0.56
# 10	0.50		0.62		0.58
# 11	0.49		0.62		0.57
# 12	0.48		0.62		0.58
# 13	0.54		0.62		0.57
# 14	0.49		0.62		0.57
# 15	0.51		0.62		0.57
# 16	0.50		0.62		0.58
# 17	0.51		0.63		0.57
# 18	0.47		0.62		0.57
# 19	0.51		0.63		0.58
# 20	0.51		0.63		0.58
# t = 20 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 21 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.45
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.50		0.64		0.57
# 2	0.47		0.64		0.58
# 3	0.51		0.64		0.57
# 4	0.53		0.64		0.57
# 5	0.46		0.64		0.57
# 6	0.51		0.64		0.57
# 7	0.48		0.64		0.57
# 8	0.49		0.64		0.57
# 9	0.50		0.64		0.57
# 10	0.48		0.64		0.57
# 11	0.47		0.64		0.57
# 12	0.48		0.64		0.57
# 13	0.49		0.64		0.57
# 14	0.47		0.64		0.57
# 15	0.49		0.64		0.57
# 16	0.50		0.64		0.57
# 17	0.49		0.64		0.57
# 18	0.49		0.64		0.57
# 19	0.48		0.64		0.57
# 20	0.47		0.64		0.57
# t = 3 was best iteration with accuracy 0.57
#
# WITH CLASS PRIOR 0.45
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.46		0.61		0.53
# 2	0.47		0.61		0.53
# 3	0.50		0.65		0.59
# 4	0.47		0.63		0.57
# 5	0.50		0.63		0.57
# 6	0.51		0.65		0.58
# 7	0.51		0.63		0.57
# 8	0.48		0.65		0.57
# 9	0.52		0.63		0.57
# 10	0.49		0.64		0.57
# 11	0.48		0.64		0.57
# 12	0.48		0.64		0.57
# 13	0.50		0.64		0.57
# 14	0.49		0.64		0.58
# 15	0.48		0.64		0.57
# 16	0.48		0.64		0.57
# 17	0.49		0.64		0.57
# 18	0.50		0.64		0.58
# 19	0.51		0.64		0.57
# 20	0.51		0.64		0.57
# t = 3 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 22 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.45
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.49		0.63		0.56
# 2	0.43		0.63		0.57
# 3	0.49		0.63		0.57
# 4	0.51		0.63		0.57
# 5	0.50		0.64		0.57
# 6	0.47		0.64		0.57
# 7	0.49		0.64		0.57
# 8	0.47		0.64		0.57
# 9	0.51		0.64		0.57
# 10	0.46		0.64		0.57
# 11	0.48		0.64		0.57
# 12	0.46		0.64		0.57
# 13	0.47		0.64		0.57
# 14	0.51		0.64		0.57
# 15	0.48		0.64		0.57
# 16	0.49		0.64		0.57
# 17	0.51		0.64		0.57
# 18	0.48		0.64		0.57
# 19	0.50		0.64		0.57
# 20	0.49		0.64		0.57
# t = 7 was best iteration with accuracy 0.57
#
# WITH CLASS PRIOR 0.45
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.53		0.57		0.49
# 2	0.44		0.57		0.49
# 3	0.48		0.57		0.49
# 4	0.50		0.57		0.50
# 5	0.47		0.60		0.55
# 6	0.52		0.60		0.54
# 7	0.47		0.62		0.56
# 8	0.52		0.61		0.56
# 9	0.49		0.63		0.58
# 10	0.50		0.62		0.56
# 11	0.49		0.62		0.56
# 12	0.50		0.63		0.57
# 13	0.50		0.63		0.56
# 14	0.48		0.63		0.56
# 15	0.50		0.63		0.57
# 16	0.52		0.62		0.55
# 17	0.50		0.63		0.57
# 18	0.47		0.63		0.57
# 19	0.48		0.63		0.58
# 20	0.50		0.62		0.56
# t = 19 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 23 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.45
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.47		0.64		0.57
# 2	0.50		0.64		0.57
# 3	0.50		0.64		0.57
# 4	0.48		0.64		0.57
# 5	0.51		0.64		0.57
# 6	0.48		0.64		0.57
# 7	0.48		0.64		0.57
# 8	0.52		0.64		0.57
# 9	0.50		0.64		0.57
# 10	0.50		0.64		0.57
# 11	0.49		0.64		0.57
# 12	0.47		0.64		0.57
# 13	0.50		0.64		0.57
# 14	0.49		0.64		0.57
# 15	0.48		0.64		0.57
# 16	0.48		0.64		0.57
# 17	0.49		0.64		0.57
# 18	0.51		0.64		0.57
# 19	0.49		0.64		0.57
# 20	0.50		0.64		0.57
# t = 8 was best iteration with accuracy 0.57
#
# WITH CLASS PRIOR 0.45
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.51		0.63		0.55
# 2	0.47		0.63		0.55
# 3	0.50		0.64		0.62
# 4	0.50		0.64		0.57
# 5	0.50		0.59		0.54
# 6	0.49		0.65		0.58
# 7	0.47		0.63		0.58
# 8	0.50		0.63		0.57
# 9	0.49		0.63		0.58
# 10	0.50		0.64		0.58
# 11	0.51		0.63		0.56
# 12	0.48		0.63		0.57
# 13	0.51		0.63		0.56
# 14	0.52		0.64		0.59
# 15	0.47		0.63		0.57
# 16	0.50		0.64		0.58
# 17	0.51		0.64		0.58
# 18	0.54		0.64		0.58
# 19	0.49		0.64		0.58
# 20	0.48		0.64		0.58
# t = 6 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 24 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.45
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.48		0.64		0.57
# 2	0.48		0.64		0.57
# 3	0.48		0.64		0.58
# 4	0.48		0.64		0.57
# 5	0.46		0.64		0.57
# 6	0.49		0.64		0.57
# 7	0.49		0.64		0.57
# 8	0.49		0.64		0.57
# 9	0.50		0.64		0.57
# 10	0.51		0.64		0.57
# 11	0.48		0.64		0.57
# 12	0.47		0.64		0.57
# 13	0.51		0.64		0.57
# 14	0.46		0.64		0.57
# 15	0.52		0.64		0.57
# 16	0.47		0.64		0.57
# 17	0.52		0.64		0.57
# 18	0.49		0.64		0.57
# 19	0.52		0.64		0.57
# 20	0.51		0.64		0.57
# t = 2 was best iteration with accuracy 0.57
#
# WITH CLASS PRIOR 0.45
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.50		0.62		0.56
# 2	0.51		0.62		0.56
# 3	0.49		0.65		0.59
# 4	0.52		0.61		0.55
# 5	0.51		0.63		0.59
# 6	0.51		0.63		0.57
# 7	0.49		0.63		0.58
# 8	0.49		0.62		0.57
# 9	0.48		0.63		0.59
# 10	0.49		0.65		0.60
# 11	0.51		0.64		0.59
# 12	0.50		0.64		0.58
# 13	0.51		0.64		0.58
# 14	0.46		0.64		0.59
# 15	0.49		0.64		0.57
# 16	0.51		0.64		0.58
# 17	0.52		0.63		0.57
# 18	0.51		0.64		0.58
# 19	0.50		0.63		0.57
# 20	0.49		0.64		0.58
# t = 3 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 25 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.45
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.50		0.64		0.57
# 2	0.48		0.64		0.57
# 3	0.51		0.64		0.57
# 4	0.50		0.64		0.57
# 5	0.49		0.64		0.57
# 6	0.51		0.64		0.57
# 7	0.46		0.64		0.57
# 8	0.48		0.64		0.57
# 9	0.47		0.64		0.57
# 10	0.49		0.64		0.57
# 11	0.47		0.64		0.57
# 12	0.46		0.64		0.57
# 13	0.47		0.64		0.57
# 14	0.51		0.64		0.57
# 15	0.47		0.64		0.57
# 16	0.55		0.64		0.57
# 17	0.54		0.64		0.57
# 18	0.47		0.64		0.57
# 19	0.51		0.64		0.57
# 20	0.50		0.64		0.57
# t = 3 was best iteration with accuracy 0.57
#
# WITH CLASS PRIOR 0.45
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.49		0.65		0.57
# 2	0.49		0.65		0.57
# 3	0.49		0.61		0.56
# 4	0.50		0.62		0.55
# 5	0.50		0.62		0.59
# 6	0.48		0.64		0.56
# 7	0.49		0.63		0.59
# 8	0.51		0.63		0.56
# 9	0.47		0.63		0.59
# 10	0.49		0.63		0.57
# 11	0.51		0.64		0.59
# 12	0.49		0.65		0.58
# 13	0.51		0.64		0.59
# 14	0.47		0.62		0.56
# 15	0.50		0.63		0.58
# 16	0.49		0.64		0.58
# 17	0.49		0.64		0.58
# 18	0.50		0.63		0.58
# 19	0.49		0.63		0.58
# 20	0.48		0.63		0.58
# t = 1 was best iteration with accuracy 0.57
#
# -----------------------------------------------
# 26 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.45
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.48		0.64		0.57
# 2	0.51		0.64		0.57
# 3	0.46		0.64		0.58
# 4	0.53		0.64		0.58
# 5	0.51		0.64		0.57
# 6	0.51		0.64		0.58
# 7	0.48		0.64		0.57
# 8	0.49		0.64		0.57
# 9	0.51		0.64		0.57
# 10	0.50		0.64		0.57
# 11	0.52		0.64		0.57
# 12	0.50		0.64		0.57
# 13	0.49		0.64		0.57
# 14	0.50		0.64		0.57
# 15	0.50		0.64		0.57
# 16	0.48		0.64		0.57
# 17	0.53		0.64		0.57
# 18	0.51		0.64		0.57
# 19	0.49		0.64		0.57
# 20	0.49		0.64		0.57
# t = 1 was best iteration with accuracy 0.57
#
# WITH CLASS PRIOR 0.45
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.50		0.56		0.48
# 2	0.49		0.56		0.48
# 3	0.47		0.59		0.55
# 4	0.53		0.60		0.55
# 5	0.48		0.62		0.56
# 6	0.54		0.61		0.55
# 7	0.47		0.64		0.57
# 8	0.50		0.63		0.56
# 9	0.50		0.63		0.58
# 10	0.49		0.62		0.56
# 11	0.52		0.62		0.56
# 12	0.49		0.62		0.55
# 13	0.50		0.62		0.56
# 14	0.51		0.62		0.57
# 15	0.51		0.64		0.58
# 16	0.50		0.64		0.58
# 17	0.51		0.64		0.58
# 18	0.51		0.63		0.57
# 19	0.50		0.63		0.56
# 20	0.47		0.63		0.57
# t = 17 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 27 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.45
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.49		0.64		0.57
# 2	0.50		0.64		0.58
# 3	0.51		0.64		0.57
# 4	0.48		0.64		0.57
# 5	0.46		0.64		0.57
# 6	0.51		0.64		0.57
# 7	0.50		0.64		0.57
# 8	0.51		0.64		0.57
# 9	0.50		0.64		0.57
# 10	0.50		0.64		0.57
# 11	0.50		0.64		0.57
# 12	0.48		0.64		0.57
# 13	0.49		0.64		0.57
# 14	0.51		0.64		0.57
# 15	0.53		0.64		0.57
# 16	0.49		0.64		0.57
# 17	0.50		0.64		0.57
# 18	0.51		0.64		0.57
# 19	0.51		0.64		0.57
# 20	0.49		0.64		0.57
# t = 1 was best iteration with accuracy 0.57
#
# WITH CLASS PRIOR 0.45
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.51		0.58		0.55
# 2	0.49		0.58		0.55
# 3	0.51		0.61		0.58
# 4	0.52		0.60		0.56
# 5	0.52		0.66		0.60
# 6	0.48		0.62		0.56
# 7	0.52		0.66		0.58
# 8	0.48		0.62		0.57
# 9	0.48		0.63		0.58
# 10	0.50		0.64		0.59
# 11	0.48		0.64		0.57
# 12	0.48		0.63		0.58
# 13	0.47		0.63		0.57
# 14	0.53		0.63		0.57
# 15	0.50		0.63		0.57
# 16	0.49		0.63		0.57
# 17	0.48		0.64		0.57
# 18	0.50		0.64		0.58
# 19	0.48		0.64		0.56
# 20	0.49		0.64		0.58
# t = 5 was best iteration with accuracy 0.60
#
# -----------------------------------------------
# 28 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.45
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.49		0.63		0.57
# 2	0.49		0.64		0.57
# 3	0.50		0.64		0.57
# 4	0.50		0.64		0.57
# 5	0.54		0.64		0.57
# 6	0.47		0.64		0.57
# 7	0.50		0.64		0.57
# 8	0.51		0.64		0.57
# 9	0.51		0.64		0.57
# 10	0.49		0.64		0.57
# 11	0.48		0.64		0.57
# 12	0.49		0.64		0.57
# 13	0.47		0.64		0.57
# 14	0.50		0.64		0.57
# 15	0.51		0.64		0.57
# 16	0.50		0.64		0.57
# 17	0.53		0.64		0.57
# 18	0.51		0.64		0.57
# 19	0.48		0.64		0.57
# 20	0.49		0.64		0.57
# t = 2 was best iteration with accuracy 0.57
#
# WITH CLASS PRIOR 0.45
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.51		0.58		0.49
# 2	0.49		0.58		0.49
# 3	0.49		0.63		0.55
# 4	0.53		0.64		0.56
# 5	0.49		0.64		0.57
# 6	0.51		0.62		0.56
# 7	0.52		0.62		0.55
# 8	0.50		0.62		0.56
# 9	0.50		0.62		0.56
# 10	0.50		0.64		0.57
# 11	0.48		0.64		0.57
# 12	0.49		0.64		0.58
# 13	0.48		0.64		0.57
# 14	0.50		0.63		0.57
# 15	0.47		0.62		0.55
# 16	0.51		0.64		0.57
# 17	0.49		0.64		0.56
# 18	0.49		0.64		0.58
# 19	0.48		0.63		0.56
# 20	0.50		0.63		0.57
# t = 16 was best iteration with accuracy 0.57
#
# -----------------------------------------------
# 29 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.45
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.49		0.64		0.57
# 2	0.48		0.64		0.57
# 3	0.47		0.64		0.57
# 4	0.49		0.64		0.57
# 5	0.49		0.64		0.57
# 6	0.48		0.64		0.57
# 7	0.51		0.64		0.57
# 8	0.50		0.64		0.57
# 9	0.49		0.64		0.57
# 10	0.48		0.64		0.57
# 11	0.49		0.64		0.57
# 12	0.50		0.64		0.57
# 13	0.51		0.64		0.57
# 14	0.48		0.64		0.57
# 15	0.44		0.64		0.57
# 16	0.49		0.64		0.57
# 17	0.48		0.64		0.57
# 18	0.50		0.64		0.57
# 19	0.50		0.64		0.57
# 20	0.47		0.64		0.57
# t = 1 was best iteration with accuracy 0.57
#
# WITH CLASS PRIOR 0.45
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.48		0.55		0.48
# 2	0.49		0.55		0.48
# 3	0.50		0.53		0.49
# 4	0.46		0.57		0.51
# 5	0.48		0.64		0.60
# 6	0.48		0.62		0.56
# 7	0.51		0.64		0.58
# 8	0.52		0.62		0.56
# 9	0.51		0.63		0.58
# 10	0.49		0.63		0.56
# 11	0.49		0.62		0.56
# 12	0.50		0.63		0.57
# 13	0.48		0.64		0.59
# 14	0.51		0.64		0.57
# 15	0.50		0.63		0.57
# 16	0.50		0.64		0.57
# 17	0.48		0.63		0.57
# 18	0.49		0.63		0.57
# 19	0.50		0.63		0.57
# 20	0.52		0.63		0.57
# t = 16 was best iteration with accuracy 0.57
#
# -----------------------------------------------
# 30 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.45
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.48		0.64		0.57
# 2	0.48		0.64		0.57
# 3	0.48		0.64		0.57
# 4	0.48		0.64		0.57
# 5	0.49		0.64		0.57
# 6	0.52		0.64		0.57
# 7	0.50		0.64		0.57
# 8	0.48		0.64		0.57
# 9	0.49		0.64		0.57
# 10	0.51		0.64		0.57
# 11	0.49		0.64		0.57
# 12	0.48		0.64		0.57
# 13	0.48		0.64		0.57
# 14	0.49		0.64		0.57
# 15	0.48		0.64		0.57
# 16	0.51		0.64		0.57
# 17	0.49		0.64		0.57
# 18	0.49		0.64		0.57
# 19	0.52		0.64		0.57
# 20	0.51		0.64		0.57
# t = 2 was best iteration with accuracy 0.57
#
# WITH CLASS PRIOR 0.45
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.50		0.63		0.54
# 2	0.50		0.63		0.54
# 3	0.48		0.64		0.57
# 4	0.45		0.62		0.54
# 5	0.52		0.63		0.56
# 6	0.51		0.63		0.56
# 7	0.48		0.63		0.56
# 8	0.48		0.63		0.56
# 9	0.47		0.63		0.58
# 10	0.49		0.63		0.58
# 11	0.51		0.63		0.58
# 12	0.51		0.63		0.56
# 13	0.50		0.63		0.57
# 14	0.50		0.63		0.56
# 15	0.49		0.64		0.58
# 16	0.51		0.63		0.57
# 17	0.49		0.63		0.57
# 18	0.53		0.63		0.57
# 19	0.49		0.64		0.58
# 20	0.50		0.63		0.57
# t = 19 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 31 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.45
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.50		0.64		0.57
# 2	0.50		0.64		0.57
# 3	0.50		0.64		0.57
# 4	0.52		0.64		0.57
# 5	0.49		0.64		0.57
# 6	0.47		0.64		0.57
# 7	0.50		0.64		0.57
# 8	0.45		0.64		0.57
# 9	0.51		0.64		0.57
# 10	0.50		0.64		0.57
# 11	0.49		0.64		0.57
# 12	0.48		0.64		0.57
# 13	0.50		0.64		0.57
# 14	0.51		0.64		0.57
# 15	0.52		0.64		0.57
# 16	0.49		0.64		0.57
# 17	0.52		0.64		0.57
# 18	0.49		0.64		0.57
# 19	0.45		0.64		0.57
# 20	0.49		0.64		0.57
# t = 4 was best iteration with accuracy 0.57
#
# WITH CLASS PRIOR 0.45
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.52		0.56		0.47
# 2	0.46		0.56		0.47
# 3	0.49		0.65		0.59
# 4	0.52		0.58		0.50
# 5	0.49		0.62		0.57
# 6	0.51		0.60		0.55
# 7	0.52		0.63		0.57
# 8	0.50		0.63		0.57
# 9	0.50		0.63		0.57
# 10	0.49		0.63		0.57
# 11	0.48		0.62		0.57
# 12	0.50		0.63		0.57
# 13	0.52		0.63		0.58
# 14	0.49		0.63		0.57
# 15	0.48		0.63		0.57
# 16	0.49		0.63		0.57
# 17	0.49		0.64		0.57
# 18	0.48		0.64		0.57
# 19	0.48		0.64		0.57
# 20	0.54		0.64		0.57
# t = 3 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 32 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.45
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.47		0.64		0.57
# 2	0.51		0.64		0.57
# 3	0.50		0.64		0.57
# 4	0.48		0.64		0.57
# 5	0.50		0.64		0.57
# 6	0.51		0.64		0.57
# 7	0.49		0.64		0.57
# 8	0.48		0.64		0.57
# 9	0.45		0.64		0.57
# 10	0.49		0.64		0.57
# 11	0.46		0.64		0.57
# 12	0.52		0.64		0.57
# 13	0.49		0.64		0.57
# 14	0.50		0.64		0.57
# 15	0.52		0.64		0.57
# 16	0.50		0.64		0.57
# 17	0.45		0.64		0.57
# 18	0.49		0.64		0.57
# 19	0.48		0.64		0.57
# 20	0.51		0.64		0.57
# t = 4 was best iteration with accuracy 0.57
#
# WITH CLASS PRIOR 0.45
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.49		0.56		0.48
# 2	0.50		0.56		0.48
# 3	0.50		0.57		0.50
# 4	0.50		0.62		0.55
# 5	0.47		0.63		0.58
# 6	0.49		0.63		0.56
# 7	0.51		0.63		0.58
# 8	0.47		0.59		0.54
# 9	0.47		0.63		0.57
# 10	0.51		0.61		0.55
# 11	0.50		0.62		0.57
# 12	0.52		0.61		0.56
# 13	0.48		0.64		0.58
# 14	0.52		0.62		0.57
# 15	0.51		0.63		0.57
# 16	0.47		0.63		0.57
# 17	0.47		0.64		0.57
# 18	0.46		0.63		0.57
# 19	0.48		0.63		0.57
# 20	0.50		0.63		0.57
# t = 13 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 33 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.45
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.50		0.64		0.58
# 2	0.52		0.64		0.58
# 3	0.52		0.64		0.57
# 4	0.48		0.64		0.57
# 5	0.48		0.64		0.57
# 6	0.51		0.64		0.57
# 7	0.51		0.64		0.57
# 8	0.49		0.64		0.57
# 9	0.50		0.64		0.57
# 10	0.51		0.64		0.57
# 11	0.50		0.64		0.57
# 12	0.51		0.64		0.57
# 13	0.47		0.64		0.57
# 14	0.50		0.64		0.57
# 15	0.48		0.64		0.57
# 16	0.50		0.64		0.57
# 17	0.48		0.64		0.57
# 18	0.47		0.64		0.57
# 19	0.48		0.64		0.57
# 20	0.52		0.64		0.57
# t = 2 was best iteration with accuracy 0.58
#
# WITH CLASS PRIOR 0.45
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.52		0.57		0.47
# 2	0.49		0.57		0.47
# 3	0.48		0.58		0.51
# 4	0.49		0.58		0.49
# 5	0.49		0.65		0.57
# 6	0.50		0.63		0.56
# 7	0.47		0.62		0.55
# 8	0.45		0.63		0.56
# 9	0.50		0.61		0.54
# 10	0.50		0.62		0.56
# 11	0.51		0.63		0.56
# 12	0.48		0.63		0.57
# 13	0.49		0.63		0.56
# 14	0.48		0.64		0.58
# 15	0.51		0.64		0.57
# 16	0.53		0.64		0.58
# 17	0.48		0.63		0.57
# 18	0.51		0.62		0.57
# 19	0.50		0.63		0.56
# 20	0.50		0.64		0.57
# t = 5 was best iteration with accuracy 0.57
#
# -----------------------------------------------
# 34 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.45
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.49		0.64		0.57
# 2	0.51		0.64		0.57
# 3	0.49		0.64		0.57
# 4	0.53		0.64		0.57
# 5	0.50		0.64		0.57
# 6	0.51		0.64		0.57
# 7	0.48		0.64		0.57
# 8	0.49		0.64		0.57
# 9	0.50		0.64		0.57
# 10	0.50		0.64		0.57
# 11	0.47		0.64		0.57
# 12	0.44		0.64		0.57
# 13	0.49		0.64		0.57
# 14	0.51		0.64		0.57
# 15	0.52		0.64		0.57
# 16	0.47		0.64		0.57
# 17	0.48		0.64		0.57
# 18	0.49		0.64		0.57
# 19	0.51		0.64		0.57
# 20	0.48		0.64		0.57
# t = 2 was best iteration with accuracy 0.57
#
# WITH CLASS PRIOR 0.45
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.48		0.62		0.53
# 2	0.51		0.62		0.53
# 3	0.51		0.66		0.62
# 4	0.50		0.62		0.56
# 5	0.50		0.64		0.59
# 6	0.49		0.60		0.54
# 7	0.49		0.62		0.57
# 8	0.48		0.61		0.56
# 9	0.47		0.62		0.56
# 10	0.53		0.63		0.57
# 11	0.50		0.63		0.57
# 12	0.50		0.62		0.57
# 13	0.49		0.63		0.57
# 14	0.49		0.64		0.57
# 15	0.49		0.63		0.57
# 16	0.53		0.64		0.57
# 17	0.50		0.64		0.58
# 18	0.50		0.64		0.58
# 19	0.50		0.64		0.57
# 20	0.49		0.64		0.57
# t = 3 was best iteration with accuracy 0.62
#
# -----------------------------------------------
# 35 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.45
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.49		0.64		0.59
# 2	0.48		0.64		0.58
# 3	0.52		0.64		0.58
# 4	0.52		0.64		0.58
# 5	0.48		0.64		0.57
# 6	0.48		0.64		0.57
# 7	0.49		0.64		0.57
# 8	0.51		0.64		0.57
# 9	0.49		0.64		0.58
# 10	0.48		0.64		0.58
# 11	0.49		0.64		0.58
# 12	0.54		0.64		0.58
# 13	0.53		0.64		0.58
# 14	0.49		0.64		0.58
# 15	0.47		0.64		0.57
# 16	0.47		0.64		0.57
# 17	0.48		0.64		0.57
# 18	0.50		0.64		0.57
# 19	0.49		0.64		0.57
# 20	0.51		0.64		0.57
# t = 20 was best iteration with accuracy 0.57
#
# WITH CLASS PRIOR 0.45
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.51		0.56		0.47
# 2	0.48		0.56		0.47
# 3	0.46		0.60		0.56
# 4	0.50		0.59		0.53
# 5	0.49		0.62		0.56
# 6	0.50		0.60		0.53
# 7	0.50		0.61		0.56
# 8	0.51		0.60		0.54
# 9	0.51		0.63		0.57
# 10	0.48		0.62		0.56
# 11	0.48		0.64		0.57
# 12	0.51		0.62		0.56
# 13	0.50		0.63		0.57
# 14	0.52		0.63		0.58
# 15	0.52		0.64		0.57
# 16	0.51		0.64		0.57
# 17	0.49		0.64		0.57
# 18	0.48		0.64		0.57
# 19	0.49		0.64		0.57
# 20	0.52		0.63		0.57
# t = 17 was best iteration with accuracy 0.57
#
# -----------------------------------------------
# 36 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.45
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.50		0.64		0.57
# 2	0.51		0.64		0.57
# 3	0.52		0.64		0.57
# 4	0.47		0.64		0.57
# 5	0.47		0.64		0.57
# 6	0.50		0.64		0.57
# 7	0.48		0.64		0.57
# 8	0.53		0.64		0.57
# 9	0.50		0.64		0.57
# 10	0.49		0.64		0.57
# 11	0.48		0.64		0.57
# 12	0.49		0.64		0.57
# 13	0.49		0.64		0.57
# 14	0.52		0.64		0.57
# 15	0.50		0.64		0.57
# 16	0.48		0.64		0.57
# 17	0.46		0.64		0.57
# 18	0.49		0.64		0.57
# 19	0.49		0.64		0.57
# 20	0.49		0.64		0.57
# t = 14 was best iteration with accuracy 0.57
#
# WITH CLASS PRIOR 0.45
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.48		0.63		0.55
# 2	0.45		0.63		0.55
# 3	0.47		0.63		0.55
# 4	0.51		0.63		0.55
# 5	0.49		0.64		0.58
# 6	0.47		0.64		0.58
# 7	0.49		0.64		0.58
# 8	0.49		0.65		0.58
# 9	0.50		0.62		0.56
# 10	0.47		0.65		0.59
# 11	0.50		0.62		0.56
# 12	0.49		0.64		0.58
# 13	0.51		0.63		0.58
# 14	0.49		0.64		0.58
# 15	0.46		0.64		0.58
# 16	0.45		0.63		0.57
# 17	0.51		0.63		0.58
# 18	0.47		0.64		0.58
# 19	0.51		0.64		0.58
# 20	0.50		0.64		0.58
# t = 10 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 37 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.45
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.53		0.64		0.57
# 2	0.50		0.64		0.57
# 3	0.48		0.64		0.57
# 4	0.49		0.64		0.57
# 5	0.53		0.64		0.57
# 6	0.51		0.64		0.57
# 7	0.46		0.64		0.57
# 8	0.52		0.64		0.57
# 9	0.50		0.64		0.57
# 10	0.49		0.64		0.57
# 11	0.51		0.64		0.57
# 12	0.50		0.64		0.57
# 13	0.54		0.64		0.57
# 14	0.51		0.64		0.57
# 15	0.50		0.64		0.57
# 16	0.49		0.64		0.57
# 17	0.50		0.64		0.57
# 18	0.48		0.64		0.57
# 19	0.50		0.64		0.57
# 20	0.47		0.64		0.57
# t = 3 was best iteration with accuracy 0.57
#
# WITH CLASS PRIOR 0.45
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.51		0.60		0.52
# 2	0.46		0.60		0.52
# 3	0.49		0.60		0.52
# 4	0.53		0.62		0.56
# 5	0.47		0.61		0.55
# 6	0.47		0.63		0.56
# 7	0.47		0.62		0.55
# 8	0.46		0.63		0.56
# 9	0.48		0.62		0.55
# 10	0.56		0.63		0.56
# 11	0.48		0.63		0.56
# 12	0.48		0.63		0.55
# 13	0.47		0.63		0.55
# 14	0.49		0.63		0.56
# 15	0.46		0.63		0.57
# 16	0.50		0.63		0.57
# 17	0.50		0.63		0.58
# 18	0.45		0.63		0.57
# 19	0.51		0.63		0.57
# 20	0.46		0.64		0.58
# t = 20 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 38 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.45
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.50		0.64		0.58
# 2	0.48		0.64		0.57
# 3	0.46		0.64		0.57
# 4	0.50		0.64		0.57
# 5	0.50		0.64		0.57
# 6	0.50		0.64		0.57
# 7	0.49		0.64		0.57
# 8	0.51		0.64		0.57
# 9	0.51		0.64		0.57
# 10	0.47		0.64		0.57
# 11	0.50		0.64		0.57
# 12	0.48		0.64		0.57
# 13	0.53		0.64		0.57
# 14	0.49		0.64		0.57
# 15	0.51		0.64		0.57
# 16	0.49		0.64		0.57
# 17	0.51		0.64		0.57
# 18	0.51		0.64		0.57
# 19	0.48		0.64		0.57
# 20	0.49		0.64		0.57
# t = 15 was best iteration with accuracy 0.57
#
# WITH CLASS PRIOR 0.45
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.53		0.55		0.48
# 2	0.50		0.55		0.48
# 3	0.50		0.63		0.58
# 4	0.45		0.58		0.52
# 5	0.49		0.62		0.52
# 6	0.51		0.58		0.52
# 7	0.49		0.61		0.53
# 8	0.50		0.62		0.55
# 9	0.49		0.61		0.53
# 10	0.50		0.62		0.55
# 11	0.49		0.63		0.57
# 12	0.48		0.63		0.57
# 13	0.47		0.64		0.58
# 14	0.46		0.63		0.57
# 15	0.47		0.63		0.57
# 16	0.55		0.63		0.56
# 17	0.50		0.64		0.57
# 18	0.45		0.64		0.57
# 19	0.48		0.64		0.57
# 20	0.49		0.63		0.56
# t = 19 was best iteration with accuracy 0.57
#
# -----------------------------------------------
# 39 / 40 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.45
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.53		0.64		0.57
# 2	0.49		0.64		0.57
# 3	0.51		0.64		0.57
# 4	0.51		0.64		0.57
# 5	0.50		0.64		0.57
# 6	0.46		0.64		0.57
# 7	0.49		0.64		0.57
# 8	0.51		0.64		0.57
# 9	0.51		0.64		0.57
# 10	0.52		0.64		0.57
# 11	0.49		0.64		0.57
# 12	0.50		0.64		0.57
# 13	0.51		0.64		0.57
# 14	0.47		0.64		0.57
# 15	0.51		0.64		0.57
# 16	0.47		0.64		0.57
# 17	0.47		0.64		0.57
# 18	0.49		0.64		0.57
# 19	0.53		0.64		0.57
# 20	0.52		0.64		0.57
# t = 4 was best iteration with accuracy 0.57
#
# WITH CLASS PRIOR 0.45
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.48		0.57		0.49
# 2	0.48		0.57		0.49
# 3	0.53		0.59		0.52
# 4	0.49		0.59		0.51
# 5	0.48		0.61		0.53
# 6	0.51		0.61		0.53
# 7	0.52		0.61		0.54
# 8	0.47		0.63		0.57
# 9	0.50		0.62		0.56
# 10	0.52		0.63		0.57
# 11	0.48		0.63		0.56
# 12	0.48		0.63		0.57
# 13	0.50		0.63		0.57
# 14	0.49		0.64		0.58
# 15	0.50		0.64		0.58
# 16	0.49		0.64		0.58
# 17	0.49		0.63		0.57
# 18	0.51		0.64		0.58
# 19	0.51		0.63		0.57
# 20	0.51		0.64		0.58
# t = 18 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 40 / 40 complete
# -----------------------------------------------

# %%
table_results(svm_arr, tree_arr)
# Out:
# (Performance on test set)
#
# 50 comparisons
# 	acc	sderr
# SVM: 	54.4	0.1
# Tree: 	52.3	0.6
#
# 200 comparisons
# 	acc	sderr
# SVM: 	57.2	0.0
# Tree: 	58.2	0.3
