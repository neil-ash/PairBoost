# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_svmlight_file
from sklearn.model_selection import train_test_split
import sys; sys.path.insert(0,'..')
from main import *

# %%
X_train, y_train = load_svmlight_file('../data/w8a/w8a.txt')
X_train = X_train.toarray()

X_test, y_test = load_svmlight_file('../data/w8a/w8a.t')
X_test = X_test.toarray()

# %%
svm_arr, tree_arr = data_size_experiment(X_train, y_train, X_test, y_test,
                                         experiment_type='table', kernel='linear',
                                         random_state=0, verbose=True)
# Out:
# PRELIMINARY
# Training accuracy of supervised SVM: 1.00
#
# GENERATE W
# [[-1. -1.]
#  [-1.  1.]
#  [ 1. -1.]
#  [ 1.  1.]] [45  1  3  1]
# Training accuracy of pairwise rank SVM: 1.00
#
# WITH CLASS PRIOR 0.03
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.09		0.94		0.95
# 2	0.09		0.96		0.96
# 3	0.08		0.97		0.97
# 4	0.07		0.97		0.97
# 5	0.08		0.97		0.97
# 6	0.07		0.97		0.97
# 7	0.07		0.97		0.97
# 8	0.07		0.97		0.97
# 9	0.07		0.97		0.97
# 10	0.07		0.97		0.97
# 11	0.08		0.97		0.97
# 12	0.09		0.97		0.97
# 13	0.06		0.97		0.97
# 14	0.07		0.97		0.97
# 15	0.07		0.97		0.97
# 16	0.06		0.97		0.97
# 17	0.06		0.97		0.97
# 18	0.07		0.97		0.97
# 19	0.06		0.97		0.97
# 20	0.06		0.97		0.97
# t = 4 was best iteration with accuracy 0.97
#
# WITH CLASS PRIOR 0.03
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.07		0.96		0.95
# 2	0.07		0.95		0.95
# 3	0.04		0.95		0.96
# 4	0.06		0.95		0.96
# 5	0.03		0.95		0.96
# 6	0.03		0.95		0.96
# 7	0.03		0.95		0.96
# 8	0.03		0.95		0.96
# 9	0.02		0.95		0.96
# 10	0.01		0.97		0.97
# 11	0.51		0.95		0.96
# 12	0.04		0.95		0.96
# 13	0.03		0.95		0.96
# 14	0.03		0.95		0.96
# 15	0.02		0.95		0.96
# 16	0.03		0.97		0.97
# 17	0.51		0.95		0.96
# 18	0.02		0.95		0.96
# 19	0.02		0.97		0.97
# 20	0.51		0.95		0.96
# t = 10 was best iteration with accuracy 0.97
#
# -----------------------------------------------
# 1 / 10 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.03
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.06		0.94		0.94
# 2	0.10		0.97		0.97
# 3	0.07		0.97		0.97
# 4	0.09		0.97		0.97
# 5	0.07		0.97		0.97
# 6	0.09		0.97		0.97
# 7	0.10		0.97		0.97
# 8	0.08		0.97		0.97
# 9	0.07		0.97		0.97
# 10	0.06		0.97		0.97
# 11	0.05		0.97		0.97
# 12	0.07		0.97		0.97
# 13	0.07		0.97		0.97
# 14	0.07		0.97		0.97
# 15	0.07		0.97		0.97
# 16	0.07		0.97		0.97
# 17	0.05		0.97		0.97
# 18	0.08		0.97		0.97
# 19	0.04		0.97		0.97
# 20	0.05		0.97		0.97
# t = 3 was best iteration with accuracy 0.97
#
# WITH CLASS PRIOR 0.03
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.08		0.95		0.95
# 2	0.06		0.95		0.95
# 3	0.06		0.97		0.96
# 4	0.03		0.92		0.91
# 5	0.03		0.92		0.91
# 6	0.04		0.97		0.96
# 7	0.36		0.93		0.93
# 8	0.04		0.97		0.97
# 9	0.48		0.92		0.92
# 10	0.04		0.94		0.93
# 11	0.02		0.94		0.93
# 12	0.02		0.97		0.96
# 13	0.49		0.83		0.81
# 14	0.03		0.83		0.82
# 15	0.02		0.94		0.92
# 16	0.03		0.97		0.96
# 17	0.39		0.94		0.94
# 18	0.03		0.97		0.96
# 19	0.40		0.97		0.96
# 20	0.51		0.93		0.93
# t = 6 was best iteration with accuracy 0.96
#
# -----------------------------------------------
# 2 / 10 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.03
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.07		0.95		0.94
# 2	0.12		0.97		0.97
# 3	0.08		0.97		0.97
# 4	0.09		0.97		0.97
# 5	0.08		0.97		0.97
# 6	0.09		0.97		0.97
# 7	0.09		0.97		0.97
# 8	0.09		0.97		0.97
# 9	0.06		0.97		0.97
# 10	0.08		0.97		0.97
# 11	0.07		0.97		0.97
# 12	0.11		0.97		0.97
# 13	0.07		0.97		0.97
# 14	0.07		0.97		0.97
# 15	0.08		0.97		0.97
# 16	0.06		0.97		0.97
# 17	0.09		0.97		0.97
# 18	0.08		0.97		0.97
# 19	0.08		0.97		0.97
# 20	0.07		0.97		0.97
# t = 3 was best iteration with accuracy 0.97
#
# WITH CLASS PRIOR 0.03
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.09		0.94		0.94
# 2	0.03		0.94		0.94
# 3	0.06		0.97		0.97
# 4	0.51		0.93		0.92
# 5	0.05		0.93		0.92
# 6	0.05		0.93		0.92
# 7	0.04		0.93		0.92
# 8	0.03		0.93		0.92
# 9	0.03		0.93		0.92
# 10	0.02		0.93		0.92
# 11	0.02		0.93		0.92
# 12	0.04		0.93		0.92
# 13	0.03		0.93		0.92
# 14	0.02		0.97		0.97
# 15	0.45		0.97		0.96
# 16	0.50		0.93		0.92
# 17	0.04		0.93		0.92
# 18	0.03		0.93		0.92
# 19	0.03		0.93		0.92
# 20	0.03		0.97		0.96
# t = 3 was best iteration with accuracy 0.97
#
# -----------------------------------------------
# 3 / 10 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.03
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.06		0.93		0.94
# 2	0.07		0.96		0.97
# 3	0.09		0.97		0.97
# 4	0.08		0.97		0.97
# 5	0.09		0.97		0.97
# 6	0.07		0.97		0.97
# 7	0.08		0.97		0.97
# 8	0.07		0.97		0.97
# 9	0.05		0.97		0.97
# 10	0.08		0.97		0.97
# 11	0.08		0.97		0.97
# 12	0.07		0.97		0.97
# 13	0.07		0.97		0.97
# 14	0.07		0.97		0.97
# 15	0.07		0.97		0.97
# 16	0.07		0.97		0.97
# 17	0.08		0.97		0.97
# 18	0.07		0.97		0.97
# 19	0.06		0.97		0.97
# 20	0.05		0.97		0.97
# t = 3 was best iteration with accuracy 0.97
#
# WITH CLASS PRIOR 0.03
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.08		0.94		0.94
# 2	0.07		0.94		0.94
# 3	0.05		0.94		0.94
# 4	0.03		0.96		0.95
# 5	0.05		0.96		0.95
# 6	0.04		0.96		0.95
# 7	0.05		0.96		0.95
# 8	0.06		0.96		0.95
# 9	0.05		0.96		0.95
# 10	0.04		0.96		0.95
# 11	0.04		0.96		0.95
# 12	0.03		0.96		0.95
# 13	0.02		0.97		0.97
# 14	0.50		0.96		0.95
# 15	0.02		0.96		0.95
# 16	0.04		0.97		0.96
# 17	0.49		0.95		0.95
# 18	0.03		0.96		0.96
# 19	0.03		0.97		0.97
# 20	0.43		0.97		0.96
# t = 13 was best iteration with accuracy 0.97
#
# -----------------------------------------------
# 4 / 10 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.03
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.06		0.94		0.93
# 2	0.09		0.97		0.97
# 3	0.08		0.97		0.97
# 4	0.06		0.97		0.97
# 5	0.06		0.97		0.97
# 6	0.06		0.97		0.97
# 7	0.05		0.97		0.97
# 8	0.05		0.97		0.97
# 9	0.07		0.97		0.97
# 10	0.09		0.97		0.97
# 11	0.06		0.97		0.97
# 12	0.07		0.97		0.97
# 13	0.06		0.97		0.97
# 14	0.07		0.97		0.97
# 15	0.07		0.97		0.97
# 16	0.06		0.97		0.97
# 17	0.06		0.97		0.97
# 18	0.06		0.97		0.97
# 19	0.06		0.97		0.97
# 20	0.04		0.97		0.97
# t = 3 was best iteration with accuracy 0.97
#
# WITH CLASS PRIOR 0.03
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.06		0.96		0.96
# 2	0.06		0.97		0.97
# 3	0.03		0.96		0.96
# 4	0.05		0.96		0.96
# 5	0.05		0.96		0.96
# 6	0.05		0.96		0.96
# 7	0.04		0.97		0.97
# 8	0.42		0.96		0.96
# 9	0.03		0.96		0.96
# 10	0.03		0.97		0.97
# 11	0.51		0.96		0.96
# 12	0.03		0.96		0.96
# 13	0.02		0.96		0.96
# 14	0.03		0.96		0.96
# 15	0.03		0.96		0.96
# 16	0.04		0.97		0.97
# 17	0.49		0.96		0.97
# 18	0.04		0.96		0.97
# 19	0.03		0.96		0.97
# 20	0.03		0.96		0.97
# t = 2 was best iteration with accuracy 0.97
#
# -----------------------------------------------
# 5 / 10 complete
# -----------------------------------------------
#
# PRELIMINARY
# Training accuracy of supervised SVM: 1.00
#
# GENERATE W
# [[-1. -1.]
#  [-1.  1.]
#  [ 1. -1.]] [185   6   9]
# Training accuracy of pairwise rank SVM: 0.99
#
# WITH CLASS PRIOR 0.03
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.07		0.96		0.96
# 2	0.08		0.97		0.97
# 3	0.07		0.98		0.97
# 4	0.06		0.97		0.97
# 5	0.05		0.98		0.97
# 6	0.06		0.97		0.97
# 7	0.05		0.97		0.97
# 8	0.05		0.97		0.97
# 9	0.04		0.97		0.97
# 10	0.04		0.97		0.97
# 11	0.03		0.97		0.97
# 12	0.05		0.97		0.97
# 13	0.03		0.98		0.97
# 14	0.04		0.97		0.97
# 15	0.05		0.97		0.97
# 16	0.06		0.97		0.97
# 17	0.04		0.98		0.97
# 18	0.04		0.97		0.97
# 19	0.05		0.97		0.97
# 20	0.06		0.97		0.97
# t = 3 was best iteration with accuracy 0.97
#
# WITH CLASS PRIOR 0.03
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.07		0.96		0.97
# 2	0.08		0.96		0.97
# 3	0.04		0.97		0.96
# 4	0.03		0.97		0.96
# 5	0.02		0.97		0.97
# 6	0.48		0.97		0.97
# 7	0.05		0.97		0.97
# 8	0.05		0.97		0.96
# 9	0.03		0.97		0.96
# 10	0.03		0.97		0.97
# 11	0.40		0.97		0.97
# 12	0.50		0.97		0.97
# 13	0.02		0.97		0.97
# 14	0.50		0.95		0.95
# 15	0.03		0.95		0.95
# 16	0.03		0.97		0.97
# 17	0.03		0.97		0.97
# 18	0.03		0.97		0.97
# 19	0.47		0.95		0.95
# 20	0.03		0.97		0.97
# t = 5 was best iteration with accuracy 0.97
#
# -----------------------------------------------
# 6 / 10 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.03
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.05		0.96		0.96
# 2	0.07		0.97		0.97
# 3	0.05		0.97		0.97
# 4	0.05		0.97		0.97
# 5	0.06		0.97		0.97
# 6	0.06		0.97		0.97
# 7	0.06		0.97		0.97
# 8	0.05		0.97		0.97
# 9	0.05		0.97		0.97
# 10	0.06		0.97		0.97
# 11	0.06		0.97		0.97
# 12	0.05		0.97		0.97
# 13	0.05		0.97		0.97
# 14	0.05		0.97		0.97
# 15	0.05		0.97		0.97
# 16	0.05		0.98		0.97
# 17	0.06		0.97		0.97
# 18	0.05		0.98		0.97
# 19	0.04		0.97		0.97
# 20	0.04		0.98		0.97
# t = 16 was best iteration with accuracy 0.97
#
# WITH CLASS PRIOR 0.03
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.06		0.96		0.95
# 2	0.07		0.94		0.93
# 3	0.04		0.97		0.96
# 4	0.03		0.97		0.96
# 5	0.04		0.97		0.97
# 6	0.04		0.97		0.96
# 7	0.04		0.97		0.96
# 8	0.02		0.97		0.96
# 9	0.04		0.97		0.96
# 10	0.01		0.97		0.96
# 11	0.02		0.97		0.97
# 12	0.41		0.97		0.97
# 13	0.02		0.97		0.97
# 14	0.04		0.97		0.97
# 15	0.01		0.97		0.97
# 16	0.47		0.97		0.97
# 17	0.48		0.97		0.97
# 18	0.02		0.97		0.97
# 19	0.02		0.97		0.97
# 20	0.02		0.97		0.97
# t = 3 was best iteration with accuracy 0.96
#
# -----------------------------------------------
# 7 / 10 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.03
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.06		0.96		0.96
# 2	0.06		0.97		0.97
# 3	0.06		0.97		0.97
# 4	0.07		0.97		0.97
# 5	0.05		0.97		0.97
# 6	0.05		0.97		0.97
# 7	0.06		0.97		0.97
# 8	0.04		0.97		0.97
# 9	0.06		0.97		0.97
# 10	0.06		0.97		0.97
# 11	0.03		0.97		0.97
# 12	0.04		0.97		0.97
# 13	0.04		0.98		0.97
# 14	0.06		0.97		0.97
# 15	0.06		0.98		0.97
# 16	0.05		0.97		0.97
# 17	0.05		0.97		0.97
# 18	0.05		0.98		0.97
# 19	0.05		0.97		0.97
# 20	0.05		0.98		0.97
# t = 13 was best iteration with accuracy 0.97
#
# WITH CLASS PRIOR 0.03
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.08		0.95		0.96
# 2	0.05		0.95		0.95
# 3	0.04		0.92		0.92
# 4	0.02		0.95		0.95
# 5	0.05		0.95		0.95
# 6	0.05		0.95		0.95
# 7	0.04		0.97		0.96
# 8	0.05		0.97		0.96
# 9	0.06		0.97		0.97
# 10	0.47		0.95		0.96
# 11	0.05		0.97		0.96
# 12	0.04		0.97		0.97
# 13	0.29		0.97		0.97
# 14	0.42		0.97		0.96
# 15	0.06		0.97		0.97
# 16	0.44		0.97		0.97
# 17	0.53		0.95		0.97
# 18	0.05		0.95		0.97
# 19	0.03		0.95		0.97
# 20	0.04		0.95		0.97
# t = 9 was best iteration with accuracy 0.97
#
# -----------------------------------------------
# 8 / 10 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.03
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.08		0.96		0.97
# 2	0.09		0.96		0.97
# 3	0.08		0.97		0.97
# 4	0.05		0.97		0.97
# 5	0.06		0.97		0.97
# 6	0.05		0.97		0.97
# 7	0.07		0.97		0.97
# 8	0.06		0.97		0.97
# 9	0.06		0.97		0.97
# 10	0.05		0.97		0.97
# 11	0.05		0.97		0.97
# 12	0.06		0.97		0.97
# 13	0.05		0.97		0.97
# 14	0.05		0.97		0.97
# 15	0.05		0.97		0.97
# 16	0.06		0.97		0.97
# 17	0.04		0.97		0.97
# 18	0.05		0.97		0.97
# 19	0.03		0.97		0.97
# 20	0.06		0.97		0.97
# t = 10 was best iteration with accuracy 0.97
#
# WITH CLASS PRIOR 0.03
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.06		0.95		0.95
# 2	0.06		0.94		0.94
# 3	0.04		0.96		0.95
# 4	0.04		0.96		0.95
# 5	0.05		0.96		0.95
# 6	0.02		0.97		0.97
# 7	0.46		0.96		0.95
# 8	0.04		0.96		0.95
# 9	0.04		0.96		0.95
# 10	0.03		0.96		0.95
# 11	0.03		0.96		0.95
# 12	0.04		0.96		0.95
# 13	0.03		0.96		0.95
# 14	0.02		0.97		0.97
# 15	0.41		0.97		0.97
# 16	0.50		0.96		0.96
# 17	0.03		0.97		0.97
# 18	0.48		0.96		0.95
# 19	0.03		0.96		0.96
# 20	0.03		0.97		0.97
# t = 6 was best iteration with accuracy 0.97
#
# -----------------------------------------------
# 9 / 10 complete
# -----------------------------------------------
#
# WITH CLASS PRIOR 0.03
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.06		0.95		0.96
# 2	0.06		0.97		0.97
# 3	0.06		0.97		0.97
# 4	0.07		0.97		0.97
# 5	0.05		0.97		0.97
# 6	0.07		0.97		0.97
# 7	0.06		0.97		0.97
# 8	0.07		0.97		0.97
# 9	0.04		0.97		0.97
# 10	0.04		0.97		0.97
# 11	0.05		0.97		0.97
# 12	0.04		0.97		0.97
# 13	0.05		0.97		0.97
# 14	0.05		0.97		0.97
# 15	0.04		0.97		0.97
# 16	0.05		0.97		0.97
# 17	0.04		0.97		0.97
# 18	0.05		0.97		0.97
# 19	0.05		0.97		0.97
# 20	0.05		0.97		0.97
# t = 7 was best iteration with accuracy 0.97
#
# WITH CLASS PRIOR 0.03
# DECISION TREE SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Prior		Train		Test
# 1	0.06		0.93		0.94
# 2	0.07		0.96		0.96
# 3	0.06		0.97		0.97
# 4	0.46		0.95		0.96
# 5	0.05		0.95		0.96
# 6	0.04		0.95		0.96
# 7	0.05		0.95		0.96
# 8	0.07		0.96		0.96
# 9	0.05		0.96		0.96
# Alpha -0.02, terminated
# t = 3 was best iteration with accuracy 0.97
#
# -----------------------------------------------
# 10 / 10 complete
# -----------------------------------------------

# %%
table_results(svm_arr, tree_arr)
# Out:
# (Performance on test set)
#
# 50 comparisons
# 	acc	sderr
# SVM: 	97.0	0.0
# Tree: 	96.6	0.1
#
# 200 comparisons
# 	acc	sderr
# SVM: 	96.8	0.0
# Tree: 	96.8	0.0
