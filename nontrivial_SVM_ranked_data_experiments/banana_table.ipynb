# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import sys; sys.path.insert(0,'..')
from main import *

# %%
data = pd.read_csv('../data/banana/banana.csv')
X = data[['V1', 'V2']].values
y = data['Class'].values

# Since classes are 1, 2
y = (y - 1) * 2 - 1

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.5, stratify=y, 
                                                    shuffle=True, random_state=1)

# %%
svm_arr, tree_arr = data_size_experiment(X_train, y_train, X_test, y_test,
                                         experiment_type='table', kernel='linear',
                                         random_state=379, verbose=True)
# Out:
# Progress:
# PRELIMINARY
# Training accuracy of rank SVM: 0.57
#
# GENERATE W
# num (-1, -1): 17
# num (-1,  1): 13
# num ( 1, -1): 12
# num ( 1,  1): 8
# Training accuracy of rank SVM: 1.00
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.54		0.50
# 2	0.54		0.50
# 3	0.54		0.50
# 4	0.54		0.49
# 5	0.54		0.49
# 6	0.53		0.49
# 7	0.53		0.49
# 8	0.53		0.49
# 9	0.53		0.49
# 10	0.53		0.49
# 11	0.53		0.49
# 12	0.53		0.49
# 13	0.53		0.49
# 14	0.53		0.49
# 15	0.53		0.49
# 16	0.53		0.49
# 17	0.53		0.49
# 18	0.53		0.49
# 19	0.53		0.49
# 20	0.53		0.49
# t = 2 was best iteration with accuracy 0.50
#
# -----------------------------------------------
# 1 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.54		0.49
# 2	0.54		0.50
# 3	0.54		0.50
# 4	0.54		0.50
# 5	0.54		0.49
# 6	0.54		0.49
# 7	0.54		0.49
# 8	0.54		0.49
# 9	0.53		0.49
# 10	0.53		0.49
# 11	0.53		0.49
# 12	0.53		0.49
# 13	0.53		0.49
# 14	0.53		0.49
# 15	0.53		0.49
# 16	0.53		0.49
# 17	0.53		0.49
# 18	0.53		0.49
# 19	0.53		0.49
# 20	0.53		0.49
# t = 1 was best iteration with accuracy 0.51
#
# -----------------------------------------------
# 2 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.55		0.51
# 2	0.54		0.50
# 3	0.54		0.50
# 4	0.54		0.49
# 5	0.54		0.49
# 6	0.54		0.50
# 7	0.54		0.50
# 8	0.54		0.50
# 9	0.54		0.50
# 10	0.54		0.50
# 11	0.54		0.49
# 12	0.54		0.49
# 13	0.54		0.49
# 14	0.53		0.49
# 15	0.53		0.49
# 16	0.53		0.49
# 17	0.53		0.49
# 18	0.53		0.49
# 19	0.53		0.49
# 20	0.53		0.49
# t = 1 was best iteration with accuracy 0.51
#
# -----------------------------------------------
# 3 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.54		0.49
# 2	0.54		0.49
# 3	0.54		0.49
# 4	0.53		0.49
# 5	0.53		0.49
# 6	0.53		0.49
# 7	0.54		0.49
# 8	0.54		0.49
# 9	0.54		0.49
# 10	0.54		0.49
# 11	0.54		0.49
# 12	0.54		0.50
# 13	0.54		0.50
# 14	0.54		0.50
# 15	0.54		0.49
# 16	0.54		0.49
# 17	0.54		0.49
# 18	0.54		0.49
# 19	0.53		0.49
# 20	0.53		0.49
# t = 1 was best iteration with accuracy 0.51
#
# -----------------------------------------------
# 4 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.53		0.49
# 2	0.54		0.49
# 3	0.54		0.50
# 4	0.54		0.50
# 5	0.54		0.50
# 6	0.54		0.50
# 7	0.54		0.50
# 8	0.54		0.50
# 9	0.54		0.50
# 10	0.53		0.49
# 11	0.53		0.49
# 12	0.53		0.49
# 13	0.53		0.49
# 14	0.53		0.49
# 15	0.53		0.49
# 16	0.54		0.49
# 17	0.53		0.49
# 18	0.53		0.49
# 19	0.53		0.49
# 20	0.53		0.49
# t = 3 was best iteration with accuracy 0.50
#
# -----------------------------------------------
# 5 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.54		0.50
# 2	0.54		0.49
# 3	0.54		0.49
# 4	0.54		0.49
# 5	0.53		0.49
# 6	0.53		0.49
# 7	0.53		0.49
# 8	0.53		0.49
# 9	0.53		0.49
# 10	0.53		0.49
# 11	0.53		0.49
# 12	0.53		0.49
# 13	0.53		0.49
# 14	0.53		0.49
# 15	0.53		0.49
# 16	0.53		0.49
# 17	0.53		0.49
# 18	0.53		0.49
# 19	0.53		0.49
# 20	0.53		0.49
# t = 1 was best iteration with accuracy 0.50
#
# -----------------------------------------------
# 6 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.54		0.51
# 2	0.55		0.50
# 3	0.54		0.49
# 4	0.54		0.49
# 5	0.54		0.49
# 6	0.53		0.49
# 7	0.53		0.49
# 8	0.54		0.49
# 9	0.54		0.49
# 10	0.53		0.49
# 11	0.53		0.49
# 12	0.53		0.49
# 13	0.53		0.49
# 14	0.53		0.49
# 15	0.53		0.49
# 16	0.53		0.49
# 17	0.53		0.49
# 18	0.53		0.49
# 19	0.53		0.49
# 20	0.53		0.49
# t = 2 was best iteration with accuracy 0.50
#
# -----------------------------------------------
# 7 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.55		0.50
# 2	0.53		0.49
# 3	0.54		0.49
# 4	0.53		0.49
# 5	0.53		0.49
# 6	0.53		0.49
# 7	0.53		0.49
# 8	0.53		0.49
# 9	0.54		0.49
# 10	0.53		0.49
# 11	0.53		0.49
# 12	0.53		0.49
# 13	0.53		0.49
# 14	0.53		0.49
# 15	0.53		0.49
# 16	0.53		0.49
# 17	0.53		0.49
# 18	0.54		0.49
# 19	0.54		0.49
# 20	0.54		0.49
# t = 1 was best iteration with accuracy 0.50
#
# -----------------------------------------------
# 8 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.54		0.50
# 2	0.54		0.49
# 3	0.54		0.50
# 4	0.54		0.50
# 5	0.54		0.50
# 6	0.54		0.50
# 7	0.54		0.50
# 8	0.54		0.49
# 9	0.54		0.49
# 10	0.54		0.49
# 11	0.54		0.49
# 12	0.53		0.49
# 13	0.53		0.49
# 14	0.53		0.49
# 15	0.54		0.49
# 16	0.53		0.49
# 17	0.53		0.49
# 18	0.53		0.49
# 19	0.54		0.49
# 20	0.53		0.49
# t = 2 was best iteration with accuracy 0.51
#
# -----------------------------------------------
# 9 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.53		0.49
# 2	0.53		0.49
# 3	0.53		0.49
# 4	0.54		0.50
# 5	0.54		0.49
# 6	0.53		0.49
# 7	0.53		0.49
# 8	0.53		0.49
# 9	0.53		0.49
# 10	0.53		0.49
# 11	0.53		0.49
# 12	0.53		0.49
# 13	0.53		0.49
# 14	0.53		0.49
# 15	0.53		0.49
# 16	0.53		0.49
# 17	0.53		0.49
# 18	0.53		0.49
# 19	0.53		0.49
# 20	0.53		0.49
# t = 4 was best iteration with accuracy 0.50
#
# -----------------------------------------------
# 10 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.53		0.49
# 2	0.53		0.49
# 3	0.52		0.49
# 4	0.53		0.49
# 5	0.53		0.49
# 6	0.53		0.49
# 7	0.53		0.49
# 8	0.53		0.49
# 9	0.53		0.49
# 10	0.53		0.49
# 11	0.53		0.49
# 12	0.53		0.49
# 13	0.53		0.49
# 14	0.53		0.49
# 15	0.53		0.49
# 16	0.53		0.49
# 17	0.53		0.49
# 18	0.53		0.49
# 19	0.53		0.49
# 20	0.53		0.49
# t = 1 was best iteration with accuracy 0.51
#
# -----------------------------------------------
# 11 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.52		0.49
# 2	0.52		0.49
# 3	0.53		0.49
# 4	0.53		0.49
# 5	0.53		0.49
# 6	0.53		0.49
# 7	0.53		0.49
# 8	0.53		0.49
# 9	0.53		0.49
# 10	0.53		0.49
# 11	0.53		0.49
# 12	0.53		0.49
# 13	0.53		0.49
# 14	0.53		0.49
# 15	0.53		0.49
# 16	0.53		0.49
# 17	0.53		0.49
# 18	0.53		0.49
# 19	0.53		0.49
# 20	0.53		0.49
# t = 16 was best iteration with accuracy 0.51
#
# -----------------------------------------------
# 12 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.53		0.49
# 2	0.53		0.49
# 3	0.53		0.49
# 4	0.53		0.49
# 5	0.53		0.49
# 6	0.53		0.49
# 7	0.53		0.49
# 8	0.53		0.49
# 9	0.54		0.49
# 10	0.53		0.49
# 11	0.53		0.50
# 12	0.54		0.49
# 13	0.53		0.50
# 14	0.53		0.49
# 15	0.53		0.49
# 16	0.53		0.49
# 17	0.53		0.49
# 18	0.53		0.49
# 19	0.53		0.49
# 20	0.53		0.49
# t = 9 was best iteration with accuracy 0.51
#
# -----------------------------------------------
# 13 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.54		0.50
# 2	0.53		0.49
# 3	0.53		0.49
# 4	0.53		0.49
# 5	0.53		0.50
# 6	0.53		0.49
# 7	0.53		0.49
# 8	0.53		0.49
# 9	0.53		0.49
# 10	0.53		0.49
# 11	0.53		0.49
# 12	0.53		0.49
# 13	0.53		0.49
# 14	0.53		0.49
# 15	0.53		0.49
# 16	0.53		0.49
# 17	0.53		0.49
# 18	0.53		0.49
# 19	0.53		0.49
# 20	0.53		0.49
# t = 1 was best iteration with accuracy 0.50
#
# -----------------------------------------------
# 14 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.53		0.49
# 2	0.53		0.49
# 3	0.53		0.49
# 4	0.53		0.49
# 5	0.53		0.49
# 6	0.53		0.49
# 7	0.53		0.50
# 8	0.53		0.49
# 9	0.53		0.49
# 10	0.53		0.49
# 11	0.53		0.49
# 12	0.53		0.49
# 13	0.53		0.49
# 14	0.53		0.49
# 15	0.53		0.49
# 16	0.53		0.49
# 17	0.53		0.49
# 18	0.53		0.50
# 19	0.53		0.49
# 20	0.53		0.49
# t = 2 was best iteration with accuracy 0.51
#
# -----------------------------------------------
# 15 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.54		0.50
# 2	0.54		0.50
# 3	0.54		0.50
# 4	0.54		0.49
# 5	0.53		0.49
# 6	0.53		0.49
# 7	0.53		0.49
# 8	0.53		0.49
# 9	0.53		0.49
# 10	0.53		0.49
# 11	0.53		0.49
# 12	0.53		0.49
# 13	0.53		0.49
# 14	0.53		0.49
# 15	0.53		0.49
# 16	0.53		0.49
# 17	0.53		0.49
# 18	0.53		0.49
# 19	0.53		0.49
# 20	0.53		0.49
# t = 1 was best iteration with accuracy 0.50
#
# -----------------------------------------------
# 16 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.53		0.49
# 2	0.53		0.49
# 3	0.53		0.49
# 4	0.53		0.49
# 5	0.53		0.49
# 6	0.53		0.49
# 7	0.53		0.49
# 8	0.53		0.49
# 9	0.53		0.49
# 10	0.53		0.49
# 11	0.53		0.49
# 12	0.53		0.49
# 13	0.53		0.49
# 14	0.53		0.49
# 15	0.53		0.49
# 16	0.53		0.49
# 17	0.53		0.49
# 18	0.53		0.49
# 19	0.53		0.49
# 20	0.53		0.49
# t = 20 was best iteration with accuracy 0.51
#
# -----------------------------------------------
# 17 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.54		0.50
# 2	0.54		0.50
# 3	0.54		0.49
# 4	0.53		0.49
# 5	0.53		0.49
# 6	0.53		0.49
# 7	0.53		0.49
# 8	0.53		0.49
# 9	0.53		0.49
# 10	0.53		0.49
# 11	0.53		0.49
# 12	0.53		0.49
# 13	0.53		0.49
# 14	0.53		0.49
# 15	0.53		0.49
# 16	0.53		0.49
# 17	0.53		0.49
# 18	0.53		0.49
# 19	0.53		0.49
# 20	0.53		0.49
# t = 1 was best iteration with accuracy 0.50
#
# -----------------------------------------------
# 18 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.53		0.49
# 2	0.54		0.49
# 3	0.54		0.50
# 4	0.54		0.49
# 5	0.54		0.49
# 6	0.54		0.49
# 7	0.54		0.49
# 8	0.54		0.49
# 9	0.54		0.50
# 10	0.54		0.50
# 11	0.54		0.49
# 12	0.54		0.49
# 13	0.54		0.49
# 14	0.53		0.49
# 15	0.53		0.49
# 16	0.53		0.49
# 17	0.53		0.49
# 18	0.53		0.49
# 19	0.53		0.49
# 20	0.53		0.49
# t = 3 was best iteration with accuracy 0.50
#
# -----------------------------------------------
# 19 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.54		0.50
# 2	0.53		0.49
# 3	0.53		0.49
# 4	0.53		0.49
# 5	0.53		0.49
# 6	0.53		0.49
# 7	0.53		0.49
# 8	0.53		0.49
# 9	0.53		0.49
# 10	0.53		0.49
# 11	0.53		0.49
# 12	0.53		0.49
# 13	0.53		0.49
# 14	0.53		0.49
# 15	0.53		0.49
# 16	0.53		0.49
# 17	0.53		0.49
# 18	0.53		0.49
# 19	0.53		0.49
# 20	0.53		0.49
# t = 1 was best iteration with accuracy 0.50
#
# -----------------------------------------------
# 20 / 40 complete
# -----------------------------------------------
#
# PRELIMINARY
# Training accuracy of rank SVM: 0.55
#
# GENERATE W
# num (-1, -1): 61
# num (-1,  1): 54
# num ( 1, -1): 41
# num ( 1,  1): 44
# Training accuracy of rank SVM: 0.97
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.64		0.57
# 2	0.63		0.59
# 3	0.63		0.59
# 4	0.63		0.59
# 5	0.63		0.59
# 6	0.63		0.59
# 7	0.63		0.59
# 8	0.63		0.59
# 9	0.63		0.59
# 10	0.63		0.59
# 11	0.63		0.59
# 12	0.63		0.59
# 13	0.63		0.59
# 14	0.64		0.59
# 15	0.63		0.59
# 16	0.64		0.59
# 17	0.64		0.59
# 18	0.64		0.59
# 19	0.64		0.59
# 20	0.64		0.59
# t = 1 was best iteration with accuracy 0.57
#
# -----------------------------------------------
# 21 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.63		0.58
# 2	0.64		0.58
# 3	0.64		0.58
# 4	0.64		0.59
# 5	0.64		0.59
# 6	0.64		0.59
# 7	0.64		0.59
# 8	0.64		0.59
# 9	0.64		0.59
# 10	0.64		0.59
# 11	0.64		0.59
# 12	0.64		0.59
# 13	0.64		0.59
# 14	0.64		0.59
# 15	0.64		0.59
# 16	0.64		0.59
# 17	0.64		0.59
# 18	0.64		0.59
# 19	0.64		0.59
# 20	0.64		0.59
# t = 2 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 22 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.64		0.59
# 2	0.63		0.59
# 3	0.64		0.59
# 4	0.64		0.59
# 5	0.64		0.59
# 6	0.64		0.59
# 7	0.64		0.59
# 8	0.64		0.59
# 9	0.64		0.59
# 10	0.64		0.59
# 11	0.64		0.59
# 12	0.64		0.59
# 13	0.64		0.59
# 14	0.64		0.59
# 15	0.64		0.59
# 16	0.64		0.59
# 17	0.64		0.59
# 18	0.64		0.59
# 19	0.64		0.59
# 20	0.64		0.59
# t = 5 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 23 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.64		0.59
# 2	0.64		0.59
# 3	0.64		0.59
# 4	0.64		0.59
# 5	0.64		0.59
# 6	0.64		0.59
# 7	0.64		0.59
# 8	0.64		0.59
# 9	0.64		0.59
# 10	0.64		0.59
# 11	0.64		0.59
# 12	0.64		0.59
# 13	0.64		0.59
# 14	0.64		0.59
# 15	0.64		0.59
# 16	0.64		0.59
# 17	0.64		0.59
# 18	0.64		0.59
# 19	0.64		0.59
# 20	0.64		0.59
# t = 1 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 24 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.64		0.57
# 2	0.64		0.57
# 3	0.64		0.58
# 4	0.63		0.59
# 5	0.64		0.59
# 6	0.63		0.59
# 7	0.63		0.59
# 8	0.63		0.59
# 9	0.64		0.59
# 10	0.64		0.59
# 11	0.64		0.59
# 12	0.63		0.59
# 13	0.63		0.59
# 14	0.63		0.59
# 15	0.63		0.59
# 16	0.64		0.59
# 17	0.64		0.59
# 18	0.64		0.59
# 19	0.64		0.59
# 20	0.64		0.59
# t = 2 was best iteration with accuracy 0.57
#
# -----------------------------------------------
# 25 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.64		0.58
# 2	0.64		0.59
# 3	0.64		0.59
# 4	0.64		0.59
# 5	0.64		0.59
# 6	0.64		0.59
# 7	0.64		0.59
# 8	0.64		0.59
# 9	0.64		0.59
# 10	0.64		0.59
# 11	0.64		0.59
# 12	0.64		0.59
# 13	0.64		0.59
# 14	0.64		0.59
# 15	0.64		0.59
# 16	0.64		0.59
# 17	0.64		0.59
# 18	0.64		0.59
# 19	0.64		0.59
# 20	0.64		0.59
# t = 8 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 26 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.64		0.58
# 2	0.64		0.58
# 3	0.64		0.58
# 4	0.63		0.58
# 5	0.64		0.59
# 6	0.63		0.59
# 7	0.63		0.59
# 8	0.63		0.59
# 9	0.64		0.59
# 10	0.63		0.59
# 11	0.63		0.59
# 12	0.63		0.59
# 13	0.63		0.59
# 14	0.63		0.59
# 15	0.63		0.59
# 16	0.63		0.59
# 17	0.63		0.59
# 18	0.63		0.59
# 19	0.63		0.59
# 20	0.64		0.59
# t = 1 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 27 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.64		0.59
# 2	0.64		0.59
# 3	0.64		0.59
# 4	0.64		0.59
# 5	0.64		0.59
# 6	0.64		0.59
# 7	0.64		0.59
# 8	0.64		0.59
# 9	0.64		0.59
# 10	0.64		0.59
# 11	0.64		0.59
# 12	0.64		0.59
# 13	0.64		0.59
# 14	0.64		0.59
# 15	0.64		0.59
# 16	0.64		0.59
# 17	0.64		0.59
# 18	0.64		0.59
# 19	0.64		0.59
# 20	0.64		0.59
# t = 6 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 28 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.63		0.58
# 2	0.64		0.58
# 3	0.64		0.58
# 4	0.63		0.59
# 5	0.64		0.58
# 6	0.64		0.58
# 7	0.63		0.59
# 8	0.63		0.59
# 9	0.64		0.59
# 10	0.64		0.59
# 11	0.63		0.59
# 12	0.63		0.59
# 13	0.63		0.59
# 14	0.63		0.59
# 15	0.63		0.59
# 16	0.64		0.59
# 17	0.64		0.59
# 18	0.64		0.59
# 19	0.64		0.59
# 20	0.64		0.59
# t = 2 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 29 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.64		0.58
# 2	0.64		0.59
# 3	0.64		0.59
# 4	0.64		0.59
# 5	0.64		0.59
# 6	0.64		0.59
# 7	0.64		0.59
# 8	0.64		0.59
# 9	0.64		0.59
# 10	0.64		0.59
# 11	0.64		0.59
# 12	0.64		0.59
# 13	0.64		0.59
# 14	0.64		0.59
# 15	0.64		0.59
# 16	0.64		0.59
# 17	0.64		0.59
# 18	0.64		0.59
# 19	0.64		0.59
# 20	0.64		0.59
# t = 6 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 30 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.64		0.58
# 2	0.64		0.59
# 3	0.64		0.59
# 4	0.64		0.59
# 5	0.64		0.59
# 6	0.64		0.59
# 7	0.64		0.59
# 8	0.64		0.59
# 9	0.64		0.59
# 10	0.63		0.59
# 11	0.64		0.59
# 12	0.64		0.59
# 13	0.64		0.59
# 14	0.64		0.59
# 15	0.64		0.59
# 16	0.64		0.59
# 17	0.64		0.59
# 18	0.64		0.59
# 19	0.64		0.59
# 20	0.64		0.59
# t = 6 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 31 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.64		0.58
# 2	0.64		0.58
# 3	0.63		0.59
# 4	0.63		0.59
# 5	0.64		0.59
# 6	0.64		0.59
# 7	0.64		0.59
# 8	0.64		0.59
# 9	0.64		0.59
# 10	0.64		0.59
# 11	0.64		0.59
# 12	0.64		0.59
# 13	0.64		0.59
# 14	0.64		0.59
# 15	0.64		0.59
# 16	0.64		0.59
# 17	0.64		0.59
# 18	0.64		0.59
# 19	0.64		0.59
# 20	0.64		0.59
# t = 8 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 32 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.64		0.57
# 2	0.64		0.58
# 3	0.64		0.58
# 4	0.64		0.58
# 5	0.64		0.59
# 6	0.64		0.59
# 7	0.64		0.59
# 8	0.64		0.59
# 9	0.64		0.59
# 10	0.64		0.59
# 11	0.64		0.59
# 12	0.64		0.59
# 13	0.64		0.59
# 14	0.64		0.59
# 15	0.64		0.59
# 16	0.64		0.59
# 17	0.64		0.59
# 18	0.64		0.59
# 19	0.64		0.59
# 20	0.64		0.59
# t = 1 was best iteration with accuracy 0.57
#
# -----------------------------------------------
# 33 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.63		0.59
# 2	0.63		0.58
# 3	0.63		0.59
# 4	0.64		0.58
# 5	0.64		0.59
# 6	0.64		0.59
# 7	0.63		0.59
# 8	0.63		0.59
# 9	0.64		0.59
# 10	0.64		0.59
# 11	0.64		0.59
# 12	0.64		0.59
# 13	0.64		0.59
# 14	0.64		0.59
# 15	0.64		0.59
# 16	0.64		0.59
# 17	0.64		0.59
# 18	0.64		0.59
# 19	0.64		0.59
# 20	0.64		0.59
# t = 4 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 34 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.64		0.57
# 2	0.64		0.58
# 3	0.64		0.58
# 4	0.63		0.58
# 5	0.63		0.58
# 6	0.63		0.58
# 7	0.64		0.58
# 8	0.64		0.59
# 9	0.64		0.59
# 10	0.64		0.59
# 11	0.64		0.59
# 12	0.64		0.59
# 13	0.64		0.59
# 14	0.64		0.59
# 15	0.64		0.59
# 16	0.64		0.59
# 17	0.64		0.59
# 18	0.64		0.59
# 19	0.64		0.59
# 20	0.64		0.59
# t = 1 was best iteration with accuracy 0.57
#
# -----------------------------------------------
# 35 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.64		0.58
# 2	0.64		0.58
# 3	0.63		0.59
# 4	0.64		0.58
# 5	0.63		0.59
# 6	0.64		0.59
# 7	0.64		0.59
# 8	0.64		0.59
# 9	0.64		0.59
# 10	0.64		0.59
# 11	0.64		0.59
# 12	0.64		0.59
# 13	0.64		0.59
# 14	0.64		0.59
# 15	0.64		0.59
# 16	0.64		0.59
# 17	0.64		0.59
# 18	0.64		0.59
# 19	0.64		0.59
# 20	0.64		0.59
# t = 1 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 36 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.64		0.58
# 2	0.64		0.58
# 3	0.63		0.59
# 4	0.63		0.59
# 5	0.63		0.59
# 6	0.63		0.59
# 7	0.63		0.59
# 8	0.63		0.59
# 9	0.64		0.59
# 10	0.64		0.59
# 11	0.64		0.59
# 12	0.64		0.59
# 13	0.63		0.59
# 14	0.63		0.59
# 15	0.63		0.59
# 16	0.63		0.59
# 17	0.63		0.59
# 18	0.63		0.59
# 19	0.63		0.59
# 20	0.63		0.59
# t = 1 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 37 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.63		0.59
# 2	0.63		0.59
# 3	0.64		0.59
# 4	0.64		0.59
# 5	0.64		0.59
# 6	0.64		0.59
# 7	0.64		0.59
# 8	0.64		0.59
# 9	0.64		0.59
# 10	0.64		0.59
# 11	0.64		0.59
# 12	0.64		0.59
# 13	0.64		0.59
# 14	0.64		0.59
# 15	0.64		0.59
# 16	0.64		0.59
# 17	0.64		0.59
# 18	0.64		0.59
# 19	0.64		0.59
# 20	0.64		0.59
# t = 4 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 38 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.64		0.58
# 2	0.63		0.59
# 3	0.63		0.59
# 4	0.64		0.59
# 5	0.64		0.59
# 6	0.63		0.59
# 7	0.63		0.59
# 8	0.64		0.59
# 9	0.64		0.59
# 10	0.64		0.59
# 11	0.64		0.59
# 12	0.64		0.59
# 13	0.64		0.59
# 14	0.64		0.59
# 15	0.64		0.59
# 16	0.64		0.59
# 17	0.64		0.59
# 18	0.64		0.59
# 19	0.64		0.59
# 20	0.64		0.59
# t = 1 was best iteration with accuracy 0.58
#
# -----------------------------------------------
# 39 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.64		0.57
# 2	0.64		0.58
# 3	0.64		0.58
# 4	0.63		0.59
# 5	0.63		0.59
# 6	0.63		0.59
# 7	0.64		0.59
# 8	0.64		0.59
# 9	0.64		0.59
# 10	0.64		0.59
# 11	0.64		0.59
# 12	0.64		0.59
# 13	0.64		0.59
# 14	0.64		0.59
# 15	0.64		0.59
# 16	0.64		0.59
# 17	0.64		0.59
# 18	0.64		0.59
# 19	0.64		0.59
# 20	0.64		0.59
# t = 15 was best iteration with accuracy 0.59
#
# -----------------------------------------------
# 40 / 40 complete
# -----------------------------------------------

# %%
table_results(svm_arr, tree_arr)
# Out:
# (Performance on test set)
#
# 50 comparisons
# 	acc	sderr
# SVM: 	50.4	0.1
# Tree: 	nan	nan
#
# 200 comparisons
# 	acc	sderr
# SVM: 	58.1	0.1
# Tree: 	nan	nan

# %%
eq1 = np.sum(y == 1) / y.size
max(eq1, 1 - eq1)
# Out:
# 0.5516981132075471
