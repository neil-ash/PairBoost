# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_svmlight_file
from sklearn.model_selection import train_test_split
import sys; sys.path.insert(0,'..')
from main import *

# %%
X_train, y_train = load_svmlight_file('../data/adult/a5a.txt', n_features=123)
X_train = X_train.toarray()

X_test, y_test = load_svmlight_file('../data/adult/a5a.t')
X_test = X_test.toarray()

# %%
svm_arr, tree_arr = data_size_experiment(X_train, y_train, X_test, y_test,
                                         experiment_type='table', kernel='linear',
                                         random_state=2, verbose=True)
# Out:
# Progress:
# PRELIMINARY
# Training accuracy of rank SVM: 0.90
# GENERATE W
# num (-1, -1): 28
# num (-1,  1): 4
# num ( 1, -1): 14
# num ( 1,  1): 4
# Training accuracy of rank SVM: 1.00
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.64		0.66
# 2	0.66		0.65
# 3	0.65		0.65
# 4	0.65		0.66
# 5	0.65		0.66
# 6	0.65		0.66
# 7	0.65		0.66
# 8	0.65		0.66
# 9	0.65		0.67
# 10	0.65		0.67
# 11	0.65		0.67
# 12	0.65		0.66
# 13	0.66		0.66
# 14	0.66		0.67
# 15	0.66		0.66
# 16	0.66		0.67
# 17	0.67		0.67
# 18	0.66		0.67
# 19	0.66		0.67
# 20	0.66		0.67
# t = 17 was best iteration with accuracy 0.67
#
# -----------------------------------------------
# 1 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.65		0.66
# 2	0.66		0.67
# 3	0.66		0.66
# 4	0.67		0.66
# 5	0.66		0.67
# 6	0.65		0.66
# 7	0.66		0.66
# 8	0.66		0.67
# 9	0.66		0.67
# 10	0.66		0.67
# 11	0.66		0.67
# 12	0.66		0.67
# 13	0.67		0.67
# 14	0.67		0.67
# 15	0.67		0.67
# 16	0.67		0.67
# 17	0.67		0.67
# 18	0.66		0.67
# 19	0.66		0.67
# 20	0.65		0.66
# t = 15 was best iteration with accuracy 0.67
#
# -----------------------------------------------
# 2 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.64		0.64
# 2	0.66		0.66
# 3	0.66		0.66
# 4	0.66		0.66
# 5	0.66		0.65
# 6	0.66		0.66
# 7	0.66		0.66
# 8	0.66		0.66
# 9	0.66		0.67
# 10	0.65		0.66
# 11	0.65		0.66
# 12	0.66		0.66
# 13	0.66		0.66
# 14	0.65		0.66
# 15	0.65		0.66
# 16	0.65		0.66
# 17	0.65		0.66
# 18	0.65		0.67
# 19	0.65		0.66
# 20	0.65		0.67
# t = 2 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 3 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.68		0.66
# 2	0.67		0.67
# 3	0.67		0.67
# 4	0.67		0.66
# 5	0.66		0.66
# 6	0.66		0.67
# 7	0.67		0.67
# 8	0.66		0.67
# 9	0.66		0.67
# 10	0.66		0.67
# 11	0.67		0.66
# 12	0.67		0.66
# 13	0.66		0.67
# 14	0.67		0.67
# 15	0.67		0.67
# 16	0.66		0.67
# 17	0.66		0.67
# 18	0.66		0.67
# 19	0.66		0.67
# 20	0.66		0.67
# t = 1 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 4 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.65		0.66
# 2	0.65		0.66
# 3	0.65		0.66
# 4	0.65		0.66
# 5	0.65		0.66
# 6	0.66		0.66
# 7	0.66		0.66
# 8	0.65		0.66
# 9	0.66		0.66
# 10	0.66		0.66
# 11	0.66		0.66
# 12	0.66		0.67
# 13	0.65		0.66
# 14	0.66		0.66
# 15	0.66		0.66
# 16	0.66		0.67
# 17	0.66		0.66
# 18	0.66		0.67
# 19	0.66		0.66
# 20	0.66		0.67
# t = 14 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 5 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.63		0.62
# 2	0.65		0.65
# 3	0.65		0.65
# 4	0.65		0.66
# 5	0.65		0.65
# 6	0.65		0.66
# 7	0.66		0.66
# 8	0.66		0.66
# 9	0.65		0.66
# 10	0.65		0.67
# 11	0.65		0.66
# 12	0.65		0.67
# 13	0.65		0.66
# 14	0.65		0.66
# 15	0.65		0.67
# 16	0.65		0.66
# 17	0.65		0.67
# 18	0.65		0.67
# 19	0.65		0.67
# 20	0.65		0.67
# t = 7 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 6 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.65		0.64
# 2	0.66		0.66
# 3	0.66		0.66
# 4	0.65		0.66
# 5	0.66		0.67
# 6	0.66		0.67
# 7	0.66		0.66
# 8	0.66		0.66
# 9	0.65		0.67
# 10	0.66		0.67
# 11	0.66		0.67
# 12	0.66		0.67
# 13	0.67		0.67
# 14	0.66		0.67
# 15	0.66		0.67
# 16	0.66		0.67
# 17	0.66		0.67
# 18	0.66		0.67
# 19	0.66		0.66
# 20	0.66		0.67
# t = 13 was best iteration with accuracy 0.67
#
# -----------------------------------------------
# 7 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.66		0.68
# 2	0.64		0.66
# 3	0.65		0.65
# 4	0.65		0.66
# 5	0.65		0.66
# 6	0.65		0.66
# 7	0.65		0.67
# 8	0.66		0.67
# 9	0.66		0.66
# 10	0.65		0.67
# 11	0.65		0.66
# 12	0.65		0.66
# 13	0.65		0.66
# 14	0.65		0.66
# 15	0.65		0.66
# 16	0.66		0.67
# 17	0.66		0.66
# 18	0.66		0.67
# 19	0.66		0.67
# 20	0.66		0.66
# t = 8 was best iteration with accuracy 0.67
#
# -----------------------------------------------
# 8 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.64		0.65
# 2	0.65		0.67
# 3	0.66		0.66
# 4	0.66		0.65
# 5	0.65		0.66
# 6	0.65		0.66
# 7	0.67		0.66
# 8	0.66		0.67
# 9	0.66		0.67
# 10	0.66		0.66
# 11	0.66		0.67
# 12	0.67		0.67
# 13	0.66		0.66
# 14	0.67		0.67
# 15	0.67		0.67
# 16	0.67		0.67
# 17	0.66		0.67
# 18	0.66		0.67
# 19	0.66		0.67
# 20	0.66		0.67
# t = 12 was best iteration with accuracy 0.67
#
# -----------------------------------------------
# 9 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.65		0.64
# 2	0.65		0.66
# 3	0.65		0.65
# 4	0.65		0.65
# 5	0.65		0.66
# 6	0.65		0.66
# 7	0.65		0.66
# 8	0.66		0.66
# 9	0.66		0.66
# 10	0.66		0.66
# 11	0.66		0.66
# 12	0.66		0.66
# 13	0.66		0.66
# 14	0.66		0.66
# 15	0.65		0.66
# 16	0.66		0.66
# 17	0.66		0.67
# 18	0.65		0.66
# 19	0.65		0.66
# 20	0.65		0.66
# t = 13 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 10 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.66		0.65
# 2	0.65		0.65
# 3	0.65		0.65
# 4	0.65		0.65
# 5	0.66		0.66
# 6	0.66		0.66
# 7	0.66		0.66
# 8	0.66		0.66
# 9	0.66		0.67
# 10	0.66		0.66
# 11	0.66		0.66
# 12	0.65		0.66
# 13	0.65		0.66
# 14	0.65		0.66
# 15	0.66		0.66
# 16	0.66		0.66
# 17	0.65		0.66
# 18	0.66		0.67
# 19	0.65		0.67
# 20	0.65		0.67
# t = 9 was best iteration with accuracy 0.67
#
# -----------------------------------------------
# 11 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.67		0.66
# 2	0.65		0.65
# 3	0.66		0.67
# 4	0.66		0.67
# 5	0.65		0.66
# 6	0.66		0.66
# 7	0.66		0.66
# 8	0.66		0.66
# 9	0.65		0.67
# 10	0.66		0.67
# 11	0.66		0.67
# 12	0.66		0.67
# 13	0.65		0.67
# 14	0.65		0.67
# 15	0.65		0.67
# 16	0.65		0.67
# 17	0.65		0.67
# 18	0.66		0.67
# 19	0.65		0.67
# 20	0.65		0.67
# t = 1 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 12 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.65		0.65
# 2	0.64		0.64
# 3	0.64		0.65
# 4	0.64		0.65
# 5	0.65		0.65
# 6	0.66		0.66
# 7	0.65		0.66
# 8	0.65		0.66
# 9	0.66		0.66
# 10	0.65		0.66
# 11	0.65		0.66
# 12	0.65		0.66
# 13	0.65		0.66
# 14	0.65		0.66
# 15	0.65		0.66
# 16	0.65		0.66
# 17	0.66		0.66
# 18	0.65		0.66
# 19	0.65		0.66
# 20	0.65		0.66
# t = 6 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 13 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.64		0.65
# 2	0.65		0.65
# 3	0.65		0.66
# 4	0.65		0.66
# 5	0.65		0.66
# 6	0.66		0.67
# 7	0.66		0.67
# 8	0.66		0.67
# 9	0.66		0.66
# 10	0.66		0.67
# 11	0.66		0.67
# 12	0.66		0.67
# 13	0.66		0.67
# 14	0.65		0.66
# 15	0.65		0.66
# 16	0.66		0.66
# 17	0.65		0.66
# 18	0.65		0.66
# 19	0.66		0.66
# 20	0.66		0.66
# t = 7 was best iteration with accuracy 0.67
#
# -----------------------------------------------
# 14 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.65		0.65
# 2	0.65		0.65
# 3	0.66		0.66
# 4	0.66		0.65
# 5	0.65		0.65
# 6	0.65		0.66
# 7	0.65		0.66
# 8	0.65		0.66
# 9	0.65		0.66
# 10	0.65		0.66
# 11	0.66		0.66
# 12	0.65		0.66
# 13	0.66		0.66
# 14	0.65		0.66
# 15	0.65		0.67
# 16	0.66		0.66
# 17	0.66		0.66
# 18	0.66		0.66
# 19	0.66		0.66
# 20	0.66		0.66
# t = 19 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 15 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.68
# 2	0.67		0.68
# 3	0.67		0.67
# 4	0.66		0.67
# 5	0.67		0.67
# 6	0.67		0.67
# 7	0.66		0.67
# 8	0.67		0.67
# 9	0.66		0.66
# 10	0.65		0.66
# 11	0.66		0.67
# 12	0.66		0.67
# 13	0.66		0.67
# 14	0.66		0.67
# 15	0.66		0.67
# 16	0.66		0.67
# 17	0.66		0.66
# 18	0.66		0.67
# 19	0.66		0.66
# 20	0.65		0.66
# t = 1 was best iteration with accuracy 0.68
#
# -----------------------------------------------
# 16 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.68		0.67
# 2	0.67		0.67
# 3	0.68		0.67
# 4	0.67		0.66
# 5	0.66		0.66
# 6	0.66		0.67
# 7	0.66		0.67
# 8	0.66		0.66
# 9	0.66		0.66
# 10	0.66		0.66
# 11	0.66		0.67
# 12	0.67		0.67
# 13	0.66		0.67
# 14	0.66		0.67
# 15	0.66		0.66
# 16	0.66		0.66
# 17	0.66		0.67
# 18	0.66		0.67
# 19	0.66		0.67
# 20	0.66		0.66
# t = 3 was best iteration with accuracy 0.67
#
# -----------------------------------------------
# 17 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.66		0.67
# 2	0.67		0.66
# 3	0.66		0.66
# 4	0.65		0.66
# 5	0.66		0.66
# 6	0.66		0.66
# 7	0.66		0.66
# 8	0.66		0.66
# 9	0.66		0.67
# 10	0.65		0.66
# 11	0.65		0.67
# 12	0.66		0.66
# 13	0.66		0.67
# 14	0.65		0.66
# 15	0.66		0.67
# 16	0.66		0.66
# 17	0.66		0.66
# 18	0.66		0.67
# 19	0.66		0.67
# 20	0.66		0.67
# t = 2 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 18 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.67		0.64
# 2	0.67		0.67
# 3	0.67		0.66
# 4	0.67		0.67
# 5	0.66		0.67
# 6	0.66		0.66
# 7	0.67		0.66
# 8	0.67		0.67
# 9	0.66		0.67
# 10	0.66		0.66
# 11	0.66		0.66
# 12	0.66		0.66
# 13	0.66		0.67
# 14	0.66		0.67
# 15	0.66		0.67
# 16	0.66		0.67
# 17	0.66		0.67
# 18	0.66		0.67
# 19	0.66		0.67
# 20	0.66		0.67
# t = 1 was best iteration with accuracy 0.64
#
# -----------------------------------------------
# 19 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.64		0.64
# 2	0.65		0.67
# 3	0.66		0.67
# 4	0.66		0.67
# 5	0.66		0.66
# 6	0.66		0.66
# 7	0.66		0.66
# 8	0.66		0.67
# 9	0.66		0.67
# 10	0.66		0.67
# 11	0.66		0.66
# 12	0.66		0.66
# 13	0.66		0.66
# 14	0.66		0.66
# 15	0.66		0.66
# 16	0.66		0.66
# 17	0.66		0.66
# 18	0.65		0.66
# 19	0.65		0.66
# 20	0.65		0.67
# t = 5 was best iteration with accuracy 0.66
#
# -----------------------------------------------
# 20 / 40 complete
# -----------------------------------------------
#
# PRELIMINARY
# Training accuracy of rank SVM: 0.89
# GENERATE W
# num (-1, -1): 116
# num (-1,  1): 36
# num ( 1, -1): 41
# num ( 1,  1): 7
# Training accuracy of rank SVM: 0.99
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.75
# 2	0.71		0.73
# 3	0.71		0.73
# 4	0.72		0.73
# 5	0.72		0.74
# 6	0.71		0.73
# 7	0.71		0.72
# 8	0.71		0.72
# 9	0.71		0.73
# 10	0.70		0.72
# 11	0.70		0.73
# 12	0.71		0.72
# 13	0.71		0.73
# 14	0.71		0.72
# 15	0.71		0.72
# 16	0.71		0.72
# 17	0.71		0.73
# 18	0.71		0.73
# 19	0.71		0.73
# 20	0.71		0.73
# t = 5 was best iteration with accuracy 0.74
#
# -----------------------------------------------
# 21 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.74		0.75
# 2	0.74		0.75
# 3	0.73		0.74
# 4	0.72		0.74
# 5	0.73		0.74
# 6	0.72		0.74
# 7	0.72		0.73
# 8	0.71		0.74
# 9	0.71		0.73
# 10	0.72		0.73
# 11	0.71		0.74
# 12	0.71		0.73
# 13	0.71		0.73
# 14	0.71		0.73
# 15	0.71		0.73
# 16	0.71		0.73
# 17	0.71		0.74
# 18	0.71		0.73
# 19	0.71		0.73
# 20	0.71		0.73
# t = 1 was best iteration with accuracy 0.75
#
# -----------------------------------------------
# 22 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.73
# 2	0.70		0.72
# 3	0.70		0.72
# 4	0.70		0.72
# 5	0.71		0.72
# 6	0.71		0.73
# 7	0.71		0.73
# 8	0.71		0.73
# 9	0.71		0.73
# 10	0.71		0.73
# 11	0.71		0.73
# 12	0.71		0.73
# 13	0.71		0.73
# 14	0.71		0.73
# 15	0.71		0.73
# 16	0.71		0.73
# 17	0.71		0.73
# 18	0.71		0.73
# 19	0.71		0.73
# 20	0.71		0.73
# t = 12 was best iteration with accuracy 0.73
#
# -----------------------------------------------
# 23 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.74		0.75
# 2	0.73		0.75
# 3	0.72		0.75
# 4	0.72		0.74
# 5	0.72		0.74
# 6	0.72		0.73
# 7	0.71		0.73
# 8	0.72		0.73
# 9	0.72		0.73
# 10	0.71		0.73
# 11	0.71		0.73
# 12	0.71		0.73
# 13	0.71		0.73
# 14	0.71		0.73
# 15	0.71		0.73
# 16	0.71		0.73
# 17	0.71		0.73
# 18	0.71		0.73
# 19	0.71		0.73
# 20	0.71		0.73
# t = 1 was best iteration with accuracy 0.75
#
# -----------------------------------------------
# 24 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.74
# 2	0.72		0.75
# 3	0.72		0.75
# 4	0.72		0.74
# 5	0.72		0.74
# 6	0.71		0.74
# 7	0.71		0.74
# 8	0.71		0.73
# 9	0.71		0.73
# 10	0.71		0.72
# 11	0.71		0.72
# 12	0.71		0.72
# 13	0.71		0.73
# 14	0.71		0.73
# 15	0.71		0.73
# 16	0.71		0.72
# 17	0.71		0.72
# 18	0.71		0.73
# 19	0.71		0.73
# 20	0.71		0.72
# t = 3 was best iteration with accuracy 0.75
#
# -----------------------------------------------
# 25 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.73
# 2	0.72		0.74
# 3	0.71		0.72
# 4	0.71		0.73
# 5	0.71		0.73
# 6	0.71		0.73
# 7	0.71		0.73
# 8	0.71		0.73
# 9	0.71		0.73
# 10	0.71		0.73
# 11	0.71		0.73
# 12	0.70		0.72
# 13	0.71		0.73
# 14	0.71		0.73
# 15	0.71		0.72
# 16	0.71		0.72
# 17	0.71		0.73
# 18	0.70		0.72
# 19	0.71		0.72
# 20	0.70		0.72
# t = 1 was best iteration with accuracy 0.73
#
# -----------------------------------------------
# 26 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.74
# 2	0.72		0.74
# 3	0.71		0.73
# 4	0.72		0.74
# 5	0.71		0.74
# 6	0.71		0.74
# 7	0.71		0.73
# 8	0.72		0.73
# 9	0.72		0.73
# 10	0.72		0.74
# 11	0.72		0.73
# 12	0.72		0.73
# 13	0.71		0.73
# 14	0.72		0.73
# 15	0.72		0.73
# 16	0.71		0.73
# 17	0.71		0.73
# 18	0.71		0.73
# 19	0.71		0.73
# 20	0.71		0.73
# t = 1 was best iteration with accuracy 0.74
#
# -----------------------------------------------
# 27 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.74		0.75
# 2	0.72		0.74
# 3	0.72		0.74
# 4	0.72		0.74
# 5	0.72		0.74
# 6	0.72		0.74
# 7	0.72		0.74
# 8	0.72		0.74
# 9	0.72		0.74
# 10	0.72		0.73
# 11	0.71		0.74
# 12	0.72		0.74
# 13	0.72		0.74
# 14	0.72		0.73
# 15	0.72		0.74
# 16	0.72		0.74
# 17	0.72		0.74
# 18	0.72		0.73
# 19	0.72		0.73
# 20	0.72		0.73
# t = 1 was best iteration with accuracy 0.75
#
# -----------------------------------------------
# 28 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.73
# 2	0.71		0.74
# 3	0.71		0.73
# 4	0.70		0.73
# 5	0.71		0.72
# 6	0.71		0.72
# 7	0.71		0.73
# 8	0.71		0.73
# 9	0.71		0.73
# 10	0.71		0.73
# 11	0.72		0.73
# 12	0.71		0.73
# 13	0.71		0.73
# 14	0.71		0.73
# 15	0.71		0.74
# 16	0.71		0.74
# 17	0.71		0.73
# 18	0.71		0.73
# 19	0.71		0.73
# 20	0.71		0.73
# t = 11 was best iteration with accuracy 0.73
#
# -----------------------------------------------
# 29 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.73
# 2	0.72		0.73
# 3	0.71		0.73
# 4	0.71		0.72
# 5	0.71		0.72
# 6	0.71		0.73
# 7	0.70		0.73
# 8	0.71		0.73
# 9	0.71		0.73
# 10	0.71		0.73
# 11	0.71		0.73
# 12	0.71		0.73
# 13	0.71		0.73
# 14	0.71		0.73
# 15	0.71		0.73
# 16	0.71		0.73
# 17	0.71		0.72
# 18	0.71		0.73
# 19	0.71		0.73
# 20	0.71		0.73
# t = 1 was best iteration with accuracy 0.73
#
# -----------------------------------------------
# 30 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.73
# 2	0.71		0.74
# 3	0.71		0.73
# 4	0.71		0.72
# 5	0.72		0.73
# 6	0.72		0.73
# 7	0.72		0.73
# 8	0.72		0.73
# 9	0.71		0.73
# 10	0.71		0.73
# 11	0.71		0.73
# 12	0.72		0.73
# 13	0.71		0.73
# 14	0.72		0.73
# 15	0.71		0.73
# 16	0.71		0.73
# 17	0.71		0.73
# 18	0.71		0.72
# 19	0.71		0.72
# 20	0.71		0.73
# t = 1 was best iteration with accuracy 0.73
#
# -----------------------------------------------
# 31 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.72
# 2	0.72		0.74
# 3	0.72		0.73
# 4	0.71		0.73
# 5	0.71		0.73
# 6	0.71		0.73
# 7	0.71		0.73
# 8	0.70		0.73
# 9	0.71		0.73
# 10	0.71		0.73
# 11	0.71		0.72
# 12	0.71		0.72
# 13	0.71		0.72
# 14	0.71		0.72
# 15	0.71		0.72
# 16	0.71		0.72
# 17	0.71		0.72
# 18	0.71		0.72
# 19	0.71		0.72
# 20	0.71		0.73
# t = 2 was best iteration with accuracy 0.74
#
# -----------------------------------------------
# 32 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.70		0.71
# 2	0.71		0.73
# 3	0.72		0.73
# 4	0.71		0.72
# 5	0.71		0.73
# 6	0.71		0.73
# 7	0.71		0.72
# 8	0.71		0.73
# 9	0.71		0.73
# 10	0.71		0.73
# 11	0.71		0.73
# 12	0.71		0.73
# 13	0.71		0.72
# 14	0.71		0.72
# 15	0.71		0.72
# 16	0.71		0.73
# 17	0.71		0.72
# 18	0.71		0.73
# 19	0.71		0.73
# 20	0.71		0.73
# t = 3 was best iteration with accuracy 0.73
#
# -----------------------------------------------
# 33 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.70
# 2	0.70		0.73
# 3	0.71		0.73
# 4	0.70		0.73
# 5	0.71		0.74
# 6	0.71		0.73
# 7	0.71		0.73
# 8	0.71		0.73
# 9	0.71		0.73
# 10	0.71		0.74
# 11	0.72		0.74
# 12	0.71		0.73
# 13	0.71		0.73
# 14	0.71		0.73
# 15	0.71		0.73
# 16	0.71		0.73
# 17	0.71		0.73
# 18	0.71		0.73
# 19	0.72		0.73
# 20	0.72		0.73
# t = 11 was best iteration with accuracy 0.74
#
# -----------------------------------------------
# 34 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.72
# 2	0.71		0.72
# 3	0.71		0.73
# 4	0.72		0.73
# 5	0.72		0.73
# 6	0.72		0.73
# 7	0.72		0.73
# 8	0.72		0.73
# 9	0.71		0.73
# 10	0.71		0.74
# 11	0.71		0.74
# 12	0.72		0.74
# 13	0.72		0.74
# 14	0.71		0.74
# 15	0.72		0.74
# 16	0.71		0.73
# 17	0.71		0.73
# 18	0.71		0.74
# 19	0.71		0.73
# 20	0.71		0.72
# t = 4 was best iteration with accuracy 0.73
#
# -----------------------------------------------
# 35 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.74
# 2	0.72		0.74
# 3	0.72		0.74
# 4	0.72		0.74
# 5	0.72		0.74
# 6	0.72		0.74
# 7	0.72		0.73
# 8	0.72		0.73
# 9	0.72		0.73
# 10	0.71		0.73
# 11	0.71		0.73
# 12	0.71		0.73
# 13	0.71		0.73
# 14	0.71		0.73
# 15	0.71		0.73
# 16	0.71		0.73
# 17	0.72		0.73
# 18	0.72		0.73
# 19	0.72		0.74
# 20	0.71		0.73
# t = 2 was best iteration with accuracy 0.74
#
# -----------------------------------------------
# 36 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.71		0.72
# 2	0.70		0.71
# 3	0.70		0.72
# 4	0.71		0.72
# 5	0.71		0.73
# 6	0.71		0.72
# 7	0.71		0.72
# 8	0.71		0.72
# 9	0.71		0.72
# 10	0.71		0.72
# 11	0.71		0.72
# 12	0.71		0.72
# 13	0.71		0.72
# 14	0.71		0.72
# 15	0.71		0.73
# 16	0.71		0.73
# 17	0.71		0.72
# 18	0.71		0.72
# 19	0.71		0.72
# 20	0.71		0.72
# t = 8 was best iteration with accuracy 0.72
#
# -----------------------------------------------
# 37 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.73
# 2	0.71		0.73
# 3	0.71		0.73
# 4	0.71		0.73
# 5	0.71		0.73
# 6	0.71		0.73
# 7	0.71		0.74
# 8	0.72		0.73
# 9	0.72		0.74
# 10	0.71		0.73
# 11	0.71		0.73
# 12	0.71		0.73
# 13	0.71		0.73
# 14	0.71		0.73
# 15	0.71		0.73
# 16	0.72		0.73
# 17	0.71		0.73
# 18	0.71		0.72
# 19	0.71		0.73
# 20	0.71		0.73
# t = 1 was best iteration with accuracy 0.73
#
# -----------------------------------------------
# 38 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.69		0.72
# 2	0.70		0.72
# 3	0.71		0.73
# 4	0.71		0.73
# 5	0.71		0.73
# 6	0.72		0.73
# 7	0.72		0.73
# 8	0.71		0.73
# 9	0.71		0.73
# 10	0.71		0.73
# 11	0.71		0.73
# 12	0.71		0.73
# 13	0.71		0.73
# 14	0.71		0.73
# 15	0.71		0.73
# 16	0.71		0.73
# 17	0.71		0.72
# 18	0.71		0.72
# 19	0.71		0.72
# 20	0.71		0.72
# t = 6 was best iteration with accuracy 0.73
#
# -----------------------------------------------
# 39 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.75
# 2	0.73		0.73
# 3	0.72		0.73
# 4	0.71		0.74
# 5	0.71		0.74
# 6	0.71		0.73
# 7	0.71		0.73
# 8	0.71		0.73
# 9	0.71		0.73
# 10	0.71		0.72
# 11	0.71		0.72
# 12	0.71		0.73
# 13	0.72		0.73
# 14	0.72		0.73
# 15	0.71		0.73
# 16	0.71		0.73
# 17	0.71		0.73
# 18	0.71		0.73
# 19	0.71		0.73
# 20	0.71		0.73
# t = 2 was best iteration with accuracy 0.73
#
# -----------------------------------------------
# 40 / 40 complete
# -----------------------------------------------

# %%
table_results(svm_arr, tree_arr)
# Out:
# (Performance on test set)
#
# 50 comparisons
# 	acc	sderr
# SVM: 	66.3	0.1
# Tree: 	nan	nan
#
# 200 comparisons
# 	acc	sderr
# SVM: 	73.7	0.2
# Tree: 	nan	nan

# %%
eq1 = np.sum(y_test == 1) / y_test.size
max(eq1, 1 - eq1)
# Out:
# 0.7601254446016752
