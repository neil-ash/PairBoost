# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_svmlight_file
from sklearn.model_selection import train_test_split
import sys; sys.path.insert(0,'..')
from main import *

# %%
X, y = load_svmlight_file('../data/phishing/phishing.txt')
X = X.toarray()

# Convert labels from {0, 1} to {-1, 1}
y = y * 2 - 1

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.5, stratify=y, 
                                                    shuffle=True, random_state=1)

# %%
svm_arr, tree_arr = data_size_experiment(X_train, y_train, X_test, y_test,
                                         experiment_type='table', kernel='linear',
                                         random_state=1, verbose=True)
# Out:
# PRELIMINARY
# Training accuracy of rank SVM: 0.94
#
# GENERATE W
# num (-1, -1): 7
# num (-1,  1): 16
# num ( 1, -1): 10
# num ( 1,  1): 17
# Training accuracy of rank SVM: 0.90
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.92		0.91
# 2	0.72		0.68
# 3	0.88		0.89
# 4	0.51		0.47
# 5	0.89		0.91
# 6	0.62		0.61
# 7	0.86		0.89
# 8	0.60		0.57
# 9	0.84		0.87
# 10	0.63		0.61
# 11	0.85		0.85
# 12	0.52		0.49
# 13	0.82		0.84
# 14	0.71		0.74
# 15	0.83		0.83
# 16	0.64		0.64
# 17	0.82		0.83
# 18	0.63		0.63
# 19	0.85		0.84
# 20	0.65		0.63
# t = 1 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 1 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.90		0.90
# 2	0.71		0.69
# 3	0.77		0.82
# 4	0.59		0.58
# 5	0.89		0.89
# 6	0.71		0.69
# 7	0.79		0.81
# 8	0.59		0.59
# 9	0.88		0.89
# 10	0.75		0.73
# 11	0.82		0.84
# 12	0.53		0.53
# 13	0.87		0.87
# 14	0.69		0.67
# 15	0.83		0.85
# 16	0.56		0.57
# 17	0.84		0.85
# 18	0.65		0.64
# 19	0.84		0.84
# 20	0.69		0.67
# t = 1 was best iteration with accuracy 0.90
#
# -----------------------------------------------
# 2 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.92		0.91
# 2	0.72		0.66
# 3	0.81		0.81
# 4	0.58		0.56
# 5	0.92		0.90
# 6	0.67		0.65
# 7	0.83		0.81
# 8	0.59		0.58
# 9	0.91		0.87
# 10	0.73		0.76
# 11	0.78		0.76
# 12	0.62		0.65
# 13	0.87		0.82
# 14	0.77		0.78
# 15	0.78		0.74
# 16	0.67		0.68
# 17	0.84		0.82
# 18	0.71		0.74
# 19	0.82		0.77
# 20	0.67		0.69
# t = 5 was best iteration with accuracy 0.90
#
# -----------------------------------------------
# 3 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.91		0.89
# 2	0.67		0.65
# 3	0.76		0.80
# 4	0.69		0.68
# 5	0.91		0.91
# 6	0.64		0.64
# 7	0.83		0.83
# 8	0.77		0.74
# 9	0.88		0.89
# 10	0.65		0.65
# 11	0.86		0.87
# 12	0.73		0.74
# 13	0.90		0.90
# 14	0.64		0.67
# 15	0.83		0.82
# 16	0.77		0.78
# 17	0.87		0.88
# 18	0.64		0.67
# 19	0.78		0.81
# 20	0.66		0.67
# t = 1 was best iteration with accuracy 0.89
#
# -----------------------------------------------
# 4 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.92		0.91
# 2	0.77		0.74
# 3	0.84		0.83
# 4	0.55		0.55
# 5	0.89		0.89
# 6	0.65		0.62
# 7	0.83		0.84
# 8	0.62		0.59
# 9	0.86		0.88
# 10	0.59		0.56
# 11	0.85		0.87
# 12	0.57		0.55
# 13	0.78		0.79
# 14	0.65		0.66
# 15	0.88		0.88
# 16	0.74		0.72
# 17	0.77		0.78
# 18	0.60		0.56
# 19	0.87		0.87
# 20	0.73		0.72
# t = 1 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 5 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.92		0.91
# 2	0.67		0.65
# 3	0.85		0.87
# 4	0.59		0.61
# 5	0.91		0.91
# 6	0.73		0.73
# 7	0.84		0.83
# 8	0.64		0.65
# 9	0.84		0.82
# 10	0.72		0.73
# 11	0.83		0.84
# 12	0.63		0.64
# 13	0.80		0.79
# 14	0.70		0.70
# 15	0.84		0.83
# 16	0.72		0.72
# 17	0.82		0.81
# 18	0.67		0.67
# 19	0.83		0.82
# 20	0.69		0.70
# t = 1 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 6 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.91		0.89
# 2	0.77		0.73
# 3	0.77		0.80
# 4	0.60		0.57
# 5	0.91		0.90
# 6	0.69		0.65
# 7	0.82		0.85
# 8	0.62		0.61
# 9	0.89		0.89
# 10	0.74		0.70
# 11	0.87		0.88
# 12	0.64		0.62
# 13	0.84		0.84
# 14	0.73		0.69
# 15	0.82		0.82
# 16	0.63		0.63
# 17	0.79		0.77
# 18	0.78		0.75
# 19	0.84		0.83
# 20	0.78		0.76
# t = 1 was best iteration with accuracy 0.89
#
# -----------------------------------------------
# 7 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.90		0.89
# 2	0.79		0.74
# 3	0.82		0.84
# 4	0.59		0.56
# 5	0.92		0.91
# 6	0.51		0.48
# 7	0.87		0.90
# 8	0.78		0.75
# 9	0.87		0.90
# 10	0.42		0.40
# 11	0.86		0.85
# 12	0.85		0.80
# 13	0.85		0.85
# 14	0.47		0.46
# 15	0.78		0.79
# 16	0.89		0.87
# 17	0.74		0.72
# 18	0.85		0.86
# 19	0.25		0.25
# 20	0.91		0.91
# t = 5 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 8 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.91		0.90
# 2	0.76		0.72
# 3	0.74		0.78
# 4	0.61		0.59
# 5	0.89		0.89
# 6	0.56		0.57
# 7	0.77		0.78
# 8	0.81		0.80
# 9	0.88		0.87
# 10	0.79		0.75
# 11	0.79		0.77
# 12	0.55		0.56
# 13	0.72		0.66
# 14	0.60		0.62
# 15	0.80		0.78
# 16	0.72		0.71
# 17	0.83		0.81
# 18	0.76		0.74
# 19	0.80		0.80
# 20	0.74		0.72
# t = 1 was best iteration with accuracy 0.90
#
# -----------------------------------------------
# 9 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.91		0.91
# 2	0.75		0.73
# 3	0.86		0.87
# 4	0.52		0.52
# 5	0.90		0.88
# 6	0.74		0.74
# 7	0.86		0.86
# 8	0.57		0.56
# 9	0.75		0.76
# 10	0.79		0.78
# 11	0.86		0.86
# 12	0.70		0.65
# 13	0.65		0.64
# 14	0.69		0.66
# 15	0.77		0.78
# 16	0.69		0.67
# 17	0.72		0.72
# 18	0.65		0.64
# 19	0.65		0.67
# 20	0.63		0.62
# t = 1 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 10 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.91		0.90
# 2	0.71		0.68
# 3	0.87		0.90
# 4	0.51		0.51
# 5	0.89		0.91
# 6	0.68		0.68
# 7	0.84		0.85
# 8	0.54		0.55
# 9	0.86		0.86
# 10	0.74		0.75
# 11	0.84		0.83
# 12	0.65		0.63
# 13	0.81		0.82
# 14	0.68		0.65
# 15	0.83		0.83
# 16	0.65		0.63
# 17	0.82		0.80
# 18	0.65		0.63
# 19	0.83		0.83
# 20	0.67		0.66
# t = 1 was best iteration with accuracy 0.90
#
# -----------------------------------------------
# 11 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.91		0.90
# 2	0.73		0.68
# 3	0.85		0.88
# 4	0.59		0.58
# 5	0.91		0.91
# 6	0.55		0.57
# 7	0.89		0.89
# 8	0.58		0.58
# 9	0.90		0.89
# 10	0.73		0.71
# 11	0.89		0.87
# 12	0.62		0.63
# 13	0.89		0.87
# 14	0.58		0.62
# 15	0.89		0.87
# 16	0.77		0.75
# 17	0.87		0.85
# 18	0.62		0.64
# 19	0.80		0.80
# 20	0.76		0.76
# t = 1 was best iteration with accuracy 0.90
#
# -----------------------------------------------
# 12 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.91		0.91
# 2	0.77		0.72
# 3	0.81		0.82
# 4	0.51		0.54
# 5	0.90		0.91
# 6	0.75		0.73
# 7	0.89		0.90
# 8	0.53		0.53
# 9	0.86		0.87
# 10	0.80		0.78
# 11	0.83		0.85
# 12	0.54		0.53
# 13	0.82		0.82
# 14	0.74		0.75
# 15	0.84		0.84
# 16	0.64		0.64
# 17	0.81		0.79
# 18	0.74		0.71
# 19	0.83		0.83
# 20	0.73		0.71
# t = 1 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 13 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.90		0.91
# 2	0.82		0.77
# 3	0.85		0.87
# 4	0.54		0.52
# 5	0.88		0.90
# 6	0.72		0.69
# 7	0.89		0.91
# 8	0.64		0.65
# 9	0.83		0.84
# 10	0.62		0.62
# 11	0.85		0.85
# 12	0.66		0.65
# 13	0.81		0.77
# 14	0.79		0.79
# 15	0.81		0.82
# 16	0.70		0.68
# 17	0.70		0.70
# 18	0.66		0.65
# 19	0.73		0.73
# 20	0.67		0.66
# t = 1 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 14 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.91		0.91
# 2	0.75		0.71
# 3	0.75		0.79
# 4	0.63		0.61
# 5	0.91		0.89
# 6	0.57		0.56
# 7	0.78		0.82
# 8	0.70		0.67
# 9	0.82		0.81
# 10	0.64		0.62
# 11	0.83		0.83
# 12	0.67		0.69
# 13	0.82		0.83
# 14	0.64		0.67
# 15	0.82		0.83
# 16	0.65		0.66
# 17	0.78		0.81
# 18	0.65		0.66
# 19	0.78		0.80
# 20	0.66		0.66
# t = 1 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 15 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.92		0.91
# 2	0.68		0.66
# 3	0.85		0.84
# 4	0.67		0.66
# 5	0.92		0.90
# 6	0.47		0.49
# 7	0.91		0.90
# 8	0.76		0.77
# 9	0.88		0.85
# 10	0.52		0.59
# 11	0.89		0.86
# 12	0.69		0.74
# 13	0.84		0.81
# 14	0.69		0.71
# 15	0.77		0.74
# 16	0.53		0.54
# 17	0.70		0.71
# 18	0.52		0.52
# 19	0.69		0.69
# 20	0.50		0.53
# t = 1 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 16 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.91		0.92
# 2	0.66		0.62
# 3	0.89		0.90
# 4	0.27		0.27
# 5	0.89		0.90
# 6	0.77		0.76
# 7	0.87		0.88
# 8	0.50		0.48
# 9	0.88		0.90
# 10	0.83		0.81
# 11	0.89		0.88
# 12	0.56		0.55
# 13	0.87		0.87
# 14	0.79		0.79
# 15	0.90		0.90
# 16	0.68		0.70
# 17	0.86		0.87
# 18	0.69		0.71
# 19	0.86		0.88
# 20	0.69		0.70
# t = 1 was best iteration with accuracy 0.92
#
# -----------------------------------------------
# 17 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.91		0.92
# 2	0.77		0.76
# 3	0.78		0.78
# 4	0.53		0.55
# 5	0.91		0.90
# 6	0.82		0.82
# 7	0.88		0.85
# 8	0.39		0.46
# 9	0.87		0.86
# 10	0.88		0.87
# 11	0.87		0.86
# 12	0.52		0.55
# 13	0.76		0.77
# 14	0.90		0.87
# 15	0.86		0.83
# 16	0.81		0.83
# 17	0.54		0.54
# 18	0.88		0.88
# 19	0.83		0.79
# 20	0.81		0.82
# t = 1 was best iteration with accuracy 0.92
#
# -----------------------------------------------
# 18 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.92		0.91
# 2	0.70		0.69
# 3	0.85		0.85
# 4	0.55		0.55
# 5	0.91		0.90
# 6	0.57		0.58
# 7	0.87		0.85
# 8	0.56		0.57
# 9	0.84		0.86
# 10	0.68		0.67
# 11	0.81		0.81
# 12	0.63		0.63
# 13	0.82		0.85
# 14	0.70		0.68
# 15	0.79		0.82
# 16	0.66		0.65
# 17	0.77		0.81
# 18	0.65		0.64
# 19	0.78		0.82
# 20	0.70		0.69
# t = 1 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 19 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.91		0.91
# 2	0.70		0.67
# 3	0.78		0.79
# 4	0.58		0.58
# 5	0.87		0.88
# 6	0.66		0.65
# 7	0.83		0.82
# 8	0.61		0.59
# 9	0.83		0.83
# 10	0.64		0.63
# 11	0.83		0.84
# 12	0.63		0.62
# 13	0.74		0.73
# 14	0.67		0.63
# 15	0.83		0.82
# 16	0.76		0.73
# 17	0.76		0.78
# 18	0.62		0.59
# 19	0.73		0.73
# 20	0.72		0.70
# t = 1 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 20 / 40 complete
# -----------------------------------------------
#
# PRELIMINARY
# Training accuracy of rank SVM: 0.94
#
# GENERATE W
# num (-1, -1): 38
# num (-1,  1): 34
# num ( 1, -1): 63
# num ( 1,  1): 65
# Training accuracy of rank SVM: 0.95
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.91		0.91
# 2	0.92		0.90
# 3	0.92		0.90
# 4	0.91		0.90
# 5	0.91		0.90
# 6	0.91		0.90
# 7	0.92		0.90
# 8	0.92		0.90
# 9	0.92		0.90
# 10	0.92		0.90
# 11	0.92		0.90
# 12	0.91		0.90
# 13	0.91		0.90
# 14	0.91		0.90
# 15	0.91		0.90
# 16	0.91		0.90
# 17	0.91		0.90
# 18	0.91		0.90
# 19	0.91		0.90
# 20	0.92		0.90
# t = 3 was best iteration with accuracy 0.90
#
# -----------------------------------------------
# 21 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.92		0.90
# 2	0.92		0.90
# 3	0.92		0.90
# 4	0.91		0.90
# 5	0.91		0.90
# 6	0.91		0.90
# 7	0.91		0.90
# 8	0.92		0.90
# 9	0.91		0.90
# 10	0.92		0.90
# 11	0.91		0.90
# 12	0.91		0.90
# 13	0.91		0.90
# 14	0.91		0.90
# 15	0.91		0.90
# 16	0.91		0.90
# 17	0.92		0.90
# 18	0.92		0.90
# 19	0.91		0.90
# 20	0.91		0.90
# t = 1 was best iteration with accuracy 0.90
#
# -----------------------------------------------
# 22 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.92		0.92
# 2	0.92		0.91
# 3	0.92		0.90
# 4	0.91		0.90
# 5	0.92		0.90
# 6	0.92		0.90
# 7	0.92		0.90
# 8	0.92		0.90
# 9	0.92		0.90
# 10	0.91		0.90
# 11	0.92		0.90
# 12	0.91		0.90
# 13	0.91		0.90
# 14	0.91		0.90
# 15	0.91		0.90
# 16	0.92		0.90
# 17	0.92		0.90
# 18	0.91		0.90
# 19	0.91		0.90
# 20	0.91		0.90
# t = 2 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 23 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.92		0.90
# 2	0.92		0.90
# 3	0.92		0.90
# 4	0.91		0.90
# 5	0.92		0.90
# 6	0.92		0.90
# 7	0.91		0.90
# 8	0.91		0.90
# 9	0.91		0.90
# 10	0.91		0.90
# 11	0.91		0.90
# 12	0.91		0.90
# 13	0.91		0.90
# 14	0.91		0.90
# 15	0.92		0.90
# 16	0.91		0.90
# 17	0.91		0.90
# 18	0.91		0.90
# 19	0.91		0.90
# 20	0.91		0.90
# t = 2 was best iteration with accuracy 0.90
#
# -----------------------------------------------
# 24 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.92		0.92
# 2	0.92		0.90
# 3	0.92		0.90
# 4	0.92		0.90
# 5	0.91		0.90
# 6	0.91		0.90
# 7	0.92		0.90
# 8	0.92		0.90
# 9	0.92		0.90
# 10	0.92		0.90
# 11	0.92		0.90
# 12	0.91		0.90
# 13	0.92		0.90
# 14	0.92		0.90
# 15	0.92		0.90
# 16	0.91		0.90
# 17	0.92		0.90
# 18	0.91		0.90
# 19	0.91		0.90
# 20	0.91		0.90
# t = 1 was best iteration with accuracy 0.92
#
# -----------------------------------------------
# 25 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.91
# 2	0.91		0.90
# 3	0.92		0.90
# 4	0.92		0.90
# 5	0.92		0.90
# 6	0.92		0.90
# 7	0.92		0.90
# 8	0.91		0.90
# 9	0.92		0.90
# 10	0.92		0.90
# 11	0.91		0.90
# 12	0.91		0.90
# 13	0.91		0.90
# 14	0.92		0.90
# 15	0.91		0.90
# 16	0.92		0.90
# 17	0.92		0.90
# 18	0.91		0.90
# 19	0.92		0.90
# 20	0.92		0.90
# t = 1 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 26 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.91		0.90
# 2	0.91		0.90
# 3	0.91		0.89
# 4	0.92		0.90
# 5	0.92		0.89
# 6	0.91		0.90
# 7	0.91		0.90
# 8	0.92		0.90
# 9	0.92		0.90
# 10	0.92		0.90
# 11	0.92		0.90
# 12	0.92		0.90
# 13	0.92		0.90
# 14	0.92		0.90
# 15	0.92		0.90
# 16	0.92		0.90
# 17	0.92		0.90
# 18	0.92		0.90
# 19	0.92		0.90
# 20	0.92		0.90
# t = 8 was best iteration with accuracy 0.90
#
# -----------------------------------------------
# 27 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.91		0.91
# 2	0.92		0.90
# 3	0.92		0.90
# 4	0.92		0.90
# 5	0.92		0.90
# 6	0.92		0.90
# 7	0.92		0.90
# 8	0.92		0.90
# 9	0.92		0.90
# 10	0.92		0.90
# 11	0.91		0.90
# 12	0.92		0.90
# 13	0.92		0.90
# 14	0.91		0.90
# 15	0.92		0.90
# 16	0.91		0.90
# 17	0.92		0.90
# 18	0.92		0.90
# 19	0.91		0.90
# 20	0.91		0.90
# t = 2 was best iteration with accuracy 0.90
#
# -----------------------------------------------
# 28 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.92		0.91
# 2	0.92		0.90
# 3	0.91		0.90
# 4	0.91		0.90
# 5	0.92		0.90
# 6	0.92		0.90
# 7	0.92		0.90
# 8	0.91		0.90
# 9	0.91		0.90
# 10	0.91		0.90
# 11	0.91		0.90
# 12	0.91		0.90
# 13	0.91		0.90
# 14	0.92		0.90
# 15	0.91		0.90
# 16	0.91		0.90
# 17	0.92		0.90
# 18	0.91		0.90
# 19	0.92		0.90
# 20	0.92		0.90
# t = 1 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 29 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.91		0.90
# 2	0.92		0.90
# 3	0.92		0.90
# 4	0.92		0.90
# 5	0.92		0.90
# 6	0.92		0.90
# 7	0.92		0.90
# 8	0.92		0.90
# 9	0.91		0.90
# 10	0.91		0.90
# 11	0.92		0.90
# 12	0.92		0.90
# 13	0.92		0.90
# 14	0.92		0.90
# 15	0.92		0.90
# 16	0.91		0.90
# 17	0.92		0.90
# 18	0.91		0.90
# 19	0.91		0.90
# 20	0.91		0.90
# t = 2 was best iteration with accuracy 0.90
#
# -----------------------------------------------
# 30 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.90		0.89
# 2	0.92		0.90
# 3	0.92		0.90
# 4	0.92		0.90
# 5	0.91		0.90
# 6	0.92		0.90
# 7	0.92		0.90
# 8	0.92		0.90
# 9	0.91		0.90
# 10	0.92		0.90
# 11	0.92		0.90
# 12	0.91		0.90
# 13	0.91		0.90
# 14	0.92		0.90
# 15	0.92		0.90
# 16	0.92		0.90
# 17	0.92		0.90
# 18	0.92		0.90
# 19	0.92		0.90
# 20	0.92		0.90
# t = 4 was best iteration with accuracy 0.90
#
# -----------------------------------------------
# 31 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.91
# 2	0.92		0.90
# 3	0.92		0.90
# 4	0.92		0.90
# 5	0.91		0.90
# 6	0.92		0.90
# 7	0.92		0.90
# 8	0.91		0.90
# 9	0.92		0.90
# 10	0.92		0.90
# 11	0.92		0.90
# 12	0.92		0.90
# 13	0.92		0.90
# 14	0.92		0.90
# 15	0.92		0.90
# 16	0.92		0.90
# 17	0.92		0.90
# 18	0.91		0.90
# 19	0.91		0.90
# 20	0.91		0.90
# t = 1 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 32 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.92		0.91
# 2	0.92		0.90
# 3	0.92		0.90
# 4	0.92		0.90
# 5	0.92		0.90
# 6	0.92		0.90
# 7	0.92		0.90
# 8	0.91		0.90
# 9	0.91		0.90
# 10	0.92		0.90
# 11	0.92		0.90
# 12	0.91		0.90
# 13	0.91		0.90
# 14	0.92		0.90
# 15	0.91		0.90
# 16	0.91		0.90
# 17	0.92		0.90
# 18	0.91		0.90
# 19	0.91		0.90
# 20	0.91		0.90
# t = 3 was best iteration with accuracy 0.90
#
# -----------------------------------------------
# 33 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.91		0.90
# 2	0.92		0.90
# 3	0.92		0.90
# 4	0.92		0.90
# 5	0.91		0.90
# 6	0.92		0.90
# 7	0.92		0.90
# 8	0.92		0.90
# 9	0.92		0.90
# 10	0.92		0.90
# 11	0.91		0.90
# 12	0.91		0.90
# 13	0.91		0.90
# 14	0.92		0.90
# 15	0.91		0.90
# 16	0.91		0.90
# 17	0.91		0.90
# 18	0.91		0.90
# 19	0.91		0.90
# 20	0.91		0.90
# t = 2 was best iteration with accuracy 0.90
#
# -----------------------------------------------
# 34 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.91		0.91
# 2	0.92		0.90
# 3	0.91		0.90
# 4	0.91		0.90
# 5	0.91		0.90
# 6	0.91		0.90
# 7	0.91		0.90
# 8	0.92		0.90
# 9	0.91		0.90
# 10	0.91		0.90
# 11	0.91		0.90
# 12	0.91		0.90
# 13	0.91		0.90
# 14	0.91		0.90
# 15	0.91		0.90
# 16	0.91		0.90
# 17	0.91		0.90
# 18	0.91		0.90
# 19	0.91		0.90
# 20	0.91		0.90
# t = 2 was best iteration with accuracy 0.90
#
# -----------------------------------------------
# 35 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.91		0.91
# 2	0.92		0.90
# 3	0.92		0.90
# 4	0.92		0.90
# 5	0.92		0.90
# 6	0.92		0.90
# 7	0.91		0.90
# 8	0.91		0.90
# 9	0.92		0.90
# 10	0.91		0.90
# 11	0.92		0.90
# 12	0.91		0.90
# 13	0.92		0.90
# 14	0.91		0.90
# 15	0.91		0.90
# 16	0.91		0.90
# 17	0.91		0.90
# 18	0.91		0.90
# 19	0.91		0.90
# 20	0.92		0.90
# t = 3 was best iteration with accuracy 0.90
#
# -----------------------------------------------
# 36 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.93		0.91
# 2	0.92		0.90
# 3	0.92		0.90
# 4	0.92		0.90
# 5	0.92		0.90
# 6	0.92		0.90
# 7	0.91		0.90
# 8	0.92		0.90
# 9	0.92		0.90
# 10	0.92		0.90
# 11	0.92		0.90
# 12	0.92		0.90
# 13	0.91		0.90
# 14	0.91		0.90
# 15	0.91		0.90
# 16	0.91		0.90
# 17	0.91		0.90
# 18	0.91		0.90
# 19	0.91		0.90
# 20	0.91		0.90
# t = 1 was best iteration with accuracy 0.91
#
# -----------------------------------------------
# 37 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.92		0.91
# 2	0.92		0.90
# 3	0.92		0.90
# 4	0.91		0.90
# 5	0.92		0.90
# 6	0.92		0.90
# 7	0.92		0.90
# 8	0.92		0.90
# 9	0.92		0.90
# 10	0.91		0.90
# 11	0.91		0.90
# 12	0.92		0.90
# 13	0.91		0.90
# 14	0.91		0.90
# 15	0.91		0.90
# 16	0.91		0.90
# 17	0.91		0.90
# 18	0.91		0.90
# 19	0.91		0.90
# 20	0.91		0.90
# t = 2 was best iteration with accuracy 0.90
#
# -----------------------------------------------
# 38 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.91		0.90
# 2	0.92		0.89
# 3	0.92		0.90
# 4	0.92		0.90
# 5	0.92		0.90
# 6	0.91		0.90
# 7	0.92		0.90
# 8	0.92		0.90
# 9	0.92		0.90
# 10	0.92		0.90
# 11	0.91		0.90
# 12	0.91		0.90
# 13	0.91		0.90
# 14	0.91		0.90
# 15	0.91		0.90
# 16	0.91		0.90
# 17	0.91		0.90
# 18	0.91		0.90
# 19	0.91		0.90
# 20	0.91		0.90
# t = 2 was best iteration with accuracy 0.89
#
# -----------------------------------------------
# 39 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.92		0.91
# 2	0.92		0.90
# 3	0.92		0.90
# 4	0.92		0.90
# 5	0.92		0.90
# 6	0.92		0.90
# 7	0.92		0.90
# 8	0.92		0.90
# 9	0.92		0.90
# 10	0.92		0.90
# 11	0.92		0.90
# 12	0.92		0.90
# 13	0.92		0.90
# 14	0.92		0.90
# 15	0.92		0.90
# 16	0.92		0.90
# 17	0.92		0.90
# 18	0.91		0.90
# 19	0.91		0.90
# 20	0.91		0.90
# t = 2 was best iteration with accuracy 0.90
#
# -----------------------------------------------
# 40 / 40 complete
# -----------------------------------------------

# %%
table_results(svm_arr, tree_arr)
# Out:
# (Performance on test set)
#
# 50 comparisons
# 	acc	sderr
# SVM: 	90.6	0.1
# Tree: 	nan	nan
#
# 200 comparisons
# 	acc	sderr
# SVM: 	90.1	0.1
# Tree: 	nan	nan

# %%
eq1 = np.sum(y == 1) / y.size
max(eq1, 1 - eq1)
# Out:
# 0.5569425599276345
