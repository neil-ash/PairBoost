# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import sys; sys.path.insert(0,'..')
from main import *

# %%
data = pd.read_csv('../data/magic/magic04.data')
X = data.iloc[:, :-1].values
y  = data.iloc[:, -1].values

# %%
# Convert labels to -1, 1 and scale features
y = np.array([-1.0 if yi == 'g' else 1.0 for yi in y])

scaler = MinMaxScaler(feature_range=(0, 1))

for i in range(X.shape[1]):
    X[:, i] = scaler.fit_transform(X[:, i].reshape(-1, 1)).ravel()
    
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.5, stratify=y, 
                                                    shuffle=True, random_state=1)

# %%
svm_arr, tree_arr = data_size_experiment(X_train, y_train, X_test, y_test,
                                         experiment_type='table', kernel='linear',
                                         random_state=1, verbose=True)
# Out:
# PRELIMINARY
# Training accuracy of rank SVM: 0.78
#
# GENERATE W
# num (-1, -1): 19
# num (-1,  1): 6
# num ( 1, -1): 17
# num ( 1,  1): 8
# Training accuracy of rank SVM: 0.88
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.73		0.76
# 2	0.73		0.77
# 3	0.73		0.77
# 4	0.74		0.77
# 5	0.74		0.77
# 6	0.74		0.77
# 7	0.74		0.77
# 8	0.74		0.77
# 9	0.74		0.77
# 10	0.74		0.77
# 11	0.74		0.77
# 12	0.74		0.77
# 13	0.74		0.77
# 14	0.74		0.77
# 15	0.74		0.77
# 16	0.74		0.77
# 17	0.74		0.77
# 18	0.74		0.77
# 19	0.74		0.77
# 20	0.74		0.77
# t = 14 was best iteration with accuracy 0.77
#
# -----------------------------------------------
# 1 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.72		0.77
# 2	0.73		0.77
# 3	0.73		0.77
# 4	0.73		0.77
# 5	0.73		0.77
# 6	0.73		0.77
# 7	0.73		0.77
# 8	0.73		0.77
# 9	0.73		0.77
# 10	0.73		0.77
# 11	0.73		0.77
# 12	0.73		0.77
# 13	0.73		0.77
# 14	0.73		0.77
# 15	0.73		0.77
# 16	0.73		0.77
# 17	0.73		0.77
# 18	0.73		0.77
# 19	0.73		0.77
# 20	0.73		0.77
# t = 3 was best iteration with accuracy 0.77
#
# -----------------------------------------------
# 2 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.73		0.76
# 2	0.74		0.77
# 3	0.74		0.77
# 4	0.74		0.77
# 5	0.73		0.77
# 6	0.73		0.77
# 7	0.73		0.77
# 8	0.74		0.77
# 9	0.74		0.77
# 10	0.74		0.77
# 11	0.74		0.77
# 12	0.74		0.77
# 13	0.74		0.77
# 14	0.74		0.77
# 15	0.74		0.77
# 16	0.74		0.77
# 17	0.74		0.77
# 18	0.74		0.77
# 19	0.74		0.77
# 20	0.74		0.77
# t = 11 was best iteration with accuracy 0.77
#
# -----------------------------------------------
# 3 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.73		0.76
# 2	0.73		0.77
# 3	0.73		0.77
# 4	0.74		0.77
# 5	0.74		0.77
# 6	0.74		0.77
# 7	0.74		0.77
# 8	0.74		0.77
# 9	0.74		0.77
# 10	0.74		0.77
# 11	0.74		0.77
# 12	0.74		0.77
# 13	0.74		0.77
# 14	0.74		0.77
# 15	0.74		0.77
# 16	0.74		0.77
# 17	0.74		0.77
# 18	0.74		0.77
# 19	0.74		0.77
# 20	0.74		0.77
# t = 8 was best iteration with accuracy 0.77
#
# -----------------------------------------------
# 4 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0
# 18	0.73		0.77
# 19	0.73		0.77
# 20	0.73		0.77
# t = 6 was best iteration with accuracy 0.77
#
# -----------------------------------------------
# 20 / 40 complete
# -----------------------------------------------
#
# PRELIMINARY
# Training accuracy of rank SVM: 0.78
#
# GENERATE W
# num (-1, -1): 80
# num (-1,  1): 44
# num ( 1, -1): 51
# num ( 1,  1): 25
# Training accuracy of rank SVM: 0.97
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.79
# 2	0.75		0.79
# 3	0.76		0.79
# 4	0.75		0.79
# 5	0.75		0.79
# 6	0.75		0.79
# 7	0.75		0.79
# 8	0.75		0.79
# 9	0.76		0.79
# 10	0.75		0.79
# 11	0.75		0.79
# 12	0.75		0.79
# 13	0.75		0.79
# 14	0.75		0.79
# 15	0.75		0.79
# 16	0.75		0.79
# 17	0.75		0.79
# 18	0.75		0.79
# 19	0.75		0.79
# 20	0.75		0.79
# t = 3 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 21 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.78
# 2	0.75		0.79
# 3	0.75		0.79
# 4	0.75		0.79
# 5	0.75		0.79
# 6	0.75		0.79
# 7	0.75		0.79
# 8	0.75		0.79
# 9	0.76		0.79
# 10	0.76		0.79
# 11	0.75		0.79
# 12	0.75		0.79
# 13	0.75		0.79
# 14	0.75		0.79
# 15	0.75		0.79
# 16	0.75		0.79
# 17	0.75		0.79
# 18	0.75		0.79
# 19	0.75		0.79
# 20	0.75		0.79
# t = 9 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 22 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.76		0.79
# 2	0.76		0.79
# 3	0.75		0.79
# 4	0.75		0.79
# 5	0.76		0.79
# 6	0.75		0.79
# 7	0.75		0.79
# 8	0.76		0.79
# 9	0.75		0.79
# 10	0.75		0.79
# 11	0.75		0.79
# 12	0.75		0.79
# 13	0.75		0.79
# 14	0.75		0.79
# 15	0.75		0.79
# 16	0.75		0.79
# 17	0.75		0.79
# 18	0.75		0.79
# 19	0.75		0.79
# 20	0.75		0.79
# t = 2 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 23 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.78
# 2	0.75		0.79
# 3	0.75		0.79
# 4	0.75		0.79
# 5	0.75		0.79
# 6	0.75		0.79
# 7	0.75		0.79
# 8	0.75		0.79
# 9	0.75		0.79
# 10	0.75		0.79
# 11	0.75		0.79
# 12	0.75		0.79
# 13	0.75		0.79
# 14	0.75		0.79
# 15	0.75		0.79
# 16	0.75		0.79
# 17	0.75		0.79
# 18	0.75		0.79
# 19	0.75		0.79
# 20	0.75		0.79
# t = 2 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 24 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.78
# 2	0.75		0.79
# 3	0.75		0.79
# 4	0.75		0.79
# 5	0.75		0.79
# 6	0.75		0.79
# 7	0.75		0.79
# 8	0.75		0.79
# 9	0.75		0.79
# 10	0.75		0.79
# 11	0.75		0.79
# 12	0.75		0.79
# 13	0.75		0.79
# 14	0.75		0.79
# 15	0.75		0.79
# 16	0.75		0.79
# 17	0.75		0.79
# 18	0.75		0.79
# 19	0.75		0.79
# 20	0.75		0.79
# t = 2 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 25 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.76		0.79
# 2	0.76		0.79
# 3	0.76		0.79
# 4	0.76		0.79
# 5	0.76		0.79
# 6	0.75		0.79
# 7	0.76		0.79
# 8	0.75		0.79
# 9	0.75		0.79
# 10	0.75		0.79
# 11	0.75		0.79
# 12	0.75		0.79
# 13	0.75		0.79
# 14	0.75		0.79
# 15	0.75		0.79
# 16	0.75		0.79
# 17	0.75		0.79
# 18	0.75		0.79
# 19	0.75		0.79
# 20	0.75		0.79
# t = 1 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 26 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.76		0.79
# 2	0.76		0.79
# 3	0.76		0.79
# 4	0.76		0.79
# 5	0.76		0.79
# 6	0.76		0.79
# 7	0.75		0.79
# 8	0.75		0.79
# 9	0.75		0.79
# 10	0.75		0.79
# 11	0.75		0.79
# 12	0.75		0.79
# 13	0.75		0.79
# 14	0.75		0.79
# 15	0.75		0.79
# 16	0.75		0.79
# 17	0.75		0.79
# 18	0.75		0.79
# 19	0.75		0.79
# 20	0.75		0.79
# t = 3 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 27 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.78
# 2	0.75		0.79
# 3	0.75		0.79
# 4	0.75		0.79
# 5	0.75		0.79
# 6	0.75		0.79
# 7	0.75		0.79
# 8	0.75		0.79
# 9	0.75		0.79
# 10	0.75		0.79
# 11	0.75		0.79
# 12	0.75		0.79
# 13	0.75		0.79
# 14	0.75		0.79
# 15	0.75		0.79
# 16	0.75		0.79
# 17	0.75		0.79
# 18	0.75		0.79
# 19	0.75		0.79
# 20	0.75		0.79
# t = 5 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 28 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.79
# 2	0.75		0.79
# 3	0.75		0.79
# 4	0.75		0.79
# 5	0.75		0.79
# 6	0.75		0.79
# 7	0.75		0.79
# 8	0.75		0.79
# 9	0.75		0.79
# 10	0.75		0.79
# 11	0.75		0.79
# 12	0.75		0.79
# 13	0.75		0.79
# 14	0.75		0.79
# 15	0.75		0.79
# 16	0.75		0.79
# 17	0.75		0.79
# 18	0.75		0.79
# 19	0.75		0.79
# 20	0.75		0.79
# t = 3 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 29 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.76		0.79
# 2	0.76		0.79
# 3	0.76		0.80
# 4	0.76		0.80
# 5	0.76		0.80
# 6	0.76		0.79
# 7	0.76		0.79
# 8	0.76		0.79
# 9	0.76		0.79
# 10	0.76		0.79
# 11	0.76		0.79
# 12	0.76		0.79
# 13	0.76		0.79
# 14	0.75		0.79
# 15	0.75		0.79
# 16	0.76		0.79
# 17	0.76		0.79
# 18	0.75		0.79
# 19	0.76		0.79
# 20	0.76		0.79
# t = 3 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 30 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.76		0.79
# 2	0.75		0.79
# 3	0.75		0.79
# 4	0.75		0.79
# 5	0.75		0.79
# 6	0.75		0.79
# 7	0.75		0.79
# 8	0.75		0.79
# 9	0.75		0.79
# 10	0.75		0.79
# 11	0.75		0.79
# 12	0.75		0.79
# 13	0.75		0.79
# 14	0.75		0.79
# 15	0.75		0.79
# 16	0.75		0.79
# 17	0.75		0.79
# 18	0.75		0.79
# 19	0.75		0.79
# 20	0.75		0.79
# t = 1 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 31 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.78
# 2	0.76		0.79
# 3	0.76		0.79
# 4	0.75		0.79
# 5	0.75		0.79
# 6	0.75		0.79
# 7	0.75		0.79
# 8	0.75		0.79
# 9	0.75		0.79
# 10	0.75		0.79
# 11	0.75		0.79
# 12	0.75		0.79
# 13	0.75		0.79
# 14	0.75		0.79
# 15	0.75		0.79
# 16	0.75		0.79
# 17	0.75		0.79
# 18	0.75		0.79
# 19	0.75		0.79
# 20	0.75		0.79
# t = 2 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 32 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.76		0.79
# 2	0.76		0.79
# 3	0.76		0.79
# 4	0.76		0.79
# 5	0.76		0.79
# 6	0.76		0.79
# 7	0.76		0.79
# 8	0.76		0.79
# 9	0.75		0.79
# 10	0.75		0.79
# 11	0.76		0.79
# 12	0.76		0.79
# 13	0.75		0.79
# 14	0.75		0.79
# 15	0.75		0.79
# 16	0.75		0.79
# 17	0.75		0.79
# 18	0.75		0.79
# 19	0.75		0.79
# 20	0.75		0.79
# t = 2 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 33 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.76		0.80
# 2	0.76		0.79
# 3	0.76		0.79
# 4	0.76		0.79
# 5	0.76		0.79
# 6	0.75		0.79
# 7	0.75		0.79
# 8	0.75		0.79
# 9	0.75		0.79
# 10	0.75		0.79
# 11	0.75		0.79
# 12	0.75		0.79
# 13	0.75		0.79
# 14	0.75		0.79
# 15	0.75		0.79
# 16	0.75		0.79
# 17	0.75		0.79
# 18	0.75		0.79
# 19	0.75		0.79
# 20	0.75		0.79
# t = 2 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 34 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.79
# 2	0.75		0.79
# 3	0.75		0.79
# 4	0.75		0.79
# 5	0.75		0.79
# 6	0.75		0.79
# 7	0.75		0.79
# 8	0.75		0.79
# 9	0.75		0.79
# 10	0.75		0.79
# 11	0.75		0.79
# 12	0.75		0.79
# 13	0.75		0.79
# 14	0.75		0.79
# 15	0.75		0.79
# 16	0.75		0.79
# 17	0.75		0.79
# 18	0.75		0.79
# 19	0.75		0.79
# 20	0.75		0.79
# t = 2 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 35 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.78
# 2	0.76		0.79
# 3	0.76		0.79
# 4	0.76		0.79
# 5	0.76		0.79
# 6	0.76		0.79
# 7	0.76		0.79
# 8	0.76		0.79
# 9	0.75		0.79
# 10	0.75		0.79
# 11	0.75		0.79
# 12	0.75		0.79
# 13	0.75		0.79
# 14	0.75		0.79
# 15	0.75		0.79
# 16	0.75		0.79
# 17	0.75		0.79
# 18	0.75		0.79
# 19	0.75		0.79
# 20	0.75		0.79
# t = 2 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 36 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.76		0.79
# 2	0.76		0.79
# 3	0.76		0.79
# 4	0.76		0.79
# 5	0.76		0.79
# 6	0.76		0.79
# 7	0.75		0.79
# 8	0.75		0.79
# 9	0.75		0.79
# 10	0.75		0.79
# 11	0.75		0.79
# 12	0.75		0.79
# 13	0.75		0.79
# 14	0.75		0.79
# 15	0.75		0.79
# 16	0.75		0.79
# 17	0.75		0.79
# 18	0.75		0.79
# 19	0.75		0.79
# 20	0.75		0.79
# t = 1 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 37 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.79
# 2	0.76		0.79
# 3	0.76		0.79
# 4	0.75		0.79
# 5	0.76		0.79
# 6	0.75		0.79
# 7	0.75		0.79
# 8	0.75		0.79
# 9	0.75		0.79
# 10	0.75		0.79
# 11	0.75		0.79
# 12	0.75		0.79
# 13	0.75		0.79
# 14	0.75		0.79
# 15	0.75		0.79
# 16	0.75		0.79
# 17	0.75		0.79
# 18	0.75		0.79
# 19	0.75		0.79
# 20	0.75		0.79
# t = 2 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 38 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.78
# 2	0.76		0.80
# 3	0.76		0.79
# 4	0.76		0.79
# 5	0.76		0.79
# 6	0.75		0.79
# 7	0.76		0.79
# 8	0.75		0.79
# 9	0.75		0.79
# 10	0.75		0.79
# 11	0.76		0.79
# 12	0.76		0.79
# 13	0.75		0.79
# 14	0.75		0.79
# 15	0.76		0.79
# 16	0.76		0.79
# 17	0.76		0.79
# 18	0.76		0.79
# 19	0.75		0.79
# 20	0.75		0.79
# t = 2 was best iteration with accuracy 0.80
#
# -----------------------------------------------
# 39 / 40 complete
# -----------------------------------------------
#
# LINEAR SVM SUBMODELS
# Using 20 classifiers and sample proportion of 1
# t	Train		Test
# 1	0.75		0.78
# 2	0.76		0.79
# 3	0.76		0.79
# 4	0.76		0.79
# 5	0.76		0.79
# 6	0.75		0.79
# 7	0.75		0.79
# 8	0.75		0.79
# 9	0.75		0.79
# 10	0.75		0.79
# 11	0.75		0.79
# 12	0.75		0.79
# 13	0.75		0.79
# 14	0.75		0.79
# 15	0.75		0.79
# 16	0.75		0.79
# 17	0.75		0.79
# 18	0.75		0.79
# 19	0.75		0.79
# 20	0.75		0.79
# t = 3 was best iteration with accuracy 0.79
#
# -----------------------------------------------
# 40 / 40 complete
# -----------------------------------------------

# %%
table_results(svm_arr, tree_arr)
# Out:
# (Performance on test set)
#
# 50 comparisons
# 	acc	sderr
# SVM: 	77.1	0.0
# Tree: 	nan	nan
#
# 200 comparisons
# 	acc	sderr
# SVM: 	79.2	0.1
# Tree: 	nan	nan
